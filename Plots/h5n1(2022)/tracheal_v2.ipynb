# %%
# Standard scientific libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.optimize import minimize

# Set plotting style for better visualization
plt.style.use("seaborn-v0_8")

# %%
vl_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/tracheal_data/h5n1(2022)/tracheal_h5n1_2022_vl.txt"
t1_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/tracheal_data/h5n1(2022)/tracheal_h5n1_2022_t1.txt"

# Load the viral load data
vl_data = pd.read_csv(vl_path)
print("Viral Load Data:")
print(vl_data, "\n")

# Load the interferon data
t1_data = pd.read_csv(t1_path)
print("Interferon Data:")
print(t1_data)

# Let's also create a simple plot to visualize our data
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot viral load data
ax1.plot(vl_data['time'], vl_data['value'], 'o-', color='blue', label='Viral Load')
ax1.set_xlabel('Time (hours)')
ax1.set_ylabel('Viral Load (log scale)')
ax1.set_title('H5N1 Tracheal Viral Load')
ax1.legend()

# Plot interferon data
ax2.plot(t1_data['time'], t1_data['value'], 'o-', color='red', label='IFN-A2')
ax2.set_xlabel('Time (hours)')
ax2.set_ylabel('IFN-A2 Level')
ax2.set_title('H5N1 Tracheal Interferon')
ax2.legend()

plt.tight_layout()
plt.savefig('tracheal_h5n1_2022.png')
plt.show()
# Out:
# Viral Load Data:
#    time  value
# 0     0  2.584
# 1     8  3.232
# 2    24  5.976
# 3    48  7.907
# 4    72  7.869
#
# Interferon Data:
#    time   value
# 0     0   2.138
# 1     8   5.896
# 2    24  14.384
# 3    48  17.235
# 4    72  25.853

# %%
def Model(y, t, beta, gamma, rho, delta, p, c, alpha):
    """
    Extended model with resistant cell class
    
    Parameters:
    y: list of variables [T, R, I, V, F]
    t: time points
    beta: infection rate
    gamma: rate of conversion to resistant state
    rho: rate of return from resistant state
    delta: death rate of infected cells
    p: virus production rate
    c: virus clearance rate
    alpha: interferon clearance rate
    """
    T, R, I, V, F = y
    
    # System of ODEs
    dTdt = -beta * T * V - gamma * T * F    # Target cells
    dRdt = gamma * T * F - rho * R          # Resistant cells
    dIdt = beta * T * V - delta * I         # Infected cells
    dVdt = p * I - c * V                    # Virus
    dFdt = I - alpha * F                    # Interferon
    
    return [dTdt, dRdt, dIdt, dVdt, dFdt]

# Initial conditions
T0 = 1.0     # Initial target cells (normalized)
R0 = 0.0     # Initial resistant cells
I0 = 0.0     # Initial infected cells
V0 = vl_data['value'].iloc[0]    # Initial virus from data
F0 = t1_data['value'].iloc[0]    # Initial interferon from data
y0 = [T0, R0, I0, V0, F0]

print("Initial conditions:")
for var, val in zip(['T0', 'R0', 'I0', 'V0', 'F0'], y0):
    print(f"{var} = {val}")
# Out:
# Initial conditions:
# T0 = 1.0
# R0 = 0.0
# I0 = 0.0
# V0 = 2.584
# F0 = 2.138

# %%
# Create two sets of time points:
# 1. Data time points for comparison
data_times = np.array([0, 8, 24, 48, 72])

# 2. Integration time points (finer mesh for solving ODEs)
t = np.linspace(0, 72, 100)

def optimize(params):
    """
    Objective function to minimize.
    Uses relative error at actual data time points.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        # Find indices in t that correspond to data_times
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        global V_model, F_model
        V_model = V[indices]
        F_model = F[indices]
        
        # Calculate relative SSR
        vl_ssr = np.sum((((np.maximum(V_model, 0)) - vl_data['value'])/vl_data['value'])**2)
        ifn_ssr = np.sum(((F_model - t1_data['value'])/t1_data['value'])**2)
        
        total_ssr = vl_ssr + ifn_ssr
        
        print(f"Parameters: {params} | SSR: {total_ssr}")
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

print("Data time points:", data_times)
print("\nNumber of integration points:", len(t))
print("Integration time range:", t[0], "to", t[-1])
# Out:
# Data time points: [ 0  8 24 48 72]
#
# Number of integration points: 100
# Integration time range: 0.0 to 72.0

# %%
guess = [0.1, 0.1, 0.1, 0.1, 10.0, 0.1, 0.1]

# %%
bounds = [
    (1e-6, 10.0),   # beta
    (1e-6, 10.0),   # gamma
    (1e-6, 10.0),   # rho 
    (1e-6, 10.0),   # delta
    (1e-1, 1e7), #p
    (1e-6, 10.0),   # c
    (1e-6, 100.0)    # alpha
]

print("Initial parameter guesses:")
for param, value in zip(['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha'], guess):
    print(f"{param}: {value}")
# Out:
# Initial parameter guesses:
# beta: 0.1
# gamma: 0.1
# rho: 0.1
# delta: 0.1
# p: 10.0
# c: 0.1
# alpha: 0.1

# %%
# Perform optimization
result = minimize(optimize, guess, method ='Nelder-Mead', bounds=bounds)

# Extract optimized parameters
beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit = result.x

# Generate solution with optimized parameters
solution_fit = odeint(Model, y0, t, args=(beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit))
T_fit, R_fit, I_fit, V_fit, F_fit = solution_fit.T

# Print optimization results
print("Optimization successful:", result.success)
print("Number of iterations:", result.nit)
print("\nOptimized parameters:")
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
for name, value in zip(param_names, result.x):
    print(f"{name}: {value:.6f}")

print("guess = ", [i for i in result.x])
# Out:
# Parameters: [ 0.1  0.1  0.1  0.1 10.   0.1  0.1] | SSR: 46.401368088742444
# Parameters: [ 0.105  0.1    0.1    0.1   10.     0.1    0.1  ] | SSR: 48.10786008085946
# Parameters: [ 0.1    0.105  0.1    0.1   10.     0.1    0.1  ] | SSR: 44.76004775251795
# Parameters: [ 0.1    0.1    0.105  0.1   10.     0.1    0.1  ] | SSR: 46.401368088742444
# Parameters: [ 0.1    0.1    0.1    0.105 10.     0.1    0.1  ] | SSR: 44.620383860950234
# Parameters: [ 0.1  0.1  0.1  0.1 10.5  0.1  0.1] | SSR: 51.98361361341298
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.105  0.1  ] | SSR: 44.31430914793026
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.1    0.105] | SSR: 46.607951019799685
# Parameters: [0.10142857 0.10142857 0.10142857 0.10142857 9.5        0.10142857
#  0.10142857] | SSR: 40.288747196628314
# Parameters: [0.10214286 0.10214286 0.10214286 0.10214286 9.         0.10214286
#  0.10214286] | SSR: 35.209666299917586
# Parameters: [0.09561224 0.10204082 0.10204082 0.10204082 9.71428571 0.10204082
#  0.10204082] | SSR: 39.95121385929935
# Parameters: [0.0993586  0.10262391 0.10262391 0.10262391 9.63265306 0.10262391
#  0.09619534] | SSR: 39.59191593879542
# Parameters: [0.09917534 0.10337359 0.09694502 0.10337359 9.52769679 0.10337359
#  0.10010829] | SSR: 38.00904328102331
# Parameters: [0.09893973 0.10433748 0.10107217 0.10433748 9.39275302 0.10433748
#  0.10013923] | SSR: 35.89213701489854
# Parameters: [0.09863679 0.09914819 0.10137851 0.10557676 9.21925388 0.10557676
#  0.10017901] | SSR: 34.916331274308895
# Parameters: [0.09795519 0.09622228 0.10206776 0.10836514 8.82888082 0.10836514
#  0.10026851] | SSR: 30.784990467825303
# Parameters: [0.09805256 0.10306884 0.1019693  0.10153823 8.8846484  0.1079668
#  0.10025572] | SSR: 31.331772484021727
# Parameters: [0.09749615 0.10394565 0.10253195 0.10697772 8.56597652 0.10381445
#  0.10032879] | SSR: 28.47508029736623
# Parameters: [0.09624422 0.10591847 0.10379793 0.11046658 7.84896478 0.10322168
#  0.10049318] | SSR: 22.522170153597273
# Parameters: [0.10206447 0.10301273 0.10099317 0.10734426 8.31874197 0.10711103
#  0.09784579] | SSR: 26.921712416175954
# Parameters: [0.09909122 0.10254074 0.09994415 0.10810985 8.02497145 0.10780997
#  0.10416283] | SSR: 24.28916616312598
# Parameters: [0.09925044 0.10155309 0.10647993 0.10871337 7.70057762 0.10832782
#  0.10140832] | SSR: 22.1541615909737
# Parameters: [0.09928799 0.10064284 0.11124738 0.11138326 6.78701803 0.11080493
#  0.10205833] | SSR: 16.586469479643448
# Parameters: [0.09958556 0.0995336  0.10525998 0.10976257 7.09102568 0.10921178
#  0.1019257 ] | SSR: 18.692161764292607
# Parameters: [0.09565178 0.10098271 0.10507991 0.11413425 6.93835747 0.11342609
#  0.09986002] | SSR: 16.203214669916328
# Parameters: [0.09240624 0.10040264 0.10654843 0.12012995 5.9075362  0.11906771
#  0.0987186 ] | SSR: 11.078646952331585
# Parameters: [0.09812884 0.09929496 0.10656179 0.1200508  6.20310557 0.11077384
#  0.10130797] | SSR: 13.360859861717339
# Parameters: [0.09827582 0.10701943 0.10774734 0.11656266 5.50865165 0.1110637
#  0.10159218] | SSR: 10.617015620988123
# Parameters: [0.09843614 0.11241801 0.11058712 0.12066141 3.84853707 0.11241299
#  0.10225401] | SSR: 6.755969266423522
# Parameters: [0.09312987 0.1029162  0.11156306 0.12138843 4.74158911 0.11383266
#  0.10527439] | SSR: 8.291624930481053
# Parameters: [0.09439988 0.10349547 0.11593176 0.12441673 4.09725039 0.11485448
#  0.09927494] | SSR: 7.052638815095525
# Parameters: [0.09671992 0.09942544 0.11554479 0.12604575 3.20133867 0.12276643
#  0.10259652] | SSR: 6.064352496746053
# Parameters: [0.09695778 0.09617893 0.12141823 0.13383534 0.87752561 0.13253881
#  0.10364818] | SSR: 6.115472697419053
# Parameters: [0.09255983 0.10577942 0.11702126 0.1314021  2.84793862 0.12064909
#  0.10135567] | SSR: 5.816204744298078
# Parameters: [0.08904697 0.10890233 0.12290189 0.14222186 0.72639509 0.12636774
#  0.10107065] | SSR: 6.273357894002961
# Parameters: [0.09093507 0.10613777 0.11268354 0.13550107 2.02649501 0.12186855
#  0.10102226] | SSR: 5.719358395745427
# Parameters: [0.08675862 0.10888524 0.11340161 0.14755998 0.1        0.12740036
#  0.10050423] | SSR: 6.6895997319040585
# Parameters: [0.09003887 0.10944074 0.1191182  0.13124789 1.41709016 0.12506956
#  0.10169099] | SSR: 5.8756111391538735
# Parameters: [0.09508508 0.11091537 0.12272292 0.13434531 0.42967495 0.11849051
#  0.10512962] | SSR: 6.374728590767737
# Parameters: [0.09492007 0.11068729 0.12089682 0.13678879 0.36364656 0.12505637
#  0.09853247] | SSR: 6.439529588158492
# Parameters: [0.09379868 0.11216283 0.11794671 0.13729537 0.1        0.12694938
#  0.10431979] | SSR: 6.667120023196297
# Parameters: [0.08843744 0.10316738 0.12539409 0.14580324 0.1        0.13354413
#  0.10193094] | SSR: 6.708634448061247
# Parameters: [0.09093712 0.10548004 0.12169235 0.13951778 0.30134232 0.12826134
#  0.1020117 ] | SSR: 6.5270173042635715
# Parameters: [0.09225731 0.10151319 0.11910468 0.12980426 2.92500751 0.11938258
#  0.09920571] | SSR: 5.842658731926524
# Parameters: [0.09549607 0.1070626  0.11461971 0.12480655 3.47328382 0.11553383
#  0.10071208] | SSR: 6.268290173021175
# Parameters: [0.09167769 0.10081971 0.11362178 0.12411205 4.29944736 0.11601807
#  0.10481406] | SSR: 7.356022887166337
# Parameters: [0.09410947 0.1082204  0.11907806 0.1336196  1.34759676 0.1227968
#  0.10010287] | SSR: 5.870130131207242
# Parameters: [0.09123394 0.09982165 0.11075429 0.12634819 4.49568235 0.12381431
#  0.09678069] | SSR: 7.40319993535482
# Parameters: [0.09412229 0.10814194 0.11973076 0.13234603 1.4461768  0.11982146
#  0.10304239] | SSR: 5.819471208311716
# Parameters: [0.09043044 0.1039828  0.1203178  0.13804108 0.87290004 0.12799602
#  0.10186404] | SSR: 6.163396295372367
# Parameters: [0.09169684 0.10475275 0.11889328 0.13473245 1.52299599 0.12488047
#  0.10157605] | SSR: 5.831699735207334
# Parameters: [0.08777142 0.11314204 0.12034943 0.13928379 0.66531872 0.12136743
#  0.09968804] | SSR: 6.2782850175787255
# Parameters: [0.0944828  0.10285459 0.11674595 0.12935526 2.56733368 0.12241668
#  0.1018694 ] | SSR: 5.727799921333926
# Parameters: [0.09572217 0.101245   0.11609824 0.1335409  2.77820823 0.11830633
#  0.10064453] | SSR: 5.818725815483583
# Parameters: [0.09211233 0.10047236 0.115287   0.1311467  3.25644776 0.11929611
#  0.10238742] | SSR: 6.067741387431619
# Parameters: [0.09361019 0.10628339 0.1181303  0.13300138 1.82480951 0.12192163
#  0.100674  ] | SSR: 5.723004203011344
# Parameters: [0.09435104 0.10854248 0.11498198 0.13587551 1.36469473 0.12343576
#  0.10370409] | SSR: 5.895986576672122
# Parameters: [0.09278074 0.10327051 0.11807401 0.13132207 2.53492932 0.12039588
#  0.1003303 ] | SSR: 5.714808134238208
# Parameters: [0.09522118 0.10487943 0.11495931 0.12997293 3.05583006 0.11665656
#  0.10097782] | SSR: 5.947259963292106
# Parameters: [0.09257793 0.10478442 0.11790979 0.13354257 1.90620451 0.12282449
#  0.10142649] | SSR: 5.719723812306178
# Parameters: [0.09235449 0.10053095 0.11360154 0.13270122 3.26408573 0.12257359
#  0.0990498 ] | SSR: 6.0395857399045685
# Parameters: [0.09368034 0.10623919 0.11819846 0.13243482 1.90065404 0.12050949
#  0.10204424] | SSR: 5.706473365314347
# Parameters: [0.09017123 0.1088548  0.11783413 0.13119032 1.68132453 0.12471818
#  0.10184757] | SSR: 5.78603563477389
# Parameters: [0.09265111 0.10519906 0.11714336 0.13326862 1.27827584 0.12353803
#  0.10127698] | SSR: 5.90130292413472
# Parameters: [0.09258265 0.10563433 0.11705178 0.13186873 2.45552292 0.12137132
#  0.10133599] | SSR: 5.709978063817047
# Parameters: [0.09572869 0.10120354 0.11610696 0.13367422 2.66608946 0.11851269
#  0.10063891] | SSR: 5.774517893547163
# Parameters: [0.09433932 0.10311636 0.11653875 0.13305325 2.41989823 0.12006406
#  0.10094108] | SSR: 5.7054790122514785
# Parameters: [0.09137613 0.10727854 0.11713594 0.13656585 1.7379559  0.12014201
#  0.10035185] | SSR: 5.7613219695089475
# Parameters: [0.09370613 0.10396058 0.11684345 0.13115791 2.35998924 0.12184801
#  0.10149001] | SSR: 5.693795824157668
# Parameters: [0.09227615 0.10318609 0.11538392 0.13239303 2.63338856 0.12061604
#  0.10178039] | SSR: 5.750627546248435
# Parameters: [0.09327668 0.10550906 0.1174437  0.13284929 2.02695428 0.12159523
#  0.1009506 ] | SSR: 5.695493409892327
# Parameters: [0.09350805 0.1048921  0.11547127 0.13165376 2.5864935  0.11936195
#  0.10089193] | SSR: 5.73293412334948
# Parameters: [0.09281046 0.10481134 0.11730016 0.13307037 2.07627676 0.12195886
#  0.10129285] | SSR: 5.6959764756092275
# Parameters: [0.09568673 0.10315976 0.12201655 0.12900077 2.48042635 0.12034369
#  0.10137347] | SSR: 5.702855687691423
# Parameters: [0.09467135 0.10599538 0.11775252 0.13251654 1.95641977 0.12180145
#  0.10236348] | SSR: 5.705182771998865
# Parameters: [0.09546621 0.10373472 0.11897496 0.13215497 1.89322526 0.1209489
#  0.10165136] | SSR: 5.693994548507515
# Parameters: [0.09487877 0.1024143  0.11805014 0.13150891 2.44597165 0.12193628
#  0.10083086] | SSR: 5.705861634000118
# Parameters: [0.09457916 0.10337052 0.11808722 0.13174039 2.30964224 0.12157959
#  0.10113421] | SSR: 5.688465856039517
# Parameters: [0.09428831 0.10560975 0.12015226 0.13051539 1.89522574 0.12281472
#  0.1019892 ] | SSR: 5.703081513430703
# Parameters: [0.09384684 0.10262054 0.11962414 0.13048034 2.34122019 0.12136683
#  0.10045986] | SSR: 5.679929361412534
# Parameters: [0.09343459 0.10093313 0.12055994 0.12946225 2.5336204  0.12114952
#  0.09950805] | SSR: 5.703309063245673
# Parameters: [0.09410375 0.10215212 0.1170735  0.13247148 2.52984121 0.11993988
#  0.10039718] | SSR: 5.721782212114505
# Parameters: [0.09424217 0.10474534 0.11938257 0.13100441 2.05387961 0.12209601
#  0.1015912 ] | SSR: 5.684176030293184
# Parameters: [0.0922926  0.10505512 0.11445665 0.13455857 1.8227701  0.12291158
#  0.10107512] | SSR: 5.739886624139453
# Parameters: [0.0948382  0.1036336  0.12012658 0.13039022 2.31601229 0.12098566
#  0.10129889] | SSR: 5.681505443885847
# Parameters: [0.09574823 0.10306705 0.11998059 0.12972321 2.29541556 0.12101835
#  0.10115747] | SSR: 5.6745558911171035
# Parameters: [0.09721711 0.10219491 0.12132081 0.12804964 2.40498496 0.1205481
#  0.10108978] | SSR: 5.682808958637794
# Parameters: [0.09598816 0.10167161 0.12056187 0.12905112 2.42144127 0.12121716
#  0.10155882] | SSR: 5.6922514839636005
# Parameters: [0.09394776 0.1028565  0.11948402 0.12885863 2.70608913 0.12194013
#  0.10083163] | SSR: 5.760485513360818
# Parameters: [0.0950866  0.10351516 0.11910222 0.13133088 2.09644123 0.12119671
#  0.10144643] | SSR: 5.676313328227726
# Parameters: [0.09610226 0.10250337 0.12226089 0.12990512 2.16402573 0.12085493
#  0.10098052] | SSR: 5.662664784610829
# Parameters: [0.09730032 0.10177477 0.12496961 0.12927872 2.06604398 0.12035839
#  0.10072578] | SSR: 5.651087188086191
# Parameters: [0.09419513 0.10482182 0.11980183 0.13207693 2.00103162 0.12124042
#  0.1006737 ] | SSR: 5.686179058919306
# Parameters: [0.09549441 0.10353756 0.12276636 0.12948381 2.02465618 0.12078109
#  0.10096674] | SSR: 5.662601318591733
# Parameters: [0.09624966 0.10171934 0.12189877 0.12840639 2.34001668 0.12098902
#  0.10151098] | SSR: 5.673781180207263
# Parameters: [0.09677619 0.10093124 0.12303693 0.12873661 2.36892214 0.11981715
#  0.10057056] | SSR: 5.673532497656192
# Parameters: [0.09673387 0.10127087 0.12312446 0.12887835 2.12190656 0.12059364
#  0.10065477] | SSR: 5.649572396952307
# Parameters: [0.09768171 0.10008951 0.1246234  0.12812241 2.02485369 0.12039763
#  0.10033272] | SSR: 5.637947344246857
# Parameters: [0.0988209  0.10156078 0.12505526 0.12811453 2.00630823 0.11993555
#  0.10145747] | SSR: 5.643919145960375
# Parameters: [0.09864809 0.10010777 0.12727804 0.12634503 2.2253349  0.11974534
#  0.10047406] | SSR: 5.637426966510057
# Parameters: [0.10042884 0.09840407 0.13136595 0.1238521  2.28978173 0.11901966
#  0.09998788] | SSR: 5.630002939110702
# Parameters: [0.09932378 0.0992236  0.12965263 0.12627523 2.0247509  0.11935265
#  0.10042886] | SSR: 5.619099826335881
# Parameters: [0.10111156 0.09730187 0.13448865 0.12455124 1.88941857 0.11851979
#  0.10006455] | SSR: 5.597638989234014
# Parameters: [0.10021146 0.09930918 0.13133157 0.12649059 1.85140747 0.11867648
#  0.09966208] | SSR: 5.618853755385602
# Parameters: [0.10066644 0.09963383 0.1325633  0.12551865 1.67464068 0.11952245
#  0.10034294] | SSR: 5.644059803073876
# Parameters: [0.10342594 0.09591215 0.13563299 0.12363854 1.91890221 0.11819889
#  0.09976852] | SSR: 5.581858305824078
# Parameters: [0.10739171 0.09209944 0.14206631 0.1207159  1.86602522 0.11690779
#  0.09916941] | SSR: 5.540731533836557
# Parameters: [0.10450328 0.09491057 0.13831451 0.12139712 1.82036619 0.11763571
#  0.09956481] | SSR: 5.561413283571012
# Parameters: [0.1022334  0.09570201 0.13236403 0.12397961 2.25340535 0.11793258
#  0.09972533] | SSR: 5.620286698954116
# Parameters: [0.10505394 0.09210112 0.14196029 0.12020232 1.99233698 0.1169472
#  0.09811589] | SSR: 5.540310866282287
# Parameters: [0.10817046 0.08737128 0.1504128  0.11624622 1.98535136 0.11545303
#  0.0964451 ] | SSR: 5.491685984607486
# Parameters: [0.10918992 0.08993861 0.14976055 0.11680124 1.96250514 0.11507239
#  0.0981299 ] | SSR: 5.50484312333512
# Parameters: [0.10894596 0.08920535 0.1482736  0.11905702 1.6040695  0.11532257
#  0.09794388] | SSR: 5.519550712861748
# Parameters: [0.10905927 0.09005122 0.15182111 0.11752306 1.45492135 0.11566392
#  0.09769745] | SSR: 5.5404518642551634
# Parameters: [0.11360916 0.08379892 0.15870773 0.11244993 1.74363748 0.11405929
#  0.09719938] | SSR: 5.429342074585287
# Parameters: [0.12030801 0.07604379 0.17239581 0.10542959 1.68975248 0.11175069
#  0.09596803] | SSR: 5.330743423904064
# Parameters: [0.11819376 0.07973249 0.16638126 0.10892594 1.64857892 0.11228195
#  0.09562647] | SSR: 5.367387539323145
# Parameters: [0.11871361 0.0777872  0.17057447 0.10851688 1.66854923 0.11163639
#  0.09500098] | SSR: 5.3534447122548166
# Parameters: [0.11906    0.07650911 0.17496786 0.10571266 1.56646849 0.11085819
#  0.09420539] | SSR: 5.313007454283919
# Parameters: [0.12489415 0.06871394 0.19141864 0.09821103 1.41669012 0.10783339
#  0.09172338] | SSR: 5.181481196987379
# Parameters: [0.1219167  0.07246097 0.17652664 0.10338778 1.96664915 0.10986476
#  0.09397047] | SSR: 5.384876084386999
# Parameters: [0.12573593 0.06852273 0.18814645 0.09737689 1.92109519 0.10864675
#  0.09258879] | SSR: 5.316696553983814
# Parameters: [0.1302194  0.06167065 0.1976269  0.09408286 1.55082813 0.10706103
#  0.09081959] | SSR: 5.117249355563095
# Parameters: [0.14073413 0.04753667 0.22156007 0.08272367 1.34498963 0.10305534
#  0.08716444] | SSR: 4.855939905486148
# Parameters: [0.14054276 0.05285666 0.21730244 0.08506    1.34502142 0.10313819
#  0.08985277] | SSR: 4.92583549472441
# Parameters: [0.13211826 0.06216574 0.20283882 0.09268194 1.1861157  0.10680458
#  0.09115092] | SSR: 5.108175067854162
# Parameters: [0.13981962 0.04987515 0.22340065 0.08250263 1.37205358 0.10282243
#  0.08821618] | SSR: 4.871963611320233
# Parameters: [0.14533007 0.04384557 0.23430064 0.07547905 1.26737023 0.10094972
#  0.08690317] | SSR: 4.705445087366055
# Parameters: [0.1586383  0.02687475 0.26616373 0.05896013 1.06678073 0.09560638
#  0.08285426] | SSR: 4.194070477148314
# Parameters: [0.15468718 0.03154068 0.25927013 0.06528934 1.06817505 0.09622276
#  0.08218933] | SSR: 4.36660919651708
# Parameters: [0.15753105 0.02849544 0.26384055 0.06417418 0.59314088 0.09577698
#  0.0825973 ] | SSR: 4.60609380731505
# Parameters: [0.16769765 0.01681323 0.28126033 0.05361522 0.86224616 0.09314566
#  0.08085525] | SSR: 3.9641353758320106
# Parameters: [1.89099397e-01 1.00000000e-06 3.26181180e-01 3.13173157e-02
#  5.85024186e-01 8.58017964e-02 7.54211790e-02] | SSR: 2.9248603815685503
# Parameters: [0.17675386 0.00560007 0.30508082 0.04161157 0.92108015 0.08817367
#  0.0769335 ] | SSR: 3.3682590723839914
# Parameters: [0.17867539 0.00140728 0.31569675 0.03681967 0.64104836 0.08756449
#  0.07454043] | SSR: 3.170644039847779
# Parameters: [1.90500177e-01 1.00000000e-06 3.35968838e-01 2.63247654e-02
#  4.05157556e-01 8.35208367e-02 7.22696556e-02] | SSR: 2.912717984906166
# Parameters: [2.15840453e-01 1.00000000e-06 3.92252930e-01 1.00000000e-06
#  1.00000000e-01 7.38700410e-02 6.42963912e-02] | SSR: 2.29708817525929
# Parameters: [2.11044620e-01 1.00000000e-06 3.86578810e-01 2.46867833e-03
#  1.00000000e-01 7.49492615e-02 6.67876692e-02] | SSR: 2.5188613938855373
# Parameters: [2.09537298e-01 1.00000000e-06 3.79366407e-01 3.38801905e-03
#  6.87461542e-01 7.62768438e-02 6.68377781e-02] | SSR: 0.6657599606317919
# Parameters: [2.35540425e-01 1.00000000e-06 4.37129336e-01 1.00000000e-06
#  7.34621873e-01 6.65267734e-02 5.89580188e-02] | SSR: 1.1309465175637097
# Parameters: [2.28052630e-01 1.00000000e-06 4.18250042e-01 1.00000000e-06
#  1.03652080e-01 7.01322405e-02 6.28595872e-02] | SSR: 2.180886279507437
# Parameters: [2.43934173e-01 1.00000000e-06 4.54809682e-01 1.00000000e-06
#  1.00000000e-01 6.34702858e-02 5.64818897e-02] | SSR: 2.0301002435314226
# Parameters: [2.45012983e-01 1.00000000e-06 4.58672266e-01 1.00000000e-06
#  1.00000000e-01 6.38448850e-02 5.65593327e-02] | SSR: 2.0378767391236345
# Parameters: [2.62045053e-01 1.00000000e-06 4.88906488e-01 1.00000000e-06
#  1.00000000e-01 5.76770429e-02 5.38149517e-02] | SSR: 1.894519415039325
# Parameters: [2.72462663e-01 1.00000000e-06 5.24914998e-01 1.00000000e-06
#  1.00000000e-01 5.14040895e-02 4.67609924e-02] | SSR: 1.7309399002525179
# Parameters: [2.68065452e-01 1.00000000e-06 5.04041994e-01 1.00000000e-06
#  2.68889606e-01 5.55294323e-02 4.96725945e-02] | SSR: 0.5155363842952142
# Parameters: [2.96575868e-01 1.00000000e-06 5.62773586e-01 1.00000000e-06
#  3.53334409e-01 4.58195177e-02 4.11150571e-02] | SSR: 0.17830019328247068
# Parameters: [2.86336881e-01 1.00000000e-06 5.47088061e-01 9.68719728e-04
#  3.41270866e-01 4.85942176e-02 4.55406342e-02] | SSR: 0.20272624649458046
# Parameters: [2.90777347e-01 1.00000000e-06 5.57901811e-01 1.24521108e-03
#  4.05509868e-01 4.61782973e-02 4.20291659e-02] | SSR: 0.1980487459419999
# Parameters: [2.86892527e-01 1.00000000e-06 5.45830887e-01 1.60069996e-03
#  4.96450482e-01 4.74180564e-02 4.41779442e-02] | SSR: 0.42604966520924414
# Parameters: [3.00245152e-01 1.00000000e-06 5.75699529e-01 2.05775709e-03
#  6.09722048e-01 4.32063042e-02 4.07399742e-02] | SSR: 1.472511192279516
# Parameters: [2.93048586e-01 1.00000000e-06 5.66400735e-01 2.64540197e-03
#  7.55356919e-01 4.48650504e-02 3.96712044e-02] | SSR: 2.9682941324807937
# Parameters: [2.69795936e-01 1.00000000e-06 5.08280050e-01 6.62100493e-04
#  2.63839230e-01 5.44740448e-02 5.02790149e-02] | SSR: 0.5619085039248801
# Parameters: [2.81869054e-01 1.00000000e-06 5.25639382e-01 2.83428783e-03
#  8.02168127e-01 5.20151339e-02 4.77303130e-02] | SSR: 2.5564046564808125
# Parameters: [2.74814261e-01 1.00000000e-06 5.25096094e-01 7.09321957e-04
#  2.75542032e-01 5.15568506e-02 4.70033225e-02] | SSR: 0.4373942212684786
# Parameters: [2.46820596e-01 1.00000000e-06 4.60396727e-01 3.92263557e-04
#  1.96966075e-01 6.25987895e-02 5.55408592e-02] | SSR: 1.181244899807074
# Parameters: [2.60176735e-01 1.00000000e-06 4.89222427e-01 8.08636941e-04
#  3.00155068e-01 5.77506682e-02 5.18406380e-02] | SSR: 0.4787949454089143
# Parameters: [3.51996860e-01 1.00000000e-06 6.88117284e-01 1.00000000e-06
#  1.00000000e-01 2.42350570e-02 2.51581581e-02] | SSR: 1.502465212126078
# Parameters: [2.45152189e-01 1.00000000e-06 4.56554126e-01 2.12227311e-03
#  5.17738054e-01 6.32663971e-02 5.64178731e-02] | SSR: 0.3234576039056811
# Parameters: [2.84697151e-01 1.00000000e-06 5.44424805e-01 1.46814601e-03
#  5.04732421e-01 4.85499566e-02 4.34708809e-02] | SSR: 0.43347134827243894
# Parameters: [3.01322186e-01 1.00000000e-06 5.79254536e-01 1.51004073e-03
#  5.26867255e-01 4.26445584e-02 3.95178986e-02] | SSR: 0.8470186757718969
# Parameters: [2.70463098e-01 1.00000000e-06 5.11730454e-01 9.83987888e-04
#  3.56833115e-01 5.39741408e-02 4.87599531e-02] | SSR: 0.23923319516047423
# Parameters: [2.85441471e-01 1.00000000e-06 5.39562115e-01 1.68783169e-03
#  5.74706315e-01 4.95290304e-02 4.48571085e-02] | SSR: 0.7648426046829808
# Parameters: [2.77471063e-01 1.00000000e-06 5.28712599e-01 9.53949391e-04
#  3.50333103e-01 5.10498955e-02 4.64667690e-02] | SSR: 0.21166814310111404
# Parameters: [2.73493983e-01 1.00000000e-06 5.15744202e-01 7.82094316e-04
#  3.01401835e-01 5.32501926e-02 4.92455182e-02] | SSR: 0.37599593982040613
# Parameters: [2.67470453e-01 1.00000000e-06 5.05741925e-01 4.15653044e-04
#  2.53955590e-01 5.60484175e-02 4.99863332e-02] | SSR: 0.6309504846095217
# Parameters: [2.82037008e-01 1.00000000e-06 5.35808646e-01 1.30443823e-03
#  4.35826759e-01 4.95756466e-02 4.56300414e-02] | SSR: 0.21138542211427236
# Parameters: [2.83309860e-01 1.00000000e-06 5.41561308e-01 1.38349980e-03
#  4.87411358e-01 4.91664110e-02 4.38857658e-02] | SSR: 0.35030315513420923
# Parameters: [2.80855891e-01 1.00000000e-06 5.35107032e-01 1.23314843e-03
#  4.40908977e-01 5.01873564e-02 4.52257039e-02] | SSR: 0.213741840107051
# Parameters: [3.21852713e-01 1.00000000e-06 6.23195071e-01 1.00000000e-06
#  2.49123974e-01 3.54133378e-02 3.35156482e-02] | SSR: 0.3871446027160361
# Parameters: [2.64327320e-01 1.00000000e-06 4.98214362e-01 1.53902618e-03
#  4.50584534e-01 5.63031322e-02 5.06923169e-02] | SSR: 0.22005093693904876
# Parameters: [2.94788725e-01 1.00000000e-06 5.64157002e-01 1.08615298e-03
#  4.36815032e-01 4.53710202e-02 4.17256722e-02] | SSR: 0.2808542908081907
# Parameters: [2.76544504e-01 1.00000000e-06 5.24837091e-01 1.00952916e-03
#  3.76828594e-01 5.18233606e-02 4.70013829e-02] | SSR: 0.18702121850106118
# Parameters: [3.04415127e-01 1.00000000e-06 5.85279588e-01 3.79829828e-04
#  3.21990488e-01 4.17620940e-02 3.87387558e-02] | SSR: 0.20487466535455828
# Parameters: [2.94617765e-01 1.00000000e-06 5.62721935e-01 4.41902258e-04
#  2.97689334e-01 4.54706520e-02 4.23519551e-02] | SSR: 0.2503430568130301
# Parameters: [2.84296360e-01 1.00000000e-06 5.42010757e-01 1.03533689e-03
#  4.05104066e-01 4.90081803e-02 4.45072667e-02] | SSR: 0.17720935966024365
# Parameters: [2.99952678e-01 1.00000000e-06 5.72915841e-01 7.44354871e-04
#  4.03914055e-01 4.40247657e-02 4.05510322e-02] | SSR: 0.23470299898406247
# Parameters: [2.83091467e-01 1.00000000e-06 5.39763410e-01 9.01550761e-04
#  3.63728341e-01 4.92936131e-02 4.49878348e-02] | SSR: 0.17790830427968513
# Parameters: [2.95688007e-01 1.00000000e-06 5.66949727e-01 2.78755326e-04
#  2.97820851e-01 4.54184335e-02 4.12042721e-02] | SSR: 0.2539129761240957
# Parameters: [2.85449758e-01 1.00000000e-06 5.43593916e-01 1.04801750e-03
#  4.01325282e-01 4.85363434e-02 4.45235991e-02] | SSR: 0.17604446192264878
# Parameters: [2.67891212e-01 1.00000000e-06 5.05568593e-01 1.39427449e-03
#  4.34324205e-01 5.51674860e-02 4.97483701e-02] | SSR: 0.2042585006971277
# Parameters: [2.77022191e-01 1.00000000e-06 5.25496342e-01 1.14066333e-03
#  4.06240776e-01 5.18161380e-02 4.69959665e-02] | SSR: 0.17904483715626246
# Parameters: [2.83308118e-01 1.00000000e-06 5.37591057e-01 8.54511335e-04
#  4.33606659e-01 4.92559111e-02 4.33623009e-02] | SSR: 0.213281446910291
# Parameters: [2.85579690e-01 1.00000000e-06 5.44713810e-01 9.40167630e-04
#  3.64354814e-01 4.87596410e-02 4.49960509e-02] | SSR: 0.17578916346959955
# Parameters: [2.77382607e-01 1.00000000e-06 5.23009306e-01 4.90864713e-04
#  3.57609070e-01 5.24093582e-02 4.77214507e-02] | SSR: 0.19877972755967743
# Parameters: [2.87428662e-01 1.00000000e-06 5.49178685e-01 1.05662449e-03
#  3.93534669e-01 4.77360625e-02 4.34522371e-02] | SSR: 0.17483247737174884
# Parameters: [2.94725209e-01 1.00000000e-06 5.63028768e-01 7.40002439e-04
#  3.91063508e-01 4.55964954e-02 4.17351921e-02] | SSR: 0.1891019449120821
# Parameters: [2.81089680e-01 1.00000000e-06 5.34385010e-01 9.42147480e-04
#  3.80387323e-01 5.02666443e-02 4.56848352e-02] | SSR: 0.17300075298533935
# Parameters: [2.95409662e-01 1.00000000e-06 5.64909137e-01 5.52149460e-04
#  3.54264625e-01 4.51610055e-02 4.13659994e-02] | SSR: 0.17451610501082324
# Parameters: [2.75522783e-01 1.00000000e-06 5.28242051e-01 1.84928406e-03
#  4.07436767e-01 5.09694794e-02 4.73186067e-02] | SSR: 0.1970473759736861
# Parameters: [2.91312597e-01 1.00000000e-06 5.54140702e-01 4.63071015e-04
#  3.66859999e-01 4.71070082e-02 4.26659445e-02] | SSR: 0.16780543145813304
# Parameters: [2.91356079e-01 1.00000000e-06 5.55360024e-01 8.23453372e-04
#  3.97937596e-01 4.68706398e-02 4.27824318e-02] | SSR: 0.18376180366181627
# Parameters: [2.85157620e-01 1.00000000e-06 5.43662563e-01 8.82026414e-04
#  3.72280654e-01 4.86878698e-02 4.44364840e-02] | SSR: 0.16977814682951048
# Parameters: [2.90397260e-01 1.00000000e-06 5.53584621e-01 6.45864251e-04
#  3.47183752e-01 4.70645553e-02 4.32427763e-02] | SSR: 0.17773267784990213
# Parameters: [2.85821585e-01 1.00000000e-06 5.44904223e-01 9.37968730e-04
#  3.90623988e-01 4.85222740e-02 4.41911441e-02] | SSR: 0.17003639577781818
# Parameters: [2.89350098e-01 1.00000000e-06 5.52375835e-01 6.01741129e-04
#  3.47905024e-01 4.75323724e-02 4.31314567e-02] | SSR: 0.1797013971308537
# Parameters: [2.86424843e-01 1.00000000e-06 5.45789396e-01 9.36448410e-04
#  3.87970217e-01 4.82853506e-02 4.41755635e-02] | SSR: 0.1693802561187414
# Parameters: [2.89461638e-01 1.00000000e-06 5.51563252e-01 7.08528369e-04
#  3.91622750e-01 4.71735633e-02 4.24245799e-02] | SSR: 0.17764494038068304
# Parameters: [2.86550177e-01 1.00000000e-06 5.46426171e-01 8.82257815e-04
#  3.71171798e-01 4.83631215e-02 4.43531832e-02] | SSR: 0.16945182012946322
# Parameters: [2.87361671e-01 1.00000000e-06 5.46311944e-01 5.42252462e-04
#  3.56053504e-01 4.83763015e-02 4.42258069e-02] | SSR: 0.17252364572274295
# Parameters: [2.77081244e-01 1.00000000e-06 5.25268009e-01 1.04389978e-03
#  3.95834656e-01 5.18700145e-02 4.71291324e-02] | SSR: 0.1778722722088289
# Parameters: [2.90827558e-01 1.00000000e-06 5.54998855e-01 6.75087039e-04
#  3.64657133e-01 4.68382577e-02 4.28067827e-02] | SSR: 0.16848226379170778
# Parameters: [2.94183477e-01 1.00000000e-06 5.61681805e-01 5.77598772e-04
#  3.65217618e-01 4.57848367e-02 4.19879959e-02] | SSR: 0.17082204060799064
# Parameters: [2.89860574e-01 1.00000000e-06 5.54146260e-01 9.87592737e-04
#  3.92169755e-01 4.69347610e-02 4.28076497e-02] | SSR: 0.1777190203279677
# Parameters: [2.87986397e-01 1.00000000e-06 5.48270523e-01 6.53587531e-04
#  3.65082567e-01 4.80159164e-02 4.38712676e-02] | SSR: 0.16784587670534576
# Parameters: [2.81268174e-01 1.00000000e-06 5.34944604e-01 9.73957500e-04
#  3.82967055e-01 5.01636771e-02 4.55835382e-02] | SSR: 0.17229092672469548
# Parameters: [2.90954651e-01 1.00000000e-06 5.54997505e-01 6.76688454e-04
#  3.69654977e-01 4.68795468e-02 4.28868815e-02] | SSR: 0.16771689163384707
# Parameters: [2.91096656e-01 1.00000000e-06 5.54605981e-01 5.38936035e-04
#  3.51569540e-01 4.69568891e-02 4.30077436e-02] | SSR: 0.17265859092207794
# Parameters: [2.87140353e-01 1.00000000e-06 5.47329663e-01 8.38210556e-04
#  3.80860376e-01 4.81309278e-02 4.38952940e-02] | SSR: 0.16753838917375316
# Parameters: [2.92327116e-01 1.00000000e-06 5.56895384e-01 5.82359535e-04
#  3.72364222e-01 4.66321671e-02 4.26077779e-02] | SSR: 0.1687026386777754
# Parameters: [2.92585113e-01 1.00000000e-06 5.57122980e-01 4.96442911e-04
#  3.73813771e-01 4.64623569e-02 4.21923916e-02] | SSR: 0.1710287578299476
# Parameters: [2.88058911e-01 1.00000000e-06 5.49100373e-01 7.85804089e-04
#  3.71832291e-01 4.78879304e-02 4.38129853e-02] | SSR: 0.16738240483715264
# Parameters: [2.93177323e-01 1.00000000e-06 5.58705748e-01 3.99211081e-04
#  3.52404515e-01 4.64265792e-02 4.22664175e-02] | SSR: 0.17223374827574495
# Parameters: [2.88112963e-01 1.00000000e-06 5.49018484e-01 8.02139078e-04
#  3.79078792e-01 4.78206578e-02 4.36982770e-02] | SSR: 0.1672712704719871
# Parameters: [2.86071007e-01 1.00000000e-06 5.45349218e-01 8.16094111e-04
#  3.69928959e-01 4.84193315e-02 4.41457742e-02] | SSR: 0.16907684056849542
# Parameters: [2.90763089e-01 1.00000000e-06 5.54008842e-01 6.40793179e-04
#  3.71755406e-01 4.70789582e-02 4.29922770e-02] | SSR: 0.16729229394635314
# Parameters: [2.87552145e-01 1.00000000e-06 5.46962886e-01 7.13568362e-04
#  3.79664127e-01 4.82820124e-02 4.39997678e-02] | SSR: 0.16607378090736147
# Parameters: [2.85914438e-01 1.00000000e-06 5.42944901e-01 7.32809023e-04
#  3.87167624e-01 4.90038897e-02 4.45962604e-02] | SSR: 0.16641635609502992
# Parameters: [2.90269234e-01 1.00000000e-06 5.53317607e-01 7.52205250e-04
#  3.83404853e-01 4.71803812e-02 4.29719973e-02] | SSR: 0.17076323741798674
# Parameters: [2.88557106e-01 1.00000000e-06 5.49532294e-01 6.78241961e-04
#  3.69663138e-01 4.78070326e-02 4.36464500e-02] | SSR: 0.16666266082812298
# Parameters: [2.86155751e-01 1.00000000e-06 5.46130740e-01 1.00419918e-03
#  3.82428318e-01 4.82892964e-02 4.44574648e-02] | SSR: 0.16910528173249734
# Parameters: [2.90023385e-01 1.00000000e-06 5.52138211e-01 5.98353056e-04
#  3.70752079e-01 4.74025802e-02 4.31138246e-02] | SSR: 0.16681374499353055
# Parameters: [2.86247621e-01 1.00000000e-06 5.44456996e-01 7.68200197e-04
#  3.79946796e-01 4.86661959e-02 4.43013687e-02] | SSR: 0.16654348002933178
# Parameters: [2.89806853e-01 1.00000000e-06 5.51304076e-01 5.86675136e-04
#  3.68480376e-01 4.75677486e-02 4.34089776e-02] | SSR: 0.1662172788836223
# Parameters: [2.89387707e-01 1.00000000e-06 5.50162995e-01 5.82187616e-04
#  3.76550770e-01 4.77192655e-02 4.33758555e-02] | SSR: 0.16608636458131615
# Parameters: [2.86290563e-01 1.00000000e-06 5.44155713e-01 7.10454080e-04
#  3.77997759e-01 4.87111826e-02 4.43061576e-02] | SSR: 0.165958529969208
# Parameters: [2.84054300e-01 1.00000000e-06 5.39229148e-01 7.45284530e-04
#  3.81118935e-01 4.95272949e-02 4.49630979e-02] | SSR: 0.1667463568964883
# Parameters: [2.88420003e-01 1.00000000e-06 5.47756708e-01 5.22912467e-04
#  3.70365506e-01 4.82239187e-02 4.37738378e-02] | SSR: 0.16532892827880355
# Parameters: [2.88573522e-01 1.00000000e-06 5.47125820e-01 3.83299161e-04
#  3.66008864e-01 4.84255492e-02 4.38116182e-02] | SSR: 0.16549829086036563
# Parameters: [2.86051471e-01 1.00000000e-06 5.43385122e-01 7.05144035e-04
#  3.78581771e-01 4.88766644e-02 4.45468654e-02] | SSR: 0.16575672371701447
# Parameters: [2.86801855e-01 1.00000000e-06 5.44234705e-01 6.32941437e-04
#  3.82218892e-01 4.87778212e-02 4.42715016e-02] | SSR: 0.1651538461471277
# Parameters: [2.85924229e-01 1.00000000e-06 5.41585910e-01 6.10291176e-04
#  3.88496768e-01 4.92632155e-02 4.45840273e-02] | SSR: 0.16537459030108514
# Parameters: [2.89269692e-01 1.00000000e-06 5.49246491e-01 5.04337841e-04
#  3.72584403e-01 4.79505508e-02 4.36080494e-02] | SSR: 0.16483445146901402
# Parameters: [2.90780728e-01 1.00000000e-06 5.51641239e-01 3.72406662e-04
#  3.68903207e-01 4.75927283e-02 4.32613898e-02] | SSR: 0.1649393353379175
# Parameters: [2.85556985e-01 1.00000000e-06 5.41811530e-01 6.62337961e-04
#  3.85223404e-01 4.91583702e-02 4.45573182e-02] | SSR: 0.16534907882231809
# Parameters: [2.84881640e-01 1.00000000e-06 5.40566477e-01 6.89725578e-04
#  3.79630905e-01 4.94180260e-02 4.49280010e-02] | SSR: 0.16602979621049088
# Parameters: [2.85954200e-01 1.00000000e-06 5.41939042e-01 5.51532609e-04
#  3.76508056e-01 4.91798545e-02 4.45692982e-02] | SSR: 0.16449371111833963
# Parameters: [2.85155228e-01 1.00000000e-06 5.39427120e-01 4.70514733e-04
#  3.74930020e-01 4.96287756e-02 4.48540633e-02] | SSR: 0.16435090389385387
# Parameters: [2.88702873e-01 1.00000000e-06 5.48009919e-01 5.12743722e-04
#  3.75198168e-01 4.81040550e-02 4.36199399e-02] | SSR: 0.16488022157262366
# Parameters: [2.87983182e-01 1.00000000e-06 5.45521886e-01 4.35526548e-04
#  3.76031431e-01 4.86374333e-02 4.40457211e-02] | SSR: 0.16348742762021579
# Parameters: [2.88829492e-01 1.00000000e-06 5.46204972e-01 2.98062782e-04
#  3.75048267e-01 4.86005587e-02 4.39155029e-02] | SSR: 0.16269642394247663
# Parameters: [2.89015994e-01 1.00000000e-06 5.47098148e-01 3.24527663e-04
#  3.74437847e-01 4.83930642e-02 4.36246240e-02] | SSR: 0.16373748997767362
# Parameters: [2.90498768e-01 1.00000000e-06 5.50182203e-01 2.70816509e-04
#  3.64714626e-01 4.78926996e-02 4.33476872e-02] | SSR: 0.165155892559118
# Parameters: [2.88229684e-01 1.00000000e-06 5.44930023e-01 3.38214587e-04
#  3.77957986e-01 4.87325170e-02 4.40094103e-02] | SSR: 0.16276683178174745
# Parameters: [2.85502609e-01 1.00000000e-06 5.41003905e-01 6.09567138e-04
#  3.87392683e-01 4.93036840e-02 4.46246246e-02] | SSR: 0.16495668218033593
# Parameters: [2.88828309e-01 1.00000000e-06 5.46028317e-01 2.40763839e-04
#  3.71366644e-01 4.85688089e-02 4.38017026e-02] | SSR: 0.1628285977596116
# Parameters: [2.91077755e-01 1.00000000e-06 5.50694663e-01 1.58765767e-04
#  3.61613984e-01 4.78329818e-02 4.32134589e-02] | SSR: 0.16569102059822757
# Parameters: [2.86896395e-01 1.00000000e-06 5.43426595e-01 4.96866795e-04
#  3.80948009e-01 4.89360084e-02 4.42718332e-02] | SSR: 0.16369532401010545
# Parameters: [2.87361354e-01 1.00000000e-06 5.42379128e-01 2.51052917e-04
#  3.75451311e-01 4.92703117e-02 4.44043989e-02] | SSR: 0.16156725287218082
# Parameters: [2.86690594e-01 1.00000000e-06 5.39563732e-01 1.20207515e-04
#  3.75577882e-01 4.98534401e-02 4.47966283e-02] | SSR: 0.16012024575368486
# Parameters: [2.86057649e-01 1.00000000e-06 5.38376054e-01 1.49707278e-04
#  3.78920355e-01 4.99674985e-02 4.47558834e-02] | SSR: 0.1601066144858117
# Parameters: [2.84451628e-01 1.00000000e-06 5.32940835e-01 1.00000000e-06
#  3.82088331e-01 5.09759724e-02 4.53298003e-02] | SSR: 0.15822387785531639
# Parameters: [2.89971085e-01 1.00000000e-06 5.46342201e-01 4.93833183e-05
#  3.78619970e-01 4.86741872e-02 4.36457943e-02] | SSR: 0.16274676083407097
# Parameters: [2.86383202e-01 1.00000000e-06 5.38455188e-01 1.16757718e-04
#  3.80307036e-01 4.99902194e-02 4.48812822e-02] | SSR: 0.15936642524008068
# Parameters: [2.88356174e-01 1.00000000e-06 5.40706339e-01 1.00000000e-06
#  3.73613739e-01 4.97484784e-02 4.44082013e-02] | SSR: 0.16070035725837095
# Parameters: [2.86289365e-01 1.00000000e-06 5.36584051e-01 2.34149956e-05
#  3.83837131e-01 5.04527263e-02 4.50516173e-02] | SSR: 0.15859367964148655
# Parameters: [2.86333613e-01 1.00000000e-06 5.35297782e-01 1.00000000e-06
#  3.78925545e-01 5.07805066e-02 4.51416830e-02] | SSR: 0.15957840894729358
# Parameters: [2.83552934e-01 1.00000000e-06 5.30730056e-01 1.11028970e-04
#  3.78350868e-01 5.14406419e-02 4.59326959e-02] | SSR: 0.1615600236944576
# Parameters: [2.83186939e-01 1.00000000e-06 5.26445880e-01 1.00000000e-06
#  3.82866170e-01 5.23257228e-02 4.62393281e-02] | SSR: 0.1607569086864451
# Parameters: [2.88358927e-01 1.00000000e-06 5.40696746e-01 1.00000000e-06
#  3.80853657e-01 4.97385198e-02 4.43097443e-02] | SSR: 0.16039808467143135
# Parameters: [2.90202632e-01 1.00000000e-06 5.49052598e-01 7.45372083e-05
#  3.75763350e-01 4.81142381e-02 4.34518025e-02] | SSR: 0.16289582066884356
# Parameters: [2.84940863e-01 1.00000000e-06 5.32097560e-01 1.93843021e-05
#  3.81090465e-01 5.12728516e-02 4.55424467e-02] | SSR: 0.1594418005172961
# Parameters: [2.84057595e-01 1.00000000e-06 5.32332488e-01 7.97898660e-05
#  3.87151989e-01 5.11270177e-02 4.56069993e-02] | SSR: 0.15846507367213136
# Parameters: [2.82825890e-01 1.00000000e-06 5.29952293e-01 1.02301256e-04
#  3.81711595e-01 5.15336900e-02 4.60761006e-02] | SSR: 0.1599559054708501
# Parameters: [2.83390022e-01 1.00000000e-06 5.28339181e-01 1.00000000e-06
#  3.88739858e-01 5.18988411e-02 4.59547801e-02] | SSR: 0.1581670805018107
# Parameters: [2.81739736e-01 1.00000000e-06 5.22726905e-01 1.00000000e-06
#  3.95320846e-01 5.29215416e-02 4.65338560e-02] | SSR: 0.15879363703452776
# Parameters: [2.87415906e-01 1.00000000e-06 5.37489731e-01 1.00000000e-06
#  3.84614221e-01 5.03229201e-02 4.46406448e-02] | SSR: 0.1599461749713753
# Parameters: [2.86268402e-01 1.00000000e-06 5.35605372e-01 1.00000000e-06
#  3.83888564e-01 5.06256126e-02 4.49995088e-02] | SSR: 0.1588338433119894
# Parameters: [2.83889552e-01 1.00000000e-06 5.32232125e-01 6.82419663e-05
#  3.88818277e-01 5.10318480e-02 4.55344412e-02] | SSR: 0.15816526785331153
# Parameters: [2.82667521e-01 1.00000000e-06 5.30699296e-01 1.01862949e-04
#  3.93764642e-01 5.11575187e-02 4.57308202e-02] | SSR: 0.1584508537378012
# Parameters: [2.84981927e-01 1.00000000e-06 5.35470794e-01 6.38169969e-05
#  3.88861302e-01 5.04706448e-02 4.51313902e-02] | SSR: 0.15870368414780434
# Parameters: [2.83139224e-01 1.00000000e-06 5.28260482e-01 1.00000000e-06
#  3.92088807e-01 5.18905414e-02 4.58640141e-02] | SSR: 0.15801715513317333
# Parameters: [2.81517235e-01 1.00000000e-06 5.23163129e-01 1.00000000e-06
#  3.97979693e-01 5.28407024e-02 4.63553801e-02] | SSR: 0.1586164838727975
# Parameters: [2.82359973e-01 1.00000000e-06 5.29011758e-01 6.70753785e-05
#  3.90850205e-01 5.16165565e-02 4.59927891e-02] | SSR: 0.15789255109824507
# Parameters: [2.80405758e-01 1.00000000e-06 5.25714952e-01 1.00113068e-04
#  3.94331026e-01 5.21120285e-02 4.64894293e-02] | SSR: 0.15811679639665194
# Parameters: [2.82897318e-01 1.00000000e-06 5.27300897e-01 5.18934781e-06
#  3.86445726e-01 5.20989276e-02 4.61070216e-02] | SSR: 0.1588204102578638
# Parameters: [2.84460775e-01 1.00000000e-06 5.33428320e-01 4.91600846e-05
#  3.88257408e-01 5.08777155e-02 4.53752981e-02] | SSR: 0.15820787269462316
# Parameters: [2.81067426e-01 1.00000000e-06 5.25286003e-01 5.29470888e-05
#  3.92732833e-01 5.22382716e-02 4.62792747e-02] | SSR: 0.1581072600663149
# Parameters: [2.82444862e-01 1.00000000e-06 5.27524285e-01 1.00000000e-06
#  3.91012503e-01 5.18814813e-02 4.59159715e-02] | SSR: 0.15760577716399823
# Parameters: [2.81638496e-01 1.00000000e-06 5.25120183e-01 1.00000000e-06
#  3.92942760e-01 5.22587130e-02 4.60704575e-02] | SSR: 0.1578004137925233
# Parameters: [2.81477467e-01 1.00000000e-06 5.25368352e-01 6.76927195e-05
#  3.98625923e-01 5.22912434e-02 4.63606479e-02] | SSR: 0.15879496329621906
# Parameters: [2.83708088e-01 1.00000000e-06 5.31047714e-01 1.76731799e-05
#  3.86222729e-01 5.13047902e-02 4.55875122e-02] | SSR: 0.15792678914333236
# Parameters: [2.81253267e-01 1.00000000e-06 5.24200694e-01 1.05363764e-05
#  3.91875510e-01 5.25115216e-02 4.63757828e-02] | SSR: 0.1581519959362472
# Parameters: [2.81713519e-01 1.00000000e-06 5.28107408e-01 6.14211400e-05
#  3.92288961e-01 5.16654477e-02 4.59165872e-02] | SSR: 0.15774634030372653
# Parameters: [2.80592265e-01 1.00000000e-06 5.23035973e-01 1.00000000e-06
#  3.93202166e-01 5.27134692e-02 4.64461107e-02] | SSR: 0.15801863863012686
# Parameters: [2.83039692e-01 1.00000000e-06 5.30734627e-01 4.72112771e-05
#  3.90523977e-01 5.12914949e-02 4.56248628e-02] | SSR: 0.15787357989999057
# Parameters: [2.83789037e-01 1.00000000e-06 5.31206068e-01 3.16176135e-06
#  3.89035552e-01 5.12942373e-02 4.55343960e-02] | SSR: 0.1577470361642874
# Parameters: [2.85177562e-01 1.00000000e-06 5.35790410e-01 5.57264962e-05
#  3.87375758e-01 5.04135449e-02 4.51070701e-02] | SSR: 0.15847519883979982
# Parameters: [2.81738589e-01 1.00000000e-06 5.26224583e-01 1.46816241e-05
#  3.91745564e-01 5.21384881e-02 4.61113506e-02] | SSR: 0.15778125713232563
# Parameters: [2.82230422e-01 1.00000000e-06 5.29984216e-01 5.96355317e-05
#  3.88391047e-01 5.13073146e-02 4.57598343e-02] | SSR: 0.15744250340743512
# Parameters: [2.81776020e-01 1.00000000e-06 5.30846083e-01 8.89532975e-05
#  3.86542167e-01 5.10157012e-02 4.57077443e-02] | SSR: 0.15717055940842642
# Parameters: [2.81109539e-01 1.00000000e-06 5.27139375e-01 6.33280997e-05
#  3.94348393e-01 5.18104690e-02 4.60706882e-02] | SSR: 0.15767029103934554
# Parameters: [2.82100387e-01 1.00000000e-06 5.28640364e-01 1.28552500e-05
#  3.90720399e-01 5.15541062e-02 4.56876682e-02] | SSR: 0.15734691094025316
# Parameters: [2.81152295e-01 1.00000000e-06 5.26319134e-01 2.29033436e-05
#  3.91102748e-01 5.19541996e-02 4.60735389e-02] | SSR: 0.15729551276379583
# Parameters: [2.82285885e-01 1.00000000e-06 5.30856193e-01 5.77820594e-05
#  3.89697500e-01 5.10545525e-02 4.55762478e-02] | SSR: 0.1573048637204949
# Parameters: [2.79805964e-01 1.00000000e-06 5.25774744e-01 8.49077215e-05
#  3.92596640e-01 5.18303219e-02 4.61651600e-02] | SSR: 0.15726464453980915
# Parameters: [2.81336468e-01 1.00000000e-06 5.28206929e-01 3.33587948e-05
#  3.89431140e-01 5.15062185e-02 4.58539896e-02] | SSR: 0.15690391212279453
# Parameters: [2.81147942e-01 1.00000000e-06 5.28256689e-01 1.93276223e-05
#  3.88002229e-01 5.14266039e-02 4.58226909e-02] | SSR: 0.15653356238043575
# Parameters: [2.81951420e-01 1.00000000e-06 5.29494194e-01 1.88802701e-05
#  3.85558517e-01 5.12515215e-02 4.56290322e-02] | SSR: 0.15700731114009775
# Parameters: [2.80475113e-01 1.00000000e-06 5.29672116e-01 8.63170184e-05
#  3.87336126e-01 5.10005206e-02 4.57017664e-02] | SSR: 0.15649060349989496
# Parameters: [2.79490238e-01 1.00000000e-06 5.30746031e-01 1.28975528e-04
#  3.85497938e-01 5.05600403e-02 4.55946638e-02] | SSR: 0.1559243963243793
# Parameters: [2.80073831e-01 1.00000000e-06 5.29157656e-01 1.07638991e-04
#  3.86136098e-01 5.10438770e-02 4.59034969e-02] | SSR: 0.156503098153026
# Parameters: [2.79256318e-01 1.00000000e-06 5.26456530e-01 7.69570187e-05
#  3.86141454e-01 5.15403805e-02 4.61084171e-02] | SSR: 0.15676192841816833
# Parameters: [2.79848201e-01 1.00000000e-06 5.31032845e-01 1.27279642e-04
#  3.83318693e-01 5.05224993e-02 4.56210912e-02] | SSR: 0.15604717596595255
# Parameters: [2.81206599e-01 1.00000000e-06 5.33079550e-01 7.73815266e-05
#  3.79173959e-01 5.02727134e-02 4.53740218e-02] | SSR: 0.1562196183616286
# Parameters: [2.79073851e-01 1.00000000e-06 5.28646344e-01 7.00297303e-05
#  3.83123229e-01 5.08750519e-02 4.57360882e-02] | SSR: 0.15559836552718365
# Parameters: [2.77722767e-01 1.00000000e-06 5.27546475e-01 6.05679467e-05
#  3.81413760e-01 5.08047273e-02 4.57502601e-02] | SSR: 0.15490883256360782
# Parameters: [2.77690265e-01 1.00000000e-06 5.29441742e-01 1.52013522e-04
#  3.82922663e-01 5.05115762e-02 4.58494369e-02] | SSR: 0.15515009474508218
# Parameters: [2.79937922e-01 1.00000000e-06 5.33332324e-01 1.15381489e-04
#  3.81420072e-01 4.99287731e-02 4.52960577e-02] | SSR: 0.15522178960396701
# Parameters: [2.77700579e-01 1.00000000e-06 5.32982346e-01 2.00454848e-04
#  3.77678680e-01 4.96145979e-02 4.54313173e-02] | SSR: 0.1547379574289317
# Parameters: [2.75976897e-01 1.00000000e-06 5.35345175e-01 2.91018460e-04
#  3.72516905e-01 4.87085950e-02 4.52356305e-02] | SSR: 0.1538868576206878
# Parameters: [2.77604137e-01 1.00000000e-06 5.33849242e-01 1.64537614e-04
#  3.75653614e-01 4.93301015e-02 4.51596922e-02] | SSR: 0.15416600676107362
# Parameters: [2.75442094e-01 1.00000000e-06 5.30147260e-01 2.19696817e-04
#  3.81609940e-01 4.98319473e-02 4.56279303e-02] | SSR: 0.15387413718317866
# Parameters: [2.72559842e-01 1.00000000e-06 5.28681115e-01 2.90854462e-04
#  3.82827930e-01 4.96115643e-02 4.57548845e-02] | SSR: 0.15297180913887706
# Parameters: [2.74718104e-01 1.00000000e-06 5.31522042e-01 2.16534365e-04
#  3.77324988e-01 4.93218943e-02 4.54190876e-02] | SSR: 0.15288547396798763
# Parameters: [2.72153056e-01 1.00000000e-06 5.31766640e-01 2.61161726e-04
#  3.74328135e-01 4.87215918e-02 4.53180858e-02] | SSR: 0.15129008222088788
# Parameters: [2.72979729e-01 1.00000000e-06 5.32100458e-01 2.52605964e-04
#  3.71954370e-01 4.87590823e-02 4.53664927e-02] | SSR: 0.1519890892323672
# Parameters: [2.70543990e-01 1.00000000e-06 5.29162203e-01 3.05406995e-04
#  3.73327750e-01 4.90561521e-02 4.56852231e-02] | SSR: 0.1520521674579927
# Parameters: [2.70749854e-01 1.00000000e-06 5.32972917e-01 3.12601668e-04
#  3.69083756e-01 4.80575136e-02 4.50849257e-02] | SSR: 0.1507596147589259
# Parameters: [2.67279649e-01 1.00000000e-06 5.34738505e-01 3.92895741e-04
#  3.62164302e-01 4.68304824e-02 4.47026701e-02] | SSR: 0.14869653218211565
# Parameters: [2.67733605e-01 1.00000000e-06 5.36923050e-01 4.98998043e-04
#  3.65092813e-01 4.66288639e-02 4.48847909e-02] | SSR: 0.14893534386406201
# Parameters: [2.65032082e-01 1.00000000e-06 5.31498514e-01 4.90588498e-04
#  3.67835588e-01 4.73317076e-02 4.53968156e-02] | SSR: 0.14856801686901994
# Parameters: [2.58746055e-01 1.00000000e-06 5.30323150e-01 6.53613941e-04
#  3.63926576e-01 4.63325106e-02 4.55153773e-02] | SSR: 0.14606424650481356
# Parameters: [2.61736224e-01 1.00000000e-06 5.28567717e-01 4.67706360e-04
#  3.68517917e-01 4.72743329e-02 4.54008051e-02] | SSR: 0.1463452144768117
# Parameters: [2.62060817e-01 1.00000000e-06 5.35199377e-01 5.18399472e-04
#  3.54118317e-01 4.57035831e-02 4.47803855e-02] | SSR: 0.1465390057486071
# Parameters: [2.61652906e-01 1.00000000e-06 5.36443196e-01 5.64701933e-04
#  3.58130087e-01 4.53011184e-02 4.45915219e-02] | SSR: 0.14479013480576425
# Parameters: [2.57207364e-01 1.00000000e-06 5.40083692e-01 6.94349402e-04
#  3.50531255e-01 4.34236016e-02 4.40446713e-02] | SSR: 0.14137743409347103
# Parameters: [2.54710777e-01 1.00000000e-06 5.35785865e-01 7.43715375e-04
#  3.53382577e-01 4.40737652e-02 4.45325891e-02] | SSR: 0.14138104878303426
# Parameters: [2.50553942e-01 1.00000000e-06 5.37268033e-01 8.73032083e-04
#  3.45024366e-01 4.27833053e-02 4.43565683e-02] | SSR: 0.13928770245797711
# Parameters: [2.39754385e-01 1.00000000e-06 5.40018730e-01 1.17896726e-03
#  3.30372482e-01 3.98141620e-02 4.38758095e-02] | SSR: 0.13303900353930326
# Parameters: [2.46979330e-01 1.00000000e-06 5.32996104e-01 8.29472687e-04
#  3.44339594e-01 4.29289754e-02 4.45015827e-02] | SSR: 0.13746204144723198
# Parameters: [2.41633195e-01 1.00000000e-06 5.34682819e-01 1.06031126e-03
#  3.42175331e-01 4.16126408e-02 4.46262501e-02] | SSR: 0.13464359823865016
# Parameters: [2.41015563e-01 1.00000000e-06 5.34074359e-01 1.08963947e-03
#  3.46809035e-01 4.15706993e-02 4.45044960e-02] | SSR: 0.13417539500893194
# Parameters: [2.35419967e-01 1.00000000e-06 5.42279345e-01 1.31802775e-03
#  3.26206897e-01 3.83703400e-02 4.36279881e-02] | SSR: 0.12944292207674868
# Parameters: [2.22261838e-01 1.00000000e-06 5.49135160e-01 1.74318845e-03
#  3.05051388e-01 3.39183435e-02 4.27415796e-02] | SSR: 0.12087397157432996
# Parameters: [2.27986074e-01 1.00000000e-06 5.45898772e-01 1.44342717e-03
#  3.13976756e-01 3.57652573e-02 4.27209022e-02] | SSR: 0.12346415619805842
# Parameters: [2.24385723e-01 1.00000000e-06 5.43325459e-01 1.55324339e-03
#  3.13261949e-01 3.56501433e-02 4.31860656e-02] | SSR: 0.12225919748363254
# Parameters: [2.12511524e-01 1.00000000e-06 5.39953852e-01 1.84800765e-03
#  3.05464898e-01 3.40793189e-02 4.34286675e-02] | SSR: 0.11767894958127206
# Parameters: [1.90163603e-01 1.00000000e-06 5.39888932e-01 2.42483678e-03
#  2.82931720e-01 2.94071776e-02 4.31206656e-02] | SSR: 0.10760627952587534
# Parameters: [2.06506493e-01 1.00000000e-06 5.49010820e-01 2.16870268e-03
#  2.94111452e-01 3.07105743e-02 4.25772083e-02] | SSR: 0.11285820703194063
# Parameters: [2.01816428e-01 1.00000000e-06 5.51417819e-01 2.25454737e-03
#  2.82543178e-01 2.89120328e-02 4.18671004e-02] | SSR: 0.10928947939655091
# Parameters: [1.91234307e-01 1.00000000e-06 5.56981553e-01 2.55804999e-03
#  2.59547801e-01 2.53372124e-02 4.12353129e-02] | SSR: 0.10463889247294413
# Parameters: [1.66343679e-01 1.00000000e-06 5.68435151e-01 3.29225525e-03
#  2.15917184e-01 1.72204689e-02 3.96007214e-02] | SSR: 0.09906477437357136
# Parameters: [1.71520997e-01 1.00000000e-06 5.59156159e-01 3.07251876e-03
#  2.43282840e-01 2.06384088e-02 4.06425456e-02] | SSR: 0.09901728709084923
# Parameters: [1.37404304e-01 1.00000000e-06 5.68724874e-01 4.01929451e-03
#  1.99738019e-01 1.10505321e-02 3.90259136e-02] | SSR: 0.12023375844326942
# Parameters: [1.67156429e-01 1.00000000e-06 5.57063942e-01 3.27351359e-03
#  2.39480304e-01 2.03653567e-02 4.12036368e-02] | SSR: 0.09867285900075244
# Parameters: [1.36741607e-01 1.00000000e-06 5.62646527e-01 4.18855680e-03
#  2.02232078e-01 1.26654064e-02 4.04450042e-02] | SSR: 0.1078209933008507
# Parameters: [1.54405554e-01 1.00000000e-06 5.63562536e-01 3.65520314e-03
#  2.19114641e-01 1.61133889e-02 4.01720651e-02] | SSR: 0.09980072075059962
# Parameters: [1.37141929e-01 1.00000000e-06 5.61874943e-01 4.01154800e-03
#  2.02771846e-01 1.27580587e-02 3.98824042e-02] | SSR: 0.10470628719242313
# Parameters: [1.33078827e-01 1.00000000e-06 5.65674746e-01 4.11256101e-03
#  1.87614751e-01 1.08365378e-02 3.92768315e-02] | SSR: 0.10531658617504064
# Parameters: [1.18129577e-01 1.00000000e-06 5.67341155e-01 4.55757736e-03
#  1.72060618e-01 7.47065217e-03 3.92468625e-02] | SSR: 0.12260819942039282
# Parameters: [1.80894715e-01 1.00000000e-06 5.55398653e-01 2.83030487e-03
#  2.54922538e-01 2.35516877e-02 4.12120410e-02] | SSR: 0.1005490625598621
# Parameters: [1.27134148e-01 1.00000000e-06 5.83301390e-01 4.50313598e-03
#  1.63669453e-01 5.30251022e-03 3.74479760e-02] | SSR: 0.1419359328011448
# Parameters: [1.74406240e-01 1.00000000e-06 5.50742047e-01 2.94441158e-03
#  2.53116153e-01 2.33810108e-02 4.17024932e-02] | SSR: 0.09913453667534439
# Parameters: [1.96026757e-01 1.00000000e-06 5.53249091e-01 2.48165476e-03
#  2.77701107e-01 2.74572851e-02 4.19848563e-02] | SSR: 0.10743836773894537
# Parameters: [1.48815809e-01 1.00000000e-06 5.62568332e-01 3.70483445e-03
#  2.10136340e-01 1.49917247e-02 3.99538377e-02] | SSR: 0.09828127377312099
# ...
#  3.77950287e-01 4.50768182e-02 4.36252413e-02] | SSR: 0.053757829753075886
# Parameters: [1.05567489e-01 1.00000000e-06 3.75721196e-01 1.12280479e-06
#  3.78923507e-01 4.52095347e-02 4.36529647e-02] | SSR: 0.05375978726409841
# Parameters: [1.06001497e-01 1.00000000e-06 3.77211915e-01 1.06208755e-06
#  3.77253681e-01 4.49812247e-02 4.36407342e-02] | SSR: 0.05375774847921642
# Parameters: [1.05911586e-01 1.00000000e-06 3.76354511e-01 1.00000000e-06
#  3.78187573e-01 4.51303743e-02 4.36523532e-02] | SSR: 0.05375717993745851
# Parameters: [1.05944185e-01 1.00000000e-06 3.75978857e-01 1.00000000e-06
#  3.78584781e-01 4.52037603e-02 4.36595103e-02] | SSR: 0.053757618556836126
# Parameters: [1.06085250e-01 1.00000000e-06 3.77199795e-01 1.13322343e-06
#  3.77548204e-01 4.50108280e-02 4.36786428e-02] | SSR: 0.05375832882796413
# Parameters: [1.06257465e-01 1.00000000e-06 3.77509143e-01 1.17128727e-06
#  3.77291278e-01 4.49978872e-02 4.36902382e-02] | SSR: 0.053759462251993836
# Parameters: [1.05818168e-01 1.00000000e-06 3.76560959e-01 1.04282182e-06
#  3.77936465e-01 4.50725246e-02 4.36410200e-02] | SSR: 0.053757554731330134
# Parameters: [1.05767641e-01 1.00000000e-06 3.76371722e-01 1.01223481e-06
#  3.78005534e-01 4.51020905e-02 4.36254599e-02] | SSR: 0.05375816822284206
# Parameters: [1.05838925e-01 1.00000000e-06 3.76120635e-01 1.14895390e-06
#  3.78593422e-01 4.51758776e-02 4.36313277e-02] | SSR: 0.05375723831518124
# Parameters: [1.05804254e-01 1.00000000e-06 3.75829196e-01 1.19151216e-06
#  3.78698205e-01 4.52041944e-02 4.36072481e-02] | SSR: 0.05375814206028469
# Parameters: [1.06006533e-01 1.00000000e-06 3.76497892e-01 1.23049945e-06
#  3.78312962e-01 4.51278951e-02 4.36507000e-02] | SSR: 0.053757348169799546
# Parameters: [1.06027715e-01 1.00000000e-06 3.77231473e-01 1.06236133e-06
#  3.77510222e-01 4.50039913e-02 4.36813266e-02] | SSR: 0.05375841960079888
# Parameters: [1.05860119e-01 1.00000000e-06 3.76179765e-01 1.15922445e-06
#  3.78401209e-01 4.51541437e-02 4.36257677e-02] | SSR: 0.05375738691412515
# Parameters: [1.05975842e-01 1.00000000e-06 3.76347403e-01 1.00671000e-06
#  3.78386974e-01 4.51534606e-02 4.36634839e-02] | SSR: 0.05375705589587427
# Parameters: [1.06035256e-01 1.00000000e-06 3.76223749e-01 1.00000000e-06
#  3.78605318e-01 4.51917818e-02 4.36826052e-02] | SSR: 0.053757929820684676
# Parameters: [1.05824028e-01 1.00000000e-06 3.75483195e-01 1.15642177e-06
#  3.79407379e-01 4.52982644e-02 4.36544908e-02] | SSR: 0.053757891275662426
# Parameters: [1.05957130e-01 1.00000000e-06 3.76779735e-01 1.08567111e-06
#  3.77792105e-01 4.50604846e-02 4.36441734e-02] | SSR: 0.05375722710844983
# Parameters: [1.05841348e-01 1.00000000e-06 3.76439966e-01 1.01596435e-06
#  3.77965100e-01 4.50859958e-02 4.36196008e-02] | SSR: 0.05375748549860078
# Parameters: [1.06007970e-01 1.00000000e-06 3.76216157e-01 1.14204197e-06
#  3.78531919e-01 4.51812559e-02 4.36410962e-02] | SSR: 0.05375713918370775
# Parameters: [1.06032396e-01 1.00000000e-06 3.76273205e-01 1.20492161e-06
#  3.78665233e-01 4.51950019e-02 4.36686569e-02] | SSR: 0.05375781447892561
# Parameters: [1.05889110e-01 1.00000000e-06 3.76398275e-01 1.06320367e-06
#  3.78140133e-01 4.51132473e-02 4.36318648e-02] | SSR: 0.05375708877147137
# Parameters: [1.06021908e-01 1.00000000e-06 3.76595837e-01 1.03422701e-06
#  3.78154530e-01 4.51151693e-02 4.36642320e-02] | SSR: 0.0537571079096229
# Parameters: [1.05879887e-01 1.00000000e-06 3.76305695e-01 1.00000000e-06
#  3.78197511e-01 4.51377819e-02 4.36431660e-02] | SSR: 0.05375740184838883
# Parameters: [1.05974871e-01 1.00000000e-06 3.76449842e-01 1.14959313e-06
#  3.78284099e-01 4.51303668e-02 4.36488165e-02] | SSR: 0.05375707695145737
# Parameters: [1.06086337e-01 1.00000000e-06 3.76777011e-01 1.00000000e-06
#  3.77828674e-01 4.50767964e-02 4.36675352e-02] | SSR: 0.05375737277457321
# Parameters: [1.05900778e-01 1.00000000e-06 3.76284729e-01 1.10886601e-06
#  3.78402235e-01 4.51511073e-02 4.36403796e-02] | SSR: 0.05375701686072822
# Parameters: [1.05952031e-01 1.00000000e-06 3.75976481e-01 1.05851226e-06
#  3.78804313e-01 4.52180815e-02 4.36536055e-02] | SSR: 0.05375704685618074
# Parameters: [1.06009131e-01 1.00000000e-06 3.76293696e-01 1.16090116e-06
#  3.78585057e-01 4.51732510e-02 4.36457836e-02] | SSR: 0.0537571019668643
# Parameters: [1.05913079e-01 1.00000000e-06 3.76454204e-01 1.02424753e-06
#  3.78255893e-01 4.51200824e-02 4.36583797e-02] | SSR: 0.05375708894956544
# Parameters: [1.05868047e-01 1.00000000e-06 3.76034058e-01 1.12921121e-06
#  3.78662242e-01 4.51875727e-02 4.36335719e-02] | SSR: 0.053757079876744905
# Parameters: [1.05840514e-01 1.00000000e-06 3.76262016e-01 1.00000000e-06
#  3.78253769e-01 4.51335829e-02 4.36485313e-02] | SSR: 0.05375727546853888
# Parameters: [1.05966977e-01 1.00000000e-06 3.76285776e-01 1.11904656e-06
#  3.78502235e-01 4.51633340e-02 4.36464705e-02] | SSR: 0.053756947886948986
# Parameters: [1.05951965e-01 1.00000000e-06 3.76053385e-01 1.15722186e-06
#  3.78653316e-01 4.51991091e-02 4.36325325e-02] | SSR: 0.053757216440030106
# Parameters: [1.05922801e-01 1.00000000e-06 3.76353999e-01 1.05749111e-06
#  3.78355249e-01 4.51398390e-02 4.36519179e-02] | SSR: 0.053756947884925924
# Parameters: [1.05985561e-01 1.00000000e-06 3.76096664e-01 1.11663356e-06
#  3.78830538e-01 4.52135418e-02 4.36647768e-02] | SSR: 0.053757455532943914
# Parameters: [1.05913223e-01 1.00000000e-06 3.76322873e-01 1.07656114e-06
#  3.78312734e-01 4.51383209e-02 4.36400928e-02] | SSR: 0.05375692898021095
# Parameters: [1.06019531e-01 1.00000000e-06 3.76543400e-01 1.03558314e-06
#  3.78208569e-01 4.51251445e-02 4.36649329e-02] | SSR: 0.05375713750799396
# Parameters: [1.05905918e-01 1.00000000e-06 3.76161393e-01 1.10580419e-06
#  3.78548824e-01 4.51719656e-02 4.36414121e-02] | SSR: 0.053756958384026325
# Parameters: [1.05893006e-01 1.00000000e-06 3.76045201e-01 1.00269010e-06
#  3.78662347e-01 4.51942358e-02 4.36475727e-02] | SSR: 0.05375683274256234
# Parameters: [1.05852073e-01 1.00000000e-06 3.75842881e-01 1.00000000e-06
#  3.78851471e-01 4.52261702e-02 4.36469508e-02] | SSR: 0.053757045961454725
# Parameters: [1.05868368e-01 1.00000000e-06 3.76061298e-01 1.14442468e-06
#  3.78638150e-01 4.51827920e-02 4.36283593e-02] | SSR: 0.05375714150804932
# Parameters: [1.05948973e-01 1.00000000e-06 3.76275877e-01 1.04113867e-06
#  3.78449768e-01 4.51607934e-02 4.36547027e-02] | SSR: 0.05375692688560117
# Parameters: [1.05891304e-01 1.00000000e-06 3.76517762e-01 1.08765853e-06
#  3.78119513e-01 4.51018030e-02 4.36385511e-02] | SSR: 0.05375708685587095
# Parameters: [1.05936850e-01 1.00000000e-06 3.76111801e-01 1.06579883e-06
#  3.78633113e-01 4.51890119e-02 4.36498419e-02] | SSR: 0.05375692878583425
# Parameters: [1.05952864e-01 1.00000000e-06 3.76160105e-01 1.02499987e-06
#  3.78587557e-01 4.51796072e-02 4.36544807e-02] | SSR: 0.053756849052555775
# Parameters: [1.05961137e-01 1.00000000e-06 3.76283073e-01 1.00497475e-06
#  3.78452034e-01 4.51609322e-02 4.36571820e-02] | SSR: 0.05375685762882537
# Parameters: [1.05898410e-01 1.00000000e-06 3.76157918e-01 1.00000000e-06
#  3.78484280e-01 4.51688776e-02 4.36551840e-02] | SSR: 0.05375701855353995
# Parameters: [1.05949835e-01 1.00000000e-06 3.76253811e-01 1.07907003e-06
#  3.78497746e-01 4.51647199e-02 4.36486489e-02] | SSR: 0.053756886232005446
# Parameters: [1.05950310e-01 1.00000000e-06 3.76061069e-01 1.02686129e-06
#  3.78671980e-01 4.51994813e-02 4.36488026e-02] | SSR: 0.053756858873891714
# Parameters: [1.05970485e-01 1.00000000e-06 3.76017396e-01 1.00000000e-06
#  3.78817136e-01 4.52184738e-02 4.36631161e-02] | SSR: 0.053757105420624625
# Parameters: [1.05927538e-01 1.00000000e-06 3.76246503e-01 1.05581868e-06
#  3.78438835e-01 4.51583592e-02 4.36458487e-02] | SSR: 0.053756854523891985
# Parameters: [1.05944197e-01 1.00000000e-06 3.76266954e-01 1.00150214e-06
#  3.78441249e-01 4.51590249e-02 4.36522261e-02] | SSR: 0.05375676718821767
# Parameters: [1.05947871e-01 1.00000000e-06 3.76344530e-01 1.00000000e-06
#  3.78345317e-01 4.51440314e-02 4.36534182e-02] | SSR: 0.05375679275195216
# Parameters: [1.05930709e-01 1.00000000e-06 3.76100329e-01 1.01483757e-06
#  3.78622159e-01 4.51867381e-02 4.36466577e-02] | SSR: 0.05375673903086374
# Parameters: [1.05921577e-01 1.00000000e-06 3.76012555e-01 1.00168702e-06
#  3.78708355e-01 4.51997104e-02 4.36426352e-02] | SSR: 0.05375668529453952
# Parameters: [1.05921773e-01 1.00000000e-06 3.76053463e-01 1.00000000e-06
#  3.78634356e-01 4.51928090e-02 4.36509934e-02] | SSR: 0.05375685265864298
# Parameters: [1.05913145e-01 1.00000000e-06 3.76244032e-01 1.00000000e-06
#  3.78449372e-01 4.51561411e-02 4.36514656e-02] | SSR: 0.05375678991314703
# Parameters: [1.05888605e-01 1.00000000e-06 3.76010874e-01 1.01979606e-06
#  3.78668558e-01 4.51933214e-02 4.36414530e-02] | SSR: 0.053756791530425126
# Parameters: [1.05911081e-01 1.00000000e-06 3.75980121e-01 1.00000000e-06
#  3.78747392e-01 4.52058837e-02 4.36515304e-02] | SSR: 0.053756838385600886
# Parameters: [1.05913791e-01 1.00000000e-06 3.76152206e-01 1.01447862e-06
#  3.78584167e-01 4.51751695e-02 4.36465391e-02] | SSR: 0.053756723572665165
# Parameters: [1.05871536e-01 1.00000000e-06 3.76043306e-01 1.00000000e-06
#  3.78629998e-01 4.51871033e-02 4.36407828e-02] | SSR: 0.053756781191447306
# Parameters: [1.05902021e-01 1.00000000e-06 3.76241344e-01 1.01147255e-06
#  3.78436621e-01 4.51554610e-02 4.36406623e-02] | SSR: 0.05375672333038393
# Parameters: [1.05922672e-01 1.00000000e-06 3.76232304e-01 1.01129173e-06
#  3.78457173e-01 4.51560304e-02 4.36426456e-02] | SSR: 0.053756666281536136
# Parameters: [1.05937505e-01 1.00000000e-06 3.76325856e-01 1.01559255e-06
#  3.78354585e-01 4.51369278e-02 4.36401821e-02] | SSR: 0.05375665999231769
# Parameters: [1.05941044e-01 1.00000000e-06 3.76356627e-01 1.00000000e-06
#  3.78361256e-01 4.51408323e-02 4.36484022e-02] | SSR: 0.053756679956630214
# Parameters: [1.05924476e-01 1.00000000e-06 3.76155639e-01 1.01278082e-06
#  3.78555265e-01 4.51736386e-02 4.36375143e-02] | SSR: 0.05375665262356912
# Parameters: [1.05930141e-01 1.00000000e-06 3.76111442e-01 1.01917124e-06
#  3.78608212e-01 4.51823874e-02 4.36305387e-02] | SSR: 0.05375670324724749
# Parameters: [1.05981210e-01 1.00000000e-06 3.76388459e-01 1.01643249e-06
#  3.78353288e-01 4.51388294e-02 4.36472633e-02] | SSR: 0.053756669041030866
# Parameters: [1.05919124e-01 1.00000000e-06 3.76199528e-01 1.01919617e-06
#  3.78516905e-01 4.51611377e-02 4.36344020e-02] | SSR: 0.05375666981422576
# Parameters: [1.05951053e-01 1.00000000e-06 3.76327796e-01 1.00756755e-06
#  3.78354769e-01 4.51409840e-02 4.36366213e-02] | SSR: 0.0537566205921702
# Parameters: [1.05969684e-01 1.00000000e-06 3.76415592e-01 1.00411201e-06
#  3.78240069e-01 4.51238913e-02 4.36316624e-02] | SSR: 0.05375666402608705
# Parameters: [1.05976833e-01 1.00000000e-06 3.76263358e-01 1.00945790e-06
#  3.78478928e-01 4.51565562e-02 4.36413435e-02] | SSR: 0.053756612020306536
# Parameters: [1.06014239e-01 1.00000000e-06 3.76274365e-01 1.00845058e-06
#  3.78500082e-01 4.51571038e-02 4.36416841e-02] | SSR: 0.05375667738886096
# Parameters: [1.05973065e-01 1.00000000e-06 3.76563807e-01 1.02146369e-06
#  3.78141644e-01 4.50999770e-02 4.36390016e-02] | SSR: 0.05375674998816714
# Parameters: [1.05934449e-01 1.00000000e-06 3.76150368e-01 1.00663119e-06
#  3.78566677e-01 4.51747771e-02 4.36417268e-02] | SSR: 0.05375663063194472
# Parameters: [1.05951713e-01 1.00000000e-06 3.76160803e-01 1.02504533e-06
#  3.78547435e-01 4.51685536e-02 4.36313273e-02] | SSR: 0.05375668434309984
# Parameters: [1.05943711e-01 1.00000000e-06 3.76307671e-01 1.00626133e-06
#  3.78407801e-01 4.51477626e-02 4.36441335e-02] | SSR: 0.053756634961059195
# Parameters: [1.05980658e-01 1.00000000e-06 3.76348800e-01 1.00215350e-06
#  3.78360613e-01 4.51444268e-02 4.36481079e-02] | SSR: 0.053756644236874276
# Parameters: [1.05918415e-01 1.00000000e-06 3.76148537e-01 1.00083747e-06
#  3.78526323e-01 4.51683343e-02 4.36354880e-02] | SSR: 0.05375662550976727
# Parameters: [1.05956664e-01 1.00000000e-06 3.76160478e-01 1.00000000e-06
#  3.78574094e-01 4.51792093e-02 4.36412280e-02] | SSR: 0.05375661534980856
# Parameters: [1.05978891e-01 1.00000000e-06 3.76332078e-01 1.00000000e-06
#  3.78378793e-01 4.51440900e-02 4.36449568e-02] | SSR: 0.05375659905771289
# Parameters: [1.06006099e-01 1.00000000e-06 3.76420297e-01 1.00000000e-06
#  3.78290558e-01 4.51293157e-02 4.36486780e-02] | SSR: 0.05375664597869215
# Parameters: [1.05922204e-01 1.00000000e-06 3.76134139e-01 1.00663377e-06
#  3.78578640e-01 4.51732056e-02 4.36334629e-02] | SSR: 0.05375663121389204
# Parameters: [1.05953005e-01 1.00000000e-06 3.76125688e-01 1.00263235e-06
#  3.78580263e-01 4.51771393e-02 4.36343886e-02] | SSR: 0.05375660858629992
# Parameters: [1.05983313e-01 1.00000000e-06 3.76296805e-01 1.00111665e-06
#  3.78409888e-01 4.51528202e-02 4.36453236e-02] | SSR: 0.05375661419948431
# Parameters: [1.05985030e-01 1.00000000e-06 3.76322416e-01 1.00000000e-06
#  3.78377054e-01 4.51449753e-02 4.36380874e-02] | SSR: 0.053756583777970594
# Parameters: [1.06010321e-01 1.00000000e-06 3.76408440e-01 1.00000000e-06
#  3.78282242e-01 4.51300744e-02 4.36362678e-02] | SSR: 0.05375661962695737
# Parameters: [1.06020097e-01 1.00000000e-06 3.76373925e-01 1.00509809e-06
#  3.78374759e-01 4.51447440e-02 4.36450690e-02] | SSR: 0.05375663263435726
# Parameters: [1.05943835e-01 1.00000000e-06 3.76204884e-01 1.00190262e-06
#  3.78488432e-01 4.51624368e-02 4.36378832e-02] | SSR: 0.05375659577744099
# Parameters: [1.05985396e-01 1.00000000e-06 3.76159548e-01 1.00000000e-06
#  3.78584504e-01 4.51782237e-02 4.36442962e-02] | SSR: 0.05375661307523186
# Parameters: [1.05987994e-01 1.00000000e-06 3.76326601e-01 1.00431701e-06
#  3.78368153e-01 4.51397168e-02 4.36405661e-02] | SSR: 0.05375660239648415
# Parameters: [1.05962682e-01 1.00000000e-06 3.76198788e-01 1.00411475e-06
#  3.78520434e-01 4.51623621e-02 4.36351112e-02] | SSR: 0.05375660582588449
# Parameters: [1.05954110e-01 1.00000000e-06 3.76347255e-01 1.00640703e-06
#  3.78327513e-01 4.51324268e-02 4.36335144e-02] | SSR: 0.05375664093304501
# Parameters: [1.05977574e-01 1.00000000e-06 3.76206475e-01 1.00160176e-06
#  3.78520256e-01 4.51667744e-02 4.36416007e-02] | SSR: 0.05375658814338591
# Parameters: [1.05962885e-01 1.00000000e-06 3.76227193e-01 1.00000000e-06
#  3.78444896e-01 4.51570137e-02 4.36365405e-02] | SSR: 0.053756589840834985
# Parameters: [1.05989535e-01 1.00000000e-06 3.76393865e-01 1.00077798e-06
#  3.78304885e-01 4.51306805e-02 4.36441103e-02] | SSR: 0.053756608348383424
# Parameters: [1.05980403e-01 1.00000000e-06 3.76326821e-01 1.00124157e-06
#  3.78373730e-01 4.51422952e-02 4.36416798e-02] | SSR: 0.0537565872513647
# Parameters: [1.05984921e-01 1.00000000e-06 3.76357346e-01 1.00000000e-06
#  3.78322799e-01 4.51397242e-02 4.36452644e-02] | SSR: 0.053756619955327815
# Parameters: [1.05968242e-01 1.00000000e-06 3.76238427e-01 1.00270473e-06
#  3.78471025e-01 4.51567027e-02 4.36376495e-02] | SSR: 0.05375658572870099
# Parameters: [1.05953966e-01 1.00000000e-06 3.76204340e-01 1.00000000e-06
#  3.78504472e-01 4.51672227e-02 4.36389762e-02] | SSR: 0.05375659677159144
# Parameters: [1.05955948e-01 1.00000000e-06 3.76162366e-01 1.00212877e-06
#  3.78529740e-01 4.51694588e-02 4.36328767e-02] | SSR: 0.05375661373911039
# Parameters: [1.05973155e-01 1.00000000e-06 3.76289650e-01 1.00053219e-06
#  3.78416530e-01 4.51504322e-02 4.36419368e-02] | SSR: 0.05375658304457527
# Parameters: [1.05986355e-01 1.00000000e-06 3.76314478e-01 1.00228082e-06
#  3.78378935e-01 4.51415289e-02 4.36397032e-02] | SSR: 0.05375659430010804
# Parameters: [1.06008634e-01 1.00000000e-06 3.76345247e-01 1.00048625e-06
#  3.78363689e-01 4.51403411e-02 4.36413162e-02] | SSR: 0.05375660286621249
# Parameters: [1.05960035e-01 1.00000000e-06 3.76239975e-01 1.00154853e-06
#  3.78457247e-01 4.51569128e-02 4.36387415e-02] | SSR: 0.05375658289536545
# Optimization successful: True
# Number of iterations: 449
#
# Optimized parameters:
# beta: 0.105960
# gamma: 0.000001
# rho: 0.376240
# delta: 0.000001
# p: 0.378457
# c: 0.045157
# alpha: 0.043639
# guess =  [np.float64(0.10596003501831482), np.float64(1.0000000000000362e-06), np.float64(0.3762399749381312), np.float64(1.0015485304252352e-06), np.float64(0.3784572466801883), np.float64(0.04515691284385312), np.float64(0.04363874146780221)]

# %%
# Calculate final SSR
final_ssr = result.fun
print(f"\nFinal SSR: {final_ssr:.6f}")

# Generate 95% confidence intervals for model predictions using bootstrap parameters
try:
    # Load bootstrap parameters if available
    bootstrap_params = np.loadtxt(f"{output_prefix}_params.txt", delimiter=",")
    
    # Generate model predictions for each bootstrap parameter set
    V_bootstrap = []
    F_bootstrap = []
    
    # Use a subset of bootstrap samples for speed (every 10th sample)
    n_samples = min(100, len(bootstrap_params))
    sample_indices = np.linspace(0, len(bootstrap_params)-1, n_samples, dtype=int)
    
    for idx in sample_indices:
        params = bootstrap_params[idx]
        try:
            solution = odeint(Model, y0, t, args=tuple(params))
            _, _, _, V_boot, F_boot = solution.T
            V_bootstrap.append(V_boot)
            F_bootstrap.append(F_boot)
        except:
            continue
    
    # Calculate 95% confidence intervals
    if len(V_bootstrap) > 10:
        V_bootstrap = np.array(V_bootstrap)
        F_bootstrap = np.array(F_bootstrap)
        
        V_ci_lower = np.percentile(V_bootstrap, 2.5, axis=0)
        V_ci_upper = np.percentile(V_bootstrap, 97.5, axis=0)
        F_ci_lower = np.percentile(F_bootstrap, 2.5, axis=0)
        F_ci_upper = np.percentile(F_bootstrap, 97.5, axis=0)
        
        print(f"Generated 95% CI from {len(V_bootstrap)} bootstrap samples")
        ci_available = True
    else:
        print("Insufficient bootstrap samples for CI calculation")
        ci_available = False
        
except:
    print("Bootstrap data not available for CI calculation")
    ci_available = False

# Plot results with 95% confidence intervals
plt.figure(figsize=(12, 5))

# Plot viral load
plt.subplot(121)
if ci_available:
    plt.fill_between(t, V_ci_lower, V_ci_upper, alpha=0.3, color='blue', label='95% CI')
plt.plot(t, V_fit, 'b-', label='Model', linewidth=2)
plt.plot(vl_data['time'], vl_data['value'], 'bo', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('Viral Load (log10)')
plt.legend()
plt.title('Viral Load Fit')

# Plot interferon
plt.subplot(122)
if ci_available:
    plt.fill_between(t, F_ci_lower, F_ci_upper, alpha=0.3, color='red', label='95% CI')
plt.plot(t, F_fit, 'r-', label='Model', linewidth=2)
plt.plot(t1_data['time'], t1_data['value'], 'ro', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('IFN-A2 Level')
plt.legend()
plt.title('Interferon Fit')

plt.tight_layout()
plt.savefig("tracheal_fit_h5n1_2022_with_ci.png")
plt.show()
# Out:
# Final SSR: 0.053757
# Bootstrap data not available for CI calculation

# %%
# %% Bootstrap Analysis
import os

# Create output directory
strain = "h5n1(2022)"  # Change for each file
location = "tracheal"     # Change for each file
output_dir = f"/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/{strain}/{location}/bootstrap_results"
os.makedirs(output_dir, exist_ok=True)
output_prefix = f"{output_dir}/{strain}_{location}"

# Calculate residuals between data and best-fit model
# Find indices for data_times in t
indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
V_best = V_fit[indices]
F_best = F_fit[indices]

# Calculate residuals (use for bootstrapping)
residuals_viral = vl_data['value'] - V_best
residuals_ifn = t1_data['value'] - F_best

# Use best-fit parameters from previous optimization
best_params = [beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit]

# Define bootstrap optimization function that uses relative error
def optimize_bootstrap(params, new_viral_data, new_ifn_data):
    """
    Objective function for bootstrap optimization.
    Uses relative error just like the original optimize function.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        V_pred = V[indices]
        F_pred = F[indices]
        
        # Calculate relative SSR (same method as in original optimize function)
        vl_ssr = np.sum((((np.maximum(V_pred, 0)) - new_viral_data)/new_viral_data)**2)
        ifn_ssr = np.sum(((F_pred - new_ifn_data)/new_ifn_data)**2)
        
        total_ssr = vl_ssr + ifn_ssr
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

# Number of bootstrap samples
n_bootstrap = 1000

# Initialize arrays for bootstrap results
bootstrap_params = []
bootstrap_ssr = []

print(f"Starting bootstrap analysis with {n_bootstrap} samples")
print(f"Using best-fit parameters: {best_params}")

# Run bootstrap
for i in range(n_bootstrap):
    # Generate new datasets by resampling residuals
    new_viral_data = V_best + np.random.choice(residuals_viral, size=len(residuals_viral), replace=True)
    new_ifn_data = F_best + np.random.choice(residuals_ifn, size=len(residuals_ifn), replace=True)
    
    # Ensure non-negative values
    new_viral_data = np.maximum(new_viral_data, 1e-6)  # Using small positive number instead of zero for relative error
    new_ifn_data = np.maximum(new_ifn_data, 1e-6)
    
    # Optimize with new dataset
    result_bootstrap = minimize(
        optimize_bootstrap, 
        best_params, 
        args=(new_viral_data, new_ifn_data), 
        method='Nelder-Mead', 
        bounds=bounds
    )
    
    bootstrap_params.append(result_bootstrap.x)
    bootstrap_ssr.append(result_bootstrap.fun)
    
    if (i+1) % 10 == 0 or i == 0:
        print(f"Processing bootstrap sample {i+1}/{n_bootstrap}")

# Save bootstrap parameters and SSR to text files
np.savetxt(f"{output_prefix}_params.txt", np.array(bootstrap_params), delimiter=",")
np.savetxt(f"{output_prefix}_ssr.txt", np.array(bootstrap_ssr), delimiter=",")

# Calculate and print statistics
print(f"\nBootstrap Statistics:")
print(f"Mean SSR: {np.mean(bootstrap_ssr)}")
print(f"Median SSR: {np.median(bootstrap_ssr)}")
print(f"Standard Deviation of SSR: {np.std(bootstrap_ssr)}")

# Calculate parameter statistics
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
param_stats = {}

# Create a results summary file
with open(f"{output_prefix}_summary.txt", "w") as f:
    f.write(f"Bootstrap Results Summary for {strain} {location}\n")
    f.write(f"Number of bootstrap samples: {n_bootstrap}\n\n")
    f.write(f"SSR Statistics:\n")
    f.write(f"Mean: {np.mean(bootstrap_ssr):.6f}\n")
    f.write(f"Median: {np.median(bootstrap_ssr):.6f}\n")
    f.write(f"Std Dev: {np.std(bootstrap_ssr):.6f}\n\n")
    
    f.write(f"Parameter Statistics:\n")
    for i, name in enumerate(param_names):
        param_values = np.array(bootstrap_params)[:, i]
        mean_val = np.mean(param_values)
        median_val = np.median(param_values)
        ci_low = np.percentile(param_values, 2.5)
        ci_high = np.percentile(param_values, 97.5)
        
        param_stats[name] = {
            'mean': mean_val,
            'median': median_val,
            'ci_low': ci_low,
            'ci_high': ci_high
        }
        
        f.write(f"{name}:\n")
        f.write(f"  Mean: {mean_val:.6f}\n")
        f.write(f"  Median: {median_val:.6f}\n")
        f.write(f"  95% CI: [{ci_low:.6f}, {ci_high:.6f}]\n\n")

print(f"Bootstrap analysis complete. Results saved to {output_dir}")
# Out:
# Starting bootstrap analysis with 1000 samples
# Using best-fit parameters: [np.float64(0.10596003501831482), np.float64(1.0000000000000362e-06), np.float64(0.3762399749381312), np.float64(1.0015485304252352e-06), np.float64(0.3784572466801883), np.float64(0.04515691284385312), np.float64(0.04363874146780221)]
# Processing bootstrap sample 1/1000
# Processing bootstrap sample 10/1000
# Processing bootstrap sample 20/1000
# Processing bootstrap sample 30/1000
# Processing bootstrap sample 40/1000
# Processing bootstrap sample 50/1000
# Processing bootstrap sample 60/1000
# Processing bootstrap sample 70/1000
# Processing bootstrap sample 80/1000
# Processing bootstrap sample 90/1000
# Processing bootstrap sample 100/1000
# Processing bootstrap sample 110/1000
# Processing bootstrap sample 120/1000
# Processing bootstrap sample 130/1000
# Processing bootstrap sample 140/1000
# Processing bootstrap sample 150/1000
# Processing bootstrap sample 160/1000
# Processing bootstrap sample 170/1000
# Processing bootstrap sample 180/1000
# Processing bootstrap sample 190/1000
# Processing bootstrap sample 200/1000
# Processing bootstrap sample 210/1000
# Processing bootstrap sample 220/1000
# Processing bootstrap sample 230/1000
# Processing bootstrap sample 240/1000
# Processing bootstrap sample 250/1000
# Processing bootstrap sample 260/1000
# Processing bootstrap sample 270/1000
# Processing bootstrap sample 280/1000
# Processing bootstrap sample 290/1000
# Processing bootstrap sample 300/1000
# Processing bootstrap sample 310/1000
# Processing bootstrap sample 320/1000
# Processing bootstrap sample 330/1000
# Processing bootstrap sample 340/1000
# Processing bootstrap sample 350/1000
# Processing bootstrap sample 360/1000
# Processing bootstrap sample 370/1000
# Processing bootstrap sample 380/1000
# Processing bootstrap sample 390/1000
# Processing bootstrap sample 400/1000
# Processing bootstrap sample 410/1000
# Processing bootstrap sample 420/1000
# Processing bootstrap sample 430/1000
# Processing bootstrap sample 440/1000
# Processing bootstrap sample 450/1000
# Processing bootstrap sample 460/1000
# Processing bootstrap sample 470/1000
# Processing bootstrap sample 480/1000
# Processing bootstrap sample 490/1000
# Processing bootstrap sample 500/1000
# Processing bootstrap sample 510/1000
# Processing bootstrap sample 520/1000
# Processing bootstrap sample 530/1000
# Processing bootstrap sample 540/1000
# Processing bootstrap sample 550/1000
# Processing bootstrap sample 560/1000
# Processing bootstrap sample 570/1000
# Processing bootstrap sample 580/1000
# Processing bootstrap sample 590/1000
# Processing bootstrap sample 600/1000
# Processing bootstrap sample 610/1000
# Processing bootstrap sample 620/1000
# Processing bootstrap sample 630/1000
# Processing bootstrap sample 640/1000
# Processing bootstrap sample 650/1000
# Processing bootstrap sample 660/1000
# Processing bootstrap sample 670/1000
# Processing bootstrap sample 680/1000
# Processing bootstrap sample 690/1000
# Processing bootstrap sample 700/1000
# Processing bootstrap sample 710/1000
# Processing bootstrap sample 720/1000
# Processing bootstrap sample 730/1000
# Processing bootstrap sample 740/1000
# Processing bootstrap sample 750/1000
# Processing bootstrap sample 760/1000
# Processing bootstrap sample 770/1000
# Processing bootstrap sample 780/1000
# Processing bootstrap sample 790/1000
# Processing bootstrap sample 800/1000
# Processing bootstrap sample 810/1000
# Processing bootstrap sample 820/1000
# Processing bootstrap sample 830/1000
# Processing bootstrap sample 840/1000
# Processing bootstrap sample 850/1000
# Processing bootstrap sample 860/1000
# Processing bootstrap sample 870/1000
# Processing bootstrap sample 880/1000
# Processing bootstrap sample 890/1000
# Processing bootstrap sample 900/1000
# Processing bootstrap sample 910/1000
# Processing bootstrap sample 920/1000
# Processing bootstrap sample 930/1000
# Processing bootstrap sample 940/1000
# Processing bootstrap sample 950/1000
# Processing bootstrap sample 960/1000
# Processing bootstrap sample 970/1000
# Processing bootstrap sample 980/1000
# Processing bootstrap sample 990/1000
# Processing bootstrap sample 1000/1000
#
# Bootstrap Statistics:
# Mean SSR: 900494825628.3481
# Median SSR: 0.12588083658555693
# Standard Deviation of SSR: 1818050243590.7908
# Bootstrap analysis complete. Results saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h5n1(2022)/tracheal/bootstrap_results

# %%
# %% Parameter Distribution Plotting
# Log ALL parameters for consistent, nice-looking bootstrap charts
fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.flatten()

# Convert bootstrap_params to numpy array for easier indexing
bootstrap_params = np.array(bootstrap_params)

for i, name in enumerate(param_names):
    if i < len(axes):
        ax = axes[i]
        param_values = bootstrap_params[:, i]
        
        # Log ALL parameters - show only 5-95 percentile
        log_values = np.log10(np.maximum(param_values, 1e-12))
        p5, p95 = np.percentile(log_values, [5, 95])
        filtered_log_values = log_values[(log_values >= p5) & (log_values <= p95)]
        n_bins = min(30, max(10, len(filtered_log_values)//30))
        
        ax.hist(filtered_log_values, bins=n_bins, alpha=0.7, color='skyblue', edgecolor='black', linewidth=0.5)
        
        # Add reference lines
        ax.axvline(np.log10(best_params[i]), color='r', linestyle='--', linewidth=2, label='Best fit')
        ax.axvline(np.log10(param_stats[name]['mean']), color='g', linestyle='-', linewidth=2, label='Bootstrap mean')
        ax.axvline(np.log10(param_stats[name]['ci_low']), color='k', linestyle=':', linewidth=1.5, label='95% CI')
        ax.axvline(np.log10(param_stats[name]['ci_high']), color='k', linestyle=':', linewidth=1.5)
        
        ax.set_xlabel(f'log₁₀({name})', fontsize=12)
        ax.set_title(f'{name} (n={len(filtered_log_values)}, log scale, 5-95%)', fontsize=14)
        ax.set_ylabel('Frequency', fontsize=12)
        ax.tick_params(labelsize=10)
        
        if i == 0:  # Only add legend to first plot
            ax.legend(fontsize=10, loc='upper right')

# Remove empty subplots
for i in range(len(param_names), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
plt.close()

print(f"Parameter distribution plots saved to {output_prefix}_param_distributions.png")
print("All parameters plotted on log scale with 5-95 percentile range")
# Out:
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_37573/4098012820.py:40: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_37573/4098012820.py:40: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_37573/4098012820.py:41: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_37573/4098012820.py:41: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# Parameter distribution plots saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h5n1(2022)/tracheal/bootstrap_results/h5n1(2022)_tracheal_param_distributions.png
# All parameters plotted on log scale with 5-95 percentile range
