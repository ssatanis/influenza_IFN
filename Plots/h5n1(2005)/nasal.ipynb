# %%
# Standard scientific libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.optimize import minimize

# Set plotting style for better visualization
plt.style.use("seaborn-v0_8")

# %%
vl_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/nasal_data/h5n1(2005)/nasal_h5n1_2005_vl.txt"
t1_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/nasal_data/h5n1(2005)/nasal_h5n1_2005_t1.txt"

# Load the viral load data
vl_data = pd.read_csv(vl_path)
print("Viral Load Data:")
print(vl_data, "\n")

# Load the interferon data
t1_data = pd.read_csv(t1_path)
print("Interferon Data:")
print(t1_data)

# Let's also create a simple plot to visualize our data
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot viral load data
ax1.plot(vl_data['time'], vl_data['value'], 'o-', color='blue', label='Viral Load')
ax1.set_xlabel('Time (hours)')
ax1.set_ylabel('Viral Load (log scale)')
ax1.set_title('H5N1 Nasal Viral Load')
ax1.legend()

# Plot interferon data
ax2.plot(t1_data['time'], t1_data['value'], 'o-', color='red', label='IFN-A2')
ax2.set_xlabel('Time (hours)')
ax2.set_ylabel('IFN-A2 Level')
ax2.set_title('H5N1 Nasal Interferon')
ax2.legend()

plt.tight_layout()
plt.savefig('nasal_h5n1_2005.png')
plt.show()
# Out:
# Viral Load Data:
#    time  value
# 0     0  2.652
# 1     8  2.951
# 2    24  4.120
# 3    48  4.256
# 4    72  3.128
#
# Interferon Data:
#    time   value
# 0     0   2.188
# 1     8   7.098
# 2    24  12.054
# 3    48  12.411
# 4    72  11.563

# %%
def Model(y, t, beta, gamma, rho, delta, p, c, alpha):
    """
    Extended model with resistant cell class
    
    Parameters:
    y: list of variables [T, R, I, V, F]
    t: time points
    beta: infection rate
    gamma: rate of conversion to resistant state
    rho: rate of return from resistant state
    delta: death rate of infected cells
    p: virus production rate
    c: virus clearance rate
    alpha: interferon clearance rate
    """
    T, R, I, V, F = y
    
    # System of ODEs
    dTdt = -beta * T * V - gamma * T * F    # Target cells
    dRdt = gamma * T * F - rho * R          # Resistant cells
    dIdt = beta * T * V - delta * I         # Infected cells
    dVdt = p * I - c * V                    # Virus
    dFdt = I - alpha * F                    # Interferon
    
    return [dTdt, dRdt, dIdt, dVdt, dFdt]

# Initial conditions
T0 = 1.0     # Initial target cells (normalized)
R0 = 0.0     # Initial resistant cells
I0 = 0.0     # Initial infected cells
V0 = vl_data['value'].iloc[0]    # Initial virus from data
F0 = t1_data['value'].iloc[0]    # Initial interferon from data
y0 = [T0, R0, I0, V0, F0]

print("Initial conditions:")
for var, val in zip(['T0', 'R0', 'I0', 'V0', 'F0'], y0):
    print(f"{var} = {val}")
# Out:
# Initial conditions:
# T0 = 1.0
# R0 = 0.0
# I0 = 0.0
# V0 = 2.652
# F0 = 2.188

# %%
# Create two sets of time points:
# 1. Data time points for comparison
data_times = np.array([0, 8, 24, 48, 72])

# 2. Integration time points (finer mesh for solving ODEs)
t = np.linspace(0, 72, 100)

def optimize(params):
    """
    Objective function to minimize.
    Uses relative error at actual data time points.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        # Find indices in t that correspond to data_times
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        global V_model, F_model
        V_model = V[indices]
        F_model = F[indices]
        
        # Calculate relative SSR
        vl_ssr = np.sum((((np.maximum(V_model, 0)) - vl_data['value'])/vl_data['value'])**2)
        ifn_ssr = np.sum(((F_model - t1_data['value'])/t1_data['value'])**2)
        
        total_ssr = vl_ssr + ifn_ssr
        
        print(f"Parameters: {params} | SSR: {total_ssr}")
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

print("Data time points:", data_times)
print("\nNumber of integration points:", len(t))
print("Integration time range:", t[0], "to", t[-1])
# Out:
# Data time points: [ 0  8 24 48 72]
#
# Number of integration points: 100
# Integration time range: 0.0 to 72.0

# %%
guess = [0.1, 0.1, 0.1, 0.1, 10.0, 0.1, 0.1]

# %%
bounds = [
    (1e-6, 10.0),   # beta
    (1e-6, 10.0),   # gamma
    (1e-6, 10.0),   # rho 
    (1e-6, 10.0),   # delta
    (1e-1, 1e7), #p
    (1e-6, 10.0),   # c
    (1e-6, 100.0)    # alpha
]

print("Initial parameter guesses:")
for param, value in zip(['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha'], guess):
    print(f"{param}: {value}")
# Out:
# Initial parameter guesses:
# beta: 0.1
# gamma: 0.1
# rho: 0.1
# delta: 0.1
# p: 10.0
# c: 0.1
# alpha: 0.1

# %%
# Perform optimization
result = minimize(optimize, guess, method ='Nelder-Mead', bounds=bounds)

# Extract optimized parameters
beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit = result.x

# Generate solution with optimized parameters
solution_fit = odeint(Model, y0, t, args=(beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit))
T_fit, R_fit, I_fit, V_fit, F_fit = solution_fit.T

# Print optimization results
print("Optimization successful:", result.success)
print("Number of iterations:", result.nit)
print("\nOptimized parameters:")
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
for name, value in zip(param_names, result.x):
    print(f"{name}: {value:.6f}")

print("guess = ", [i for i in result.x])
# Out:
# Parameters: [ 0.1  0.1  0.1  0.1 10.   0.1  0.1] | SSR: 60.914666426755545
# Parameters: [ 0.105  0.1    0.1    0.1   10.     0.1    0.1  ] | SSR: 63.11929113287982
# Parameters: [ 0.1    0.105  0.1    0.1   10.     0.1    0.1  ] | SSR: 58.68593792708351
# Parameters: [ 0.1    0.1    0.105  0.1   10.     0.1    0.1  ] | SSR: 60.914666426755545
# Parameters: [ 0.1    0.1    0.1    0.105 10.     0.1    0.1  ] | SSR: 58.134082546999146
# Parameters: [ 0.1  0.1  0.1  0.1 10.5  0.1  0.1] | SSR: 68.34582870895672
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.105  0.1  ] | SSR: 57.73005994578483
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.1    0.105] | SSR: 61.18858594875988
# Parameters: [0.10142857 0.10142857 0.10142857 0.10142857 9.5        0.10142857
#  0.10142857] | SSR: 52.52176272701608
# Parameters: [0.10214286 0.10214286 0.10214286 0.10214286 9.         0.10214286
#  0.10214286] | SSR: 45.666815157707276
# Parameters: [0.09561224 0.10204082 0.10204082 0.10204082 9.71428571 0.10204082
#  0.10204082] | SSR: 52.04958762796276
# Parameters: [0.0993586  0.10262391 0.10262391 0.10262391 9.63265306 0.10262391
#  0.09619534] | SSR: 51.44322890308958
# Parameters: [0.09917534 0.10337359 0.09694502 0.10337359 9.52769679 0.10337359
#  0.10010829] | SSR: 49.24274583398319
# Parameters: [0.09893973 0.10433748 0.10107217 0.10433748 9.39275302 0.10433748
#  0.10013923] | SSR: 46.32187782131714
# Parameters: [0.09863679 0.09914819 0.10137851 0.10557676 9.21925388 0.10557676
#  0.10017901] | SSR: 44.92890014257052
# Parameters: [0.09795519 0.09622228 0.10206776 0.10836514 8.82888082 0.10836514
#  0.10026851] | SSR: 39.24460298723879
# Parameters: [0.09805256 0.10306884 0.1019693  0.10153823 8.8846484  0.1079668
#  0.10025572] | SSR: 40.2752327236258
# Parameters: [0.09749615 0.10394565 0.10253195 0.10697772 8.56597652 0.10381445
#  0.10032879] | SSR: 36.43403853846151
# Parameters: [0.09624422 0.10591847 0.10379793 0.11046658 7.84896478 0.10322168
#  0.10049318] | SSR: 28.458612075851075
# Parameters: [0.10206447 0.10301273 0.10099317 0.10734426 8.31874197 0.10711103
#  0.09784579] | SSR: 34.20425800799312
# Parameters: [0.09909122 0.10254074 0.09994415 0.10810985 8.02497145 0.10780997
#  0.10416283] | SSR: 30.70504725635661
# Parameters: [0.09925044 0.10155309 0.10647993 0.10871337 7.70057762 0.10832782
#  0.10140832] | SSR: 27.863700318802312
# Parameters: [0.09928799 0.10064284 0.11124738 0.11138326 6.78701803 0.11080493
#  0.10205833] | SSR: 20.410805696848843
# Parameters: [0.09958556 0.0995336  0.10525998 0.10976257 7.09102568 0.10921178
#  0.1019257 ] | SSR: 23.2571883957466
# Parameters: [0.09565178 0.10098271 0.10507991 0.11413425 6.93835747 0.11342609
#  0.09986002] | SSR: 19.821189550958522
# Parameters: [0.09240624 0.10040264 0.10654843 0.12012995 5.9075362  0.11906771
#  0.0987186 ] | SSR: 12.972236278285983
# Parameters: [0.09812884 0.09929496 0.10656179 0.1200508  6.20310557 0.11077384
#  0.10130797] | SSR: 16.041648525381717
# Parameters: [0.09827582 0.10701943 0.10774734 0.11656266 5.50865165 0.1110637
#  0.10159218] | SSR: 12.440637076707437
# Parameters: [0.09843614 0.11241801 0.11058712 0.12066141 3.84853707 0.11241299
#  0.10225401] | SSR: 7.215780211128741
# Parameters: [0.09312987 0.1029162  0.11156306 0.12138843 4.74158911 0.11383266
#  0.10527439] | SSR: 9.300328232369232
# Parameters: [0.09439988 0.10349547 0.11593176 0.12441673 4.09725039 0.11485448
#  0.09927494] | SSR: 7.616870289126633
# Parameters: [0.09671992 0.09942544 0.11554479 0.12604575 3.20133867 0.12276643
#  0.10259652] | SSR: 6.228573158561563
# Parameters: [0.09695778 0.09617893 0.12141823 0.13383534 0.87752561 0.13253881
#  0.10364818] | SSR: 6.014543018245218
# Parameters: [0.09262779 0.10485184 0.11869938 0.13362769 2.18399203 0.1234412
#  0.10165614] | SSR: 5.62678193120335
# Parameters: [0.08914891 0.10751097 0.12541908 0.14556026 0.1        0.13055591
#  0.10152136] | SSR: 6.665868137803794
# Parameters: [0.09102245 0.10494517 0.11484112 0.13836255 1.1728494  0.12545841
#  0.10140859] | SSR: 5.8833198541107325
# Parameters: [0.09015121 0.1079074  0.12189224 0.13492694 0.3195458  0.12968509
#  0.1021877 ] | SSR: 6.4614531025880115
# Parameters: [0.09522951 0.10894393 0.12628954 0.13907551 0.1        0.12442475
#  0.10576824] | SSR: 6.619237519529069
# Parameters: [0.09510577 0.10815259 0.12548248 0.14287048 0.1        0.13268612
#  0.09935355] | SSR: 6.645465617424479
# Parameters: [0.09403744 0.10890392 0.12384256 0.14511468 0.1        0.13675905
#  0.10537547] | SSR: 6.705095350977361
# Parameters: [0.08874442 0.09897736 0.13297447 0.15585664 0.1        0.14615656
#  0.10328824] | SSR: 6.765629124708203
# Parameters: [0.09116735 0.10233752 0.12737763 0.14705784 0.1        0.13772067
#  0.10302968] | SSR: 6.701333058425564
# Parameters: [0.09232309 0.10061533 0.12072905 0.13195856 1.28683224 0.12208525
#  0.09949656] | SSR: 5.728494216339676
# Parameters: [0.09552339 0.10668967 0.11529438 0.12570133 1.62592717 0.11665637
#  0.10083288] | SSR: 5.551635747604537
# Parameters: [0.09770141 0.10886575 0.10925276 0.11502308 2.38889075 0.10612422
#  0.09973448] | SSR: 5.544464605665047
# Parameters: [0.09232658 0.10107837 0.11255247 0.12193229 2.27989595 0.1141018
#  0.10461784] | SSR: 5.554700492099477
# Parameters: [0.09137343 0.09803972 0.10782053 0.12082919 2.90272337 0.11941375
#  0.09787447] | SSR: 5.862974805271168
# Parameters: [0.09680095 0.09625692 0.10819734 0.12094983 3.4212283  0.11121875
#  0.10022266] | SSR: 6.744033226715375
# Parameters: [0.09181364 0.10499478 0.11846851 0.13143266 1.09496643 0.1250685
#  0.10169644] | SSR: 5.8710736678634365
# Parameters: [0.08852462 0.1105042  0.10782858 0.12135496 2.92537443 0.10623066
#  0.09820454] | SSR: 5.846352113143041
# Parameters: [0.09374629 0.10332625 0.1124021  0.11196843 3.13077209 0.10781741
#  0.09952869] | SSR: 6.218805451859529
# Parameters: [0.09170341 0.10454044 0.11423137 0.13176402 1.66233007 0.12104816
#  0.10093861] | SSR: 5.625495267329587
# Parameters: [0.0929236  0.10314684 0.10756409 0.11899299 3.37075896 0.10705865
#  0.09902432] | SSR: 6.528482518700054
# Parameters: [0.09209113 0.10453279 0.11574241 0.12832275 1.66391456 0.12056604
#  0.10102841] | SSR: 5.5948726724760025
# Parameters: [0.09356886 0.11195706 0.12047548 0.13173748 1.20905664 0.11304263
#  0.10374741] | SSR: 5.748287536951189
# Parameters: [0.09785888 0.09990768 0.12408083 0.13417815 0.69602906 0.128172
#  0.10500102] | SSR: 6.121443956123929
# Parameters: [0.09085819 0.10785507 0.11189164 0.12456075 2.36803809 0.11171599
#  0.09990366] | SSR: 5.564653518128171
# Parameters: [0.09204016 0.09728283 0.1089814  0.12174514 2.74348441 0.12098099
#  0.09835993] | SSR: 5.75300526655314
# Parameters: [0.09318669 0.1082885  0.11760196 0.12923939 1.59266359 0.11502722
#  0.10240054] | SSR: 5.59541570296852
# Parameters: [0.09353269 0.11081689 0.10783437 0.12074714 2.7530892  0.10992178
#  0.1034405 ] | SSR: 5.785191090941044
# Parameters: [0.09262549 0.10316572 0.11750538 0.12915571 1.65339648 0.11904438
#  0.10048254] | SSR: 5.5838349773957265
# Parameters: [0.09322732 0.10609863 0.1095229  0.1178003  1.70433068 0.1073096
#  0.1009456 ] | SSR: 5.410387400818628
# Parameters: [0.09352709 0.10672202 0.10493466 0.1098866  1.4645     0.09924381
#  0.10059032] | SSR: 5.305232941846421
# Parameters: [0.09467276 0.10703333 0.11133471 0.11341328 2.16946977 0.10347283
#  0.10156361] | SSR: 5.421904692093072
# Parameters: [0.09361407 0.10292666 0.10617348 0.11141617 2.40393802 0.10619252
#  0.09986256] | SSR: 5.516287580513849
# Parameters: [0.09514475 0.10622347 0.10529905 0.10750236 2.54412232 0.09654697
#  0.1009016 ] | SSR: 5.640342684656249
# Parameters: [0.09285454 0.10495546 0.11313157 0.12311765 1.8839665  0.11456127
#  0.10099671] | SSR: 5.490697236578974
# Parameters: [0.09467584 0.1081019  0.10228641 0.10494424 2.62051754 0.09678774
#  0.10159437] | SSR: 5.693967043196459
# Parameters: [0.09313807 0.10439976 0.11370064 0.12310284 1.89517675 0.11348022
#  0.1007605 ] | SSR: 5.481546011582909
# Parameters: [0.09709453 0.10242532 0.10841701 0.10912265 1.77077269 0.1046202
#  0.10241806] | SSR: 5.3019477319567985
# Parameters: [0.1002127  0.09971044 0.1066797  0.1014036  1.47213999 0.1010723
#  0.10367527] | SSR: 5.197000659329458
# Parameters: [0.09787931 0.10881118 0.10607825 0.10588578 1.62812741 0.09851167
#  0.09743457] | SSR: 5.212317083298303
# Parameters: [0.09255531 0.10100821 0.10847096 0.11018433 1.30177166 0.10431425
#  0.10166082] | SSR: 5.392033822876097
# Parameters: [0.09634016 0.10639917 0.11220666 0.11343928 0.97181972 0.1037093
#  0.10204652] | SSR: 5.594928552908456
# Parameters: [0.09429559 0.10379479 0.10768177 0.11192195 2.04590844 0.10557171
#  0.10040855] | SSR: 5.367326876200873
# Parameters: [0.09751142 0.10403875 0.10369149 0.09853903 1.53806036 0.0927721
#  0.10074434] | SSR: 5.085781880659641
# Parameters: [0.09983986 0.10358039 0.09897144 0.08624972 1.36510729 0.08187751
#  0.10061815] | SSR: 4.802255721497575
# Parameters: [0.09914268 0.10436034 0.09891407 0.08802437 1.3754017  0.0848238
#  0.10093987] | SSR: 4.870361092643347
# Parameters: [0.09888511 0.10096305 0.09773125 0.09045996 0.87423209 0.0895029
#  0.09995855] | SSR: 5.188086489544927
# Parameters: [0.10281107 0.10697528 0.09752652 0.08805338 1.61977603 0.08442967
#  0.09937498] | SSR: 4.876811974566694
# Parameters: [0.10350379 0.10509741 0.0954142  0.07949617 0.75388713 0.07713162
#  0.10033194] | SSR: 4.93550000149787
# Parameters: [0.10712278 0.101706   0.09544118 0.07284853 1.13226332 0.07714176
#  0.10007634] | SSR: 4.500629585699591
# Parameters: [0.11392062 0.099198   0.09069444 0.05432949 0.96614498 0.06609073
#  0.09981935] | SSR: 3.8169756133997934
# Parameters: [0.10735378 0.09687022 0.08990221 0.06211899 0.77949808 0.06861076
#  0.10391345] | SSR: 4.307099696226694
# Parameters: [0.1070607  0.10515947 0.08450719 0.055377   0.73758782 0.05677541
#  0.09774082] | SSR: 3.8741426843828095
# Parameters: [0.11072417 0.10510583 0.08967734 0.05629693 1.29645449 0.0589941
#  0.1008239 ] | SSR: 3.8749309483132297
# Parameters: [0.10816846 0.10097388 0.09035529 0.06063237 1.57181869 0.06618323
#  0.10059107] | SSR: 4.29589776754097
# Parameters: [0.11039186 0.09738133 0.08619405 0.04424058 0.6922277  0.05367192
#  0.10189548] | SSR: 3.3768536681528105
# Parameters: [0.11418226 0.09258436 0.08052782 0.02233419 0.22845353 0.03829304
#  0.10315573] | SSR: 2.897051561173497
# Parameters: [0.11835728 0.09663171 0.07955328 0.02550097 0.60890255 0.03998328
#  0.10096369] | SSR: 2.2865851052367403
# Parameters: [1.27964588e-01 9.27673920e-02 6.98728855e-02 1.00000000e-06
#  2.25652982e-01 1.75630237e-02 1.00975597e-01] | SSR: 2.1538682215349247
# Parameters: [0.12569574 0.09432223 0.07118204 0.00263313 0.29363859 0.02455401
#  0.10138754] | SSR: 1.9712305948954216
# Parameters: [1.38623674e-01 8.96931481e-02 5.72873339e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.01772230e-01] | SSR: 2.6970474382079006
# Parameters: [0.12342237 0.1003044  0.07490265 0.0097679  0.7404308  0.02523311
#  0.09737054] | SSR: 9.826153315888785
# Parameters: [0.11137093 0.09772876 0.08615232 0.04903122 0.76973126 0.05776635
#  0.10227773] | SSR: 3.595611014276487
# Parameters: [0.12352268 0.09527356 0.07324872 0.0079399  0.1        0.02525581
#  0.10117483] | SSR: 2.1277088866518596
# Parameters: [1.24623687e-01 8.83323877e-02 6.92327749e-02 1.00000000e-06
#  1.00000000e-01 2.28054362e-02 1.01042272e-01] | SSR: 1.317977662046605
# Parameters: [1.31573443e-01 7.99456649e-02 5.90104910e-02 1.00000000e-06
#  1.00000000e-01 4.71110420e-03 1.01151459e-01] | SSR: 1.6361236854957038
# Parameters: [1.33305157e-01 8.34710099e-02 7.00388046e-02 1.00000000e-06
#  1.00000000e-01 1.53184184e-02 1.05068626e-01] | SSR: 1.104923713387514
# Parameters: [1.46427385e-01 7.26267784e-02 6.28046101e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.08732532e-01] | SSR: 3.0388144556423478
# Parameters: [1.31983675e-01 8.49390594e-02 5.79499514e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.04489891e-01] | SSR: 2.7446237060412537
# Parameters: [1.40422723e-01 8.27540919e-02 5.44342500e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.02663556e-01] | SSR: 2.787893385712792
# Parameters: [1.45108669e-01 8.50898488e-02 5.26034403e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.01644926e-01] | SSR: 2.7766149273084366
# Parameters: [0.12020705 0.09558748 0.07817392 0.0030213  0.19122616 0.03014149
#  0.10184607] | SSR: 1.3898294708791545
# Parameters: [0.10840635 0.09625104 0.08731059 0.00388424 0.21729078 0.03875305
#  0.10292217] | SSR: 1.687788306883767
# Parameters: [0.11479497 0.09963382 0.09035283 0.00499373 0.25080243 0.04982507
#  0.09962928] | SSR: 1.8467573703768538
# Parameters: [0.11505131 0.09376733 0.08428131 0.00642023 0.13233501 0.04148077
#  0.10275891] | SSR: 2.4874643574783963
# Parameters: [0.12473627 0.09301738 0.07347499 0.00160581 0.20232349 0.02354246
#  0.10142143] | SSR: 1.2989578284808492
# Parameters: [1.19839950e-01 9.06165380e-02 8.09701256e-02 1.00000000e-06
#  2.87223271e-01 3.32984506e-02 1.02630132e-01] | SSR: 1.4015941891509494
# Parameters: [0.11599381 0.0905091  0.0858334  0.00122632 0.1        0.03649867
#  0.10277245] | SSR: 2.1019243770783005
# Parameters: [0.12327026 0.09336895 0.07484488 0.00228143 0.24316687 0.02754017
#  0.10173377] | SSR: 1.360161124602231
# Parameters: [1.29316095e-01 8.34075397e-02 6.22317673e-02 1.00000000e-06
#  1.32406304e-01 4.86049696e-03 1.05131993e-01] | SSR: 2.5656212708242756
# Parameters: [0.11842525 0.09557725 0.08332256 0.00326799 0.2212034  0.03858393
#  0.10100496] | SSR: 1.4775800338923222
# Parameters: [1.38567252e-01 8.65978130e-02 6.41345738e-02 1.00000000e-06
#  1.67035847e-01 1.58841898e-02 1.01291333e-01] | SSR: 1.455028732461052
# Parameters: [1.34303213e-01 8.47060459e-02 6.26403146e-02 1.00000000e-06
#  1.47646784e-01 9.56767884e-03 1.03290362e-01] | SSR: 1.964620992234932
# Parameters: [0.12239474 0.09285945 0.078152   0.00212775 0.20281425 0.03132986
#  0.10157631] | SSR: 1.277873252758177
# Parameters: [0.10954049 0.09547453 0.08583328 0.00258165 0.21203674 0.03668046
#  0.10308541] | SSR: 1.5374369249144026
# Parameters: [0.13131056 0.08881699 0.06955925 0.00064616 0.17828607 0.02108326
#  0.10173985] | SSR: 1.2280367352684283
# Parameters: [0.13154511 0.09094164 0.06573748 0.00276598 0.1        0.01577615
#  0.10149224] | SSR: 1.2860952022995127
# Parameters: [1.34417462e-01 8.46433266e-02 6.49804135e-02 1.00000000e-06
#  1.30656888e-01 1.48287310e-02 1.02175217e-01] | SSR: 1.1652477126912948
# Parameters: [1.34539169e-01 8.43688215e-02 6.54910410e-02 1.00000000e-06
#  1.00000000e-01 1.37982034e-02 1.02413647e-01] | SSR: 1.0678284051325018
# Parameters: [1.40173626e-01 7.98687591e-02 6.08141224e-02 1.00000000e-06
#  1.00000000e-01 6.92721876e-03 1.02753587e-01] | SSR: 1.3754636518391583
# Parameters: [0.13601873 0.08827293 0.07003408 0.00204149 0.18973734 0.01595944
#  0.10349696] | SSR: 1.706478257304168
# Parameters: [0.12747245 0.08831752 0.0694331  0.00051112 0.12243434 0.02109394
#  0.10165594] | SSR: 1.171342265577726
# Parameters: [1.36687918e-01 8.22451290e-02 6.46370359e-02 1.23911798e-04
#  1.00000000e-01 1.45228426e-02 1.03184815e-01] | SSR: 1.0569668044786469
# Parameters: [1.42663744e-01 7.68590053e-02 6.02180585e-02 1.00000000e-06
#  1.00000000e-01 1.00130336e-02 1.04066509e-01] | SSR: 1.1382488514605509
# Parameters: [1.31348448e-01 8.18361424e-02 7.20601321e-02 1.00000000e-06
#  1.66911868e-01 2.19310679e-02 1.03597587e-01] | SSR: 1.1368293837389993
# Parameters: [1.43057022e-01 7.67688185e-02 5.79050786e-02 1.00000000e-06
#  1.00000000e-01 3.69198219e-03 1.04091030e-01] | SSR: 1.8888739777115404
# Parameters: [0.12756031 0.08883679 0.07309027 0.00115567 0.16557063 0.02442039
#  0.10220499] | SSR: 1.1739392187165634
# Parameters: [1.33069699e-01 8.08169364e-02 6.75066911e-02 1.00000000e-06
#  1.00000000e-01 1.48920545e-02 1.04060384e-01] | SSR: 1.0721267064983433
# Parameters: [1.38394062e-01 7.85057468e-02 6.23803635e-02 1.00000000e-06
#  1.00000000e-01 8.83253715e-03 1.04125359e-01] | SSR: 1.2285022260688587
# Parameters: [0.13026875 0.08625403 0.07041279 0.00062355 0.14135697 0.02052343
#  0.10268508] | SSR: 1.1288054585203884
# Parameters: [1.39280866e-01 7.84354467e-02 6.63174457e-02 1.00000000e-06
#  1.17258729e-01 1.19959894e-02 1.04968443e-01] | SSR: 1.2152037940810807
# Parameters: [0.13042455 0.085847   0.06865419 0.00030931 0.12114043 0.01881945
#  0.10248407] | SSR: 1.1113738773877366
# Parameters: [0.13119502 0.08245355 0.07181978 0.00030208 0.10631719 0.0194014
#  0.10453741] | SSR: 1.1532404958281683
# Parameters: [0.13200063 0.083001   0.07010994 0.00022681 0.11240211 0.01825823
#  0.10394686] | SSR: 1.1061931532967724
# Parameters: [0.13445037 0.08559355 0.06418287 0.0003666  0.1        0.01124968
#  0.10321484] | SSR: 1.144419511764749
# Parameters: [1.32123929e-01 8.27754947e-02 7.00908156e-02 9.23987555e-05
#  1.38805899e-01 1.92607221e-02 1.03501900e-01] | SSR: 1.098421103349158
# Parameters: [1.36060125e-01 8.01817947e-02 6.57382106e-02 1.00000000e-06
#  1.00000000e-01 1.22965499e-02 1.04360720e-01] | SSR: 1.087686616035799
# Parameters: [1.37514484e-01 7.89701901e-02 6.66636814e-02 1.00000000e-06
#  1.00000000e-01 1.21368419e-02 1.05097918e-01] | SSR: 1.090597662561815
# Parameters: [1.37513792e-01 8.06645404e-02 6.42232828e-02 1.00000000e-06
#  1.00000000e-01 1.09490890e-02 1.03963995e-01] | SSR: 1.1206400691468381
# Parameters: [1.33378922e-01 8.24168819e-02 6.86382758e-02 1.29212242e-04
#  1.08972907e-01 1.64309482e-02 1.03951147e-01] | SSR: 1.0846592661368653
# Parameters: [1.36230342e-01 7.98933468e-02 6.38942672e-02 9.88636557e-05
#  1.13651087e-01 1.42067709e-02 1.02522954e-01] | SSR: 1.0714063298569128
# Parameters: [1.38584830e-01 7.97653912e-02 6.20718139e-02 9.31201445e-06
#  1.00000000e-01 8.82048113e-03 1.03809982e-01] | SSR: 1.2273281605782662
# Parameters: [1.33739155e-01 8.20229688e-02 6.80860651e-02 7.16270703e-05
#  1.21018949e-01 1.66506618e-02 1.03578920e-01] | SSR: 1.083290969685529
# Parameters: [1.32115610e-01 8.44429181e-02 6.59053434e-02 1.20889933e-04
#  1.12469412e-01 1.72340242e-02 1.01779964e-01] | SSR: 1.073113748548104
# Parameters: [0.13244296 0.08444878 0.06687857 0.00015514 0.1160321  0.01848502
#  0.1017798 ] | SSR: 1.075008566399601
# Parameters: [1.34856752e-01 8.27942319e-02 6.34757272e-02 3.43410885e-05
#  1.09076108e-01 1.49375034e-02 1.01568992e-01] | SSR: 1.0484238966523016
# Parameters: [1.35595667e-01 8.29829069e-02 6.08944529e-02 1.00000000e-06
#  1.09127708e-01 1.41907809e-02 1.00377914e-01] | SSR: 1.0381052778867002
# Parameters: [1.35026951e-01 8.34624130e-02 6.19731914e-02 7.17470971e-05
#  1.00000000e-01 1.40149666e-02 1.01026646e-01] | SSR: 1.0409009822464652
# Parameters: [1.37061423e-01 8.07547859e-02 6.17791544e-02 1.00000000e-06
#  1.00000000e-01 1.09034463e-02 1.02610575e-01] | SSR: 1.1041361891054189
# Parameters: [1.33597579e-01 8.35252796e-02 6.56037134e-02 1.07458706e-04
#  1.10533780e-01 1.65896289e-02 1.01987496e-01] | SSR: 1.060974514736805
# Parameters: [1.37812197e-01 8.04984628e-02 6.26661974e-02 1.00000000e-06
#  1.00000000e-01 1.19703323e-02 1.02669709e-01] | SSR: 1.0658415092991191
# Parameters: [1.38213108e-01 8.40334520e-02 5.96818515e-02 1.14708930e-04
#  1.09517879e-01 1.34775242e-02 9.99919536e-02] | SSR: 1.047640565075257
# Parameters: [1.35618969e-01 8.61399289e-02 6.20907281e-02 2.13724959e-05
#  1.00000000e-01 1.39544517e-02 1.00806240e-01] | SSR: 1.0498286750213888
# Parameters: [1.37618657e-01 8.21704848e-02 5.95224363e-02 1.25056865e-04
#  1.08336962e-01 1.44076616e-02 1.00456288e-01] | SSR: 1.0248163775235282
# Parameters: [0.1391584  0.08107132 0.05653813 0.00018709 0.11250544 0.01471239
#  0.09947761] | SSR: 1.0068412323310423
# Parameters: [0.13473026 0.08620452 0.0605964  0.00017822 0.11190995 0.01701898
#  0.0992882 ] | SSR: 1.0364857083509125
# Parameters: [1.39268498e-01 8.39431954e-02 5.62282290e-02 9.19840687e-05
#  1.01769356e-01 1.25223524e-02 9.91991824e-02] | SSR: 1.0222388816862638
# Parameters: [1.36915468e-01 8.57085077e-02 5.47923902e-02 6.64087686e-05
#  1.12808666e-01 1.40175701e-02 9.68631118e-02] | SSR: 1.0116171711131803
# Parameters: [0.13835485 0.08169044 0.05525346 0.00018182 0.11646829 0.01460399
#  0.09811508] | SSR: 1.0097451842324623
# Parameters: [1.35801203e-01 8.31274909e-02 5.63970801e-02 1.07652470e-04
#  1.08936237e-01 1.54027710e-02 9.83931146e-02] | SSR: 0.9968001821472303
# Parameters: [1.34595251e-01 8.26745103e-02 5.47546944e-02 1.04124240e-04
#  1.08645416e-01 1.63653944e-02 9.75936951e-02] | SSR: 0.9841977317538564
# Parameters: [0.13886402 0.08347341 0.05204331 0.00015986 0.12092423 0.01553688
#  0.09637758] | SSR: 0.9840502913347813
# Parameters: [0.14078255 0.08347892 0.04707837 0.00020392 0.13138635 0.01629784
#  0.09405305] | SSR: 0.9683308485199836
# Parameters: [0.13977727 0.08409464 0.0491746  0.00028859 0.11815614 0.01596308
#  0.09521921] | SSR: 0.9530127375210926
# Parameters: [0.14186807 0.0846505  0.04331467 0.00043239 0.12267035 0.01684923
#  0.09263985] | SSR: 0.9096508210438492
# Parameters: [0.14268205 0.08042903 0.04453501 0.00018398 0.1184483  0.01308638
#  0.0944094 ] | SSR: 1.00227162982694
# Parameters: [0.13911911 0.0816863  0.04556227 0.00029651 0.13335431 0.01774416
#  0.0931299 ] | SSR: 0.9234724513674676
# Parameters: [0.14210175 0.07877178 0.04436093 0.00038783 0.12818518 0.01731369
#  0.09439934] | SSR: 0.9120452169186821
# Parameters: [0.14173292 0.08195594 0.04078771 0.00033128 0.12787324 0.01750146
#  0.09208573] | SSR: 0.8866519898686436
# Parameters: [0.14342196 0.08208869 0.03355483 0.00040601 0.13357572 0.01895019
#  0.08907106] | SSR: 0.8269614525724964
# Parameters: [0.14214753 0.08286575 0.03293637 0.00038856 0.13785617 0.01860386
#  0.0877499 ] | SSR: 0.8314869688336533
# Parameters: [0.13847115 0.08420424 0.0416256  0.00045012 0.13745841 0.02180629
#  0.0909154 ] | SSR: 0.8815899991782561
# Parameters: [0.14766536 0.08239583 0.02765475 0.00062883 0.15549358 0.02008182
#  0.08582302] | SSR: 0.8209159312373407
# Parameters: [0.15420041 0.08225648 0.01410477 0.00089118 0.17891767 0.02194003
#  0.07993768] | SSR: 0.7803921175282241
# Parameters: [0.14531173 0.08124215 0.02591004 0.00072539 0.14633302 0.02176144
#  0.08533071] | SSR: 0.7559098694148207
# Parameters: [0.14757632 0.08012377 0.01532587 0.00098612 0.15380636 0.02449324
#  0.08096954] | SSR: 0.6699263614529262
# Parameters: [0.14939152 0.08258834 0.01878718 0.00082984 0.15020851 0.02224342
#  0.08277946] | SSR: 0.7099155069742465
# Parameters: [0.14849166 0.0865933  0.01268173 0.00086481 0.16167002 0.02408239
#  0.07819006] | SSR: 0.6581535078785659
# Parameters: [1.51686615e-01 9.05040571e-02 1.00000000e-06 1.10329603e-03
#  1.78412435e-01 2.74667404e-02 7.00854221e-02] | SSR: 0.5319664590849263
# Parameters: [0.15153065 0.08238702 0.00135265 0.00101194 0.18311115 0.02758042
#  0.07350542] | SSR: 0.5498387673953054
# Parameters: [1.58658843e-01 8.23140727e-02 1.00000000e-06 1.15472789e-03
#  1.81366734e-01 2.42731095e-02 7.02555941e-02] | SSR: 0.5392423706337011
# Parameters: [1.59699991e-01 8.34949492e-02 1.00000000e-06 1.43518502e-03
#  1.93400569e-01 2.90953226e-02 6.84227221e-02] | SSR: 0.4559702771668199
# Parameters: [1.68476223e-01 8.38095503e-02 1.00000000e-06 1.95849614e-03
#  2.21172769e-01 3.43410531e-02 5.87591326e-02] | SSR: 0.2902064008483005
# Parameters: [1.65583918e-01 8.47636819e-02 1.00000000e-06 1.86129979e-03
#  2.22708739e-01 3.31463845e-02 5.84410132e-02] | SSR: 0.30672208075982094
# Parameters: [1.58057901e-01 8.53122286e-02 1.00000000e-06 1.65330807e-03
#  1.89878533e-01 3.33583536e-02 6.14324864e-02] | SSR: 0.374706692603421
# Parameters: [1.65342904e-01 8.57586289e-02 1.00000000e-06 1.94993144e-03
#  2.29921982e-01 3.62306675e-02 5.24915676e-02] | SSR: 0.22949766076821615
# Parameters: [1.73318599e-01 8.73437742e-02 1.00000000e-06 2.50997887e-03
#  2.69778718e-01 4.32242928e-02 3.73476195e-02] | SSR: 0.23588601947423551
# Parameters: [1.72234265e-01 8.98331517e-02 1.00000000e-06 2.06901938e-03
#  2.48071456e-01 3.73343995e-02 4.61649317e-02] | SSR: 0.19752226269618792
# Parameters: [1.84563238e-01 9.46878405e-02 1.00000000e-06 2.61046778e-03
#  2.95204007e-01 4.37549810e-02 2.87626292e-02] | SSR: 0.5573168261018628
# Parameters: [1.74195259e-01 8.96973709e-02 1.00000000e-06 2.34522782e-03
#  2.37326749e-01 3.70340708e-02 4.58174753e-02] | SSR: 0.18329519399046296
# Parameters: [1.85527565e-01 9.33525459e-02 1.00000000e-06 3.01187297e-03
#  2.64434547e-01 4.17608975e-02 3.19735009e-02] | SSR: 0.3581871493730245
# Parameters: [1.71506038e-01 9.18798328e-02 1.00000000e-06 2.54258030e-03
#  2.55059741e-01 4.39873674e-02 4.20849856e-02] | SSR: 0.19937250818193927
# Parameters: [1.84140959e-01 8.40829272e-02 1.00000000e-06 3.00523623e-03
#  2.79913270e-01 4.55139158e-02 3.42550329e-02] | SSR: 0.31107478666019694
# Parameters: [1.85221975e-01 8.89235267e-02 1.00000000e-06 2.84148939e-03
#  2.94171383e-01 4.30953203e-02 3.51429818e-02] | SSR: 0.30240035942942567
# Parameters: [1.59447779e-01 9.15358566e-02 1.00000000e-06 1.44277641e-03
#  2.08210392e-01 3.02487308e-02 6.25741351e-02] | SSR: 0.40534917487161315
# Parameters: [1.77967664e-01 8.59461595e-02 1.00000000e-06 2.61462128e-03
#  2.61987551e-01 4.16976195e-02 4.13348084e-02] | SSR: 0.18323671096884553
# Parameters: [1.81543033e-01 9.11929527e-02 1.00000000e-06 2.80194757e-03
#  2.76637441e-01 4.50594721e-02 3.35006676e-02] | SSR: 0.31668768816104353
# Parameters: [1.69573697e-01 8.63709996e-02 1.00000000e-06 2.09646173e-03
#  2.36190914e-01 3.61246564e-02 5.22059268e-02] | SSR: 0.22495334412453816
# Parameters: [1.57434039e-01 8.63038143e-02 1.00000000e-06 1.60889292e-03
#  1.88608949e-01 3.31189181e-02 6.16738262e-02] | SSR: 0.3850626797950041
# Parameters: [1.78274991e-01 8.82685986e-02 1.00000000e-06 2.53334027e-03
#  2.67780774e-01 4.06012197e-02 4.17756929e-02] | SSR: 0.1893182345140145
# Parameters: [1.76979440e-01 9.26918046e-02 1.00000000e-06 2.65612735e-03
#  2.74924135e-01 4.36618042e-02 3.32052641e-02] | SSR: 0.32115219911366666
# Parameters: [1.70602027e-01 8.60301138e-02 1.00000000e-06 2.13290394e-03
#  2.34610611e-01 3.66712409e-02 5.23706654e-02] | SSR: 0.21961306874760597
# Parameters: [1.81615365e-01 9.08202931e-02 1.00000000e-06 2.71696992e-03
#  2.67514532e-01 4.18980680e-02 3.94382856e-02] | SSR: 0.1949364370322436
# Parameters: [1.80825049e-01 9.14791491e-02 1.00000000e-06 2.74772767e-03
#  2.70195204e-01 4.36536253e-02 3.60760289e-02] | SSR: 0.24749102774710188
# Parameters: [1.72386535e-01 8.76480370e-02 1.00000000e-06 2.25927822e-03
#  2.44691987e-01 3.80068986e-02 4.81734523e-02] | SSR: 0.1905222465757609
# Parameters: [1.80306578e-01 9.22822986e-02 1.00000000e-06 2.74739240e-03
#  2.74655900e-01 4.34886573e-02 3.47120865e-02] | SSR: 0.27740471768703573
# Parameters: [1.73028165e-01 8.75931600e-02 1.00000000e-06 2.28652606e-03
#  2.44621933e-01 3.83755950e-02 4.79560207e-02] | SSR: 0.18697998094628665
# Parameters: [1.79837460e-01 8.52078159e-02 1.00000000e-06 2.26455768e-03
#  2.51224540e-01 3.45691672e-02 4.66752050e-02] | SSR: 0.25131511416343044
# Parameters: [1.73588894e-01 9.02118286e-02 1.00000000e-06 2.47307465e-03
#  2.54100940e-01 4.16328174e-02 4.32325404e-02] | SSR: 0.17990142530848724
# Parameters: [1.79496270e-01 8.73626905e-02 1.00000000e-06 2.85356297e-03
#  2.59935534e-01 4.24502545e-02 4.17574328e-02] | SSR: 0.1716783566333003
# Parameters: [1.83127272e-01 8.61274599e-02 1.00000000e-06 3.24583476e-03
#  2.65867573e-01 4.50081821e-02 3.95536833e-02] | SSR: 0.18442097339582178
# Parameters: [1.69509714e-01 8.53876627e-02 1.00000000e-06 2.24463901e-03
#  2.38327031e-01 3.80443536e-02 4.91466923e-02] | SSR: 0.19372435802856286
# Parameters: [1.72536127e-01 8.67458203e-02 1.00000000e-06 2.36272174e-03
#  2.45623906e-01 3.90077822e-02 4.67195907e-02] | SSR: 0.18014857519489733
# Parameters: [1.78781285e-01 8.83021426e-02 1.00000000e-06 2.73188601e-03
#  2.61415838e-01 4.22214897e-02 3.99961366e-02] | SSR: 0.18963987542980776
# Parameters: [1.77182598e-01 8.81386162e-02 1.00000000e-06 2.61373406e-03
#  2.57234875e-01 4.11678419e-02 4.20404655e-02] | SSR: 0.17728349926537917
# Parameters: [1.72580716e-01 8.76444431e-02 1.00000000e-06 2.48079360e-03
#  2.35313937e-01 3.97890607e-02 4.64695453e-02] | SSR: 0.18727209757854107
# Parameters: [1.74004285e-01 8.78004820e-02 1.00000000e-06 2.49393027e-03
#  2.43430646e-01 3.99921004e-02 4.52960822e-02] | SSR: 0.17705948579123285
# Parameters: [1.78106434e-01 8.83791165e-02 1.00000000e-06 2.78686617e-03
#  2.58132410e-01 4.24765441e-02 3.95292351e-02] | SSR: 0.19489942806320829
# Parameters: [1.74297732e-01 8.77896492e-02 1.00000000e-06 2.41161108e-03
#  2.47999552e-01 3.94008323e-02 4.58493243e-02] | SSR: 0.17677347818259087
# Parameters: [1.76968618e-01 8.57298423e-02 1.00000000e-06 2.74713105e-03
#  2.68476967e-01 4.44942859e-02 4.16768802e-02] | SSR: 0.1753935475883845
# Parameters: [1.72910771e-01 8.94192488e-02 1.00000000e-06 2.51559753e-03
#  2.45670284e-01 4.06297846e-02 4.62572819e-02] | SSR: 0.18303293348579652
# Parameters: [1.74174994e-01 8.85509765e-02 1.00000000e-06 2.54035346e-03
#  2.49749601e-01 4.08967434e-02 4.50266635e-02] | SSR: 0.17545462192996103
# Parameters: [1.78810556e-01 8.91353469e-02 1.00000000e-06 2.81824898e-03
#  2.63212699e-01 4.38593252e-02 4.03888062e-02] | SSR: 0.18531498958200623
# Parameters: [1.74104734e-01 8.73432019e-02 1.00000000e-06 2.47660355e-03
#  2.50021104e-01 4.02206679e-02 4.51368945e-02] | SSR: 0.17423403324820258
# Parameters: [1.77905172e-01 8.48497310e-02 1.00000000e-06 2.70890434e-03
#  2.53569996e-01 4.08308187e-02 4.44199576e-02] | SSR: 0.1652237982281211
# Parameters: [1.80063311e-01 8.21686822e-02 1.00000000e-06 2.82681918e-03
#  2.53304524e-01 4.04298194e-02 4.50136662e-02] | SSR: 0.1601876441893329
# Parameters: [1.75134529e-01 8.52172480e-02 1.00000000e-06 2.62912639e-03
#  2.49313104e-01 4.10849306e-02 4.64615184e-02] | SSR: 0.17074996433515138
# Parameters: [1.78635769e-01 8.48173153e-02 1.00000000e-06 2.78755764e-03
#  2.64798036e-01 4.25729093e-02 4.35388835e-02] | SSR: 0.16334904341715245
# Parameters: [1.79581761e-01 8.39789099e-02 1.00000000e-06 2.97729013e-03
#  2.65028696e-01 4.40704851e-02 4.23255154e-02] | SSR: 0.1652042907382783
# Parameters: [1.81249289e-01 8.19112779e-02 1.00000000e-06 2.97338679e-03
#  2.67644104e-01 4.34813574e-02 4.23764196e-02] | SSR: 0.16323036090418944
# Parameters: [1.79678715e-01 8.36413936e-02 1.00000000e-06 2.83125371e-03
#  2.48678777e-01 3.95944068e-02 4.59260713e-02] | SSR: 0.1614096250363803
# Parameters: [1.84135164e-01 8.09703744e-02 1.00000000e-06 3.20310982e-03
#  2.66751117e-01 4.36890930e-02 4.26915361e-02] | SSR: 0.15432424758232124
# Parameters: [1.89150379e-01 7.77839607e-02 1.00000000e-06 3.56636296e-03
#  2.75116124e-01 4.54233055e-02 4.14688569e-02] | SSR: 0.15308132541473787
# Parameters: [1.81501946e-01 7.82141059e-02 1.00000000e-06 3.02980755e-03
#  2.61173999e-01 4.23089495e-02 4.59885476e-02] | SSR: 0.14943079248434887
# Parameters: [1.82504784e-01 7.36398136e-02 1.00000000e-06 3.11792984e-03
#  2.61793232e-01 4.22382969e-02 4.81041051e-02] | SSR: 0.14607934635149927
# Parameters: [1.87969473e-01 7.70517100e-02 1.00000000e-06 3.39390225e-03
#  2.75362179e-01 4.40038067e-02 4.17537725e-02] | SSR: 0.1598970900860352
# Parameters: [1.85918730e-01 7.63108482e-02 1.00000000e-06 3.16477055e-03
#  2.62599011e-01 4.09992011e-02 4.57264203e-02] | SSR: 0.15268287064970004
# Parameters: [1.88945568e-01 7.30420235e-02 1.00000000e-06 3.46227816e-03
#  2.62201379e-01 4.20471461e-02 4.51380627e-02] | SSR: 0.1400620376690968
# Parameters: [1.94100468e-01 6.71543777e-02 1.00000000e-06 3.79963841e-03
#  2.60903050e-01 4.17842645e-02 4.59376524e-02] | SSR: 0.1315894986047676
# Parameters: [1.90003814e-01 7.17318038e-02 1.00000000e-06 3.51252089e-03
#  2.57429295e-01 4.06538143e-02 4.73180217e-02] | SSR: 0.13930171415607628
# Parameters: [1.94524416e-01 6.65989482e-02 1.00000000e-06 3.84930175e-03
#  2.78894771e-01 4.48434528e-02 4.41660701e-02] | SSR: 0.13744013837726113
# Parameters: [1.98271564e-01 6.36231642e-02 1.00000000e-06 4.14587415e-03
#  2.81580522e-01 4.52690783e-02 4.48363049e-02] | SSR: 0.12683829050050427
# Parameters: [2.07375691e-01 5.43504052e-02 1.00000000e-06 4.80540163e-03
#  2.95718521e-01 4.76887077e-02 4.47476243e-02] | SSR: 0.1214684968771117
# Parameters: [1.95910036e-01 6.22540492e-02 1.00000000e-06 3.98207661e-03
#  2.65338965e-01 4.27479198e-02 4.89515849e-02] | SSR: 0.12161036362110703
# Parameters: [1.96660461e-01 5.70846810e-02 1.00000000e-06 3.92839124e-03
#  2.62791546e-01 4.05640251e-02 5.13744227e-02] | SSR: 0.15269862733475023
# Parameters: [1.94782940e-01 6.22595009e-02 1.00000000e-06 3.83788417e-03
#  2.65872691e-01 4.17788452e-02 4.88980313e-02] | SSR: 0.13632951260518783
# Parameters: [2.02424741e-01 5.45431228e-02 1.00000000e-06 4.52230182e-03
#  2.76243996e-01 4.52108850e-02 4.80230339e-02] | SSR: 0.10635814871248202
# Parameters: [2.10677746e-01 4.36592602e-02 1.00000000e-06 5.20106746e-03
#  2.83066488e-01 4.73167269e-02 4.91713407e-02] | SSR: 0.08813780095478702
# Parameters: [2.13888105e-01 4.86482850e-02 1.00000000e-06 5.16432471e-03
#  2.83127849e-01 4.54227691e-02 4.59502736e-02] | SSR: 0.11689219771396528
# Parameters: [2.13213159e-01 4.39610037e-02 1.00000000e-06 5.24167760e-03
#  2.94834229e-01 4.83698103e-02 4.63455718e-02] | SSR: 0.1113576632354582
# Parameters: [2.14032197e-01 4.26258752e-02 1.00000000e-06 5.30271842e-03
#  2.77922884e-01 4.51877026e-02 5.01202382e-02] | SSR: 0.09775192482852765
# Parameters: [2.19273460e-01 4.13557151e-02 1.00000000e-06 5.73266008e-03
#  2.94387877e-01 4.92262693e-02 4.57374790e-02] | SSR: 0.09752713448170164
# Parameters: [2.27148216e-01 2.90897919e-02 1.00000000e-06 6.32319773e-03
#  3.08924610e-01 5.13471371e-02 4.86406655e-02] | SSR: 0.09032966186994928
# Parameters: [2.34263842e-01 2.45146183e-02 1.00000000e-06 6.80965128e-03
#  3.16941737e-01 5.28404010e-02 4.55378988e-02] | SSR: 0.12133693162911197
# Parameters: [2.30480516e-01 2.38937518e-02 1.00000000e-06 6.55896902e-03
#  2.92625957e-01 4.93715255e-02 4.99676521e-02] | SSR: 0.08031338846963613
# Parameters: [2.42032929e-01 8.66542509e-03 1.00000000e-06 7.43575272e-03
#  2.91079675e-01 5.02129344e-02 5.25776661e-02] | SSR: 0.07064234695931396
# Parameters: [2.05812104e-01 4.92011977e-02 1.00000000e-06 4.73360550e-03
#  2.64013580e-01 4.34691275e-02 5.11887397e-02] | SSR: 0.10092266541620717
# Parameters: [2.23880412e-01 2.52255061e-02 1.00000000e-06 6.25586943e-03
#  2.92366249e-01 5.03285760e-02 5.22730695e-02] | SSR: 0.0667681278330271
# Parameters: [2.28876565e-01 1.35141167e-02 1.00000000e-06 6.80164180e-03
#  2.96985450e-01 5.27814795e-02 5.54344675e-02] | SSR: 0.05450733204737415
# Parameters: [2.29030618e-01 2.12136768e-02 1.00000000e-06 6.62422060e-03
#  2.81274504e-01 4.86420117e-02 5.44745986e-02] | SSR: 0.060533042525270524
# Parameters: [2.43065533e-01 7.97704825e-03 1.00000000e-06 7.67246845e-03
#  3.17026845e-01 5.50206615e-02 5.05702476e-02] | SSR: 0.07560362419179192
# Parameters: [2.43140680e-01 4.65270597e-03 1.00000000e-06 7.78042695e-03
#  3.14290102e-01 5.61115033e-02 5.17673233e-02] | SSR: 0.06000277526276704
# Parameters: [2.44718622e-01 1.00000000e-06 1.00000000e-06 7.93556155e-03
#  3.03511459e-01 5.40401462e-02 5.78728951e-02] | SSR: 0.05450283792806461
# Parameters: [2.57441202e-01 1.00000000e-06 1.00000000e-06 9.03701229e-03
#  3.08073250e-01 5.64470847e-02 6.39406032e-02] | SSR: 0.08477108296997851
# Parameters: [2.41863982e-01 1.00000000e-06 1.00000000e-06 7.80569928e-03
#  2.87428110e-01 5.26887096e-02 5.76074885e-02] | SSR: 0.04146933311089853
# Parameters: [2.49221865e-01 1.00000000e-06 1.00000000e-06 8.54695005e-03
#  2.76679860e-01 5.33594959e-02 6.20909001e-02] | SSR: 0.05484314716876833
# Parameters: [2.67244805e-01 1.00000000e-06 1.00000000e-06 9.67201007e-03
#  3.14532410e-01 5.82539721e-02 5.94871412e-02] | SSR: 0.057729432625872074
# Parameters: [2.41765381e-01 5.75121590e-03 1.00000000e-06 7.77190669e-03
#  2.79859358e-01 5.14738404e-02 6.06359182e-02] | SSR: 0.05168882549197498
# Parameters: [2.42721543e-01 4.23020787e-03 1.00000000e-06 8.10466640e-03
#  3.02600723e-01 5.66418264e-02 6.09308575e-02] | SSR: 0.05104616003465577
# Parameters: [2.59635547e-01 1.00000000e-06 1.00000000e-06 9.33918304e-03
#  3.18499099e-01 6.04984104e-02 6.08785703e-02] | SSR: 0.06328270218402017
# Parameters: [2.36681850e-01 1.26176417e-02 1.00000000e-06 7.30296121e-03
#  2.90580653e-01 5.16061114e-02 5.60755916e-02] | SSR: 0.04748971557535327
# Parameters: [2.43680105e-01 5.66620322e-03 1.00000000e-06 8.04655790e-03
#  2.78709373e-01 5.17416640e-02 6.48167795e-02] | SSR: 0.08661175153964439
# Parameters: [2.43275536e-01 4.90608028e-03 1.00000000e-06 7.84695969e-03
#  3.05394919e-01 5.50190435e-02 5.50296873e-02] | SSR: 0.04170340149607308
# Parameters: [2.12727618e-01 1.17193607e-02 1.00000000e-06 5.63353182e-03
#  2.75856353e-01 4.86749299e-02 5.58234033e-02] | SSR: 0.1002456206535879
# Parameters: [2.53615508e-01 2.93059017e-03 1.00000000e-06 8.66239051e-03
#  3.04863396e-01 5.58592115e-02 5.85712067e-02] | SSR: 0.042220961456895204
# Parameters: [2.58164127e-01 1.00000000e-06 1.00000000e-06 9.03554258e-03
#  2.95654155e-01 5.50267746e-02 6.07722882e-02] | SSR: 0.05400132987382594
# Parameters: [2.46163643e-01 8.69549599e-03 1.00000000e-06 8.21590312e-03
#  2.86883202e-01 5.40500016e-02 5.91622586e-02] | SSR: 0.04810868616947661
# Parameters: [2.29289429e-01 1.11796377e-02 1.00000000e-06 6.88173939e-03
#  2.92234519e-01 5.27842953e-02 5.58028571e-02] | SSR: 0.049138708377769506
# Parameters: [2.42123616e-01 6.98039945e-03 1.00000000e-06 7.89104177e-03
#  3.11565077e-01 5.67116451e-02 5.45583525e-02] | SSR: 0.0359501937514273
# Parameters: [2.42302734e-01 7.59499123e-03 1.00000000e-06 7.95060931e-03
#  3.27417937e-01 5.93305474e-02 5.15195696e-02] | SSR: 0.044532881501314826
# Parameters: [2.40996618e-01 9.28717651e-03 1.00000000e-06 7.49724644e-03
#  2.91384957e-01 5.15636073e-02 5.24426974e-02] | SSR: 0.05390251770978675
# Parameters: [2.42290312e-01 5.49445003e-03 1.00000000e-06 7.95281141e-03
#  2.99796781e-01 5.53722716e-02 5.88088175e-02] | SSR: 0.04144206155020888
# Parameters: [2.58143271e-01 7.13407346e-04 1.00000000e-06 9.02619404e-03
#  3.03911806e-01 5.61605602e-02 5.84295437e-02] | SSR: 0.040835762118698354
# Parameters: [2.44691807e-01 9.16952302e-04 1.00000000e-06 7.92354200e-03
#  3.14128438e-01 5.54978707e-02 5.48607951e-02] | SSR: 0.05908791744735801
# Parameters: [2.45795684e-01 6.75086007e-03 1.00000000e-06 8.14281284e-03
#  2.93694511e-01 5.44119689e-02 5.80868927e-02] | SSR: 0.03895830354366527
# Parameters: [2.56777552e-01 1.00000000e-06 1.00000000e-06 9.07644151e-03
#  3.11320662e-01 5.87434344e-02 5.85221196e-02] | SSR: 0.04077664568378556
# Parameters: [2.40747336e-01 4.16860902e-03 1.00000000e-06 7.83531250e-03
#  2.98882852e-01 5.53143980e-02 5.60124795e-02] | SSR: 0.03397708499495262
# Parameters: [2.34313249e-01 4.78761844e-03 1.00000000e-06 7.42177350e-03
#  2.95892580e-01 5.50419912e-02 5.47331158e-02] | SSR: 0.03916521688844994
# Parameters: [2.50364965e-01 1.98241284e-03 1.00000000e-06 8.64741555e-03
#  2.96490738e-01 5.62389531e-02 5.98347967e-02] | SSR: 0.04510228981144458
# Parameters: [2.45047893e-01 4.17516342e-03 1.00000000e-06 8.04707366e-03
#  3.03168874e-01 5.53240209e-02 5.62309647e-02] | SSR: 0.035964534569838225
# Parameters: [2.52686208e-01 8.08011124e-03 1.00000000e-06 8.75764008e-03
#  3.18954908e-01 5.93222330e-02 5.68637029e-02] | SSR: 0.040817211747196026
# Parameters: [2.55230134e-01 3.32542155e-03 1.00000000e-06 8.84047898e-03
#  3.12059988e-01 5.77672314e-02 5.51066269e-02] | SSR: 0.029860067004328375
# Parameters: [2.61700045e-01 2.24090731e-03 1.00000000e-06 9.28431277e-03
#  3.18191591e-01 5.89647112e-02 5.32555317e-02] | SSR: 0.02929101666624981
# Parameters: [2.40393396e-01 8.54289280e-03 1.00000000e-06 7.84084457e-03
#  3.12024901e-01 5.77801288e-02 5.40076116e-02] | SSR: 0.032359049692383554
# Parameters: [2.42338227e-01 1.30841221e-03 1.00000000e-06 7.84745696e-03
#  2.95001797e-01 5.41778548e-02 5.47574263e-02] | SSR: 0.04057299351771816
# Parameters: [2.34121361e-01 9.76106980e-03 1.00000000e-06 7.17751708e-03
#  2.97973511e-01 5.34522020e-02 5.20233830e-02] | SSR: 0.05829761799140521
# Parameters: [2.51113505e-01 2.44101745e-03 1.00000000e-06 8.60171040e-03
#  3.07983874e-01 5.74206263e-02 5.68974354e-02] | SSR: 0.03242244799371249
# Parameters: [2.51067909e-01 8.77725908e-03 1.00000000e-06 8.62200262e-03
#  3.18001540e-01 5.89442878e-02 5.63995074e-02] | SSR: 0.03792449699062585
# Parameters: [2.49116802e-01 3.91378237e-03 1.00000000e-06 8.46355810e-03
#  3.26253691e-01 6.00051220e-02 5.25879309e-02] | SSR: 0.03468353294685616
# Parameters: [2.43287118e-01 4.97818585e-04 1.00000000e-06 7.93909846e-03
#  3.04304420e-01 5.57758986e-02 5.31862943e-02] | SSR: 0.04766477004242582
# Parameters: [2.49122711e-01 6.70739896e-03 1.00000000e-06 8.45127658e-03
#  3.14577260e-01 5.81521905e-02 5.55962042e-02] | SSR: 0.03191775743593061
# Parameters: [2.50471367e-01 5.82341011e-03 1.00000000e-06 8.62951397e-03
#  3.22396625e-01 6.02042140e-02 5.31734770e-02] | SSR: 0.029571864744096767
# Parameters: [2.55780716e-01 2.68760570e-03 1.00000000e-06 8.99653792e-03
#  3.17095150e-01 5.98144666e-02 5.44504104e-02] | SSR: 0.029387281787447376
# Parameters: [2.50691506e-01 5.40388658e-03 1.00000000e-06 8.57630153e-03
#  2.99789810e-01 5.64665167e-02 5.69529690e-02] | SSR: 0.03461005109348116
# Parameters: [2.50297830e-01 5.03136053e-03 1.00000000e-06 8.54811567e-03
#  3.06405780e-01 5.73511680e-02 5.58617095e-02] | SSR: 0.0306907450465054
# Parameters: [2.61789684e-01 5.39556037e-03 1.00000000e-06 9.40820518e-03
#  3.29310057e-01 6.17391750e-02 5.34853433e-02] | SSR: 0.03405583030335982
# Parameters: [2.46007923e-01 4.47534686e-03 1.00000000e-06 8.22853567e-03
#  3.06489653e-01 5.69205922e-02 5.53806954e-02] | SSR: 0.030358051420413725
# Parameters: [2.49964777e-01 7.70438892e-03 1.00000000e-06 8.53518593e-03
#  3.19782115e-01 5.94900798e-02 5.21670331e-02] | SSR: 0.03070005964185153
# Parameters: [2.63419566e-01 1.36294102e-03 1.00000000e-06 9.49443500e-03
#  3.17957434e-01 5.96191347e-02 5.45309773e-02] | SSR: 0.03197494692538614
# Parameters: [2.57663023e-01 3.15792897e-03 1.00000000e-06 9.08103739e-03
#  3.16474301e-01 5.91593833e-02 5.44001359e-02] | SSR: 0.029645093403375965
# Parameters: [2.57130341e-01 2.18430058e-03 1.00000000e-06 9.06393466e-03
#  3.15947087e-01 5.95348424e-02 5.26006510e-02] | SSR: 0.029675038137403804
# Parameters: [2.58335578e-01 1.00000000e-06 1.00000000e-06 9.13109638e-03
#  3.09646510e-01 5.82097424e-02 5.61537129e-02] | SSR: 0.031103128325515508
# Parameters: [2.52057478e-01 5.68082732e-03 1.00000000e-06 8.68416354e-03
#  3.17248213e-01 5.91699954e-02 5.31637030e-02] | SSR: 0.029097443631248304
# Parameters: [2.58505282e-01 2.46873286e-03 1.00000000e-06 9.15703745e-03
#  3.26120683e-01 6.08683192e-02 5.16881775e-02] | SSR: 0.03229244394403832
# Parameters: [2.52349693e-01 4.39070361e-03 1.00000000e-06 8.70034612e-03
#  3.11334506e-01 5.82304558e-02 5.48183265e-02] | SSR: 0.02902256559851677
# Parameters: [2.64607123e-01 3.00056275e-03 1.00000000e-06 9.61142043e-03
#  3.27421053e-01 6.16731417e-02 5.20085147e-02] | SSR: 0.03344984406759668
# Parameters: [2.50657723e-01 4.10665083e-03 1.00000000e-06 8.57425686e-03
#  3.11722503e-01 5.81087296e-02 5.45376502e-02] | SSR: 0.028770071128255952
# Parameters: [2.51635386e-01 5.84085195e-03 1.00000000e-06 8.63611351e-03
#  3.16756596e-01 5.86514307e-02 5.53419875e-02] | SSR: 0.03133227170542438
# Parameters: [2.55756602e-01 3.09843843e-03 1.00000000e-06 8.95697937e-03
#  3.16149464e-01 5.93139895e-02 5.32859851e-02] | SSR: 0.02877934302283596
# Parameters: [2.50558012e-01 4.85022626e-03 1.00000000e-06 8.58356562e-03
#  3.16136571e-01 5.90710631e-02 5.32241738e-02] | SSR: 0.029287619771823613
# Parameters: [2.57774424e-01 1.90669259e-03 1.00000000e-06 9.02196094e-03
#  3.08425660e-01 5.77024749e-02 5.44653175e-02] | SSR: 0.02822076514185736
# Parameters: [2.61425952e-01 1.00000000e-06 1.00000000e-06 9.21818442e-03
#  3.01440178e-01 5.64516054e-02 5.51112378e-02] | SSR: 0.02845887068067887
# Parameters: [2.53034706e-01 4.81937898e-03 1.00000000e-06 8.66220072e-03
#  3.11250138e-01 5.74887961e-02 5.31926432e-02] | SSR: 0.029306613663257576
# Parameters: [2.53721208e-01 4.28643566e-03 1.00000000e-06 8.74578502e-03
#  3.12711391e-01 5.80702137e-02 5.35070850e-02] | SSR: 0.028683670366224358
# Parameters: [2.44835709e-01 5.85051403e-03 1.00000000e-06 8.22056079e-03
#  3.08587926e-01 5.80829808e-02 5.44593944e-02] | SSR: 0.02895673754270431
# Parameters: [2.54342799e-01 3.52699158e-03 1.00000000e-06 8.81759228e-03
#  3.08486190e-01 5.76943197e-02 5.48436724e-02] | SSR: 0.028757179003372782
# Parameters: [2.53496282e-01 2.08100889e-03 1.00000000e-06 8.75511685e-03
#  3.04871112e-01 5.71737657e-02 5.53841345e-02] | SSR: 0.028479780308335992
# Parameters: [2.53531664e-01 2.71121982e-03 1.00000000e-06 8.75458306e-03
#  3.08938136e-01 5.78113939e-02 5.38911704e-02] | SSR: 0.028072932857029314
# Parameters: [2.54122649e-01 1.87147792e-03 1.00000000e-06 8.78170153e-03
#  3.07739952e-01 5.76018629e-02 5.34275924e-02] | SSR: 0.028504780964126498
# Parameters: [2.63530206e-01 3.54468197e-04 1.00000000e-06 9.38694617e-03
#  3.11784776e-01 5.78812727e-02 5.40877528e-02] | SSR: 0.028994306100541947
# Parameters: [2.49509333e-01 4.47650257e-03 1.00000000e-06 8.51215714e-03
#  3.09387139e-01 5.80325537e-02 5.43664840e-02] | SSR: 0.02837446850280735
# Parameters: [2.50824379e-01 3.50027641e-03 1.00000000e-06 8.52343553e-03
#  3.02291145e-01 5.62841395e-02 5.55698761e-02] | SSR: 0.02930539692176479
# Parameters: [2.54523546e-01 3.19889792e-03 1.00000000e-06 8.84859341e-03
#  3.12684884e-01 5.85565270e-02 5.38569579e-02] | SSR: 0.028284391049716143
# Parameters: [2.57027779e-01 2.23270603e-03 1.00000000e-06 8.98453991e-03
#  3.06993072e-01 5.76173415e-02 5.41237274e-02] | SSR: 0.027865827694722185
# Parameters: [2.60212807e-01 1.29573364e-03 1.00000000e-06 9.18968143e-03
#  3.04628356e-01 5.73716474e-02 5.39167660e-02] | SSR: 0.027951466480756176
# Parameters: [2.54109840e-01 2.44256941e-03 1.00000000e-06 8.78890381e-03
#  3.09802780e-01 5.80097575e-02 5.36120066e-02] | SSR: 0.028256123497579496
# Parameters: [2.54842468e-01 1.15630641e-03 1.00000000e-06 8.87303073e-03
#  3.04746547e-01 5.76165903e-02 5.49785716e-02] | SSR: 0.027757918152599287
# Parameters: [2.55403098e-01 1.00000000e-06 1.00000000e-06 8.93665359e-03
#  3.00764125e-01 5.73897786e-02 5.57143149e-02] | SSR: 0.028356996252834412
# Parameters: [2.55452019e-01 3.09753247e-03 1.00000000e-06 8.89738857e-03
#  3.12551236e-01 5.86395597e-02 5.29856471e-02] | SSR: 0.02877066400634492
# Parameters: [2.53985216e-01 2.33513978e-03 1.00000000e-06 8.79068478e-03
#  3.06791143e-01 5.75402142e-02 5.47845126e-02] | SSR: 0.0280239639739813
# Parameters: [2.60717791e-01 9.02208486e-05 1.00000000e-06 9.21992762e-03
#  3.07293497e-01 5.76401032e-02 5.41227343e-02] | SSR: 0.027924414965640215
# Parameters: [2.57473363e-01 4.79632047e-04 1.00000000e-06 8.98958683e-03
#  3.02455354e-01 5.68542946e-02 5.47081966e-02] | SSR: 0.0274222597045899
# Parameters: [2.58948271e-01 1.00000000e-06 1.00000000e-06 9.06008355e-03
#  2.97340589e-01 5.60031784e-02 5.51338160e-02] | SSR: 0.02749375455906114
# Parameters: [2.58848076e-01 6.75121311e-04 1.00000000e-06 9.10661443e-03
#  3.03238194e-01 5.70709318e-02 5.52663450e-02] | SSR: 0.028728077841745928
# Parameters: [2.55294399e-01 2.00070739e-03 1.00000000e-06 8.86833147e-03
#  3.08161634e-01 5.77750511e-02 5.40255912e-02] | SSR: 0.027820729989816082
# Parameters: [2.54474913e-01 1.23785950e-03 1.00000000e-06 8.82966317e-03
#  3.04539878e-01 5.73989505e-02 5.42873980e-02] | SSR: 0.02741270032521554
# Parameters: [2.52825158e-01 9.03442957e-04 1.00000000e-06 8.73351429e-03
#  3.02596987e-01 5.72471882e-02 5.41984382e-02] | SSR: 0.02737945396846139
# Parameters: [2.58515815e-01 1.00000000e-06 1.00000000e-06 9.09102141e-03
#  3.02215645e-01 5.71288299e-02 5.49493358e-02] | SSR: 0.02778592486769339
# Parameters: [2.59356719e-01 1.00000000e-06 1.00000000e-06 9.14073015e-03
#  3.03055352e-01 5.72824712e-02 5.41030860e-02] | SSR: 0.027460333437721817
# Parameters: [2.52235266e-01 1.84543482e-03 1.00000000e-06 8.68885947e-03
#  3.01342101e-01 5.70804016e-02 5.47592505e-02] | SSR: 0.027317272644336716
# Parameters: [2.47994003e-01 2.72304180e-03 1.00000000e-06 8.42332539e-03
#  2.98366403e-01 5.68005508e-02 5.50775086e-02] | SSR: 0.027523701308516658
# Parameters: [2.54555989e-01 1.00000000e-06 1.00000000e-06 8.83976705e-03
#  3.00027962e-01 5.69497519e-02 5.49398354e-02] | SSR: 0.02698410092491444
# Parameters: [2.53320094e-01 1.00000000e-06 1.00000000e-06 8.76738062e-03
#  2.96545407e-01 5.66159572e-02 5.53478895e-02] | SSR: 0.026957907152866657
# Parameters: [2.55725282e-01 1.00000000e-06 1.00000000e-06 8.92713239e-03
#  2.95540479e-01 5.64608726e-02 5.54157711e-02] | SSR: 0.027564858721886475
# ...
#  2.46347431e-01 4.37497282e-02 5.09492450e-02] | SSR: 0.024982311528590272
# Parameters: [2.60164467e-01 1.02979284e-03 1.00000000e-06 1.07043808e-02
#  2.43703977e-01 4.28746736e-02 5.06195512e-02] | SSR: 0.024990710571791912
# Parameters: [2.60315770e-01 8.48643595e-04 1.00000000e-06 1.04537401e-02
#  2.46475696e-01 4.38683710e-02 5.10782567e-02] | SSR: 0.02497555412233351
# Parameters: [2.61320694e-01 8.06218204e-04 1.00000000e-06 1.04160299e-02
#  2.45674691e-01 4.37921399e-02 5.12247256e-02] | SSR: 0.024973884052484185
# Parameters: [2.59834065e-01 9.23511040e-04 1.00000000e-06 1.04493121e-02
#  2.44796561e-01 4.34669406e-02 5.10806785e-02] | SSR: 0.024983288196923643
# Parameters: [2.60728329e-01 8.65909350e-04 1.00000000e-06 1.05198538e-02
#  2.45959714e-01 4.36790313e-02 5.09821034e-02] | SSR: 0.024975321768693645
# Parameters: [2.57308805e-01 9.84443393e-04 1.00000000e-06 1.05335407e-02
#  2.45596872e-01 4.35383524e-02 5.09272425e-02] | SSR: 0.024969340243432746
# Parameters: [2.54501074e-01 1.07487322e-03 1.00000000e-06 1.05639955e-02
#  2.45575905e-01 4.34682909e-02 5.08529207e-02] | SSR: 0.024972837426542476
# Parameters: [2.62234117e-01 7.23354889e-04 1.00000000e-06 1.03788302e-02
#  2.47628276e-01 4.42487177e-02 5.13321558e-02] | SSR: 0.024981866465736222
# Parameters: [2.58942720e-01 9.65971435e-04 1.00000000e-06 1.05495803e-02
#  2.44944200e-01 4.33833023e-02 5.08789801e-02] | SSR: 0.024972795408530486
# Parameters: [2.59957423e-01 8.86225766e-04 1.00000000e-06 1.05247936e-02
#  2.44694875e-01 4.34793663e-02 5.09596675e-02] | SSR: 0.02497627963678135
# Parameters: [2.59933106e-01 8.90217992e-04 1.00000000e-06 1.05136756e-02
#  2.45153622e-01 4.35488547e-02 5.09825514e-02] | SSR: 0.02497261223724319
# Parameters: [2.59144357e-01 9.01607166e-04 1.00000000e-06 1.04727847e-02
#  2.46116683e-01 4.37288184e-02 5.10939863e-02] | SSR: 0.024970572773505006
# Parameters: [2.59002650e-01 9.55665896e-04 1.00000000e-06 1.05526711e-02
#  2.44656592e-01 4.33375511e-02 5.09517009e-02] | SSR: 0.0249720040576606
# Parameters: [2.58097040e-01 9.64044869e-04 1.00000000e-06 1.04959338e-02
#  2.44800254e-01 4.34293250e-02 5.10391677e-02] | SSR: 0.024972898644057214
# Parameters: [2.56583631e-01 1.06882935e-03 1.00000000e-06 1.06225874e-02
#  2.44835438e-01 4.32125551e-02 5.07435290e-02] | SSR: 0.02497370759652013
# Parameters: [2.57767897e-01 1.00317656e-03 1.00000000e-06 1.05709480e-02
#  2.45045251e-01 4.33574513e-02 5.08638281e-02] | SSR: 0.02497092486245323
# Parameters: [2.56962562e-01 1.00360641e-03 1.00000000e-06 1.05370643e-02
#  2.44858051e-01 4.33993873e-02 5.09097256e-02] | SSR: 0.024970845277658027
# Parameters: [2.58777845e-01 9.51580518e-04 1.00000000e-06 1.05698562e-02
#  2.45591537e-01 4.35117371e-02 5.08488365e-02] | SSR: 0.02497248384855823
# Parameters: [2.57885058e-01 9.45542261e-04 1.00000000e-06 1.05220027e-02
#  2.45632546e-01 4.35944555e-02 5.10004117e-02] | SSR: 0.024969553111727515
# Parameters: [2.56309515e-01 1.03710264e-03 1.00000000e-06 1.05602866e-02
#  2.45559959e-01 4.34419319e-02 5.09019433e-02] | SSR: 0.02497297381388115
# Parameters: [2.59027208e-01 9.26939154e-04 1.00000000e-06 1.05253284e-02
#  2.45255206e-01 4.35221240e-02 5.09623994e-02] | SSR: 0.02497008282597421
# Parameters: [2.57536023e-01 9.68699723e-04 1.00000000e-06 1.04913838e-02
#  2.45025949e-01 4.34820172e-02 5.10681048e-02] | SSR: 0.024973286702398602
# Parameters: [2.58467389e-01 9.55860319e-04 1.00000000e-06 1.05502381e-02
#  2.45450140e-01 4.35043071e-02 5.09036536e-02] | SSR: 0.024969986971184698
# Parameters: [2.57158286e-01 9.64669893e-04 1.00000000e-06 1.05078738e-02
#  2.46187622e-01 4.37038477e-02 5.09515126e-02] | SSR: 0.024970758602453316
# Parameters: [2.58218865e-01 9.06157322e-04 1.00000000e-06 1.04715757e-02
#  2.46125355e-01 4.37829179e-02 5.10644380e-02] | SSR: 0.024970599411635378
# Parameters: [2.59383143e-01 8.77884879e-04 1.00000000e-06 1.04867482e-02
#  2.46674642e-01 4.38505621e-02 5.10627442e-02] | SSR: 0.024971561851005967
# Parameters: [2.57567707e-01 9.72176027e-04 1.00000000e-06 1.05244853e-02
#  2.45312199e-01 4.35121810e-02 5.09479802e-02] | SSR: 0.02496944366616072
# Parameters: [2.59304397e-01 9.18966004e-04 1.00000000e-06 1.05206850e-02
#  2.45094950e-01 4.34913398e-02 5.10199479e-02] | SSR: 0.02497083157068404
# Parameters: [2.57694814e-01 9.53243921e-04 1.00000000e-06 1.05110766e-02
#  2.45914454e-01 4.36507207e-02 5.09686214e-02] | SSR: 0.024969479948685914
# Parameters: [2.58094089e-01 9.90931889e-04 1.00000000e-06 1.05682691e-02
#  2.45096960e-01 4.33744989e-02 5.08796463e-02] | SSR: 0.024970983667229926
# Parameters: [2.58187671e-01 9.27350964e-04 1.00000000e-06 1.04957490e-02
#  2.45868256e-01 4.36808132e-02 5.10182401e-02] | SSR: 0.024969409244022384
# Parameters: [2.56895258e-01 1.00283742e-03 1.00000000e-06 1.05736212e-02
#  2.45034652e-01 4.34148827e-02 5.08284562e-02] | SSR: 0.02497188695337044
# Parameters: [2.58582082e-01 9.26914729e-04 1.00000000e-06 1.04979939e-02
#  2.45846175e-01 4.36503345e-02 5.10276038e-02] | SSR: 0.024969309578418815
# Parameters: [2.56885228e-01 9.77498450e-04 1.00000000e-06 1.05132677e-02
#  2.46064977e-01 4.36582087e-02 5.09786730e-02] | SSR: 0.0249691344757422
# Parameters: [2.55814237e-01 1.00277810e-03 1.00000000e-06 1.05072374e-02
#  2.46469863e-01 4.37262511e-02 5.09868098e-02] | SSR: 0.0249704801166124
# Parameters: [2.56993000e-01 9.54759608e-04 1.00000000e-06 1.04777950e-02
#  2.46045711e-01 4.37199974e-02 5.10588529e-02] | SSR: 0.024969803858386763
# Parameters: [2.57361598e-01 9.55034786e-04 1.00000000e-06 1.04959058e-02
#  2.45896818e-01 4.36660749e-02 5.10200531e-02] | SSR: 0.024969125592701723
# Parameters: [2.57425772e-01 9.67789816e-04 1.00000000e-06 1.04985741e-02
#  2.45938812e-01 4.36503118e-02 5.09677066e-02] | SSR: 0.024971376282735207
# Parameters: [2.57770236e-01 9.51104150e-04 1.00000000e-06 1.05161456e-02
#  2.45709112e-01 4.36084195e-02 5.09922354e-02] | SSR: 0.02496892645456202
# Parameters: [2.57637565e-01 9.59476793e-04 1.00000000e-06 1.05109486e-02
#  2.45598235e-01 4.35819605e-02 5.10062437e-02] | SSR: 0.024969189566716028
# Parameters: [2.57784631e-01 9.36916334e-04 1.00000000e-06 1.04936722e-02
#  2.46282214e-01 4.37404372e-02 5.10435317e-02] | SSR: 0.024969099467431893
# Parameters: [2.57049513e-01 9.84474360e-04 1.00000000e-06 1.05218151e-02
#  2.45844431e-01 4.35888404e-02 5.09804979e-02] | SSR: 0.024969758499883858
# Parameters: [2.57903131e-01 9.41631813e-04 1.00000000e-06 1.05022655e-02
#  2.45862300e-01 4.36578200e-02 5.10088046e-02] | SSR: 0.024968985341746082
# Parameters: [2.58098187e-01 9.15150051e-04 1.00000000e-06 1.04750876e-02
#  2.46191651e-01 4.37654348e-02 5.10947990e-02] | SSR: 0.024969410414929546
# Parameters: [2.57506150e-01 9.67120057e-04 1.00000000e-06 1.05189274e-02
#  2.45745567e-01 4.35951230e-02 5.09691316e-02] | SSR: 0.024968993095416888
# Parameters: [2.56517500e-01 9.84165952e-04 1.00000000e-06 1.05166155e-02
#  2.45913603e-01 4.36376780e-02 5.09777314e-02] | SSR: 0.024969508775449942
# Parameters: [2.58065937e-01 9.41227535e-04 1.00000000e-06 1.05026493e-02
#  2.45863032e-01 4.36471704e-02 5.10151357e-02] | SSR: 0.0249689747103192
# Parameters: [2.57584409e-01 9.46389815e-04 1.00000000e-06 1.05012896e-02
#  2.46237200e-01 4.37246834e-02 5.10016320e-02] | SSR: 0.024969138000172815
# Parameters: [2.57597698e-01 9.49661559e-04 1.00000000e-06 1.05037043e-02
#  2.46077459e-01 4.36890027e-02 5.10027849e-02] | SSR: 0.02496894008647594
# Parameters: [2.58540310e-01 9.20414760e-04 1.00000000e-06 1.04962380e-02
#  2.45774023e-01 4.36572335e-02 5.10360919e-02] | SSR: 0.024969173765625543
# Parameters: [2.57298998e-01 9.63227528e-04 1.00000000e-06 1.05090103e-02
#  2.45992239e-01 4.36579649e-02 5.09930277e-02] | SSR: 0.024968938500285077
# Parameters: [2.58046055e-01 9.45219207e-04 1.00000000e-06 1.05173441e-02
#  2.45969445e-01 4.36470502e-02 5.09869902e-02] | SSR: 0.02496904157981967
# Parameters: [2.57697713e-01 9.65709908e-04 1.00000000e-06 1.05263411e-02
#  2.45494687e-01 4.35460059e-02 5.09473570e-02] | SSR: 0.024969166156025353
# Parameters: [2.57762902e-01 9.44114728e-04 1.00000000e-06 1.05018394e-02
#  2.46085332e-01 4.36918293e-02 5.10194880e-02] | SSR: 0.02496891897309363
# Parameters: [2.57355389e-01 9.57091470e-04 1.00000000e-06 1.04982393e-02
#  2.45840566e-01 4.36521869e-02 5.10131835e-02] | SSR: 0.02496914503378358
# Parameters: [2.57873388e-01 9.48187273e-04 1.00000000e-06 1.05125679e-02
#  2.45937226e-01 4.36483344e-02 5.09935385e-02] | SSR: 0.0249689012730636
# Parameters: [2.58000219e-01 9.29781252e-04 1.00000000e-06 1.04948389e-02
#  2.46119204e-01 4.37193173e-02 5.10380155e-02] | SSR: 0.02496899171868435
# Parameters: [2.57876701e-01 9.39115954e-04 1.00000000e-06 1.05008611e-02
#  2.46025795e-01 4.36882688e-02 5.10207945e-02] | SSR: 0.0249688984303595
# Parameters: [2.57595686e-01 9.54550680e-04 1.00000000e-06 1.05110996e-02
#  2.46049185e-01 4.36653200e-02 5.10017682e-02] | SSR: 0.024968932719438622
# Parameters: [2.57298523e-01 9.58761571e-04 1.00000000e-06 1.05131302e-02
#  2.46101638e-01 4.36811552e-02 5.09916178e-02] | SSR: 0.024968934478376163
# Parameters: [2.57681283e-01 9.52927550e-04 1.00000000e-06 1.05147682e-02
#  2.45894121e-01 4.36370808e-02 5.10007780e-02] | SSR: 0.02496896387719287
# Parameters: [2.57618594e-01 9.50478057e-04 1.00000000e-06 1.05064703e-02
#  2.46031624e-01 4.36760222e-02 5.10022832e-02] | SSR: 0.024968874147170205
# Parameters: [2.58071296e-01 9.35718876e-04 1.00000000e-06 1.05087366e-02
#  2.45990593e-01 4.36732778e-02 5.10131797e-02] | SSR: 0.024969025104118903
# Parameters: [2.57492073e-01 9.56350365e-04 1.00000000e-06 1.05089419e-02
#  2.45991827e-01 4.36617931e-02 5.09980657e-02] | SSR: 0.024968868261725296
# Parameters: [2.58127071e-01 9.39495916e-04 1.00000000e-06 1.05034200e-02
#  2.45849819e-01 4.36445554e-02 5.10164318e-02] | SSR: 0.024968978573216196
# Parameters: [2.57505660e-01 9.53945158e-04 1.00000000e-06 1.05107026e-02
#  2.46038684e-01 4.36720053e-02 5.09978213e-02] | SSR: 0.024968871781412022
# Parameters: [2.57804187e-01 9.43533801e-04 1.00000000e-06 1.05053372e-02
#  2.45899273e-01 4.36623008e-02 5.10051537e-02] | SSR: 0.024968961971986545
# Parameters: [2.57647811e-01 9.51796460e-04 1.00000000e-06 1.05096590e-02
#  2.46011707e-01 4.36645652e-02 5.10026146e-02] | SSR: 0.024968872812348483
# Parameters: [2.57594658e-01 9.47178134e-04 1.00000000e-06 1.04984379e-02
#  2.46325801e-01 4.37352428e-02 5.10176519e-02] | SSR: 0.02496909524248403
# Parameters: [2.57726342e-01 9.50122646e-04 1.00000000e-06 1.05117187e-02
#  2.45863284e-01 4.36401254e-02 5.09985896e-02] | SSR: 0.024968859606603777
# Parameters: [2.57591547e-01 9.55884104e-04 1.00000000e-06 1.05155667e-02
#  2.45886138e-01 4.36370605e-02 5.09844284e-02] | SSR: 0.024968840969139046
# Parameters: [2.57505869e-01 9.61768792e-04 1.00000000e-06 1.05224303e-02
#  2.45786541e-01 4.36096760e-02 5.09668986e-02] | SSR: 0.024968875407167128
# Parameters: [2.57400534e-01 9.54010654e-04 1.00000000e-06 1.05056950e-02
#  2.46019648e-01 4.36773343e-02 5.10077750e-02] | SSR: 0.024968898411662
# Parameters: [2.57261173e-01 9.67337601e-04 1.00000000e-06 1.05187830e-02
#  2.45929323e-01 4.36342758e-02 5.09767991e-02] | SSR: 0.02496887612412465
# Parameters: [2.57697523e-01 9.56250601e-04 1.00000000e-06 1.05176884e-02
#  2.45909662e-01 4.36329078e-02 5.09809684e-02] | SSR: 0.024968881244314463
# Parameters: [2.57623276e-01 9.55690614e-04 1.00000000e-06 1.05146901e-02
#  2.45937159e-01 4.36440144e-02 5.09876701e-02] | SSR: 0.02496885269026742
# Parameters: [2.57940342e-01 9.39595942e-04 1.00000000e-06 1.05034311e-02
#  2.46002226e-01 4.36787488e-02 5.10150503e-02] | SSR: 0.024968903051318624
# Parameters: [2.57430965e-01 9.60402187e-04 1.00000000e-06 1.05149450e-02
#  2.45947549e-01 4.36453940e-02 5.09863619e-02] | SSR: 0.02496885069583882
# Parameters: [2.57529312e-01 9.59290953e-04 1.00000000e-06 1.05181651e-02
#  2.45875904e-01 4.36282515e-02 5.09850172e-02] | SSR: 0.024968858856289904
# Parameters: [2.57466239e-01 9.60113833e-04 1.00000000e-06 1.05174068e-02
#  2.45857020e-01 4.36293331e-02 5.09796580e-02] | SSR: 0.024968870244121377
# Parameters: [2.57597127e-01 9.59727614e-04 1.00000000e-06 1.05182785e-02
#  2.45778140e-01 4.36097010e-02 5.09792618e-02] | SSR: 0.024968846500412117
# Parameters: [2.57673944e-01 9.53448591e-04 1.00000000e-06 1.05118235e-02
#  2.45937265e-01 4.36467640e-02 5.09973119e-02] | SSR: 0.02496886160778911
# Parameters: [2.57700074e-01 9.56382981e-04 1.00000000e-06 1.05211117e-02
#  2.45786869e-01 4.36100099e-02 5.09786888e-02] | SSR: 0.0249688593468454
# Parameters: [2.57525668e-01 9.60123152e-04 1.00000000e-06 1.05208839e-02
#  2.45798461e-01 4.36145380e-02 5.09741218e-02] | SSR: 0.024968876411113904
# Parameters: [2.57636875e-01 9.55117231e-04 1.00000000e-06 1.05140886e-02
#  2.45902564e-01 4.36387075e-02 5.09915144e-02] | SSR: 0.02496884271315898
# Parameters: [2.57447709e-01 9.64876121e-04 1.00000000e-06 1.05216659e-02
#  2.45883665e-01 4.36207714e-02 5.09708226e-02] | SSR: 0.024968852204691357
# Parameters: [2.57401872e-01 9.61042398e-04 1.00000000e-06 1.05124311e-02
#  2.45987736e-01 4.36539616e-02 5.09884758e-02] | SSR: 0.024968876142365995
# Parameters: [2.57625523e-01 9.57547835e-04 1.00000000e-06 1.05189416e-02
#  2.45837086e-01 4.36209978e-02 5.09811356e-02] | SSR: 0.024968841396526543
# Parameters: [2.57600123e-01 9.57636392e-04 1.00000000e-06 1.05155996e-02
#  2.45887611e-01 4.36336476e-02 5.09810384e-02] | SSR: 0.024968856266505725
# Parameters: [2.57582420e-01 9.58050032e-04 1.00000000e-06 1.05162410e-02
#  2.45884684e-01 4.36322986e-02 5.09820331e-02] | SSR: 0.02496884172877939
# Parameters: [2.57494486e-01 9.61910850e-04 1.00000000e-06 1.05195177e-02
#  2.45811363e-01 4.36145372e-02 5.09767750e-02] | SSR: 0.024968835038261084
# Parameters: [2.57430091e-01 9.65020968e-04 1.00000000e-06 1.05219315e-02
#  2.45748465e-01 4.35997986e-02 5.09713275e-02] | SSR: 0.02496884953937365
# Parameters: [2.57683418e-01 9.51878123e-04 1.00000000e-06 1.05119282e-02
#  2.45844199e-01 4.36359990e-02 5.09953232e-02] | SSR: 0.024968848862989286
# Parameters: [2.57772291e-01 9.53916610e-04 1.00000000e-06 1.05177871e-02
#  2.45750786e-01 4.36086921e-02 5.09823442e-02] | SSR: 0.024968849957250176
# Parameters: [2.57686959e-01 9.55538004e-04 1.00000000e-06 1.05170766e-02
#  2.45799977e-01 4.36178676e-02 5.09833486e-02] | SSR: 0.024968838197383828
# Parameters: [2.57520850e-01 9.63486354e-04 1.00000000e-06 1.05222749e-02
#  2.45841502e-01 4.36129067e-02 5.09699617e-02] | SSR: 0.024968846436359812
# Parameters: [2.57585348e-01 9.56710789e-04 1.00000000e-06 1.05170663e-02
#  2.45925664e-01 4.36401207e-02 5.09833659e-02] | SSR: 0.02496883480048707
# Parameters: [2.57579459e-01 9.55202376e-04 1.00000000e-06 1.05164602e-02
#  2.45999427e-01 4.36553305e-02 5.09854179e-02] | SSR: 0.02496885103321287
# Parameters: [2.57680053e-01 9.51016173e-04 1.00000000e-06 1.05115818e-02
#  2.45886349e-01 4.36446903e-02 5.09964957e-02] | SSR: 0.02496884591567699
# Parameters: [2.57640252e-01 9.54133718e-04 1.00000000e-06 1.05142551e-02
#  2.45875137e-01 4.36367444e-02 5.09898622e-02] | SSR: 0.024968835736076694
# Parameters: [2.57564992e-01 9.59104292e-04 1.00000000e-06 1.05198156e-02
#  2.45817450e-01 4.36183288e-02 5.09744710e-02] | SSR: 0.024968849159442537
# Parameters: [2.57618904e-01 9.56113996e-04 1.00000000e-06 1.05155204e-02
#  2.45881286e-01 4.36336128e-02 5.09872535e-02] | SSR: 0.02496883436442318
# Parameters: [2.57629871e-01 9.55618338e-04 1.00000000e-06 1.05174574e-02
#  2.45834359e-01 4.36251132e-02 5.09854438e-02] | SSR: 0.024968841343826396
# Parameters: [2.57588010e-01 9.55569251e-04 1.00000000e-06 1.05143327e-02
#  2.45881178e-01 4.36375897e-02 5.09875723e-02] | SSR: 0.024968830446121075
# Parameters: [2.57569254e-01 9.54579959e-04 1.00000000e-06 1.05120283e-02
#  2.45903224e-01 4.36458856e-02 5.09907906e-02] | SSR: 0.024968837608412366
# Optimization successful: True
# Number of iterations: 614
#
# Optimized parameters:
# beta: 0.257588
# gamma: 0.000956
# rho: 0.000001
# delta: 0.010514
# p: 0.245881
# c: 0.043638
# alpha: 0.050988
# guess =  [np.float64(0.2575880102642967), np.float64(0.0009555692508340179), np.float64(1.000000000002647e-06), np.float64(0.010514332732879526), np.float64(0.24588117801631307), np.float64(0.04363758968038428), np.float64(0.050987572273508835)]

# %%
# Calculate final SSR
final_ssr = result.fun
print(f"\nFinal SSR: {final_ssr:.6f}")

# Generate 95% confidence intervals for model predictions using bootstrap parameters
try:
    # Load bootstrap parameters if available
    bootstrap_params = np.loadtxt(f"{output_prefix}_params.txt", delimiter=",")
    
    # Generate model predictions for each bootstrap parameter set
    V_bootstrap = []
    F_bootstrap = []
    
    # Use a subset of bootstrap samples for speed (every 10th sample)
    n_samples = min(100, len(bootstrap_params))
    sample_indices = np.linspace(0, len(bootstrap_params)-1, n_samples, dtype=int)
    
    for idx in sample_indices:
        params = bootstrap_params[idx]
        try:
            solution = odeint(Model, y0, t, args=tuple(params))
            _, _, _, V_boot, F_boot = solution.T
            V_bootstrap.append(V_boot)
            F_bootstrap.append(F_boot)
        except:
            continue
    
    # Calculate 95% confidence intervals
    if len(V_bootstrap) > 10:
        V_bootstrap = np.array(V_bootstrap)
        F_bootstrap = np.array(F_bootstrap)
        
        V_ci_lower = np.percentile(V_bootstrap, 2.5, axis=0)
        V_ci_upper = np.percentile(V_bootstrap, 97.5, axis=0)
        F_ci_lower = np.percentile(F_bootstrap, 2.5, axis=0)
        F_ci_upper = np.percentile(F_bootstrap, 97.5, axis=0)
        
        print(f"Generated 95% CI from {len(V_bootstrap)} bootstrap samples")
        ci_available = True
    else:
        print("Insufficient bootstrap samples for CI calculation")
        ci_available = False
        
except:
    print("Bootstrap data not available for CI calculation")
    ci_available = False

# Plot results with 95% confidence intervals
plt.figure(figsize=(12, 5))

# Plot viral load
plt.subplot(121)
if ci_available:
    plt.fill_between(t, V_ci_lower, V_ci_upper, alpha=0.3, color='blue', label='95% CI')
plt.plot(t, V_fit, 'b-', label='Model', linewidth=2)
plt.plot(vl_data['time'], vl_data['value'], 'bo', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('Viral Load (log10)')
plt.legend()
plt.title('Viral Load Fit')

# Plot interferon
plt.subplot(122)
if ci_available:
    plt.fill_between(t, F_ci_lower, F_ci_upper, alpha=0.3, color='red', label='95% CI')
plt.plot(t, F_fit, 'r-', label='Model', linewidth=2)
plt.plot(t1_data['time'], t1_data['value'], 'ro', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('IFN-A2 Level')
plt.legend()
plt.title('Interferon Fit')

plt.tight_layout()
plt.savefig("h5n1(2005)_nasal_fit_with_ci.png")
plt.show()
# Out:
# Final SSR: 0.024969
# Bootstrap data not available for CI calculation

# %%
# %% Bootstrap Analysis
import os

# Create output directory
strain = "h5n1(2005)"  # Change for each file
location = "nasal"     # Change for each file
output_dir = f"/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/{strain}/{location}/bootstrap_results"
os.makedirs(output_dir, exist_ok=True)
output_prefix = f"{output_dir}/{strain}_{location}"

# Calculate residuals between data and best-fit model
# Find indices for data_times in t
indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
V_best = V_fit[indices]
F_best = F_fit[indices]

# Calculate residuals (use for bootstrapping)
residuals_viral = vl_data['value'] - V_best
residuals_ifn = t1_data['value'] - F_best

# Use best-fit parameters from previous optimization
best_params = [beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit]

# Define bootstrap optimization function that uses relative error
def optimize_bootstrap(params, new_viral_data, new_ifn_data):
    """
    Objective function for bootstrap optimization.
    Uses relative error just like the original optimize function.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        V_pred = V[indices]
        F_pred = F[indices]
        
        # Calculate relative SSR (same method as in original optimize function)
        vl_ssr = np.sum((((np.maximum(V_pred, 0)) - new_viral_data)/new_viral_data)**2)
        ifn_ssr = np.sum(((F_pred - new_ifn_data)/new_ifn_data)**2)
        
        total_ssr = vl_ssr + ifn_ssr
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

# Number of bootstrap samples
n_bootstrap = 1000

# Initialize arrays for bootstrap results
bootstrap_params = []
bootstrap_ssr = []

print(f"Starting bootstrap analysis with {n_bootstrap} samples")
print(f"Using best-fit parameters: {best_params}")

# Run bootstrap
for i in range(n_bootstrap):
    # Generate new datasets by resampling residuals
    new_viral_data = V_best + np.random.choice(residuals_viral, size=len(residuals_viral), replace=True)
    new_ifn_data = F_best + np.random.choice(residuals_ifn, size=len(residuals_ifn), replace=True)
    
    # Ensure non-negative values
    new_viral_data = np.maximum(new_viral_data, 1e-6)  # Using small positive number instead of zero for relative error
    new_ifn_data = np.maximum(new_ifn_data, 1e-6)
    
    # Optimize with new dataset
    result_bootstrap = minimize(
        optimize_bootstrap, 
        best_params, 
        args=(new_viral_data, new_ifn_data), 
        method='Nelder-Mead', 
        bounds=bounds
    )
    
    bootstrap_params.append(result_bootstrap.x)
    bootstrap_ssr.append(result_bootstrap.fun)
    
    if (i+1) % 10 == 0 or i == 0:
        print(f"Processing bootstrap sample {i+1}/{n_bootstrap}")

# Save bootstrap parameters and SSR to text files
np.savetxt(f"{output_prefix}_params.txt", np.array(bootstrap_params), delimiter=",")
np.savetxt(f"{output_prefix}_ssr.txt", np.array(bootstrap_ssr), delimiter=",")

# Calculate and print statistics
print(f"\nBootstrap Statistics:")
print(f"Mean SSR: {np.mean(bootstrap_ssr)}")
print(f"Median SSR: {np.median(bootstrap_ssr)}")
print(f"Standard Deviation of SSR: {np.std(bootstrap_ssr)}")

# Calculate parameter statistics
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
param_stats = {}

# Create a results summary file
with open(f"{output_prefix}_summary.txt", "w") as f:
    f.write(f"Bootstrap Results Summary for {strain} {location}\n")
    f.write(f"Number of bootstrap samples: {n_bootstrap}\n\n")
    f.write(f"SSR Statistics:\n")
    f.write(f"Mean: {np.mean(bootstrap_ssr):.6f}\n")
    f.write(f"Median: {np.median(bootstrap_ssr):.6f}\n")
    f.write(f"Std Dev: {np.std(bootstrap_ssr):.6f}\n\n")
    
    f.write(f"Parameter Statistics:\n")
    for i, name in enumerate(param_names):
        param_values = np.array(bootstrap_params)[:, i]
        mean_val = np.mean(param_values)
        median_val = np.median(param_values)
        ci_low = np.percentile(param_values, 2.5)
        ci_high = np.percentile(param_values, 97.5)
        
        param_stats[name] = {
            'mean': mean_val,
            'median': median_val,
            'ci_low': ci_low,
            'ci_high': ci_high
        }
        
        f.write(f"{name}:\n")
        f.write(f"  Mean: {mean_val:.6f}\n")
        f.write(f"  Median: {median_val:.6f}\n")
        f.write(f"  95% CI: [{ci_low:.6f}, {ci_high:.6f}]\n\n")

print(f"Bootstrap analysis complete. Results saved to {output_dir}")
# Out:
# Starting bootstrap analysis with 1000 samples
# Using best-fit parameters: [np.float64(0.2575880102642967), np.float64(0.0009555692508340179), np.float64(1.000000000002647e-06), np.float64(0.010514332732879526), np.float64(0.24588117801631307), np.float64(0.04363758968038428), np.float64(0.050987572273508835)]
# Processing bootstrap sample 1/1000
# Processing bootstrap sample 10/1000
# Processing bootstrap sample 20/1000
# Processing bootstrap sample 30/1000
# Processing bootstrap sample 40/1000
# Processing bootstrap sample 50/1000
# Processing bootstrap sample 60/1000
# Processing bootstrap sample 70/1000
# Processing bootstrap sample 80/1000
# Processing bootstrap sample 90/1000
# Processing bootstrap sample 100/1000
# Processing bootstrap sample 110/1000
# Processing bootstrap sample 120/1000
# Processing bootstrap sample 130/1000
# Processing bootstrap sample 140/1000
# Processing bootstrap sample 150/1000
# Processing bootstrap sample 160/1000
# Processing bootstrap sample 170/1000
# Processing bootstrap sample 180/1000
# Processing bootstrap sample 190/1000
# Processing bootstrap sample 200/1000
# Processing bootstrap sample 210/1000
# Processing bootstrap sample 220/1000
# Processing bootstrap sample 230/1000
# Processing bootstrap sample 240/1000
# Processing bootstrap sample 250/1000
# Processing bootstrap sample 260/1000
# Processing bootstrap sample 270/1000
# Processing bootstrap sample 280/1000
# Processing bootstrap sample 290/1000
# Processing bootstrap sample 300/1000
# Processing bootstrap sample 310/1000
# Processing bootstrap sample 320/1000
# Processing bootstrap sample 330/1000
# Processing bootstrap sample 340/1000
# Processing bootstrap sample 350/1000
# Processing bootstrap sample 360/1000
# Processing bootstrap sample 370/1000
# Processing bootstrap sample 380/1000
# Processing bootstrap sample 390/1000
# Processing bootstrap sample 400/1000
# Processing bootstrap sample 410/1000
# Processing bootstrap sample 420/1000
# Processing bootstrap sample 430/1000
# Processing bootstrap sample 440/1000
# Processing bootstrap sample 450/1000
# Processing bootstrap sample 460/1000
# Processing bootstrap sample 470/1000
# Processing bootstrap sample 480/1000
# Processing bootstrap sample 490/1000
# Processing bootstrap sample 500/1000
# Processing bootstrap sample 510/1000
# Processing bootstrap sample 520/1000
# Processing bootstrap sample 530/1000
# Processing bootstrap sample 540/1000
# Processing bootstrap sample 550/1000
# Processing bootstrap sample 560/1000
# Processing bootstrap sample 570/1000
# Processing bootstrap sample 580/1000
# Processing bootstrap sample 590/1000
# Processing bootstrap sample 600/1000
# Processing bootstrap sample 610/1000
# Processing bootstrap sample 620/1000
# Processing bootstrap sample 630/1000
# Processing bootstrap sample 640/1000
# Processing bootstrap sample 650/1000
# Processing bootstrap sample 660/1000
# Processing bootstrap sample 670/1000
# Processing bootstrap sample 680/1000
# Processing bootstrap sample 690/1000
# Processing bootstrap sample 700/1000
# Processing bootstrap sample 710/1000
# Processing bootstrap sample 720/1000
# Processing bootstrap sample 730/1000
# Processing bootstrap sample 740/1000
# Processing bootstrap sample 750/1000
# Processing bootstrap sample 760/1000
# Processing bootstrap sample 770/1000
# Processing bootstrap sample 780/1000
# Processing bootstrap sample 790/1000
# Processing bootstrap sample 800/1000
# Processing bootstrap sample 810/1000
# Processing bootstrap sample 820/1000
# Processing bootstrap sample 830/1000
# Processing bootstrap sample 840/1000
# Processing bootstrap sample 850/1000
# Processing bootstrap sample 860/1000
# Processing bootstrap sample 870/1000
# Processing bootstrap sample 880/1000
# Processing bootstrap sample 890/1000
# Processing bootstrap sample 900/1000
# Processing bootstrap sample 910/1000
# Processing bootstrap sample 920/1000
# Processing bootstrap sample 930/1000
# Processing bootstrap sample 940/1000
# Processing bootstrap sample 950/1000
# Processing bootstrap sample 960/1000
# Processing bootstrap sample 970/1000
# Processing bootstrap sample 980/1000
# Processing bootstrap sample 990/1000
# Processing bootstrap sample 1000/1000
#
# Bootstrap Statistics:
# Mean SSR: 0.05037556565157215
# Median SSR: 0.03290320339298508
# Standard Deviation of SSR: 0.04585983712523511
# Bootstrap analysis complete. Results saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h5n1(2005)/nasal/bootstrap_results

# %%
# %% Parameter Distribution Plotting
# Log ALL parameters for consistent, nice-looking bootstrap charts
fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.flatten()

# Convert bootstrap_params to numpy array for easier indexing
bootstrap_params = np.array(bootstrap_params)

for i, name in enumerate(param_names):
    if i < len(axes):
        ax = axes[i]
        param_values = bootstrap_params[:, i]
        
        # Log ALL parameters - show only 5-95 percentile
        log_values = np.log10(np.maximum(param_values, 1e-12))
        p5, p95 = np.percentile(log_values, [5, 95])
        filtered_log_values = log_values[(log_values >= p5) & (log_values <= p95)]
        n_bins = min(30, max(10, len(filtered_log_values)//30))
        
        ax.hist(filtered_log_values, bins=n_bins, alpha=0.7, color='skyblue', edgecolor='black', linewidth=0.5)
        
        # Add reference lines
        ax.axvline(np.log10(best_params[i]), color='r', linestyle='--', linewidth=2, label='Best fit')
        ax.axvline(np.log10(param_stats[name]['mean']), color='g', linestyle='-', linewidth=2, label='Bootstrap mean')
        ax.axvline(np.log10(param_stats[name]['ci_low']), color='k', linestyle=':', linewidth=1.5, label='95% CI')
        ax.axvline(np.log10(param_stats[name]['ci_high']), color='k', linestyle=':', linewidth=1.5)
        
        ax.set_xlabel(f'log₁₀({name})', fontsize=12)
        ax.set_title(f'{name} (n={len(filtered_log_values)}, log scale, 5-95%)', fontsize=14)
        ax.set_ylabel('Frequency', fontsize=12)
        ax.tick_params(labelsize=10)
        
        if i == 0:  # Only add legend to first plot
            ax.legend(fontsize=10, loc='upper right')

# Remove empty subplots
for i in range(len(param_names), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
plt.close()

print(f"Parameter distribution plots saved to {output_prefix}_param_distributions.png")
print("All parameters plotted on log scale with 5-95 percentile range")
# Out:
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_1989/4098012820.py:40: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_1989/4098012820.py:40: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_1989/4098012820.py:41: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_1989/4098012820.py:41: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# Parameter distribution plots saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h5n1(2005)/nasal/bootstrap_results/h5n1(2005)_nasal_param_distributions.png
# All parameters plotted on log scale with 5-95 percentile range
