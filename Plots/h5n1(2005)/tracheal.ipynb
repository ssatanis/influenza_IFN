# %%
# Standard scientific libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.optimize import minimize

# Set plotting style for better visualization
plt.style.use("seaborn-v0_8")

# %%
vl_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/tracheal_data/h5n1(2005)/tracheal_h5n1_2005_vl.txt"
t1_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/tracheal_data/h5n1(2005)/tracheal_h5n1_2005_t1.txt"

# Load the viral load data
vl_data = pd.read_csv(vl_path)
print("Viral Load Data:")
print(vl_data, "\n")

# Load the interferon data
t1_data = pd.read_csv(t1_path)
print("Interferon Data:")
print(t1_data)

# Let's also create a simple plot to visualize our data
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot viral load data
ax1.plot(vl_data['time'], vl_data['value'], 'o-', color='blue', label='Viral Load')
ax1.set_xlabel('Time (hours)')
ax1.set_ylabel('Viral Load (log scale)')
ax1.set_title('H5N1 Tracheal Viral Load')
ax1.legend()

# Plot interferon data
ax2.plot(t1_data['time'], t1_data['value'], 'o-', color='red', label='IFN-A2')
ax2.set_xlabel('Time (hours)')
ax2.set_ylabel('IFN-A2 Level')
ax2.set_title('H5N1 Tracheal Interferon')
ax2.legend()

plt.tight_layout()
plt.savefig('tracheal_h5n1_2005.png')
plt.show()
# Out:
# Viral Load Data:
#    time  value
# 0     0  2.584
# 1     8  3.791
# 2    24  4.566
# 3    48  5.138
# 4    72  4.338
#
# Interferon Data:
#    time  value
# 0     0  2.138
# 1     8  2.203
# 2    24  3.629
# 3    48  5.961
# 4    72  5.248

# %%
def Model(y, t, beta, gamma, rho, delta, p, c, alpha):
    """
    Extended model with resistant cell class
    
    Parameters:
    y: list of variables [T, R, I, V, F]
    t: time points
    beta: infection rate
    gamma: rate of conversion to resistant state
    rho: rate of return from resistant state
    delta: death rate of infected cells
    p: virus production rate
    c: virus clearance rate
    alpha: interferon clearance rate
    """
    T, R, I, V, F = y
    
    # System of ODEs
    dTdt = -beta * T * V - gamma * T * F    # Target cells
    dRdt = gamma * T * F - rho * R          # Resistant cells
    dIdt = beta * T * V - delta * I         # Infected cells
    dVdt = p * I - c * V                    # Virus
    dFdt = I - alpha * F                    # Interferon
    
    return [dTdt, dRdt, dIdt, dVdt, dFdt]

# Initial conditions
T0 = 1.0     # Initial target cells (normalized)
R0 = 0.0     # Initial resistant cells
I0 = 0.0     # Initial infected cells
V0 = vl_data['value'].iloc[0]    # Initial virus from data
F0 = t1_data['value'].iloc[0]    # Initial interferon from data
y0 = [T0, R0, I0, V0, F0]

print("Initial conditions:")
for var, val in zip(['T0', 'R0', 'I0', 'V0', 'F0'], y0):
    print(f"{var} = {val}")
# Out:
# Initial conditions:
# T0 = 1.0
# R0 = 0.0
# I0 = 0.0
# V0 = 2.584
# F0 = 2.138

# %%
# Create two sets of time points:
# 1. Data time points for comparison
data_times = np.array([0, 8, 24, 48, 72])

# 2. Integration time points (finer mesh for solving ODEs)
t = np.linspace(0, 72, 100)

def optimize(params):
    """
    Objective function to minimize.
    Uses relative error at actual data time points.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        # Find indices in t that correspond to data_times
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        global V_model, F_model
        V_model = V[indices]
        F_model = F[indices]
        
        # Calculate relative SSR
        vl_ssr = np.sum((((np.maximum(V_model, 0)) - vl_data['value'])/vl_data['value'])**2)
        ifn_ssr = np.sum(((F_model - t1_data['value'])/t1_data['value'])**2)
        
        total_ssr = vl_ssr + ifn_ssr
        
        print(f"Parameters: {params} | SSR: {total_ssr}")
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

print("Data time points:", data_times)
print("\nNumber of integration points:", len(t))
print("Integration time range:", t[0], "to", t[-1])
# Out:
# Data time points: [ 0  8 24 48 72]
#
# Number of integration points: 100
# Integration time range: 0.0 to 72.0

# %%
guess = [0.1, 0.1, 0.1, 0.1, 10.0, 0.1, 0.1]

# %%
bounds = [
    (1e-6, 10.0),   # beta
    (1e-6, 10.0),   # gamma
    (1e-6, 10.0),   # rho 
    (1e-6, 10.0),   # delta
    (1e-1, 1e7), #p
    (1e-6, 10.0),   # c
    (1e-6, 100.0)    # alpha
]

print("Initial parameter guesses:")
for param, value in zip(['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha'], guess):
    print(f"{param}: {value}")
# Out:
# Initial parameter guesses:
# beta: 0.1
# gamma: 0.1
# rho: 0.1
# delta: 0.1
# p: 10.0
# c: 0.1
# alpha: 0.1

# %%
# Perform optimization
result = minimize(optimize, guess, method ='Nelder-Mead', bounds=bounds)

# Extract optimized parameters
beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit = result.x

# Generate solution with optimized parameters
solution_fit = odeint(Model, y0, t, args=(beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit))
T_fit, R_fit, I_fit, V_fit, F_fit = solution_fit.T

# Print optimization results
print("Optimization successful:", result.success)
print("Number of iterations:", result.nit)
print("\nOptimized parameters:")
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
for name, value in zip(param_names, result.x):
    print(f"{name}: {value:.6f}")

print("guess = ", [i for i in result.x])
# Out:
# Parameters: [ 0.1  0.1  0.1  0.1 10.   0.1  0.1] | SSR: 36.9373071503988
# Parameters: [ 0.105  0.1    0.1    0.1   10.     0.1    0.1  ] | SSR: 38.28457042078866
# Parameters: [ 0.1    0.105  0.1    0.1   10.     0.1    0.1  ] | SSR: 35.552719184394434
# Parameters: [ 0.1    0.1    0.105  0.1   10.     0.1    0.1  ] | SSR: 36.9373071503988
# Parameters: [ 0.1    0.1    0.1    0.105 10.     0.1    0.1  ] | SSR: 35.11512432032652
# Parameters: [ 0.1  0.1  0.1  0.1 10.5  0.1  0.1] | SSR: 41.53717969641655
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.105  0.1  ] | SSR: 34.863930072110925
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.1    0.105] | SSR: 37.10487826679122
# Parameters: [0.10142857 0.10142857 0.10142857 0.10142857 9.5        0.10142857
#  0.10142857] | SSR: 31.701626923747995
# Parameters: [0.10214286 0.10214286 0.10214286 0.10214286 9.         0.10214286
#  0.10214286] | SSR: 27.481208714580866
# Parameters: [0.09561224 0.10204082 0.10204082 0.10204082 9.71428571 0.10204082
#  0.10204082] | SSR: 31.402545056049075
# Parameters: [0.0993586  0.10262391 0.10262391 0.10262391 9.63265306 0.10262391
#  0.09619534] | SSR: 31.001265975786303
# Parameters: [0.09917534 0.10337359 0.09694502 0.10337359 9.52769679 0.10337359
#  0.10010829] | SSR: 29.629635669584975
# Parameters: [0.09893973 0.10433748 0.10107217 0.10433748 9.39275302 0.10433748
#  0.10013923] | SSR: 27.819470285672573
# Parameters: [0.09863679 0.09914819 0.10137851 0.10557676 9.21925388 0.10557676
#  0.10017901] | SSR: 26.947425934873657
# Parameters: [0.09795519 0.09622228 0.10206776 0.10836514 8.82888082 0.10836514
#  0.10026851] | SSR: 23.4571171536349
# Parameters: [0.09805256 0.10306884 0.1019693  0.10153823 8.8846484  0.1079668
#  0.10025572] | SSR: 24.138884968403282
# Parameters: [0.09749615 0.10394565 0.10253195 0.10697772 8.56597652 0.10381445
#  0.10032879] | SSR: 21.811742298226406
# Parameters: [0.09624422 0.10591847 0.10379793 0.11046658 7.84896478 0.10322168
#  0.10049318] | SSR: 17.02138550819189
# Parameters: [0.10206447 0.10301273 0.10099317 0.10734426 8.31874197 0.10711103
#  0.09784579] | SSR: 20.441934602188375
# Parameters: [0.09909122 0.10254074 0.09994415 0.10810985 8.02497145 0.10780997
#  0.10416283] | SSR: 18.34696760473988
# Parameters: [0.09925044 0.10155309 0.10647993 0.10871337 7.70057762 0.10832782
#  0.10140832] | SSR: 16.655023628531637
# Parameters: [0.09928799 0.10064284 0.11124738 0.11138326 6.78701803 0.11080493
#  0.10205833] | SSR: 12.280986678942591
# Parameters: [0.09958556 0.0995336  0.10525998 0.10976257 7.09102568 0.10921178
#  0.1019257 ] | SSR: 13.941843143088782
# Parameters: [0.09565178 0.10098271 0.10507991 0.11413425 6.93835747 0.11342609
#  0.09986002] | SSR: 11.931157719532484
# Parameters: [0.09240624 0.10040264 0.10654843 0.12012995 5.9075362  0.11906771
#  0.0987186 ] | SSR: 8.081477125375004
# Parameters: [0.09812884 0.09929496 0.10656179 0.1200508  6.20310557 0.11077384
#  0.10130797] | SSR: 9.794686160408279
# Parameters: [0.09827582 0.10701943 0.10774734 0.11656266 5.50865165 0.1110637
#  0.10159218] | SSR: 7.778978586946092
# Parameters: [0.09843614 0.11241801 0.11058712 0.12066141 3.84853707 0.11241299
#  0.10225401] | SSR: 5.114333113071359
# Parameters: [0.09312987 0.1029162  0.11156306 0.12138843 4.74158911 0.11383266
#  0.10527439] | SSR: 6.133753590298447
# Parameters: [0.09439988 0.10349547 0.11593176 0.12441673 4.09725039 0.11485448
#  0.09927494] | SSR: 5.309354621242925
# Parameters: [0.09671992 0.09942544 0.11554479 0.12604575 3.20133867 0.12276643
#  0.10259652] | SSR: 4.77378315688398
# Parameters: [0.09695778 0.09617893 0.12141823 0.13383534 0.87752561 0.13253881
#  0.10364818] | SSR: 5.382243654979664
# Parameters: [0.09255983 0.10577942 0.11702126 0.1314021  2.84793862 0.12064909
#  0.10135567] | SSR: 4.695503888248947
# Parameters: [0.08904697 0.10890233 0.12290189 0.14222186 0.72639509 0.12636774
#  0.10107065] | SSR: 5.555946714523996
# Parameters: [0.09093507 0.10613777 0.11268354 0.13550107 2.02649501 0.12186855
#  0.10102226] | SSR: 4.822572803167883
# Parameters: [0.09003887 0.10944074 0.1191182  0.13124789 1.41709016 0.12506956
#  0.10169099] | SSR: 5.071654242414444
# Parameters: [0.09508508 0.11091537 0.12272292 0.13434531 0.42967495 0.11849051
#  0.10512962] | SSR: 5.666714821802326
# Parameters: [0.09492007 0.11068729 0.12089682 0.13678879 0.36364656 0.12505637
#  0.09853247] | SSR: 5.729769870871136
# Parameters: [0.09447252 0.10874452 0.11856338 0.1329387  1.4581322  0.12225044
#  0.10021795] | SSR: 5.0121416861501356
# Parameters: [0.09278985 0.10206788 0.10854852 0.12343003 4.96940565 0.12147279
#  0.0972739 ] | SSR: 6.193372794165912
# Parameters: [0.09451127 0.1087035  0.11917932 0.13161649 1.56460763 0.11923608
#  0.10316569] | SSR: 4.942146911677014
# Parameters: [0.09350687 0.11097579 0.11626756 0.13541568 0.57821799 0.1263607
#  0.10424023] | SSR: 5.621284588884494
# Parameters: [0.09417663 0.10536555 0.11601571 0.12716647 3.21749229 0.11773104
#  0.10051626] | SSR: 4.7386642641354015
# Parameters: [0.08825361 0.10003826 0.12316322 0.14102958 0.64663281 0.13032164
#  0.10076466] | SSR: 5.596881834664988
# Parameters: [0.09589051 0.10932307 0.11373115 0.12575345 3.048061   0.11689015
#  0.10188167] | SSR: 4.690331217716984
# Parameters: [0.09832278 0.10298191 0.11309299 0.12887326 3.54407139 0.11532809
#  0.10138216] | SSR: 4.960964876525172
# Parameters: [0.0949892  0.10203167 0.11208483 0.1260209  4.09901197 0.11616939
#  0.10318783] | SSR: 5.351887143636588
# Parameters: [0.09460169 0.10706631 0.11694375 0.13120925 2.11835214 0.12073018
#  0.10096042] | SSR: 4.745667148877429
# Parameters: [0.09007577 0.10896125 0.11865544 0.13075377 1.60572443 0.1246352
#  0.10190313] | SSR: 4.974083464363044
# Parameters: [0.09626103 0.10447674 0.1144836  0.12934338 3.05948465 0.11765487
#  0.1015124 ] | SSR: 4.725727163706898
# Parameters: [0.09438721 0.10203202 0.11122748 0.12736108 4.01229591 0.12027544
#  0.09964722] | SSR: 5.200234518495842
# Parameters: [0.09448026 0.10703563 0.11719136 0.13055263 2.1765297  0.11949592
#  0.10228607] | SSR: 4.725423876568265
# Parameters: [0.09897632 0.10485427 0.11901121 0.12206265 3.59327559 0.11696507
#  0.10215174] | SSR: 4.96534471184278
# Parameters: [0.09294539 0.1058169  0.11426545 0.13214147 2.41819015 0.12064268
#  0.10130463] | SSR: 4.704233938985797
# Parameters: [0.09211303 0.11339273 0.11578443 0.13325961 2.19467521 0.11546041
#  0.10020838] | SSR: 4.73165954367193
# Parameters: [0.09352021 0.10755942 0.11405424 0.12868193 3.29946832 0.115991
#  0.1016296 ] | SSR: 4.7730924652629225
# Parameters: [0.09433132 0.10718958 0.11622137 0.13057742 2.41363119 0.11954539
#  0.10112772] | SSR: 4.6858522243557434
# Parameters: [0.09398947 0.10978133 0.11504104 0.13369927 1.97065357 0.11950853
#  0.10224846] | SSR: 4.816884070555595
# Parameters: [0.09412984 0.10646949 0.11577204 0.12879967 2.90578261 0.11817541
#  0.10094931] | SSR: 4.675312217685189
# Parameters: [0.09662931 0.09977608 0.11526878 0.12633186 3.1966442  0.12255488
#  0.10276804] | SSR: 4.773307352394268
# Parameters: [0.0932421  0.10998857 0.11565552 0.13152767 2.44516746 0.11723402
#  0.10084829] | SSR: 4.6829346477231955
# Parameters: [0.09161876 0.11026687 0.11690444 0.13087216 2.15631556 0.12024018
#  0.10127428] | SSR: 4.750135827124115
# Parameters: [0.09510046 0.10592428 0.11508881 0.12972558 2.83369238 0.1183012
#  0.10145287] | SSR: 4.679121691970367
# Parameters: [0.09357673 0.10739046 0.11359595 0.12942661 3.22703128 0.11805778
#  0.10026254] | SSR: 4.747316672122175
# Parameters: [0.09425437 0.10712434 0.11629251 0.13027113 2.43915509 0.11913638
#  0.10178019] | SSR: 4.681688324871779
# Parameters: [0.0954856  0.10898274 0.11710102 0.12730339 2.9913608  0.11648064
#  0.10137986] | SSR: 4.6826342314327505
# Parameters: [0.09670708 0.10993546 0.114368   0.1268717  2.60259011 0.11528325
#  0.10133574] | SSR: 4.629140359573692
# Parameters: [0.0987807  0.11201348 0.11304138 0.12460651 2.47991585 0.11260033
#  0.10132577] | SSR: 4.596887266950231
# Parameters: [0.09420218 0.1071605  0.11746104 0.13219265 2.24014053 0.11781653
#  0.1006509 ] | SSR: 4.708578285136885
# Parameters: [0.09546842 0.10878243 0.11466362 0.12736325 2.84608089 0.11712174
#  0.10157398] | SSR: 4.660307276156831
# Parameters: [0.09608625 0.10974908 0.11452574 0.12645035 2.99812741 0.11446882
#  0.10153236] | SSR: 4.675513348704586
# Parameters: [0.09798809 0.10688167 0.1147688  0.12404944 3.1245797  0.11599013
#  0.10200723] | SSR: 4.717507696721903
# Parameters: [0.09442859 0.10921184 0.11543384 0.12965811 2.61502052 0.11692305
#  0.10113803] | SSR: 4.657745097806676
# Parameters: [0.09544259 0.10795295 0.11284696 0.12894649 2.47086055 0.11686991
#  0.10140658] | SSR: 4.653420706060536
# Parameters: [0.0970133  0.11004811 0.11267103 0.12560029 3.03212496 0.11356661
#  0.10089949] | SSR: 4.676935133115036
# Parameters: [0.09671374 0.1124264  0.11318394 0.12496718 2.6942827  0.11304906
#  0.10106871] | SSR: 4.607467938667976
# Parameters: [0.09471531 0.10898208 0.11574826 0.12891159 2.39932376 0.11763577
#  0.10167043] | SSR: 4.667029433372255
# Parameters: [0.09525067 0.10906197 0.11424284 0.12876473 2.26223456 0.1176384
#  0.10107701] | SSR: 4.678925134379581
# Parameters: [0.09587735 0.1095773  0.11445502 0.12702895 2.81415419 0.11526122
#  0.10141853] | SSR: 4.646358076333248
# Parameters: [0.09770636 0.1132295  0.11262025 0.1259095  2.3283998  0.11309919
#  0.10179412] | SSR: 4.625260810884736
# Parameters: [0.09797548 0.11193046 0.11175031 0.12493984 2.81459467 0.11234266
#  0.10110835] | SSR: 4.6235213775883395
# Parameters: [0.09793866 0.11302955 0.11200258 0.12579577 2.35884148 0.11149123
#  0.10107176] | SSR: 4.605583438932591
# Parameters: [0.09998137 0.11369091 0.110252   0.12239738 2.51670784 0.11013798
#  0.10148878] | SSR: 4.566966457766014
# Parameters: [0.10275776 0.11593045 0.10766108 0.11876702 2.4675515  0.10674544
#  0.10166415] | SSR: 4.517677292995893
# Parameters: [0.10105743 0.11722909 0.11135719 0.12020058 2.65992237 0.10729841
#  0.10129382] | SSR: 4.548480612320688
# Parameters: [0.10210269 0.11779096 0.10886405 0.12016717 2.27256249 0.10663201
#  0.10124624] | SSR: 4.532645378850898
# Parameters: [0.10152977 0.11544204 0.10962562 0.11964595 2.74236336 0.10694628
#  0.1007141 ] | SSR: 4.554402171285591
# Parameters: [0.10227617 0.11774439 0.10988849 0.11910307 2.23553097 0.10616099
#  0.10128724] | SSR: 4.520814355780937
# Parameters: [0.10512717 0.11876787 0.10751332 0.11740026 2.22477101 0.10348657
#  0.10138931] | SSR: 4.48624627357666
# Parameters: [0.10933388 0.12193861 0.10467801 0.1136168  1.99001517 0.09870533
#  0.10154962] | SSR: 4.435069783109778
# Parameters: [0.10715802 0.12071016 0.10660194 0.11309197 2.45483329 0.10139128
#  0.1015228 ] | SSR: 4.440029718386817
# Parameters: [0.1087095  0.12421101 0.1037233  0.11099137 2.32659248 0.09707959
#  0.10132508] | SSR: 4.38143689805068
# Parameters: [0.1136739  0.13030978 0.09906426 0.1041838  2.24993079 0.08931922
#  0.10132473] | SSR: 4.253129186314121
# Parameters: [0.10943019 0.12503037 0.10412153 0.11153417 1.92344995 0.09769734
#  0.10211121] | SSR: 4.423121681565119
# Parameters: [0.11229474 0.12547226 0.10032263 0.10850342 1.79547025 0.09460205
#  0.10176503] | SSR: 4.378033221285396
# Parameters: [0.1141615  0.12710504 0.10037537 0.10520434 2.04651807 0.09183131
#  0.10196084] | SSR: 4.277534577546858
# Parameters: [0.11738384 0.12982609 0.09663288 0.10229737 2.0295459  0.08820815
#  0.10211229] | SSR: 4.214427717640419
# Parameters: [0.12493767 0.13586693 0.09000507 0.09389452 1.92655336 0.07923172
#  0.10252481] | SSR: 4.0234713406682
# Parameters: [0.12323936 0.13733617 0.09381572 0.09552699 1.64295446 0.07976264
#  0.10198129] | SSR: 4.075964223659524
# Parameters: [0.12343377 0.13730674 0.09122166 0.09618347 1.4237073  0.07893718
#  0.10225364] | SSR: 4.147793111058567
# Parameters: [0.12528644 0.14046919 0.08930092 0.09067768 1.72672317 0.07597509
#  0.10242797] | SSR: 3.9414577032585867
# Parameters: [0.13326272 0.14973448 0.08161238 0.07920812 1.59507717 0.06460997
#  0.10286714] | SSR: 3.5947922286493417
# Parameters: [0.13199943 0.14443574 0.08342621 0.0835243  1.69946759 0.06752955
#  0.10208236] | SSR: 3.7117253542151927
# Parameters: [0.13476479 0.14941199 0.08239756 0.07941816 1.80001796 0.06288983
#  0.1025192 ] | SSR: 3.6059694607315005
# Parameters: [0.13878468 0.15415262 0.07720831 0.07534977 1.47854154 0.05739157
#  0.10248292] | SSR: 3.399456500300363
# Parameters: [0.15109627 0.16767641 0.06562478 0.06042248 1.19455328 0.0401717
#  0.10274397] | SSR: 2.6975098442308756
# Parameters: [0.14996438 0.16162407 0.06896528 0.06386706 0.97359238 0.04586152
#  0.10352453] | SSR: 3.014655327834481
# Parameters: [0.14778469 0.16157492 0.07044891 0.06263414 1.67121162 0.04679337
#  0.10295873] | SSR: 3.140284794918872
# Parameters: [0.15499206 0.16847084 0.06117862 0.05389267 1.46003792 0.03654813
#  0.10351035] | SSR: 2.8416126939240414
# Parameters: [0.16188071 0.17925548 0.05675314 0.04409604 1.0431489  0.02488373
#  0.10324841] | SSR: 2.2970898922296303
# Parameters: [1.80352231e-01 2.00949759e-01 4.01271694e-02 1.91967976e-02
#  6.01446674e-01 1.00000000e-06 1.03610207e-01] | SSR: 9.934382864838588
# Parameters: [0.16335646 0.18063518 0.05571113 0.04320104 1.08271505 0.02440139
#  0.10402403] | SSR: 2.450329342497586
# Parameters: [0.16876015 0.18457983 0.04911507 0.03695943 0.77722099 0.0180444
#  0.10401713] | SSR: 2.041570289209373
# Parameters: [1.85757837e-01 2.02163752e-01 3.24738296e-02 1.57300571e-02
#  2.65822505e-01 1.00000000e-06 1.04766102e-01] | SSR: 2.1226689569484316
# Parameters: [0.18040434 0.19421316 0.04061532 0.02509841 0.74848859 0.00301981
#  0.10399776] | SSR: 9.314962988073626
# Parameters: [0.14504813 0.16085415 0.07136311 0.06568069 1.38343002 0.04921243
#  0.1031498 ] | SSR: 3.032480427678901
# Parameters: [0.16510049 0.18216679 0.05203998 0.04254283 0.59013082 0.02152757
#  0.10396076] | SSR: 1.8713047528357782
# Parameters: [0.17375839 0.19246272 0.04283551 0.03249717 0.1        0.00889467
#  0.10446177] | SSR: 2.1957820069879395
# Parameters: [0.17356631 0.18897688 0.04560489 0.03288546 0.6512555  0.01119855
#  0.1040014 ] | SSR: 2.3747757574473054
# Parameters: [0.17539346 0.19602205 0.04132833 0.02584721 0.96899689 0.00464575
#  0.10376291] | SSR: 13.532687556273105
# Parameters: [0.15632165 0.17022357 0.06205604 0.0543621  0.97244351 0.03555758
#  0.10358413] | SSR: 2.4363839404710066
# Parameters: [0.17074567 0.18967605 0.04936567 0.03595572 0.34323866 0.01367613
#  0.10379817] | SSR: 1.7128254359501767
# Parameters: [0.17862247 0.20027866 0.0434592  0.02698725 0.1        0.00224014
#  0.10394207] | SSR: 1.6052137514147526
# Parameters: [1.82506092e-01 1.99785410e-01 3.85864873e-02 1.98729870e-02
#  2.95993801e-01 1.00000000e-06 1.04906868e-01] | SSR: 2.28332498970707
# Parameters: [0.17571722 0.19229815 0.04360739 0.03042928 0.18305453 0.00801375
#  0.10387905] | SSR: 1.681612734048707
# Parameters: [1.88293621e-01 2.09016778e-01 3.19914346e-02 1.24302632e-02
#  1.00000000e-01 1.00000000e-06 1.04403213e-01] | SSR: 0.9565831386399289
# Parameters: [2.04279606e-01 2.28413383e-01 1.69591329e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.04812757e-01] | SSR: 0.739925040047702
# Parameters: [0.17982419 0.20153103 0.04025809 0.02451134 0.2314728  0.01014762
#  0.10421776] | SSR: 1.3821517493141104
# Parameters: [1.96636499e-01 2.17616874e-01 2.43969620e-02 7.70513668e-03
#  1.00000000e-01 1.00000000e-06 1.05247705e-01] | SSR: 0.7993188568236301
# Parameters: [0.18004838 0.20218165 0.03850946 0.02845166 0.29882881 0.01713485
#  0.10368663] | SSR: 1.6357564444468033
# Parameters: [1.97019522e-01 2.22416320e-01 2.49507001e-02 8.93442989e-03
#  1.00000000e-01 1.00000000e-06 1.04481932e-01] | SSR: 0.8331022310221564
# Parameters: [2.09798905e-01 2.36329231e-01 1.42860008e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.04687217e-01] | SSR: 0.7374917666703498
# Parameters: [2.32148111e-01 2.63410452e-01 1.00000000e-06 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.05050447e-01] | SSR: 0.739962616678026
# Parameters: [2.08919799e-01 2.38778184e-01 1.43410529e-02 1.00000000e-06
#  1.11317353e-01 4.22426032e-04 1.04999828e-01] | SSR: 0.768693287833452
# Parameters: [2.12837622e-01 2.39350830e-01 1.25337192e-02 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.05567450e-01] | SSR: 0.7328701092967076
# Parameters: [2.29232244e-01 2.57935419e-01 1.00000000e-06 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.06507860e-01] | SSR: 0.7333553053596584
# Parameters: [2.24039281e-01 2.52417299e-01 1.00000000e-06 1.00000000e-06
#  1.40797185e-01 7.81304817e-04 1.05776397e-01] | SSR: 1.0499069465418782
# Parameters: [2.35470446e-01 2.65703859e-01 1.00000000e-06 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 1.05946036e-01] | SSR: 0.7388773030497371
# Parameters: [1.94521404e-01 2.18613753e-01 3.07043051e-02 4.75459045e-03
#  1.00000000e-01 1.00000000e-06 1.04435867e-01] | SSR: 0.7248580832288237
# Parameters: [1.79762466e-01 2.01711980e-01 4.60559577e-02 7.13138567e-03
#  1.00000000e-01 1.00000000e-06 1.03765602e-01] | SSR: 0.7684359657643967
# Parameters: [2.20827415e-01 2.47528284e-01 7.39849211e-03 1.00000000e-06
#  1.03233529e-01 1.21407438e-04 1.05717171e-01] | SSR: 0.753019587952722
# Parameters: [2.28122129e-01 2.60873847e-01 3.09552461e-03 1.00000000e-06
#  1.04157395e-01 1.55809563e-04 1.05085531e-01] | SSR: 0.7465433232791858
# Parameters: [2.21325209e-01 2.46025584e-01 9.93842561e-03 1.35916870e-03
#  1.00000000e-01 1.00000000e-06 1.05357894e-01] | SSR: 0.7285450777394065
# Parameters: [2.09559820e-01 2.36846141e-01 1.76066817e-02 1.74721690e-03
#  1.00000000e-01 1.00000000e-06 1.04537901e-01] | SSR: 0.7110717887315544
# Parameters: [2.03926022e-01 2.31505070e-01 2.27107764e-02 2.62032535e-03
#  1.00000000e-01 1.00000000e-06 1.03948265e-01] | SSR: 0.7066709712375726
# Parameters: [1.95351932e-01 2.15109499e-01 2.75140068e-02 2.49559557e-03
#  1.00000000e-01 1.00000000e-06 1.04844608e-01] | SSR: 0.7166346269108246
# Parameters: [2.16643691e-01 2.43768852e-01 1.66660769e-02 3.20833716e-03
#  1.00000000e-01 1.00000000e-06 1.05126482e-01] | SSR: 0.7167582632106637
# Parameters: [1.80073779e-01 2.00211232e-01 3.83856603e-02 4.12471921e-03
#  1.00000000e-01 1.00000000e-06 1.03759045e-01] | SSR: 0.7130880014394287
# Parameters: [1.97252426e-01 2.19266432e-01 3.09862764e-02 5.30292470e-03
#  1.00000000e-01 1.00000000e-06 1.04752672e-01] | SSR: 0.7405183253801304
# Parameters: [2.06662285e-01 2.32063531e-01 1.84610697e-02 1.32648117e-03
#  1.00000000e-01 1.00000000e-06 1.04703581e-01] | SSR: 0.7163128691931364
# Parameters: [1.92449327e-01 2.14162747e-01 3.44320867e-02 5.68163360e-03
#  1.00000000e-01 1.00000000e-06 1.03625620e-01] | SSR: 0.74700597108318
# Parameters: [2.07740548e-01 2.33053809e-01 1.80083111e-02 1.42115840e-03
#  1.00000000e-01 1.00000000e-06 1.05081992e-01] | SSR: 0.7141977108218117
# Parameters: [1.80080408e-01 2.03781772e-01 3.93330619e-02 4.34117625e-03
#  1.00000000e-01 1.00000000e-06 1.03756346e-01] | SSR: 0.7067476795127667
# Parameters: [2.02758214e-01 2.26955894e-01 2.10325415e-02 8.27636155e-04
#  1.00000000e-01 1.00000000e-06 1.04484224e-01] | SSR: 0.7243608666097179
# Parameters: [2.00699012e-01 2.24870359e-01 2.34504824e-02 1.80937473e-03
#  1.00000000e-01 1.00000000e-06 1.04472135e-01] | SSR: 0.7120736456826862
# Parameters: [1.76080305e-01 1.96401225e-01 3.70091713e-02 1.97418589e-03
#  1.00000000e-01 1.00000000e-06 1.03606653e-01] | SSR: 0.7009360975049023
# Parameters: [1.55798612e-01 1.72717412e-01 4.71807186e-02 1.35711025e-03
#  1.00000000e-01 1.00000000e-06 1.02846738e-01] | SSR: 0.6954535081071416
# Parameters: [1.86071115e-01 2.12948554e-01 3.17803018e-02 2.36164596e-03
#  1.00000000e-01 1.00000000e-06 1.03317707e-01] | SSR: 0.6918584104191874
# Parameters: [1.81430707e-01 2.11868082e-01 3.39134493e-02 2.29467116e-03
#  1.00000000e-01 1.00000000e-06 1.02554257e-01] | SSR: 0.6789698181997798
# Parameters: [1.67551740e-01 1.90224394e-01 4.52482046e-02 3.80738607e-03
#  1.00000000e-01 1.00000000e-06 1.02844642e-01] | SSR: 0.6911176675660444
# Parameters: [1.54990960e-01 1.76997140e-01 5.34837899e-02 4.39448817e-03
#  1.00000000e-01 1.00000000e-06 1.01826988e-01] | SSR: 0.6862671140817933
# Parameters: [1.75491210e-01 2.03207119e-01 3.74201921e-02 1.76800421e-03
#  1.00000000e-01 1.00000000e-06 1.02597918e-01] | SSR: 0.6805351727697182
# Parameters: [1.47663748e-01 1.72358495e-01 5.63467156e-02 4.07152855e-03
#  1.00000000e-01 1.00000000e-06 1.01349338e-01] | SSR: 0.6652486996561839
# Parameters: [1.21146116e-01 1.46102563e-01 7.27948321e-02 5.20260545e-03
#  1.00000000e-01 1.00000000e-06 9.97879393e-02] | SSR: 0.6406747760258116
# Parameters: [1.51443982e-01 1.76967308e-01 5.00246418e-02 1.78584966e-03
#  1.00000000e-01 1.00000000e-06 1.00931296e-01] | SSR: 0.6605495448260266
# Parameters: [1.12603500e-01 1.33661792e-01 7.44508888e-02 3.26827893e-03
#  1.00000000e-01 1.00000000e-06 9.98773854e-02] | SSR: 0.6025025530845851
# Parameters: [6.69422394e-02 8.47401531e-02 1.00320945e-01 3.59225572e-03
#  1.00000000e-01 1.00000000e-06 9.78419454e-02] | SSR: 0.4760027485599625
# Parameters: [1.35343375e-01 1.67313091e-01 6.51638685e-02 5.17010702e-03
#  1.00000000e-01 1.00000000e-06 9.95489719e-02] | SSR: 0.6526682339444285
# Parameters: [1.14387857e-01 1.43260022e-01 7.27865722e-02 3.10918004e-03
#  1.00000000e-01 1.00000000e-06 9.86094482e-02] | SSR: 0.5858112701029858
# Parameters: [1.15347751e-01 1.46848100e-01 7.00660676e-02 2.15484704e-03
#  1.00000000e-01 1.00000000e-06 9.87078056e-02] | SSR: 0.5724102940596512
# Parameters: [7.76636548e-02 1.04535543e-01 9.54570584e-02 4.89185753e-03
#  1.00000000e-01 1.00000000e-06 9.68254144e-02] | SSR: 0.5285932197785256
# Parameters: [4.20764288e-02 6.52081407e-02 1.16547689e-01 5.10724383e-03
#  1.00000000e-01 1.00000000e-06 9.52322631e-02] | SSR: 0.4528956979624311
# Parameters: [1.00000000e-06 1.00000000e-06 1.57864809e-01 6.51353017e-03
#  1.00000000e-01 1.00000000e-06 9.15712661e-02] | SSR: 3.847306781378153
# Parameters: [4.08152813e-02 6.81777246e-02 1.19443082e-01 6.56503510e-03
#  1.00000000e-01 1.00000000e-06 9.52269290e-02] | SSR: 0.5354403229133274
# Parameters: [2.99078616e-02 4.95075512e-02 1.19812202e-01 3.57932862e-03
#  1.00000000e-01 1.00000000e-06 9.53743838e-02] | SSR: 0.40534434743500436
# Parameters: [1.00000000e-06 1.00000000e-06 1.47136369e-01 2.78393942e-03
#  1.00000000e-01 1.00000000e-06 9.32870897e-02] | SSR: 3.859808019614114
# Parameters: [1.80370480e-02 4.31195040e-02 1.25614773e-01 3.08303680e-03
#  1.00000000e-01 1.00000000e-06 9.38744006e-02] | SSR: 0.6153755458503058
# Parameters: [4.38143150e-02 6.88652688e-02 1.12409787e-01 3.61292896e-03
#  1.00000000e-01 1.00000000e-06 9.53527852e-02] | SSR: 0.4138895697720404
# Parameters: [4.63143735e-03 2.47064011e-02 1.36943951e-01 5.32039047e-03
#  1.00000000e-01 1.00000000e-06 9.41224166e-02] | SSR: 1.7697184481656998
# Parameters: [8.69487523e-02 1.13621617e-01 8.88259170e-02 3.66198265e-03
#  1.00000000e-01 1.00000000e-06 9.74876903e-02] | SSR: 0.5282062535184342
# Parameters: [1.00000000e-06 1.16250425e-02 1.45024413e-01 6.70533364e-03
#  1.00000000e-01 1.00000000e-06 9.36754548e-02] | SSR: 3.862948902025502
# Parameters: [8.54001991e-02 1.13042336e-01 8.88056539e-02 3.29246869e-03
#  1.00000000e-01 1.00000000e-06 9.74497179e-02] | SSR: 0.5157739737308139
# Parameters: [8.28285618e-02 1.03113878e-01 8.68938475e-02 1.36012662e-03
#  1.00000000e-01 1.00000000e-06 9.77914139e-02] | SSR: 0.5145207181704887
# Parameters: [4.74558760e-02 6.63498694e-02 1.08433239e-01 2.02423821e-03
#  1.00000000e-01 1.00000000e-06 9.64689283e-02] | SSR: 0.37833979729909933
# Parameters: [3.23519866e-02 4.72570324e-02 1.14921330e-01 5.90428555e-04
#  1.00000000e-01 1.00000000e-06 9.62906853e-02] | SSR: 0.3186214725766381
# Parameters: [2.25717026e-02 3.83024859e-02 1.22520213e-01 2.37652621e-03
#  1.00000000e-01 1.00000000e-06 9.54646510e-02] | SSR: 0.38551488829057134
# Parameters: [6.16925684e-03 1.75275245e-02 1.32173207e-01 2.48434231e-03
#  1.00000000e-01 1.00000000e-06 9.49354615e-02] | SSR: 1.092776625755538
# Parameters: [6.55924635e-02 8.91636328e-02 9.96475422e-02 3.09043710e-03
#  1.00000000e-01 1.00000000e-06 9.68211538e-02] | SSR: 0.4552857160767289
# Parameters: [3.81629458e-03 2.34701975e-02 1.37728927e-01 4.91105881e-03
#  1.00000000e-01 1.00000000e-06 9.43165483e-02] | SSR: 1.9465983215744707
# Parameters: [6.30754950e-02 8.32029580e-02 9.96026172e-02 2.24785966e-03
#  1.00000000e-01 1.00000000e-06 9.69226975e-02] | SSR: 0.43966641286123664
# Parameters: [1.85978329e-02 4.14047240e-02 1.24096592e-01 2.29481655e-03
#  1.00000000e-01 1.00000000e-06 9.40033745e-02] | SSR: 0.5307901069936091
# Parameters: [5.48561378e-02 7.39062958e-02 1.06264857e-01 3.26789593e-03
#  1.00000000e-01 1.00000000e-06 9.68823027e-02] | SSR: 0.4246383010190648
# Parameters: [1.68800871e-02 3.26220051e-02 1.26660657e-01 2.84733769e-03
#  1.00000000e-01 1.00000000e-06 9.50416373e-02] | SSR: 0.49309338317354734
# Parameters: [5.34143694e-02 7.50282259e-02 1.06400821e-01 3.02966225e-03
#  1.00000000e-01 1.00000000e-06 9.63762746e-02] | SSR: 0.4146297349192556
# Parameters: [4.36355335e-02 5.93832359e-02 1.06861404e-01 2.36936218e-04
#  1.00000000e-01 1.00000000e-06 9.69573884e-02] | SSR: 0.35589255113068324
# Parameters: [1.70821925e-02 3.45827837e-02 1.25880415e-01 2.52177083e-03
#  1.00000000e-01 1.00000000e-06 9.52768657e-02] | SSR: 0.5074980308108055
# Parameters: [5.15771694e-02 7.10479144e-02 1.06172067e-01 2.31633746e-03
#  1.00000000e-01 1.00000000e-06 9.65112395e-02] | SSR: 0.3967462493019994
# Parameters: [2.43647017e-02 4.30627655e-02 1.19191664e-01 1.22986072e-03
#  1.00000000e-01 1.00000000e-06 9.52112424e-02] | SSR: 0.36218412785238174
# Parameters: [1.75065649e-02 3.28078467e-02 1.22710227e-01 9.53865392e-04
#  1.00000000e-01 1.00000000e-06 9.53844041e-02] | SSR: 0.41331218836332195
# Parameters: [1.95901194e-02 2.86686832e-02 1.19644243e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.64169275e-02] | SSR: 0.3174040567468108
# Parameters: [7.47802156e-03 8.57039039e-03 1.23261471e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.69489986e-02] | SSR: 0.5947250206719072
# Parameters: [4.64931707e-02 6.35434872e-02 1.08467808e-01 1.99768254e-03
#  1.00000000e-01 1.00000000e-06 9.66803153e-02] | SSR: 0.3757491687711172
# Parameters: [3.88305338e-02 5.08540500e-02 1.08124578e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.70634589e-02] | SSR: 0.3466204926458682
# Parameters: [1.35193301e-02 2.35440113e-02 1.22322573e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.60843801e-02] | SSR: 0.42192038450741
# Parameters: [4.20627096e-02 5.91719387e-02 1.10209693e-01 1.61769975e-03
#  1.00000000e-01 1.00000000e-06 9.64045247e-02] | SSR: 0.3553856407564646
# Parameters: [4.80936560e-02 6.22521406e-02 1.02457136e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.73995039e-02] | SSR: 0.3857181920353232
# Parameters: [2.89521909e-02 4.42898996e-02 1.17504444e-01 1.59359223e-03
#  1.00000000e-01 1.00000000e-06 9.59483643e-02] | SSR: 0.33268779987219965
# Parameters: [1.91604794e-02 3.15101143e-02 1.19091437e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.59747108e-02] | SSR: 0.3385096689079637
# Parameters: [3.98020278e-02 4.86900785e-02 1.08338944e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.76619175e-02] | SSR: 0.36736264182275513
# Parameters: [2.82240332e-02 4.44695938e-02 1.16478484e-01 9.03620127e-04
#  1.00000000e-01 1.00000000e-06 9.58239112e-02] | SSR: 0.3244485356702887
# Parameters: [1.61279102e-02 2.81085675e-02 1.23416941e-01 1.10830397e-03
#  1.00000000e-01 1.00000000e-06 9.55919210e-02] | SSR: 0.4041041997990566
# Parameters: [3.67586277e-02 5.15645688e-02 1.11000288e-01 4.54778156e-04
#  1.00000000e-01 1.00000000e-06 9.66160215e-02] | SSR: 0.3298079191171904
# Parameters: [1.61852822e-02 2.61463305e-02 1.20294536e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.62052123e-02] | SSR: 0.3603408470546603
# Parameters: [3.55933527e-02 5.09155366e-02 1.12730904e-01 1.06209409e-03
#  1.00000000e-01 1.00000000e-06 9.63546966e-02] | SSR: 0.3303287757832975
# Parameters: [1.84925490e-02 3.44817867e-02 1.23695745e-01 1.31514662e-03
#  1.00000000e-01 1.00000000e-06 9.53437746e-02] | SSR: 0.41310695962223676
# Parameters: [3.37460376e-02 4.67609842e-02 1.12017370e-01 3.29536654e-04
#  1.00000000e-01 1.00000000e-06 9.66335378e-02] | SSR: 0.3217061552361257
# Parameters: [4.23299057e-02 5.81831138e-02 1.10707724e-01 1.40901423e-03
#  1.00000000e-01 1.00000000e-06 9.66207589e-02] | SSR: 0.3550320635310563
# Parameters: [2.49528360e-02 3.81783642e-02 1.16995508e-01 3.53003558e-04
#  1.00000000e-01 1.00000000e-06 9.61362229e-02] | SSR: 0.3133841423730595
# Parameters: [3.13955214e-02 4.36571756e-02 1.12149307e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67007794e-02] | SSR: 0.31501893519714386
# Parameters: [2.35549792e-02 3.49577211e-02 1.16756676e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.63933279e-02] | SSR: 0.3085352038040543
# Parameters: [1.75357925e-02 2.69788134e-02 1.18769562e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.64126435e-02] | SSR: 0.33791882753699076
# Parameters: [1.86172333e-02 2.95638753e-02 1.20131974e-01 1.67961528e-04
#  1.00000000e-01 1.00000000e-06 9.60683762e-02] | SSR: 0.33704510567598933
# Parameters: [3.22232791e-02 4.60643954e-02 1.13283210e-01 3.83073999e-04
#  1.00000000e-01 1.00000000e-06 9.64791102e-02] | SSR: 0.31688982392038334
# Parameters: [2.82944695e-02 3.71145080e-02 1.13740843e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.70476862e-02] | SSR: 0.313300420436188
# Parameters: [2.12148742e-02 3.20669815e-02 1.18694378e-01 5.06079492e-05
#  1.00000000e-01 1.00000000e-06 9.63563877e-02] | SSR: 0.3158426287034156
# Parameters: [1.94268930e-02 2.72309188e-02 1.16868432e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67180123e-02] | SSR: 0.3150104293814952
# Parameters: [3.21421242e-02 4.54084781e-02 1.11352429e-01 2.24910145e-04
#  1.00000000e-01 1.00000000e-06 9.66777944e-02] | SSR: 0.316508470569456
# Parameters: [1.94857773e-02 2.78253610e-02 1.17161811e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.66723786e-02] | SSR: 0.31630842350297345
# Parameters: [1.59508332e-02 2.34575305e-02 1.20752415e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.64721470e-02] | SSR: 0.3447359390314052
# Parameters: [2.80943014e-02 3.99207412e-02 1.13702426e-01 1.41641609e-04
#  1.00000000e-01 1.00000000e-06 9.66263825e-02] | SSR: 0.30874523945896526
# Parameters: [3.10667583e-02 4.44964706e-02 1.13954637e-01 1.55929462e-04
#  1.00000000e-01 1.00000000e-06 9.64644211e-02] | SSR: 0.3132003576533772
# Parameters: [3.21524855e-02 4.38061327e-02 1.11067859e-01 1.36413373e-04
#  1.00000000e-01 1.00000000e-06 9.68112787e-02] | SSR: 0.31865822437408875
# Parameters: [2.39492770e-02 3.50017693e-02 1.16787748e-01 7.20593052e-05
#  1.00000000e-01 1.00000000e-06 9.64701104e-02] | SSR: 0.3077266768592994
# Parameters: [1.98443399e-02 2.97429653e-02 1.18938199e-01 2.06323981e-04
#  1.00000000e-01 1.00000000e-06 9.64009816e-02] | SSR: 0.3216918217409827
# Parameters: [2.85077260e-02 4.01786230e-02 1.13846530e-01 5.23309953e-05
#  1.00000000e-01 1.00000000e-06 9.66258299e-02] | SSR: 0.3089523248421708
# Parameters: [3.44074919e-02 4.98685662e-02 1.13355674e-01 2.20989980e-04
#  1.00000000e-01 1.00000000e-06 9.63574108e-02] | SSR: 0.32045876191355993
# Parameters: [2.31720428e-02 3.28903307e-02 1.15990242e-01 5.59974949e-05
#  1.00000000e-01 1.00000000e-06 9.66278619e-02] | SSR: 0.30694942193919394
# Parameters: [2.83727509e-02 3.74102541e-02 1.12941378e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.70796686e-02] | SSR: 0.31302095353402926
# Parameters: [2.50534836e-02 3.85586091e-02 1.15967625e-01 1.36131104e-04
#  1.00000000e-01 1.00000000e-06 9.61773430e-02] | SSR: 0.3116157057503988
# Parameters: [2.05631163e-02 2.94801147e-02 1.16328970e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.66785858e-02] | SSR: 0.31272236785309354
# Parameters: [2.10257995e-02 3.43005771e-02 1.18310113e-01 1.30474431e-04
#  1.00000000e-01 1.00000000e-06 9.59487433e-02] | SSR: 0.3294451226785708
# Parameters: [2.65360130e-02 3.66328348e-02 1.14283562e-01 3.33686077e-05
#  1.00000000e-01 1.00000000e-06 9.67969372e-02] | SSR: 0.307158229844392
# Parameters: [3.05419760e-02 4.42743508e-02 1.14338118e-01 1.39722605e-04
#  1.00000000e-01 1.00000000e-06 9.63836407e-02] | SSR: 0.31190362112349035
# Parameters: [2.80472611e-02 4.05757918e-02 1.14835831e-01 1.05041953e-04
#  1.00000000e-01 1.00000000e-06 9.64573770e-02] | SSR: 0.3083199553627189
# Parameters: [2.69069737e-02 3.57721943e-02 1.14376093e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.69648932e-02] | SSR: 0.3094960967714181
# Parameters: [2.64436012e-02 3.64687980e-02 1.14773976e-01 3.08144403e-05
#  1.00000000e-01 1.00000000e-06 9.67680057e-02] | SSR: 0.3070073308516724
# Parameters: [2.28629813e-02 3.30922304e-02 1.16762173e-01 7.33614077e-05
#  1.00000000e-01 1.00000000e-06 9.65570280e-02] | SSR: 0.30847934087582246
# Parameters: [2.17817431e-02 3.13991091e-02 1.17780491e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.65366598e-02] | SSR: 0.309414476020792
# Parameters: [2.65161618e-02 3.77903332e-02 1.14721942e-01 9.73667478e-05
#  1.00000000e-01 1.00000000e-06 9.66039518e-02] | SSR: 0.3069953994048475
# Parameters: [2.71671174e-02 3.71714469e-02 1.14144888e-01 1.32717131e-04
#  1.00000000e-01 1.00000000e-06 9.68298927e-02] | SSR: 0.308363192628925
# Parameters: [2.90888685e-02 4.02024281e-02 1.13391595e-01 7.73145009e-05
#  1.00000000e-01 1.00000000e-06 9.67441540e-02] | SSR: 0.3107596662596789
# Parameters: [2.44194531e-02 3.48697798e-02 1.15919529e-01 7.43496810e-05
#  1.00000000e-01 1.00000000e-06 9.66038095e-02] | SSR: 0.3065083969721294
# Parameters: [2.39996855e-02 3.54655924e-02 1.16515921e-01 1.28236380e-06
#  1.00000000e-01 1.00000000e-06 9.64066940e-02] | SSR: 0.30776941506690114
# Parameters: [2.19630916e-02 3.06011905e-02 1.16305003e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67647289e-02] | SSR: 0.3077530613831226
# Parameters: [2.54287832e-02 3.43215608e-02 1.14564652e-01 1.02990858e-04
#  1.00000000e-01 1.00000000e-06 9.69177076e-02] | SSR: 0.3070022370109712
# Parameters: [2.84555748e-02 4.02489256e-02 1.14278326e-01 1.32413467e-04
#  1.00000000e-01 1.00000000e-06 9.66033809e-02] | SSR: 0.30910776803092876
# Parameters: [2.35862124e-02 3.30131243e-02 1.15798334e-01 3.38533668e-05
#  1.00000000e-01 1.00000000e-06 9.67243919e-02] | SSR: 0.3062397387762257
# Parameters: [2.63656566e-02 3.52801626e-02 1.13512891e-01 5.04381796e-05
#  1.00000000e-01 1.00000000e-06 9.69706512e-02] | SSR: 0.308341473575865
# Parameters: [2.45533719e-02 3.50713676e-02 1.15969034e-01 6.66540238e-05
#  1.00000000e-01 1.00000000e-06 9.65952456e-02] | SSR: 0.30641249715641894
# Parameters: [2.32124517e-02 3.32029636e-02 1.16498641e-01 9.86389959e-05
#  1.00000000e-01 1.00000000e-06 9.65861982e-02] | SSR: 0.3074829097210409
# Parameters: [2.57051227e-02 3.57753670e-02 1.14837331e-01 4.96862048e-05
#  1.00000000e-01 1.00000000e-06 9.67442525e-02] | SSR: 0.30635300919214153
# Parameters: [2.30938696e-02 3.31688773e-02 1.16026328e-01 1.06585096e-04
#  1.00000000e-01 1.00000000e-06 9.66083431e-02] | SSR: 0.3080344994203115
# Parameters: [2.56061683e-02 3.56438178e-02 1.15087064e-01 4.97571042e-05
#  1.00000000e-01 1.00000000e-06 9.67280900e-02] | SSR: 0.30625392394949835
# Parameters: [2.41593690e-02 3.56939021e-02 1.16384913e-01 1.91990342e-05
#  1.00000000e-01 1.00000000e-06 9.64044648e-02] | SSR: 0.30775955962348506
# Parameters: [2.51114297e-02 3.46646462e-02 1.15019717e-01 8.20429022e-05
#  1.00000000e-01 1.00000000e-06 9.67893969e-02] | SSR: 0.306254588489153
# Parameters: [2.26706384e-02 3.13320764e-02 1.16312701e-01 2.04449030e-05
#  1.00000000e-01 1.00000000e-06 9.67712048e-02] | SSR: 0.3066261414601891
# Parameters: [2.58714991e-02 3.57868634e-02 1.15136532e-01 5.16562724e-05
#  1.00000000e-01 1.00000000e-06 9.67882498e-02] | SSR: 0.30658722599563293
# Parameters: [2.72874351e-02 3.86179140e-02 1.14478025e-01 9.61263985e-05
#  1.00000000e-01 1.00000000e-06 9.66497770e-02] | SSR: 0.307653109009805
# Parameters: [2.38248376e-02 3.31535358e-02 1.15854032e-01 3.93652769e-05
#  1.00000000e-01 1.00000000e-06 9.67408479e-02] | SSR: 0.3060365808518789
# Parameters: [2.35018140e-02 3.34107476e-02 1.15859194e-01 6.14033160e-05
#  1.00000000e-01 1.00000000e-06 9.66191885e-02] | SSR: 0.3067492773648961
# Parameters: [2.52790778e-02 3.51928344e-02 1.15317198e-01 5.40930333e-05
#  1.00000000e-01 1.00000000e-06 9.67459845e-02] | SSR: 0.3061668399504082
# Parameters: [2.51994670e-02 3.44201325e-02 1.14904103e-01 3.29222939e-05
#  1.00000000e-01 1.00000000e-06 9.68442503e-02] | SSR: 0.3063595932251904
# Parameters: [2.52501468e-02 3.40324775e-02 1.14550331e-01 3.09803139e-05
#  1.00000000e-01 1.00000000e-06 9.69239584e-02] | SSR: 0.306841019424433
# Parameters: [2.47275656e-02 3.48116451e-02 1.15614358e-01 5.77355963e-05
#  1.00000000e-01 1.00000000e-06 9.66774238e-02] | SSR: 0.30607579059070145
# Parameters: [2.44692228e-02 3.47955734e-02 1.15818193e-01 7.18015588e-05
#  1.00000000e-01 1.00000000e-06 9.66272890e-02] | SSR: 0.30637009009483074
# Parameters: [2.50169059e-02 3.45139927e-02 1.15132625e-01 4.26421101e-05
#  1.00000000e-01 1.00000000e-06 9.67900100e-02] | SSR: 0.30610319968242117
# Parameters: [2.37669337e-02 3.30799462e-02 1.15969334e-01 5.30250495e-05
#  1.00000000e-01 1.00000000e-06 9.67403604e-02] | SSR: 0.3061148597514377
# Parameters: [2.39764850e-02 3.37378957e-02 1.16058267e-01 1.23775370e-05
#  1.00000000e-01 1.00000000e-06 9.66812055e-02] | SSR: 0.3060019674094063
# Parameters: [2.34090126e-02 3.32745204e-02 1.16577542e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.66271099e-02] | SSR: 0.3065100850287027
# Parameters: [2.30161225e-02 3.22141748e-02 1.16268407e-01 3.39834586e-05
#  1.00000000e-01 1.00000000e-06 9.67291168e-02] | SSR: 0.30666800263207955
# Parameters: [2.49586569e-02 3.47864071e-02 1.15382400e-01 4.58136928e-05
#  1.00000000e-01 1.00000000e-06 9.67283467e-02] | SSR: 0.30599995544665065
# Parameters: [2.54282055e-02 3.53515205e-02 1.15438299e-01 5.33044320e-05
#  1.00000000e-01 1.00000000e-06 9.67339449e-02] | SSR: 0.30618433431569275
# Parameters: [2.49677072e-02 3.47669215e-02 1.15528307e-01 4.84416657e-05
#  1.00000000e-01 1.00000000e-06 9.67315566e-02] | SSR: 0.306008693321242
# Parameters: [2.36463770e-02 3.30501210e-02 1.15979752e-01 3.14500890e-05
#  1.00000000e-01 1.00000000e-06 9.67082300e-02] | SSR: 0.3060983713948139
# Parameters: [2.51240764e-02 3.51544877e-02 1.15330593e-01 2.63537985e-05
#  1.00000000e-01 1.00000000e-06 9.67046741e-02] | SSR: 0.30595636350264643
# Parameters: [2.58026477e-02 3.61917585e-02 1.15011222e-01 1.30181730e-05
#  1.00000000e-01 1.00000000e-06 9.66868310e-02] | SSR: 0.3061688488318902
# Parameters: [2.39047242e-02 3.39034398e-02 1.16223863e-01 3.20829345e-05
#  1.00000000e-01 1.00000000e-06 9.66306428e-02] | SSR: 0.3062600620267715
# Parameters: [2.47388605e-02 3.43613545e-02 1.15405435e-01 4.00023162e-05
#  1.00000000e-01 1.00000000e-06 9.67501682e-02] | SSR: 0.3059553456074862
# Parameters: [2.55873913e-02 3.57419497e-02 1.15212646e-01 4.57184491e-05
#  1.00000000e-01 1.00000000e-06 9.67244051e-02] | SSR: 0.3062434649447847
# Parameters: [2.41316306e-02 3.37230782e-02 1.15787975e-01 3.50171791e-05
#  1.00000000e-01 1.00000000e-06 9.67122738e-02] | SSR: 0.3059510939246601
# Parameters: [2.43359355e-02 3.36694064e-02 1.15627644e-01 1.29419654e-05
#  1.00000000e-01 1.00000000e-06 9.67651684e-02] | SSR: 0.3058331129135018
# Parameters: [2.41401205e-02 3.30982871e-02 1.15634287e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.68090407e-02] | SSR: 0.30586680808886785
# Parameters: [2.53846916e-02 3.54749074e-02 1.15323288e-01 2.37627674e-05
#  1.00000000e-01 1.00000000e-06 9.67086931e-02] | SSR: 0.3060335983858057
# Parameters: [2.49947281e-02 3.48945645e-02 1.15455974e-01 2.76633947e-05
#  1.00000000e-01 1.00000000e-06 9.67167318e-02] | SSR: 0.30593181770187083
# Parameters: [2.42495422e-02 3.38979911e-02 1.15628346e-01 8.74972964e-06
#  1.00000000e-01 1.00000000e-06 9.67137487e-02] | SSR: 0.30583906217057966
# Parameters: [2.53187808e-02 3.49727585e-02 1.14975552e-01 4.37773420e-05
#  1.00000000e-01 1.00000000e-06 9.67733978e-02] | SSR: 0.30619298110852905
# Parameters: [2.43120589e-02 3.40466114e-02 1.15787588e-01 2.02274882e-05
#  1.00000000e-01 1.00000000e-06 9.67042536e-02] | SSR: 0.3058872746472174
# Parameters: [2.41518666e-02 3.37128769e-02 1.15767188e-01 3.03084199e-06
#  1.00000000e-01 1.00000000e-06 9.67193729e-02] | SSR: 0.305819767807198
# Parameters: [2.37484715e-02 3.31761117e-02 1.15959582e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67148859e-02] | SSR: 0.3059370201873342
# Parameters: [2.37086729e-02 3.29329074e-02 1.15943736e-01 1.58270344e-05
#  1.00000000e-01 1.00000000e-06 9.67472451e-02] | SSR: 0.3059691601683837
# Parameters: [2.47702255e-02 3.45990926e-02 1.15483879e-01 2.37221075e-05
#  1.00000000e-01 1.00000000e-06 9.67153169e-02] | SSR: 0.30588012828308564
# Parameters: [2.41028502e-02 3.37939658e-02 1.15891307e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.66917935e-02] | SSR: 0.3058421921250679
# Parameters: [2.47018571e-02 3.44524957e-02 1.15538289e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67238364e-02] | SSR: 0.3057946374055669
# Parameters: [2.49869704e-02 3.48172045e-02 1.15413446e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67296177e-02] | SSR: 0.3058547274520708
# Parameters: [2.37550822e-02 3.31547041e-02 1.15893809e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67214083e-02] | SSR: 0.3059307368943144
# Parameters: [2.40649937e-02 3.35896692e-02 1.15784350e-01 1.31233109e-06
#  1.00000000e-01 1.00000000e-06 9.67202392e-02] | SSR: 0.30583263405465194
# Parameters: [2.43671613e-02 3.38721023e-02 1.15561270e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67384538e-02] | SSR: 0.305775226459343
# Parameters: [2.43947125e-02 3.37848477e-02 1.15448110e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67555539e-02] | SSR: 0.3057813368724651
# Parameters: [2.37938335e-02 3.31119095e-02 1.15887091e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67340011e-02] | SSR: 0.30588543671690377
# Parameters: [2.45261275e-02 3.42272968e-02 1.15584682e-01 1.39349729e-05
#  1.00000000e-01 1.00000000e-06 9.67199879e-02] | SSR: 0.30582606390371314
# Parameters: [2.45821452e-02 3.40408452e-02 1.15392056e-01 1.09913832e-05
#  1.00000000e-01 1.00000000e-06 9.67655800e-02] | SSR: 0.30585445582147763
# Parameters: [2.42226739e-02 3.38556856e-02 1.15766494e-01 3.49784579e-06
#  1.00000000e-01 1.00000000e-06 9.67102401e-02] | SSR: 0.3058093717955699
# Parameters: [2.44277766e-02 3.39247326e-02 1.15694487e-01 1.74111528e-06
#  1.00000000e-01 1.00000000e-06 9.67426224e-02] | SSR: 0.3057776496750039
# Parameters: [2.43676235e-02 3.42262676e-02 1.15714287e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.66847609e-02] | SSR: 0.3058150345328151
# Parameters: [2.47250311e-02 3.44878901e-02 1.15537563e-01 5.88903347e-06
#  1.00000000e-01 1.00000000e-06 9.67195535e-02] | SSR: 0.30580271906695616
# Parameters: [2.43207268e-02 3.39247177e-02 1.15723769e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67196807e-02] | SSR: 0.3057772781724283
# Parameters: [2.47432335e-02 3.44996636e-02 1.15528858e-01 1.29144216e-06
#  1.00000000e-01 1.00000000e-06 9.67203837e-02] | SSR: 0.30578670260622676
# Parameters: [2.46347937e-02 3.40643860e-02 1.15528779e-01 3.40555334e-06
#  1.00000000e-01 1.00000000e-06 9.67651736e-02] | SSR: 0.3058294644915416
# Parameters: [2.44344161e-02 3.41857972e-02 1.15667910e-01 1.60138834e-06
#  1.00000000e-01 1.00000000e-06 9.67048641e-02] | SSR: 0.3057844543345223
# Parameters: [2.48402411e-02 3.45292856e-02 1.15448405e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67381583e-02] | SSR: 0.3058224204444824
# Parameters: [2.43770657e-02 3.40240856e-02 1.15686972e-01 2.71484998e-06
#  1.00000000e-01 1.00000000e-06 9.67172197e-02] | SSR: 0.3057831891889716
# Parameters: [2.42384653e-02 3.37645655e-02 1.15720024e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67281781e-02] | SSR: 0.3057866299145627
# Parameters: [2.41292415e-02 3.36034084e-02 1.15771222e-01 1.95679879e-06
#  1.00000000e-01 1.00000000e-06 9.67251357e-02] | SSR: 0.3057908038309536
# Parameters: [2.42723954e-02 3.38156802e-02 1.15712989e-01 1.71759909e-06
#  1.00000000e-01 1.00000000e-06 9.67248109e-02] | SSR: 0.3057774308784895
# Parameters: [2.39533400e-02 3.33608167e-02 1.15833262e-01 1.78711575e-06
#  1.00000000e-01 1.00000000e-06 9.67298534e-02] | SSR: 0.3058441555666949
# Parameters: [2.45457601e-02 3.42149519e-02 1.15604959e-01 1.41536056e-06
#  1.00000000e-01 1.00000000e-06 9.67227511e-02] | SSR: 0.30577221835361534
# Parameters: [2.45459068e-02 3.42245966e-02 1.15609220e-01 2.19723236e-06
#  1.00000000e-01 1.00000000e-06 9.67205084e-02] | SSR: 0.3057723800984153
# Parameters: [2.43818104e-02 3.38144505e-02 1.15644566e-01 1.76608517e-06
#  1.00000000e-01 1.00000000e-06 9.67482922e-02] | SSR: 0.30577708916798685
# Parameters: [2.44405164e-02 3.39162663e-02 1.15613388e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67448144e-02] | SSR: 0.30577295654543535
# Parameters: [2.43934455e-02 3.40132004e-02 1.15582702e-01 1.14353535e-06
#  1.00000000e-01 1.00000000e-06 9.67200380e-02] | SSR: 0.3057677565933762
# Parameters: [2.43762800e-02 3.40574343e-02 1.15526809e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67087458e-02] | SSR: 0.30577039418393903
# Parameters: [2.45834124e-02 3.41786871e-02 1.15526975e-01 1.00303332e-06
#  1.00000000e-01 1.00000000e-06 9.67364858e-02] | SSR: 0.30577944791311085
# Parameters: [2.43501497e-02 3.39064320e-02 1.15666485e-01 1.53895765e-06
#  1.00000000e-01 1.00000000e-06 9.67277296e-02] | SSR: 0.3057714133738008
# Parameters: [2.45434875e-02 3.40644252e-02 1.15499828e-01 1.87462031e-06
#  1.00000000e-01 1.00000000e-06 9.67439158e-02] | SSR: 0.3057812712232051
# Parameters: [2.43764170e-02 3.39596446e-02 1.15667784e-01 1.21865508e-06
#  1.00000000e-01 1.00000000e-06 9.67257394e-02] | SSR: 0.30577119217022064
# Parameters: [2.44808630e-02 3.42161764e-02 1.15585665e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67088606e-02] | SSR: 0.3057731118281355
# Parameters: [2.45279982e-02 3.42568315e-02 1.15675931e-01 1.71821171e-06
#  1.00000000e-01 1.00000000e-06 9.67102438e-02] | SSR: 0.3057666018293966
# Parameters: [2.46084167e-02 3.44491961e-02 1.15733262e-01 2.07731757e-06
#  1.00000000e-01 1.00000000e-06 9.66961388e-02] | SSR: 0.30576883967405305
# Parameters: [2.44277638e-02 3.39243731e-02 1.15677326e-01 1.92341506e-06
#  1.00000000e-01 1.00000000e-06 9.67402322e-02] | SSR: 0.30577103121900245
# Parameters: [2.44644668e-02 3.42265994e-02 1.15667871e-01 2.18724793e-06
#  1.00000000e-01 1.00000000e-06 9.67029691e-02] | SSR: 0.30577873294110236
# Parameters: [2.44465040e-02 3.39938496e-02 1.15627009e-01 1.29681198e-06
#  1.00000000e-01 1.00000000e-06 9.67343531e-02] | SSR: 0.30576863890242045
# Parameters: [2.43306756e-02 3.38523414e-02 1.15677122e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67312309e-02] | SSR: 0.3057684157608074
# Parameters: [2.42693695e-02 3.37583831e-02 1.15702001e-01 1.39594996e-06
#  1.00000000e-01 1.00000000e-06 9.67314109e-02] | SSR: 0.30577006652200267
# Parameters: [2.44419000e-02 3.40246034e-02 1.15650622e-01 1.23149353e-06
#  1.00000000e-01 1.00000000e-06 9.67274842e-02] | SSR: 0.30576337060566683
# Parameters: [2.44877751e-02 3.40836891e-02 1.15642690e-01 1.07776147e-06
#  1.00000000e-01 1.00000000e-06 9.67273614e-02] | SSR: 0.30576129065254565
# Parameters: [2.44474492e-02 3.40068321e-02 1.15642153e-01 1.51154079e-06
#  1.00000000e-01 1.00000000e-06 9.67299378e-02] | SSR: 0.30576094372456497
# Parameters: [2.44829654e-02 3.40304258e-02 1.15629338e-01 1.65798364e-06
#  1.00000000e-01 1.00000000e-06 9.67320369e-02] | SSR: 0.30575864698649835
# Parameters: [2.44118743e-02 3.40724043e-02 1.15618900e-01 1.00000000e-06
#  1.00000000e-01 1.00000000e-06 9.67131035e-02] | SSR: 0.3057627423547935
# Parameters: [2.46109842e-02 3.43281146e-02 1.15570482e-01 1.14527980e-06
#  1.00000000e-01 1.00000000e-06 9.67166942e-02] | SSR: 0.3057665948025218
# Parameters: [2.44808441e-02 3.41881524e-02 1.15629324e-01 1.20112287e-06
#  1.00000000e-01 1.00000000e-06 9.67087065e-02] | SSR: 0.3057585969090377
# Parameters: [2.44980142e-02 3.42853038e-02 1.15630481e-01 1.15327831e-06
#  1.00000000e-01 1.00000000e-06 9.66958832e-02] | SSR: 0.30575904519758046
# Parameters: [2.46395777e-02 3.44256067e-02 1.15565555e-01 1.55539853e-06
#  1.00000000e-01 1.00000000e-06 9.67053933e-02] | SSR: 0.30576224216683257
# Parameters: [2.46471314e-02 3.43825780e-02 1.15655076e-01 1.52953838e-06
#  1.00000000e-01 1.00000000e-06 9.67124019e-02] | SSR: 0.30575975511467357
# Parameters: [2.45466167e-02 3.41748745e-02 1.15555887e-01 1.00000000e-06
# ...
# Parameters: [1.86874820e-02 3.34911476e-02 1.06442683e-02 1.05966002e-03
#  1.00000000e-01 1.00000000e-06 7.10321630e-02] | SSR: 0.26306271334966913
# Parameters: [1.61059248e-02 3.18564031e-02 3.20200988e-03 1.35518478e-03
#  1.00000000e-01 1.00000000e-06 6.37759844e-02] | SSR: 0.2634685285437126
# Parameters: [1.66472078e-02 3.16820161e-02 4.44015589e-03 1.27987684e-03
#  1.00000000e-01 1.00000000e-06 6.56947236e-02] | SSR: 0.2623998392437002
# Parameters: [1.60675816e-02 3.19025607e-02 1.26239341e-02 1.28934113e-03
#  1.00000000e-01 1.00000000e-06 6.51847890e-02] | SSR: 0.26457245329407536
# Parameters: [1.74719133e-02 3.14050497e-02 3.15673352e-03 1.18886281e-03
#  1.00000000e-01 1.00000000e-06 6.81032308e-02] | SSR: 0.2623274277071046
# Parameters: [1.63514936e-02 2.89619920e-02 7.68431067e-03 1.07809027e-03
#  1.00000000e-01 1.00000000e-06 7.06689480e-02] | SSR: 0.264071398480198
# Parameters: [1.72992575e-02 3.24128788e-02 5.32923024e-03 1.26486189e-03
#  1.00000000e-01 1.00000000e-06 6.61130421e-02] | SSR: 0.2623147498792093
# Parameters: [1.48825549e-02 2.87259420e-02 6.56635074e-05 1.40417845e-03
#  1.00000000e-01 1.00000000e-06 6.28257288e-02] | SSR: 0.2647469963637908
# Parameters: [1.77362502e-02 3.22998462e-02 7.99961710e-03 1.14578963e-03
#  1.00000000e-01 1.00000000e-06 6.89805544e-02] | SSR: 0.26223279995595167
# Parameters: [1.64638840e-02 3.19294417e-02 1.00000000e-06 1.38972696e-03
#  1.00000000e-01 1.00000000e-06 6.30006285e-02] | SSR: 0.26356228849572483
# Parameters: [1.70506019e-02 3.10334628e-02 8.29422399e-03 1.16496172e-03
#  1.00000000e-01 1.00000000e-06 6.85803197e-02] | SSR: 0.262232833667172
# Parameters: [1.77233045e-02 3.17899215e-02 4.53917060e-03 1.09669083e-03
#  1.00000000e-01 1.00000000e-06 7.01497189e-02] | SSR: 0.26251046123105404
# Parameters: [1.83523789e-02 3.44364762e-02 1.16390232e-02 1.19447959e-03
#  1.00000000e-01 1.00000000e-06 6.78150395e-02] | SSR: 0.2625832671497964
# Parameters: [1.83972417e-02 3.27342429e-02 5.98995159e-03 1.12206943e-03
#  1.00000000e-01 1.00000000e-06 6.96994332e-02] | SSR: 0.2627637920439577
# Parameters: [1.70044322e-02 3.18599467e-02 6.73320017e-03 1.22514885e-03
#  1.00000000e-01 1.00000000e-06 6.70295610e-02] | SSR: 0.26219977318195675
# Parameters: [1.61998975e-02 2.91301300e-02 1.00000000e-06 1.19586114e-03
#  1.00000000e-01 1.00000000e-06 6.77995750e-02] | SSR: 0.2626273572485682
# Parameters: [1.78142585e-02 3.31098897e-02 8.71182097e-03 1.19482498e-03
#  1.00000000e-01 1.00000000e-06 6.78111734e-02] | SSR: 0.26222304434120974
# Parameters: [1.68549588e-02 3.21538185e-02 8.22225280e-03 1.32168823e-03
#  1.00000000e-01 1.00000000e-06 6.47967397e-02] | SSR: 0.26259157415451145
# Parameters: [1.75062180e-02 3.18808958e-02 5.45994115e-03 1.15294018e-03
#  1.00000000e-01 1.00000000e-06 6.88114741e-02] | SSR: 0.26218527228769023
# Parameters: [1.81764870e-02 3.23185466e-02 8.61263472e-03 1.10223461e-03
#  1.00000000e-01 1.00000000e-06 7.01422352e-02] | SSR: 0.26258192733573443
# Parameters: [1.70295276e-02 3.18411487e-02 5.48327560e-03 1.23546628e-03
#  1.00000000e-01 1.00000000e-06 6.68066015e-02] | SSR: 0.26213990005384763
# Parameters: [1.72253855e-02 3.27201127e-02 1.05607834e-02 1.20656392e-03
#  1.00000000e-01 1.00000000e-06 6.73632624e-02] | SSR: 0.26259436717309836
# Parameters: [1.74102814e-02 3.17338155e-02 5.00774599e-03 1.19328808e-03
#  1.00000000e-01 1.00000000e-06 6.79182387e-02] | SSR: 0.262120034324132
# Parameters: [1.74297624e-02 3.15182656e-02 8.29643403e-03 1.11011518e-03
#  1.00000000e-01 1.00000000e-06 6.98692215e-02] | SSR: 0.26258635388815676
# Parameters: [1.73318837e-02 3.21892255e-02 6.07103119e-03 1.22617521e-03
#  1.00000000e-01 1.00000000e-06 6.70520870e-02] | SSR: 0.2621178586665429
# Parameters: [1.77587843e-02 3.32278995e-02 4.69624234e-03 1.22750491e-03
#  1.00000000e-01 1.00000000e-06 6.69653060e-02] | SSR: 0.2622890568854222
# Parameters: [1.72276475e-02 3.15820719e-02 7.39472858e-03 1.18059752e-03
#  1.00000000e-01 1.00000000e-06 6.81765663e-02] | SSR: 0.2621238031019471
# Parameters: [1.69278209e-02 3.17564377e-02 4.81802394e-03 1.25662212e-03
#  1.00000000e-01 1.00000000e-06 6.63353604e-02] | SSR: 0.26218138331360835
# Parameters: [1.65965447e-02 3.05596937e-02 2.99330663e-03 1.22524309e-03
#  1.00000000e-01 1.00000000e-06 6.70830807e-02] | SSR: 0.2622278447756161
# Parameters: [1.75098301e-02 3.24723407e-02 7.28219239e-03 1.20242951e-03
#  1.00000000e-01 1.00000000e-06 6.76291502e-02] | SSR: 0.2621227130254061
# Parameters: [1.75507705e-02 3.19846064e-02 5.12878236e-03 1.18842798e-03
#  1.00000000e-01 1.00000000e-06 6.80360042e-02] | SSR: 0.26214862771564384
# Parameters: [1.70617138e-02 3.19932889e-02 6.30742458e-03 1.27077602e-03
#  1.00000000e-01 1.00000000e-06 6.60325282e-02] | SSR: 0.26224996162499986
# Parameters: [1.73950920e-02 3.19089941e-02 5.67181201e-03 1.18239914e-03
#  1.00000000e-01 1.00000000e-06 6.81167376e-02] | SSR: 0.26210124760091563
# Parameters: [1.77736170e-02 3.21613345e-02 7.19328123e-03 1.14588751e-03
#  1.00000000e-01 1.00000000e-06 6.90176068e-02] | SSR: 0.2622328791488789
# Parameters: [1.71392699e-02 3.18576619e-02 5.41183826e-03 1.22893847e-03
#  1.00000000e-01 1.00000000e-06 6.70059220e-02] | SSR: 0.2621005010140227
# Parameters: [1.70330959e-02 3.18968960e-02 6.96339594e-03 1.22565608e-03
#  1.00000000e-01 1.00000000e-06 6.70226539e-02] | SSR: 0.2621809740811689
# Parameters: [1.74213518e-02 3.19626788e-02 5.58743575e-03 1.19773500e-03
#  1.00000000e-01 1.00000000e-06 6.77826666e-02] | SSR: 0.2620955338423119
# Parameters: [1.76662885e-02 3.20750765e-02 6.63866273e-03 1.16783742e-03
#  1.00000000e-01 1.00000000e-06 6.85309324e-02] | SSR: 0.26217245792179
# Parameters: [1.71887178e-02 3.18996307e-02 5.77212238e-03 1.21855906e-03
#  1.00000000e-01 1.00000000e-06 6.72376842e-02] | SSR: 0.26209254101602664
# Parameters: [1.74570459e-02 3.24248844e-02 4.26360798e-03 1.23355233e-03
#  1.00000000e-01 1.00000000e-06 6.68927155e-02] | SSR: 0.26219173697945
# Parameters: [1.72849971e-02 3.17927751e-02 6.61194843e-03 1.19383622e-03
#  1.00000000e-01 1.00000000e-06 6.78556036e-02] | SSR: 0.26208660251821103
# Parameters: [1.71106253e-02 3.13404540e-02 4.18464590e-03 1.20926512e-03
#  1.00000000e-01 1.00000000e-06 6.75048326e-02] | SSR: 0.2620920587372465
# Parameters: [1.71245580e-02 3.19665902e-02 6.22392085e-03 1.22297141e-03
#  1.00000000e-01 1.00000000e-06 6.70976281e-02] | SSR: 0.2621318465970002
# Parameters: [1.73388505e-02 3.17920092e-02 5.31178970e-03 1.20070892e-03
#  1.00000000e-01 1.00000000e-06 6.77130860e-02] | SSR: 0.26208809501896446
# Parameters: [1.72049461e-02 3.13976898e-02 4.94370951e-03 1.18280820e-03
#  1.00000000e-01 1.00000000e-06 6.81526367e-02] | SSR: 0.26210059987144374
# Parameters: [1.70874104e-02 3.15318344e-02 5.13489941e-03 1.22670114e-03
#  1.00000000e-01 1.00000000e-06 6.70982429e-02] | SSR: 0.2620984480929967
# Parameters: [1.72439747e-02 3.20814656e-02 5.91762759e-03 1.23883293e-03
#  1.00000000e-01 1.00000000e-06 6.67610885e-02] | SSR: 0.2621422007114048
# Parameters: [1.72147033e-02 3.15686338e-02 5.18718903e-03 1.19681438e-03
#  1.00000000e-01 1.00000000e-06 6.78047496e-02] | SSR: 0.26207899969844245
# Parameters: [1.73312033e-02 3.15389141e-02 5.38531334e-03 1.18352435e-03
#  1.00000000e-01 1.00000000e-06 6.81360395e-02] | SSR: 0.2621012831168482
# Parameters: [1.71872533e-02 3.17779749e-02 5.40520703e-03 1.21758494e-03
#  1.00000000e-01 1.00000000e-06 6.72884514e-02] | SSR: 0.26208285377647916
# Parameters: [1.74115893e-02 3.19350675e-02 5.73948295e-03 1.18315704e-03
#  1.00000000e-01 1.00000000e-06 6.80980640e-02] | SSR: 0.26209932055611485
# Parameters: [1.71684552e-02 3.16326426e-02 5.28604529e-03 1.21581512e-03
#  1.00000000e-01 1.00000000e-06 6.73481982e-02] | SSR: 0.26208211772366985
# Parameters: [1.70053917e-02 3.14099270e-02 5.20083504e-03 1.21728893e-03
#  1.00000000e-01 1.00000000e-06 6.72895064e-02] | SSR: 0.2620967979355072
# Parameters: [1.73173618e-02 3.18244908e-02 5.49078557e-03 1.20262348e-03
#  1.00000000e-01 1.00000000e-06 6.76593766e-02] | SSR: 0.26208136203022153
# Parameters: [1.72747811e-02 3.14515066e-02 4.93576646e-03 1.19191184e-03
#  1.00000000e-01 1.00000000e-06 6.79549724e-02] | SSR: 0.26210021670269207
# Parameters: [1.72102336e-02 3.17875997e-02 5.56303340e-03 1.21189726e-03
#  1.00000000e-01 1.00000000e-06 6.74170062e-02] | SSR: 0.26207988302243196
# Parameters: [1.73813332e-02 3.21384391e-02 6.91706794e-03 1.20195783e-03
#  1.00000000e-01 1.00000000e-06 6.76627307e-02] | SSR: 0.2620951185200562
# Parameters: [1.71783023e-02 3.15399503e-02 4.86775141e-03 1.20743830e-03
#  1.00000000e-01 1.00000000e-06 6.75443071e-02] | SSR: 0.26208004018857334
# Parameters: [1.71072370e-02 3.16148672e-02 5.66305606e-03 1.21243671e-03
#  1.00000000e-01 1.00000000e-06 6.74062547e-02] | SSR: 0.2620877364165088
# Parameters: [1.71651404e-02 3.16591527e-02 5.57523947e-03 1.20950476e-03
#  1.00000000e-01 1.00000000e-06 6.74829626e-02] | SSR: 0.26207914816559874
# Parameters: [1.71268457e-02 3.15759235e-02 4.06669477e-03 1.22378613e-03
#  1.00000000e-01 1.00000000e-06 6.71572683e-02] | SSR: 0.26209762092830324
# Parameters: [1.72454592e-02 3.17385622e-02 5.97563502e-03 1.20132370e-03
#  1.00000000e-01 1.00000000e-06 6.76810198e-02] | SSR: 0.26207795894614455
# Parameters: [1.72412198e-02 3.15794628e-02 5.43641559e-03 1.19539135e-03
#  1.00000000e-01 1.00000000e-06 6.78365829e-02] | SSR: 0.2620796888075225
# Parameters: [1.72808078e-02 3.17096008e-02 5.59854028e-03 1.19132581e-03
#  1.00000000e-01 1.00000000e-06 6.79163746e-02] | SSR: 0.26208438329919365
# Parameters: [1.71965433e-02 3.16518822e-02 5.36416904e-03 1.20969279e-03
#  1.00000000e-01 1.00000000e-06 6.74902423e-02] | SSR: 0.26207741196708045
# Parameters: [1.70973816e-02 3.14684359e-02 5.35762385e-03 1.20653724e-03
#  1.00000000e-01 1.00000000e-06 6.75568722e-02] | SSR: 0.26208404094348453
# Parameters: [1.72623667e-02 3.17354771e-02 5.45749514e-03 1.20360192e-03
#  1.00000000e-01 1.00000000e-06 6.76337505e-02] | SSR: 0.2620772157510021
# Parameters: [1.72604596e-02 3.18088412e-02 6.14915621e-03 1.20062632e-03
#  1.00000000e-01 1.00000000e-06 6.76974968e-02] | SSR: 0.26208203580803385
# Parameters: [1.71988416e-02 3.16071730e-02 5.18810261e-03 1.20573530e-03
#  1.00000000e-01 1.00000000e-06 6.75826046e-02] | SSR: 0.2620769363767793
# Parameters: [1.72252733e-02 3.15096414e-02 5.34675114e-03 1.19440680e-03
#  1.00000000e-01 1.00000000e-06 6.78721115e-02] | SSR: 0.2620814319393844
# Parameters: [1.72139936e-02 3.17181101e-02 5.50896284e-03 1.20752464e-03
#  1.00000000e-01 1.00000000e-06 6.75307826e-02] | SSR: 0.2620769528617688
# Parameters: [1.71865082e-02 3.17573918e-02 5.49409673e-03 1.21437937e-03
#  1.00000000e-01 1.00000000e-06 6.73651633e-02] | SSR: 0.2620806125562525
# Parameters: [1.72275419e-02 3.16239450e-02 5.45083588e-03 1.20013835e-03
#  1.00000000e-01 1.00000000e-06 6.77187280e-02] | SSR: 0.26207694839514295
# Parameters: [1.72804166e-02 3.16676426e-02 5.31972897e-03 1.19758983e-03
#  1.00000000e-01 1.00000000e-06 6.77861452e-02] | SSR: 0.26208005643259674
# Parameters: [1.71939595e-02 3.16612752e-02 5.51136185e-03 1.20652603e-03
#  1.00000000e-01 1.00000000e-06 6.75587582e-02] | SSR: 0.26207680611819806
# Parameters: [1.72249270e-02 3.17846304e-02 5.80040022e-03 1.21305497e-03
#  1.00000000e-01 1.00000000e-06 6.73940749e-02] | SSR: 0.2620803542913589
# Parameters: [1.72172592e-02 3.16226329e-02 5.34049183e-03 1.20087453e-03
#  1.00000000e-01 1.00000000e-06 6.77020809e-02] | SSR: 0.26207673100438755
# Parameters: [1.71861138e-02 3.15815794e-02 4.83048475e-03 1.20841732e-03
#  1.00000000e-01 1.00000000e-06 6.75238222e-02] | SSR: 0.2620787193052637
# Parameters: [1.72306229e-02 3.16993165e-02 5.68934745e-03 1.20309711e-03
#  1.00000000e-01 1.00000000e-06 6.76417204e-02] | SSR: 0.2620765328491831
# Parameters: [1.72447668e-02 3.16818121e-02 5.53485885e-03 1.19816375e-03
#  1.00000000e-01 1.00000000e-06 6.77578792e-02] | SSR: 0.26207826512477744
# Parameters: [1.72085992e-02 3.16593647e-02 5.40684149e-03 1.20681053e-03
#  1.00000000e-01 1.00000000e-06 6.75571515e-02] | SSR: 0.262076391159586
# Parameters: [1.71635812e-02 3.15764707e-02 5.42706027e-03 1.20517136e-03
#  1.00000000e-01 1.00000000e-06 6.75924856e-02] | SSR: 0.26207790762655875
# Parameters: [1.72376704e-02 3.16957255e-02 5.44988642e-03 1.20399428e-03
#  1.00000000e-01 1.00000000e-06 6.76234342e-02] | SSR: 0.2620763662636176
# Parameters: [1.72187192e-02 3.15874421e-02 5.35871360e-03 1.20023997e-03
#  1.00000000e-01 1.00000000e-06 6.77219254e-02] | SSR: 0.2620772239029067
# Parameters: [1.72151750e-02 3.16854431e-02 5.47140053e-03 1.20570347e-03
#  1.00000000e-01 1.00000000e-06 6.75785683e-02] | SSR: 0.26207634156685383
# Parameters: [1.72016374e-02 3.16991781e-02 5.42271617e-03 1.20921629e-03
#  1.00000000e-01 1.00000000e-06 6.74939343e-02] | SSR: 0.2620770551970426
# Parameters: [1.72210658e-02 3.16427533e-02 5.44380595e-03 1.20240784e-03
#  1.00000000e-01 1.00000000e-06 6.76625296e-02] | SSR: 0.26207635178627914
# Parameters: [1.72366875e-02 3.17261159e-02 5.75850753e-03 1.20266864e-03
#  1.00000000e-01 1.00000000e-06 6.76528935e-02] | SSR: 0.2620772172611928
# Parameters: [1.72083031e-02 3.16369087e-02 5.33070384e-03 1.20496864e-03
#  1.00000000e-01 1.00000000e-06 6.76001768e-02] | SSR: 0.26207632913440926
# Parameters: [1.72456678e-02 3.16650519e-02 5.38363173e-03 1.20143294e-03
#  1.00000000e-01 1.00000000e-06 6.76885737e-02] | SSR: 0.262076973726234
# Parameters: [1.72068866e-02 3.16622193e-02 5.47942932e-03 1.20525276e-03
#  1.00000000e-01 1.00000000e-06 6.75912121e-02] | SSR: 0.2620763064068222
# Parameters: [1.72194045e-02 3.17150045e-02 5.59419817e-03 1.20833536e-03
#  1.00000000e-01 1.00000000e-06 6.75135742e-02] | SSR: 0.26207704850102564
# Parameters: [1.72177955e-02 3.16457258e-02 5.40391841e-03 1.20273974e-03
#  1.00000000e-01 1.00000000e-06 6.76549542e-02] | SSR: 0.2620762742083099
# Parameters: [1.72023758e-02 3.16230094e-02 5.16379140e-03 1.20601068e-03
#  1.00000000e-01 1.00000000e-06 6.75777158e-02] | SSR: 0.2620766191414009
# Parameters: [1.72235611e-02 3.16802397e-02 5.55795844e-03 1.20382550e-03
#  1.00000000e-01 1.00000000e-06 6.76257192e-02] | SSR: 0.2620762473474246
# Parameters: [1.72286743e-02 3.16689255e-02 5.48947363e-03 1.20144439e-03
#  1.00000000e-01 1.00000000e-06 6.76818755e-02] | SSR: 0.2620767064485538
# Parameters: [1.72136180e-02 3.16617549e-02 5.42749952e-03 1.20546900e-03
#  1.00000000e-01 1.00000000e-06 6.75883325e-02] | SSR: 0.26207619267467325
# Parameters: [1.71927311e-02 3.16228587e-02 5.44003244e-03 1.20468199e-03
#  1.00000000e-01 1.00000000e-06 6.76055637e-02] | SSR: 0.26207655678474784
# Parameters: [1.72264355e-02 3.16775088e-02 5.44742293e-03 1.20416621e-03
#  1.00000000e-01 1.00000000e-06 6.76189666e-02] | SSR: 0.2620762016288052
# Parameters: [1.72108698e-02 3.16857611e-02 5.44714633e-03 1.20677082e-03
#  1.00000000e-01 1.00000000e-06 6.75540218e-02] | SSR: 0.2620763973785918
# Parameters: [1.72185168e-02 3.16535053e-02 5.44464105e-03 1.20349858e-03
#  1.00000000e-01 1.00000000e-06 6.76354026e-02] | SSR: 0.26207621205839593
# Parameters: [1.72177155e-02 3.16339462e-02 5.41190619e-03 1.20284522e-03
#  1.00000000e-01 1.00000000e-06 6.76542215e-02] | SSR: 0.2620762860626998
# Parameters: [1.72272766e-02 3.16816341e-02 5.57580354e-03 1.20297336e-03
#  1.00000000e-01 1.00000000e-06 6.76480543e-02] | SSR: 0.26207630795790615
# Parameters: [1.72225332e-02 3.16704528e-02 5.51452862e-03 1.20347218e-03
#  1.00000000e-01 1.00000000e-06 6.76360849e-02] | SSR: 0.2620761956793654
# Parameters: [1.72331636e-02 3.16586759e-02 5.43710644e-03 1.20218051e-03
#  1.00000000e-01 1.00000000e-06 6.76698398e-02] | SSR: 0.2620764183901045
# Parameters: [1.72134558e-02 3.16613335e-02 5.46884860e-03 1.20448469e-03
#  1.00000000e-01 1.00000000e-06 6.76108690e-02] | SSR: 0.2620761867769158
# Optimization successful: True
# Number of iterations: 386
#
# Optimized parameters:
# beta: 0.017213
# gamma: 0.031661
# rho: 0.005469
# delta: 0.001204
# p: 0.100000
# c: 0.000001
# alpha: 0.067611
# guess =  [np.float64(0.017213455822756962), np.float64(0.031661333492966404), np.float64(0.005468848598255898), np.float64(0.0012044846949651237), np.float64(0.1), np.float64(1.0000000000000006e-06), np.float64(0.06761086902112376)]

# %%
# Calculate final SSR
final_ssr = result.fun
print(f"\nFinal SSR: {final_ssr:.6f}")

# Generate 95% confidence intervals for model predictions using bootstrap parameters
try:
    # Load bootstrap parameters if available
    bootstrap_params = np.loadtxt(f"{output_prefix}_params.txt", delimiter=",")
    
    # Generate model predictions for each bootstrap parameter set
    V_bootstrap = []
    F_bootstrap = []
    
    # Use a subset of bootstrap samples for speed (every 10th sample)
    n_samples = min(100, len(bootstrap_params))
    sample_indices = np.linspace(0, len(bootstrap_params)-1, n_samples, dtype=int)
    
    for idx in sample_indices:
        params = bootstrap_params[idx]
        try:
            solution = odeint(Model, y0, t, args=tuple(params))
            _, _, _, V_boot, F_boot = solution.T
            V_bootstrap.append(V_boot)
            F_bootstrap.append(F_boot)
        except:
            continue
    
    # Calculate 95% confidence intervals
    if len(V_bootstrap) > 10:
        V_bootstrap = np.array(V_bootstrap)
        F_bootstrap = np.array(F_bootstrap)
        
        V_ci_lower = np.percentile(V_bootstrap, 2.5, axis=0)
        V_ci_upper = np.percentile(V_bootstrap, 97.5, axis=0)
        F_ci_lower = np.percentile(F_bootstrap, 2.5, axis=0)
        F_ci_upper = np.percentile(F_bootstrap, 97.5, axis=0)
        
        print(f"Generated 95% CI from {len(V_bootstrap)} bootstrap samples")
        ci_available = True
    else:
        print("Insufficient bootstrap samples for CI calculation")
        ci_available = False
        
except:
    print("Bootstrap data not available for CI calculation")
    ci_available = False

# Plot results with 95% confidence intervals
plt.figure(figsize=(12, 5))

# Plot viral load
plt.subplot(121)
if ci_available:
    plt.fill_between(t, V_ci_lower, V_ci_upper, alpha=0.3, color='blue', label='95% CI')
plt.plot(t, V_fit, 'b-', label='Model', linewidth=2)
plt.plot(vl_data['time'], vl_data['value'], 'bo', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('Viral Load (log10)')
plt.legend()
plt.title('Viral Load Fit')

# Plot interferon
plt.subplot(122)
if ci_available:
    plt.fill_between(t, F_ci_lower, F_ci_upper, alpha=0.3, color='red', label='95% CI')
plt.plot(t, F_fit, 'r-', label='Model', linewidth=2)
plt.plot(t1_data['time'], t1_data['value'], 'ro', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('IFN-A2 Level')
plt.legend()
plt.title('Interferon Fit')

plt.tight_layout()
plt.savefig("h5n1(2005)_tracheal_fit_with_ci.png")
plt.show()
# Out:
# Final SSR: 0.262076
# Bootstrap data not available for CI calculation

# %%
# %% Bootstrap Analysis
import os

# Create output directory
strain = "h5n1(2005)"  # Change for each file
location = "tracheal"     # Change for each file
output_dir = f"/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/{strain}/{location}/bootstrap_results"
os.makedirs(output_dir, exist_ok=True)
output_prefix = f"{output_dir}/{strain}_{location}"

# Calculate residuals between data and best-fit model
# Find indices for data_times in t
indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
V_best = V_fit[indices]
F_best = F_fit[indices]

# Calculate residuals (use for bootstrapping)
residuals_viral = vl_data['value'] - V_best
residuals_ifn = t1_data['value'] - F_best

# Use best-fit parameters from previous optimization
best_params = [beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit]

# Define bootstrap optimization function that uses relative error
def optimize_bootstrap(params, new_viral_data, new_ifn_data):
    """
    Objective function for bootstrap optimization.
    Uses relative error just like the original optimize function.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        V_pred = V[indices]
        F_pred = F[indices]
        
        # Calculate relative SSR (same method as in original optimize function)
        vl_ssr = np.sum((((np.maximum(V_pred, 0)) - new_viral_data)/new_viral_data)**2)
        ifn_ssr = np.sum(((F_pred - new_ifn_data)/new_ifn_data)**2)
        
        total_ssr = vl_ssr + ifn_ssr
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

# Number of bootstrap samples
n_bootstrap = 1000

# Initialize arrays for bootstrap results
bootstrap_params = []
bootstrap_ssr = []

print(f"Starting bootstrap analysis with {n_bootstrap} samples")
print(f"Using best-fit parameters: {best_params}")

# Run bootstrap
for i in range(n_bootstrap):
    # Generate new datasets by resampling residuals
    new_viral_data = V_best + np.random.choice(residuals_viral, size=len(residuals_viral), replace=True)
    new_ifn_data = F_best + np.random.choice(residuals_ifn, size=len(residuals_ifn), replace=True)
    
    # Ensure non-negative values
    new_viral_data = np.maximum(new_viral_data, 1e-6)  # Using small positive number instead of zero for relative error
    new_ifn_data = np.maximum(new_ifn_data, 1e-6)
    
    # Optimize with new dataset
    result_bootstrap = minimize(
        optimize_bootstrap, 
        best_params, 
        args=(new_viral_data, new_ifn_data), 
        method='Nelder-Mead', 
        bounds=bounds
    )
    
    bootstrap_params.append(result_bootstrap.x)
    bootstrap_ssr.append(result_bootstrap.fun)
    
    if (i+1) % 10 == 0 or i == 0:
        print(f"Processing bootstrap sample {i+1}/{n_bootstrap}")

# Save bootstrap parameters and SSR to text files
np.savetxt(f"{output_prefix}_params.txt", np.array(bootstrap_params), delimiter=",")
np.savetxt(f"{output_prefix}_ssr.txt", np.array(bootstrap_ssr), delimiter=",")

# Calculate and print statistics
print(f"\nBootstrap Statistics:")
print(f"Mean SSR: {np.mean(bootstrap_ssr)}")
print(f"Median SSR: {np.median(bootstrap_ssr)}")
print(f"Standard Deviation of SSR: {np.std(bootstrap_ssr)}")

# Calculate parameter statistics
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
param_stats = {}

# Create a results summary file
with open(f"{output_prefix}_summary.txt", "w") as f:
    f.write(f"Bootstrap Results Summary for {strain} {location}\n")
    f.write(f"Number of bootstrap samples: {n_bootstrap}\n\n")
    f.write(f"SSR Statistics:\n")
    f.write(f"Mean: {np.mean(bootstrap_ssr):.6f}\n")
    f.write(f"Median: {np.median(bootstrap_ssr):.6f}\n")
    f.write(f"Std Dev: {np.std(bootstrap_ssr):.6f}\n\n")
    
    f.write(f"Parameter Statistics:\n")
    for i, name in enumerate(param_names):
        param_values = np.array(bootstrap_params)[:, i]
        mean_val = np.mean(param_values)
        median_val = np.median(param_values)
        ci_low = np.percentile(param_values, 2.5)
        ci_high = np.percentile(param_values, 97.5)
        
        param_stats[name] = {
            'mean': mean_val,
            'median': median_val,
            'ci_low': ci_low,
            'ci_high': ci_high
        }
        
        f.write(f"{name}:\n")
        f.write(f"  Mean: {mean_val:.6f}\n")
        f.write(f"  Median: {median_val:.6f}\n")
        f.write(f"  95% CI: [{ci_low:.6f}, {ci_high:.6f}]\n\n")

print(f"Bootstrap analysis complete. Results saved to {output_dir}")
# Out:
# Starting bootstrap analysis with 1000 samples
# Using best-fit parameters: [np.float64(0.017213455822756962), np.float64(0.031661333492966404), np.float64(0.005468848598255898), np.float64(0.0012044846949651237), np.float64(0.1), np.float64(1.0000000000000006e-06), np.float64(0.06761086902112376)]
# Processing bootstrap sample 1/1000
# Processing bootstrap sample 10/1000
# Processing bootstrap sample 20/1000
# Processing bootstrap sample 30/1000
# Processing bootstrap sample 40/1000
# Processing bootstrap sample 50/1000
# Processing bootstrap sample 60/1000
# Processing bootstrap sample 70/1000
# Processing bootstrap sample 80/1000
# Processing bootstrap sample 90/1000
# Processing bootstrap sample 100/1000
# Processing bootstrap sample 110/1000
# Processing bootstrap sample 120/1000
# Processing bootstrap sample 130/1000
# Processing bootstrap sample 140/1000
# Processing bootstrap sample 150/1000
# Processing bootstrap sample 160/1000
# Processing bootstrap sample 170/1000
# Processing bootstrap sample 180/1000
# Processing bootstrap sample 190/1000
# Processing bootstrap sample 200/1000
# Processing bootstrap sample 210/1000
# Processing bootstrap sample 220/1000
# Processing bootstrap sample 230/1000
# Processing bootstrap sample 240/1000
# Processing bootstrap sample 250/1000
# Processing bootstrap sample 260/1000
# Processing bootstrap sample 270/1000
# Processing bootstrap sample 280/1000
# Processing bootstrap sample 290/1000
# Processing bootstrap sample 300/1000
# Processing bootstrap sample 310/1000
# Processing bootstrap sample 320/1000
# Processing bootstrap sample 330/1000
# Processing bootstrap sample 340/1000
# Processing bootstrap sample 350/1000
# Processing bootstrap sample 360/1000
# Processing bootstrap sample 370/1000
# Processing bootstrap sample 380/1000
# Processing bootstrap sample 390/1000
# Processing bootstrap sample 400/1000
# Processing bootstrap sample 410/1000
# Processing bootstrap sample 420/1000
# Processing bootstrap sample 430/1000
# Processing bootstrap sample 440/1000
# Processing bootstrap sample 450/1000
# Processing bootstrap sample 460/1000
# Processing bootstrap sample 470/1000
# Processing bootstrap sample 480/1000
# Processing bootstrap sample 490/1000
# Processing bootstrap sample 500/1000
# Processing bootstrap sample 510/1000
# Processing bootstrap sample 520/1000
# Processing bootstrap sample 530/1000
# Processing bootstrap sample 540/1000
# Processing bootstrap sample 550/1000
# Processing bootstrap sample 560/1000
# Processing bootstrap sample 570/1000
# Processing bootstrap sample 580/1000
# Processing bootstrap sample 590/1000
# Processing bootstrap sample 600/1000
# Processing bootstrap sample 610/1000
# Processing bootstrap sample 620/1000
# Processing bootstrap sample 630/1000
# Processing bootstrap sample 640/1000
# Processing bootstrap sample 650/1000
# Processing bootstrap sample 660/1000
# Processing bootstrap sample 670/1000
# Processing bootstrap sample 680/1000
# Processing bootstrap sample 690/1000
# Processing bootstrap sample 700/1000
# Processing bootstrap sample 710/1000
# Processing bootstrap sample 720/1000
# Processing bootstrap sample 730/1000
# Processing bootstrap sample 740/1000
# Processing bootstrap sample 750/1000
# Processing bootstrap sample 760/1000
# Processing bootstrap sample 770/1000
# Processing bootstrap sample 780/1000
# Processing bootstrap sample 790/1000
# Processing bootstrap sample 800/1000
# Processing bootstrap sample 810/1000
# Processing bootstrap sample 820/1000
# Processing bootstrap sample 830/1000
# Processing bootstrap sample 840/1000
# Processing bootstrap sample 850/1000
# Processing bootstrap sample 860/1000
# Processing bootstrap sample 870/1000
# Processing bootstrap sample 880/1000
# Processing bootstrap sample 890/1000
# Processing bootstrap sample 900/1000
# Processing bootstrap sample 910/1000
# Processing bootstrap sample 920/1000
# Processing bootstrap sample 930/1000
# Processing bootstrap sample 940/1000
# Processing bootstrap sample 950/1000
# Processing bootstrap sample 960/1000
# Processing bootstrap sample 970/1000
# Processing bootstrap sample 980/1000
# Processing bootstrap sample 990/1000
# Processing bootstrap sample 1000/1000
#
# Bootstrap Statistics:
# Mean SSR: 0.24753372411053748
# Median SSR: 0.24927362487750038
# Standard Deviation of SSR: 0.08544675901934384
# Bootstrap analysis complete. Results saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h5n1(2005)/tracheal/bootstrap_results

# %%
# %% Parameter Distribution Plotting
# Log ALL parameters for consistent, nice-looking bootstrap charts
fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.flatten()

# Convert bootstrap_params to numpy array for easier indexing
bootstrap_params = np.array(bootstrap_params)

for i, name in enumerate(param_names):
    if i < len(axes):
        ax = axes[i]
        param_values = bootstrap_params[:, i]
        
        # Log ALL parameters - show only 5-95 percentile
        log_values = np.log10(np.maximum(param_values, 1e-12))
        p5, p95 = np.percentile(log_values, [5, 95])
        filtered_log_values = log_values[(log_values >= p5) & (log_values <= p95)]
        n_bins = min(30, max(10, len(filtered_log_values)//30))
        
        ax.hist(filtered_log_values, bins=n_bins, alpha=0.7, color='skyblue', edgecolor='black', linewidth=0.5)
        
        # Add reference lines
        ax.axvline(np.log10(best_params[i]), color='r', linestyle='--', linewidth=2, label='Best fit')
        ax.axvline(np.log10(param_stats[name]['mean']), color='g', linestyle='-', linewidth=2, label='Bootstrap mean')
        ax.axvline(np.log10(param_stats[name]['ci_low']), color='k', linestyle=':', linewidth=1.5, label='95% CI')
        ax.axvline(np.log10(param_stats[name]['ci_high']), color='k', linestyle=':', linewidth=1.5)
        
        ax.set_xlabel(f'log₁₀({name})', fontsize=12)
        ax.set_title(f'{name} (n={len(filtered_log_values)}, log scale, 5-95%)', fontsize=14)
        ax.set_ylabel('Frequency', fontsize=12)
        ax.tick_params(labelsize=10)
        
        if i == 0:  # Only add legend to first plot
            ax.legend(fontsize=10, loc='upper right')

# Remove empty subplots
for i in range(len(param_names), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
plt.close()

print(f"Parameter distribution plots saved to {output_prefix}_param_distributions.png")
print("All parameters plotted on log scale with 5-95 percentile range")
# Out:
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_27799/4098012820.py:40: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_27799/4098012820.py:40: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_27799/4098012820.py:41: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_27799/4098012820.py:41: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# Parameter distribution plots saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h5n1(2005)/tracheal/bootstrap_results/h5n1(2005)_tracheal_param_distributions.png
# All parameters plotted on log scale with 5-95 percentile range
