# %%
# Standard scientific libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.optimize import minimize

# Set plotting style for better visualization
plt.style.use("seaborn-v0_8")

# %%
vl_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/tracheal_data/h3n2(2003)/tracheal_h3n2_vl.txt"
t1_path = "/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/data/tracheal_data/h3n2(2003)/tracheal_h3n2_t1.txt"

# Load the viral load data
vl_data = pd.read_csv(vl_path)
print("Viral Load Data:")
print(vl_data, "\n")

# Load the interferon data
t1_data = pd.read_csv(t1_path)
print("Interferon Data:")
print(t1_data)

# Let's also create a simple plot to visualize our data
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot viral load data
ax1.plot(vl_data['time'], vl_data['value'], 'o-', color='blue', label='Viral Load')
ax1.set_xlabel('Time (hours)')
ax1.set_ylabel('Viral Load (log scale)')
ax1.set_title('H3N2 Tracheal Viral Load')
ax1.legend()

# Plot interferon data
ax2.plot(t1_data['time'], t1_data['value'], 'o-', color='red', label='IFN-A2')
ax2.set_xlabel('Time (hours)')
ax2.set_ylabel('IFN-A2 Level')
ax2.set_title('H3N2 Tracheal Interferon')
ax2.legend()

plt.tight_layout()
plt.savefig('tracheal_h3n2_2003.png')
plt.show()
# Out:
# Viral Load Data:
#    time  value
# 0     0  2.584
# 1     8  2.203
# 2    24  7.247
# 3    48  8.403
# 4    72  7.120
#
# Interferon Data:
#    time   value
# 0     0   2.138
# 1     8   3.499
# 2    24   8.099
# 3    48  20.734
# 4    72  21.965

# %%
def Model(y, t, beta, gamma, rho, delta, p, c, alpha):
    """
    Extended model with resistant cell class
    
    Parameters:
    y: list of variables [T, R, I, V, F]
    t: time points
    beta: infection rate
    gamma: rate of conversion to resistant state
    rho: rate of return from resistant state
    delta: death rate of infected cells
    p: virus production rate
    c: virus clearance rate
    alpha: interferon clearance rate
    """
    T, R, I, V, F = y
    
    # System of ODEs
    dTdt = -beta * T * V - gamma * T * F    # Target cells
    dRdt = gamma * T * F - rho * R          # Resistant cells
    dIdt = beta * T * V - delta * I         # Infected cells
    dVdt = p * I - c * V                    # Virus
    dFdt = I - alpha * F                    # Interferon
    
    return [dTdt, dRdt, dIdt, dVdt, dFdt]

# Initial conditions
T0 = 1.0     # Initial target cells (normalized)
R0 = 0.0     # Initial resistant cells
I0 = 0.0     # Initial infected cells
V0 = vl_data['value'].iloc[0]    # Initial virus from data
F0 = t1_data['value'].iloc[0]    # Initial interferon from data
y0 = [T0, R0, I0, V0, F0]

print("Initial conditions:")
for var, val in zip(['T0', 'R0', 'I0', 'V0', 'F0'], y0):
    print(f"{var} = {val}")
# Out:
# Initial conditions:
# T0 = 1.0
# R0 = 0.0
# I0 = 0.0
# V0 = 2.584
# F0 = 2.138

# %%
# Create two sets of time points:
# 1. Data time points for comparison
data_times = np.array([0, 8, 24, 48, 72])

# 2. Integration time points (finer mesh for solving ODEs)
t = np.linspace(0, 72, 100)

def optimize(params):
    """
    Objective function to minimize.
    Uses relative error at actual data time points.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        # Find indices in t that correspond to data_times
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        global V_model, F_model
        V_model = V[indices]
        F_model = F[indices]
        
        # Calculate relative SSR
        vl_ssr = np.sum((((np.maximum(V_model, 0)) - vl_data['value'])/vl_data['value'])**2)
        ifn_ssr = np.sum(((F_model - t1_data['value'])/t1_data['value'])**2)
        
        total_ssr = vl_ssr + ifn_ssr
        
        print(f"Parameters: {params} | SSR: {total_ssr}")
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

print("Data time points:", data_times)
print("\nNumber of integration points:", len(t))
print("Integration time range:", t[0], "to", t[-1])
# Out:
# Data time points: [ 0  8 24 48 72]
#
# Number of integration points: 100
# Integration time range: 0.0 to 72.0

# %%
guess = [0.1, 0.1, 0.1, 0.1, 10.0, 0.1, 0.1]

# %%
bounds = [
    (1e-6, 10.0),   # beta
    (1e-6, 10.0),   # gamma
    (1e-6, 10.0),   # rho 
    (1e-6, 10.0),   # delta
    (1e-1, 1e7), #p
    (1e-6, 10.0),   # c
    (1e-6, 100.0)    # alpha
]

print("Initial parameter guesses:")
for param, value in zip(['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha'], guess):
    print(f"{param}: {value}")
# Out:
# Initial parameter guesses:
# beta: 0.1
# gamma: 0.1
# rho: 0.1
# delta: 0.1
# p: 10.0
# c: 0.1
# alpha: 0.1

# %%
# Perform optimization
result = minimize(optimize, guess, method ='Nelder-Mead', bounds=bounds)

# Extract optimized parameters
beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit = result.x

# Generate solution with optimized parameters
solution_fit = odeint(Model, y0, t, args=(beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit))
T_fit, R_fit, I_fit, V_fit, F_fit = solution_fit.T

# Print optimization results
print("Optimization successful:", result.success)
print("Number of iterations:", result.nit)
print("\nOptimized parameters:")
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
for name, value in zip(param_names, result.x):
    print(f"{name}: {value:.6f}")

print("guess = ", [i for i in result.x])
# Out:
# Parameters: [ 0.1  0.1  0.1  0.1 10.   0.1  0.1] | SSR: 98.5203073600752
# Parameters: [ 0.105  0.1    0.1    0.1   10.     0.1    0.1  ] | SSR: 102.23049254788735
# Parameters: [ 0.1    0.105  0.1    0.1   10.     0.1    0.1  ] | SSR: 95.06897925793739
# Parameters: [ 0.1    0.1    0.105  0.1   10.     0.1    0.1  ] | SSR: 98.5203073600752
# Parameters: [ 0.1    0.1    0.1    0.105 10.     0.1    0.1  ] | SSR: 95.19225471246563
# Parameters: [ 0.1  0.1  0.1  0.1 10.5  0.1  0.1] | SSR: 110.28353754479681
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.105  0.1  ] | SSR: 94.55458589350192
# Parameters: [ 0.1    0.1    0.1    0.1   10.     0.1    0.105] | SSR: 98.91939319341122
# Parameters: [0.10142857 0.10142857 0.10142857 0.10142857 9.5        0.10142857
#  0.10142857] | SSR: 85.82544887087398
# Parameters: [0.10214286 0.10214286 0.10214286 0.10214286 9.         0.10214286
#  0.10214286] | SSR: 75.06645318152103
# Parameters: [0.09561224 0.10204082 0.10204082 0.10204082 9.71428571 0.10204082
#  0.10204082] | SSR: 85.08638037389261
# Parameters: [0.0993586  0.10262391 0.10262391 0.10262391 9.63265306 0.10262391
#  0.09619534] | SSR: 84.52175294036176
# Parameters: [0.09917534 0.10337359 0.09694502 0.10337359 9.52769679 0.10337359
#  0.10010829] | SSR: 81.2039391201024
# Parameters: [0.09893973 0.10433748 0.10107217 0.10433748 9.39275302 0.10433748
#  0.10013923] | SSR: 76.76989702085935
# Parameters: [0.09863679 0.10557676 0.10137851 0.09914819 9.21925388 0.10557676
#  0.10017901] | SSR: 74.53915702998695
# Parameters: [0.09795519 0.10836514 0.10206776 0.09622228 8.82888082 0.10836514
#  0.10026851] | SSR: 65.52578359103708
# Parameters: [0.09805256 0.10153823 0.1019693  0.10306884 8.8846484  0.1079668
#  0.10025572] | SSR: 67.00534991868467
# Parameters: [0.09749615 0.10697772 0.10253195 0.10394565 8.56597652 0.10381445
#  0.10032879] | SSR: 60.625240210992324
# Parameters: [0.09624422 0.11046658 0.10379793 0.10591847 7.84896478 0.10322168
#  0.10049318] | SSR: 47.519509315034746
# Parameters: [0.10206447 0.10734426 0.10099317 0.10301273 8.31874197 0.10711103
#  0.09784579] | SSR: 57.41802977223382
# Parameters: [0.09909122 0.10810985 0.09994415 0.10254074 8.02497145 0.10780997
#  0.10416283] | SSR: 51.4980360099594
# Parameters: [0.09925044 0.10871337 0.10647993 0.10155309 7.70057762 0.10832782
#  0.10140832] | SSR: 46.734200435950285
# Parameters: [0.09928799 0.11138326 0.11124738 0.10064284 6.78701803 0.11080493
#  0.10205833] | SSR: 34.1180223891432
# Parameters: [0.09958556 0.10976257 0.10525998 0.0995336  7.09102568 0.10921178
#  0.1019257 ] | SSR: 38.88792381244376
# Parameters: [0.09565178 0.11413425 0.10507991 0.10098271 6.93835747 0.11342609
#  0.09986002] | SSR: 33.11639799134687
# Parameters: [0.09240624 0.12012995 0.10654843 0.10040264 5.9075362  0.11906771
#  0.0987186 ] | SSR: 20.88472123391042
# Parameters: [0.09812884 0.1200508  0.10656179 0.09929496 6.20310557 0.11077384
#  0.10130797] | SSR: 26.35439446516314
# Parameters: [0.09827582 0.11656266 0.10774734 0.10701943 5.50865165 0.1110637
#  0.10159218] | SSR: 20.19430975247609
# Parameters: [0.09843614 0.12066141 0.11058712 0.11241801 3.84853707 0.11241299
#  0.10225401] | SSR: 10.265313560605659
# Parameters: [0.09312987 0.12138843 0.11156306 0.1029162  4.74158911 0.11383266
#  0.10527439] | SSR: 14.117595063245604
# Parameters: [0.09439988 0.12441673 0.11593176 0.10349547 4.09725039 0.11485448
#  0.09927494] | SSR: 10.846647243031674
# Parameters: [0.09671992 0.12604575 0.11554479 0.09942544 3.20133867 0.12276643
#  0.10259652] | SSR: 7.7685471488507165
# Parameters: [0.09695778 0.13383534 0.12141823 0.09617893 0.87752561 0.13253881
#  0.10364818] | SSR: 5.56182702403804
# Parameters: [0.09262779 0.13362769 0.11869938 0.10485184 2.18399203 0.1234412
#  0.10165614] | SSR: 5.876503181388361
# Parameters: [0.09102245 0.13836255 0.11484112 0.10494517 1.1728494  0.12545841
#  0.10140859] | SSR: 5.544115635153567
# Parameters: [0.08688968 0.1518522  0.11663799 0.10709634 0.1        0.13278514
#  0.10108372] | SSR: 6.170293536738184
# Parameters: [0.09015121 0.13492694 0.12189224 0.1079074  0.3195458  0.12968509
#  0.1021877 ] | SSR: 5.957517945254789
# Parameters: [0.09522951 0.13907551 0.12628954 0.10894393 0.1        0.12442475
#  0.10576824] | SSR: 6.104457923500708
# Parameters: [0.09510577 0.14287048 0.12548248 0.10815259 0.1        0.13268612
#  0.09935355] | SSR: 6.117155784746577
# Parameters: [0.09403744 0.14511468 0.12384256 0.10890392 0.1        0.13675905
#  0.10537547] | SSR: 6.18257196371266
# Parameters: [0.08874442 0.15585664 0.13297447 0.09897736 0.1        0.14615656
#  0.10328824] | SSR: 6.2206852655669636
# Parameters: [0.09116735 0.14705784 0.12737763 0.10233752 0.1        0.13772067
#  0.10302968] | SSR: 6.164902945671209
# Parameters: [0.09232309 0.13195856 0.12072905 0.10061533 1.28683224 0.12208525
#  0.09949656] | SSR: 5.466511495237735
# Parameters: [0.09146591 0.1253805  0.11917229 0.09647103 1.88024836 0.11474835
#  0.0965571 ] | SSR: 5.631053357173512
# Parameters: [0.09552339 0.12570133 0.11529438 0.10668967 1.62592717 0.11665637
#  0.10083288] | SSR: 5.574212215365034
# Parameters: [0.09170429 0.12498322 0.11427864 0.10045663 2.06190636 0.11711099
#  0.10493167] | SSR: 5.84457702942589
# Parameters: [0.09057334 0.12475182 0.1100399  0.09724035 2.62245103 0.1232827
#  0.09827796] | SSR: 6.389256903701985
# Parameters: [0.09406547 0.13549459 0.12222713 0.10601804 0.73061276 0.12413924
#  0.10389567] | SSR: 5.670227062652174
# Parameters: [0.09677001 0.12906257 0.11453289 0.09773707 2.52035293 0.11643784
#  0.1023465 ] | SSR: 6.470844202551405
# Parameters: [0.09180591 0.13346085 0.1200524  0.10536481 0.86974758 0.12637327
#  0.1022274 ] | SSR: 5.6157750320110145
# Parameters: [0.0940586  0.13031414 0.11811232 0.10093918 0.28040829 0.12351947
#  0.10304127] | SSR: 5.894158039931991
# Parameters: [0.09298549 0.13279931 0.11855262 0.10387368 1.7080961  0.12346076
#  0.10200242] | SSR: 5.5827268428976655
# Parameters: [0.09534816 0.14119179 0.12375419 0.10631069 0.30140532 0.1316639
#  0.09892882] | SSR: 5.946047535170482
# Parameters: [0.09261526 0.12903536 0.11664753 0.10192015 1.6217811  0.12074921
#  0.10343096] | SSR: 5.5496966005280495
# Parameters: [0.09257263 0.12883493 0.11421153 0.09957846 1.88731844 0.12366707
#  0.09983204] | SSR: 5.6345951409074555
# Parameters: [0.09294584 0.13049984 0.11621543 0.10118836 1.59814202 0.12378511
#  0.10084795] | SSR: 5.521132015254635
# Parameters: [0.09515789 0.13002267 0.11528999 0.09903841 1.95629631 0.12069356
#  0.10110618] | SSR: 5.716715459376029
# Parameters: [0.0926439  0.1326013  0.1188618  0.10378321 1.14138477 0.12495335
#  0.10194709] | SSR: 5.521495137865385
# Parameters: [0.09388071 0.13062763 0.11687811 0.1005037  0.95603028 0.12403252
#  0.10131535] | SSR: 5.521921649020671
# Parameters: [0.09087347 0.13913313 0.12058884 0.09592028 0.84680009 0.13294439
#  0.10262274] | SSR: 5.616158508685032
# Parameters: [0.09436091 0.12905928 0.116618   0.10399733 1.4311454  0.12072837
#  0.10128035] | SSR: 5.501095951884189
# Parameters: [0.08869713 0.12963453 0.1130935  0.10866486 1.75337873 0.11368754
#  0.09913092] | SSR: 5.616728877792108
# Parameters: [0.09489261 0.13278514 0.11933705 0.09930041 1.09648889 0.12782599
#  0.10251887] | SSR: 5.50264671764902
# Parameters: [0.09369032 0.13550587 0.11863263 0.10217514 0.85903976 0.12749907
#  0.09908754] | SSR: 5.5836301400357
# Parameters: [0.09288402 0.13065299 0.11714381 0.1019839  1.43109576 0.12243668
#  0.1023451 ] | SSR: 5.499010126401727
# Parameters: [0.095815   0.12397594 0.12109695 0.09830403 1.38175613 0.12192653
#  0.10137748] | SSR: 5.447103048120193
# Parameters: [0.09821128 0.11678264 0.12422486 0.09498347 1.4862095  0.12016059
#  0.10136193] | SSR: 5.444057631866949
# Parameters: [0.09419405 0.12775515 0.12115903 0.1011683  1.75005503 0.12224615
#  0.10148403] | SSR: 5.589894535318752
# Parameters: [0.09395904 0.12990951 0.11794834 0.10066985 1.15453646 0.12358593
#  0.10135752] | SSR: 5.479377251938414
# Parameters: [0.09580661 0.1250124  0.11891435 0.09699925 1.56845817 0.12093463
#  0.10068384] | SSR: 5.48570604547082
# Parameters: [0.09632204 0.12554602 0.12233184 0.09839722 1.10321982 0.12128844
#  0.1017361 ] | SSR: 5.44525936401867
# Parameters: [0.09478367 0.12119241 0.12006588 0.10002712 1.60679607 0.11537969
#  0.09984153] | SSR: 5.52193385800255
# Parameters: [0.09486538 0.12988695 0.11951925 0.09948209 1.22406569 0.12471442
#  0.10184953] | SSR: 5.468278291362009
# Parameters: [0.09545951 0.12515474 0.12361386 0.09404013 1.21297393 0.12361618
#  0.10124268] | SSR: 5.408463042196101
# Parameters: [0.0960088  0.12320247 0.12711179 0.08906153 1.10388819 0.12506008
#  0.10122385] | SSR: 5.372961040923437
# Parameters: [0.09782919 0.12143232 0.12593605 0.09236146 1.11953569 0.12265742
#  0.09985756] | SSR: 5.373789176796054
# Parameters: [0.09548448 0.12605002 0.1261717  0.09602102 0.85390971 0.12465169
#  0.10128275] | SSR: 5.504292985845792
# Parameters: [0.09572608 0.12527181 0.12072869 0.09675469 1.38982106 0.12186389
#  0.10083357] | SSR: 5.43625486773454
# Parameters: [0.09783691 0.11982785 0.12793209 0.09123181 1.33505559 0.12150838
#  0.10045936] | SSR: 5.370982948011017
# Parameters: [0.09977585 0.11478702 0.13292397 0.08651278 1.42531515 0.12046961
#  0.10001028] | SSR: 5.345777017889985
# Parameters: [0.09833357 0.11553614 0.1301911  0.08871405 1.32302621 0.11916709
#  0.09944185] | SSR: 5.331830580061791
# Parameters: [0.10006767 0.10836073 0.13552702 0.08333004 1.37250648 0.11639343
#  0.09823801] | SSR: 5.281493441223361
# Parameters: [0.1030886  0.1067223  0.1332093  0.08264216 1.28473801 0.12017003
#  0.10143524] | SSR: 5.264384143804506
# Parameters: [0.10847136 0.09410416 0.13944942 0.07365557 1.28369089 0.11921242
#  0.10240459] | SSR: 5.161639016618451
# Parameters: [0.10256089 0.10415145 0.13649725 0.07779122 1.5199136  0.12037369
#  0.0993867 ] | SSR: 5.312784360548972
# Parameters: [0.10191438 0.10930592 0.13811063 0.0762929  1.14655366 0.12156242
#  0.09919651] | SSR: 5.167055489031465
# Parameters: [0.10616768 0.09625507 0.14657306 0.06867545 1.17343713 0.11977298
#  0.09925715] | SSR: 5.035358585775306
# Parameters: [0.11138848 0.08174671 0.15949525 0.05463583 1.06524517 0.11872753
#  0.09846894] | SSR: 4.723883905282242
# Parameters: [0.10793865 0.08875582 0.15095405 0.06228993 1.42821092 0.11785664
#  0.0998364 ] | SSR: 5.090971228597617
# Parameters: [0.11316756 0.07714376 0.15659038 0.05794083 1.53652205 0.11339584
#  0.09807371] | SSR: 5.252898610344456
# Parameters: [0.11322672 0.074804   0.15754003 0.05232616 1.2468685  0.11596524
#  0.09873396] | SSR: 4.766894381838668
# Parameters: [0.11348906 0.07705458 0.15997897 0.053772   1.07425717 0.11480161
#  0.09917105] | SSR: 4.6976361507245965
# Parameters: [0.11895315 0.06350614 0.17171983 0.04176239 0.85142895 0.11201557
#  0.09906323] | SSR: 4.286533196688403
# Parameters: [0.12137813 0.0600297  0.17129    0.03635671 1.07278499 0.11753104
#  0.10055551] | SSR: 4.180434494521294
# Parameters: [0.13203336 0.03586418 0.18917149 0.01287005 0.92292425 0.11809984
#  0.10171426] | SSR: 2.697671024103227
# Parameters: [0.11366846 0.07945251 0.15953553 0.04886855 0.73345576 0.12187263
#  0.10175998] | SSR: 4.671477247018281
# Parameters: [0.12827995 0.0387608  0.18413669 0.02268095 1.00539619 0.11379468
#  0.10136959] | SSR: 3.4468867179863416
# Parameters: [0.12738257 0.03815017 0.19556568 0.01075411 0.78874617 0.11459676
#  0.0978658 ] | SSR: 2.455042958183477
# Parameters: [1.36838177e-01 1.01731678e-02 2.23623812e-01 1.00000000e-06
#  5.41273814e-01 1.12288927e-01 9.55964074e-02] | SSR: 1.401118929364276
# Parameters: [0.13617229 0.02104632 0.20482385 0.00432291 0.39081554 0.11436177
#  0.09922256] | SSR: 2.3534488937260827
# Parameters: [0.1374401  0.01963881 0.21174753 0.00057146 0.32757141 0.11579503
#  0.1004646 ] | SSR: 2.2485403932562393
# Parameters: [1.46721664e-01 1.00000000e-06 2.24721534e-01 1.00000000e-06
#  2.98430806e-01 1.12194883e-01 1.01299809e-01] | SSR: 2.0113138412818854
# Parameters: [1.53885447e-01 1.00000000e-06 2.43305818e-01 1.00000000e-06
#  5.05927372e-01 1.06284713e-01 9.78772949e-02] | SSR: 1.3945097108054605
# Parameters: [1.73993938e-01 1.00000000e-06 2.85190960e-01 1.00000000e-06
#  3.92163178e-01 9.84907544e-02 9.59359547e-02] | SSR: 1.5994790523981797
# Parameters: [1.58581422e-01 1.00000000e-06 2.51574657e-01 1.00000000e-06
#  2.89239445e-01 1.14504388e-01 1.00235205e-01] | SSR: 2.099889827781721
# Parameters: [1.57912182e-01 1.00000000e-06 2.58425794e-01 1.00000000e-06
#  1.00000000e-01 1.12928050e-01 9.76047357e-02] | SSR: 3.1617330446963106
# Parameters: [1.50504124e-01 1.00000000e-06 2.39853518e-01 1.00000000e-06
#  1.99341044e-01 1.13144707e-01 9.85459487e-02] | SSR: 2.5193295823806716
# Parameters: [1.59436134e-01 1.00000000e-06 2.67871574e-01 1.00000000e-06
#  1.00000000e-01 1.07207133e-01 9.63548309e-02] | SSR: 3.1114715492018123
# Parameters: [0.13888405 0.02156511 0.20884651 0.00678498 0.64379066 0.11537667
#  0.1003744 ] | SSR: 2.0888947959426196
# Parameters: [0.13764535 0.02069226 0.2083304  0.0033371  0.65695868 0.11279997
#  0.10004556] | SSR: 1.7321620751074618
# Parameters: [1.52398054e-01 1.00000000e-06 2.44361942e-01 1.00000000e-06
#  5.41525080e-01 1.11136685e-01 9.96040946e-02] | SSR: 1.386936000004971
# Parameters: [1.60510934e-01 1.00000000e-06 2.64130990e-01 1.00000000e-06
#  6.16879848e-01 1.09524144e-01 9.97948639e-02] | SSR: 1.4225796491805474
# Parameters: [1.55403948e-01 1.00000000e-06 2.46756661e-01 2.32199126e-03
#  6.65898840e-01 1.08372464e-01 9.81161936e-02] | SSR: 1.610223348188954
# Parameters: [0.13335478 0.0149803  0.20555296 0.00355559 0.81184777 0.10791113
#  0.09774015] | SSR: 1.7562164036140167
# Parameters: [1.51472351e-01 1.00000000e-06 2.47340099e-01 1.00000000e-06
#  5.05312874e-01 1.04905841e-01 9.68483147e-02] | SSR: 1.3736517716606336
# Parameters: [1.57766501e-01 1.00000000e-06 2.66586894e-01 1.00000000e-06
#  4.36073983e-01 9.96704283e-02 9.50852705e-02] | SSR: 1.4573123388285083
# Parameters: [0.14499208 0.01309892 0.23792752 0.00263291 0.90978189 0.10600504
#  0.09465105] | SSR: 2.070910389109385
# Parameters: [0.14628927 0.00327548 0.22802303 0.00065898 0.45126858 0.11064742
#  0.09963762] | SSR: 1.5863573717564803
# Parameters: [1.62054537e-01 1.00000000e-06 2.63516111e-01 1.00000000e-06
#  2.93342299e-01 1.11070592e-01 9.87528406e-02] | SSR: 2.047602447037532
# Parameters: [0.14052972 0.00992907 0.22004375 0.00222937 0.6822214  0.10870099
#  0.09799333] | SSR: 1.5488495631060653
# Parameters: [1.58588068e-01 1.00000000e-06 2.64085348e-01 1.00000000e-06
#  4.55449306e-01 1.05010614e-01 9.58610850e-02] | SSR: 1.469669828415686
# Parameters: [1.41739218e-01 6.67949101e-03 2.30610140e-01 1.00000000e-06
#  3.86380710e-01 1.08477592e-01 9.71461329e-02] | SSR: 1.6989365864949804
# Parameters: [0.15198777 0.00167062 0.24272003 0.00136766 0.59601931 0.10839875
#  0.09787368] | SSR: 1.477661566776288
# Parameters: [1.52482040e-01 2.94647995e-03 2.53542913e-01 3.70175711e-04
#  6.42368325e-01 1.05560155e-01 9.51207232e-02] | SSR: 1.4185626709514034
# Parameters: [1.61656542e-01 1.00000000e-06 2.71093381e-01 1.00000000e-06
#  4.00028906e-01 1.06609200e-01 9.59442733e-02] | SSR: 1.6161568688131727
# Parameters: [0.14581142 0.00602127 0.23280616 0.00123917 0.61167328 0.10817805
#  0.09748106] | SSR: 1.4539831645056318
# Parameters: [1.48433823e-01 3.79935340e-03 2.45584567e-01 1.00000000e-06
#  4.90703564e-01 1.06848391e-01 9.59517452e-02] | SSR: 1.417981124986253
# Parameters: [1.38932308e-01 6.55421999e-03 2.18933312e-01 4.60242915e-04
#  6.41346210e-01 1.10761603e-01 9.79902416e-02] | SSR: 1.3655793241738334
# Parameters: [1.29104427e-01 9.83082998e-03 1.96357294e-01 6.89864372e-04
#  7.34294663e-01 1.13637097e-01 9.90548198e-02] | SSR: 1.3941666673602733
# Parameters: [1.49743492e-01 6.86222941e-04 2.46248831e-01 1.00000000e-06
#  4.93600219e-01 1.08332330e-01 9.65157432e-02] | SSR: 1.4052422058697882
# Parameters: [1.42290432e-01 3.11522409e-03 2.23428054e-01 1.00000000e-06
#  4.20399999e-01 1.11742270e-01 9.92746601e-02] | SSR: 1.5959918096286108
# Parameters: [1.49934138e-01 2.98866598e-03 2.46014198e-01 2.18390921e-04
#  5.86876243e-01 1.07105684e-01 9.61592074e-02] | SSR: 1.3682723229971288
# Parameters: [1.46767310e-01 2.03072565e-03 2.31509151e-01 1.94323953e-04
#  5.99542668e-01 1.10527546e-01 9.85029130e-02] | SSR: 1.360692282448995
# Parameters: [1.45934054e-01 1.14641178e-03 2.24471443e-01 2.90985929e-04
#  6.53962221e-01 1.12367124e-01 9.97784969e-02] | SSR: 1.3857149901412953
# Parameters: [1.44607304e-01 5.52799975e-03 2.26633550e-01 2.49559368e-04
#  6.26915285e-01 1.09670813e-01 9.85066778e-02] | SSR: 1.3717566171661764
# Parameters: [1.59732369e-01 1.00000000e-06 2.50118494e-01 3.20576330e-04
#  6.03710681e-01 1.04966182e-01 1.00257519e-01] | SSR: 1.4363661730464177
# Parameters: [1.42561725e-01 6.30834185e-03 2.30247483e-01 8.08940826e-05
#  5.56883031e-01 1.10458241e-01 9.67616854e-02] | SSR: 1.3705523016721126
# Parameters: [1.39449750e-01 6.68812949e-03 2.26705535e-01 3.43403211e-04
#  6.53615883e-01 1.12162834e-01 9.76578864e-02] | SSR: 1.362818317701164
# Parameters: [1.37237628e-01 8.59873792e-03 2.20604723e-01 4.41232700e-04
#  6.50044119e-01 1.07604047e-01 9.53750272e-02] | SSR: 1.3511833760688414
# Parameters: [1.29657415e-01 1.28976069e-02 2.08726113e-01 6.61349050e-04
#  7.04303638e-01 1.05837728e-01 9.32604936e-02] | SSR: 1.3608306043356326
# Parameters: [1.34096267e-01 1.10552345e-02 2.09987887e-01 5.67013471e-04
#  7.27608108e-01 1.14605807e-01 9.77098678e-02] | SSR: 1.407322928020307
# Parameters: [1.47128330e-01 2.76455862e-03 2.38002046e-01 1.42503368e-04
#  5.60886683e-01 1.07330832e-01 9.70637030e-02] | SSR: 1.3558947973202848
# Parameters: [1.41681607e-01 4.73868011e-03 2.33942578e-01 2.87866675e-04
#  5.87140383e-01 1.09172269e-01 9.56392262e-02] | SSR: 1.3448512251677704
# Parameters: [1.40218759e-01 4.34402029e-03 2.37597092e-01 3.07020328e-04
#  5.67252933e-01 1.08922997e-01 9.42055004e-02] | SSR: 1.3396241168533578
# Parameters: [1.43057767e-01 3.39710327e-03 2.32428534e-01 5.21139459e-04
#  6.60135466e-01 1.07946200e-01 9.66538800e-02] | SSR: 1.3881035161649695
# Parameters: [1.42685736e-01 5.58053221e-03 2.30792745e-01 1.90955427e-04
#  5.82696140e-01 1.09830231e-01 9.67347341e-02] | SSR: 1.3554040665712093
# Parameters: [1.33614382e-01 7.45731235e-03 2.12312832e-01 3.75803908e-04
#  6.28947938e-01 1.12077199e-01 9.74207942e-02] | SSR: 1.3363062516639321
# Parameters: [1.25454505e-01 9.69163553e-03 1.95462149e-01 4.54510402e-04
#  6.49983786e-01 1.14562957e-01 9.80515875e-02] | SSR: 1.32699853015137
# Parameters: [1.40765412e-01 4.78816279e-03 2.32687671e-01 1.32314054e-04
#  5.76945850e-01 1.09507382e-01 9.56072875e-02] | SSR: 1.3327758078438536
# Parameters: [1.40623872e-01 4.11140565e-03 2.26624630e-01 1.88842569e-04
#  5.42770453e-01 1.07347450e-01 9.53537572e-02] | SSR: 1.34432012818828
# Parameters: [1.31551045e-01 9.36328949e-03 2.20425437e-01 3.36355718e-04
#  5.80623035e-01 1.08074138e-01 9.36089718e-02] | SSR: 1.3263849384040052
# Parameters: [1.23942912e-01 1.30295714e-02 2.14883579e-01 4.07371600e-04
#  5.71163219e-01 1.06847434e-01 9.11620012e-02] | SSR: 1.3281246040507062
# Parameters: [1.26739372e-01 1.05148082e-02 2.08910653e-01 4.43562689e-04
#  6.24917979e-01 1.11483225e-01 9.40611158e-02] | SSR: 1.3154018603546527
# Parameters: [1.16544893e-01 1.43899330e-02 1.94364956e-01 5.94092349e-04
#  6.56933627e-01 1.13559422e-01 9.25598222e-02] | SSR: 1.3057873928950299
# Parameters: [1.23713154e-01 1.02158063e-02 2.05712014e-01 5.10292608e-04
#  6.24319233e-01 1.10049310e-01 9.31972528e-02] | SSR: 1.2941905453105043
# Parameters: [0.11422686 0.01253344 0.19317165 0.00066996 0.64513078 0.11015885
#  0.09142851] | SSR: 1.2669534262281301
# Parameters: [1.22586757e-01 8.32180210e-03 2.08062016e-01 3.25366334e-04
#  5.55567442e-01 1.13005437e-01 9.34293838e-02] | SSR: 1.3373380454703079
# Parameters: [1.14047051e-01 1.40121048e-02 1.96738504e-01 6.16763254e-04
#  6.66497390e-01 1.14878602e-01 9.29008328e-02] | SSR: 1.2966189485375588
# Parameters: [1.06974534e-01 1.65418000e-02 1.74092160e-01 5.87083474e-04
#  6.70370470e-01 1.15004656e-01 9.36763276e-02] | SSR: 1.305002236392022
# Parameters: [1.20145901e-01 1.49125890e-02 1.93921563e-01 6.43513795e-04
#  7.14856825e-01 1.11493422e-01 9.45229995e-02] | SSR: 1.3261816799537132
# Parameters: [0.09607596 0.02133892 0.15821988 0.00098262 0.73288155 0.11555892
#  0.0920353 ] | SSR: 1.324147078774988
# Parameters: [0.10299299 0.01976324 0.18480475 0.00081132 0.68352869 0.1107879
#  0.08787206] | SSR: 1.2775263718783743
# Parameters: [0.08873701 0.02306301 0.14966412 0.00106517 0.78229106 0.11805208
#  0.09067556] | SSR: 1.3146224069122547
# Parameters: [0.09116819 0.0198424  0.16352301 0.00087849 0.6673242  0.1165067
#  0.08866226] | SSR: 1.3419073546272713
# Parameters: [1.12901472e-01 1.61450412e-02 1.86321926e-01 7.02257853e-04
#  7.02973668e-01 1.12746741e-01 9.30578148e-02] | SSR: 1.2986576632731572
# Parameters: [1.20045419e-01 1.19320995e-02 2.07253856e-01 4.59276312e-04
#  6.40754358e-01 1.11637727e-01 9.14421084e-02] | SSR: 1.2773583577145207
# Parameters: [1.36329626e-01 7.02775526e-03 2.32263820e-01 2.03612068e-04
#  5.50905792e-01 1.07311889e-01 9.30208645e-02] | SSR: 1.333483651696645
# Parameters: [0.10063516 0.01905419 0.17031405 0.00084978 0.72444474 0.11536703
#  0.09126188] | SSR: 1.2882236595089138
# Parameters: [0.10397611 0.01703347 0.1806913  0.00074775 0.69555212 0.11232101
#  0.09076576] | SSR: 1.2621025027045185
# Parameters: [0.09769171 0.01835525 0.17385447 0.00082458 0.71486136 0.1117018
#  0.08986873] | SSR: 1.2444416035113175
# Parameters: [0.11089423 0.01539974 0.20089618 0.00082261 0.69482696 0.1099321
#  0.08856137] | SSR: 1.2543088673773592
# Parameters: [0.1043938  0.01558355 0.19283049 0.00074182 0.65989613 0.11138584
#  0.08789518] | SSR: 1.2441068613267956
# Parameters: [0.10013996 0.0153028  0.19608477 0.00076161 0.63835736 0.11070538
#  0.08531387] | SSR: 1.2286221060615068
# Parameters: [0.09927476 0.01808526 0.18222713 0.0008687  0.6883324  0.10806163
#  0.08588446] | SSR: 1.2160619560467905
# Parameters: [0.09188861 0.02012183 0.17497145 0.00099467 0.6992499  0.10465314
#  0.08237628] | SSR: 1.1784204932767965
# Parameters: [0.11018763 0.01334821 0.20998227 0.00067708 0.62318652 0.10451208
#  0.08498467] | SSR: 1.2048152566534631
# Parameters: [0.10988542 0.01080629 0.20268515 0.00067719 0.64686194 0.10729812
#  0.08754952] | SSR: 1.1913503744974416
# Parameters: [0.08993013 0.01831577 0.1789307  0.0010915  0.6913813  0.10520841
#  0.0828673 ] | SSR: 1.1692645320969939
# Parameters: [0.07487249 0.02150761 0.16476912 0.00140761 0.71669478 0.10199376
#  0.0785799 ] | SSR: 1.1548077582484826
# Parameters: [0.08450458 0.02027848 0.1848979  0.00109157 0.70745174 0.10435441
#  0.07920987] | SSR: 1.1387126672389472
# Parameters: [0.06964344 0.024151   0.18076102 0.00130237 0.73861222 0.10145219
#  0.07310055] | SSR: 1.1246789800667885
# Parameters: [0.07605127 0.01991255 0.17142046 0.00107599 0.67026563 0.10215832
#  0.07765963] | SSR: 1.1446875467507835
# Parameters: [0.08307081 0.01740198 0.19776675 0.00114586 0.63748959 0.09766191
#  0.07286396] | SSR: 1.0634200222370183
# Parameters: [0.07576035 0.01692535 0.20972289 0.0013065  0.59880371 0.09064196
#  0.06436158] | SSR: 0.9803035497511814
# Parameters: [0.07365696 0.020918   0.17943305 0.00136451 0.70269255 0.09292592
#  0.07143245] | SSR: 1.0124421272389048
# Parameters: [0.05317195 0.0250354  0.15680719 0.00164545 0.74057941 0.09580889
#  0.0678896 ] | SSR: 1.188515483262961
# Parameters: [0.03727032 0.03164278 0.15099633 0.00192198 0.7436804  0.08974021
#  0.05970762] | SSR: 1.6326966338989934
# Parameters: [0.09173164 0.01601541 0.18976295 0.00098839 0.67106656 0.10290865
#  0.08058905] | SSR: 1.1156093127715354
# Parameters: [0.10500084 0.01483653 0.20629022 0.00076599 0.63010212 0.10325795
#  0.08299596] | SSR: 1.1826522506750439
# Parameters: [0.09204362 0.01738625 0.19391946 0.00098586 0.65772144 0.10139568
#  0.07921937] | SSR: 1.127095157372718
# Parameters: [0.06632847 0.0189685  0.19353968 0.00141425 0.65956635 0.09348299
#  0.0676073 ] | SSR: 1.0061343386703083
# Parameters: [0.08090344 0.01685726 0.21196217 0.00100321 0.62579907 0.09371073
#  0.06826865] | SSR: 0.9832338269590717
# Parameters: [0.08111099 0.01757939 0.21689417 0.00131404 0.65952348 0.09113257
#  0.06650578] | SSR: 0.9531308437436227
# Parameters: [0.08364085 0.0164128  0.23963102 0.00143306 0.6541524  0.0856197
#  0.06092885] | SSR: 0.8989997476854924
# Parameters: [0.06271786 0.01982756 0.20745562 0.00153194 0.67104795 0.08738779
#  0.05972018] | SSR: 0.8827000962271472
# Parameters: [0.04805497 0.02104822 0.2142237  0.00180498 0.6777112  0.08038384
#  0.04997059] | SSR: 0.8247890776890687
# Parameters: [0.0789499  0.0121763  0.23017482 0.00135903 0.57275688 0.08131176
#  0.05923044] | SSR: 0.8398576003522429
# Parameters: [0.05320977 0.019215   0.23271914 0.00177891 0.61221407 0.07368476
#  0.04563949] | SSR: 0.7097038968039702
# Parameters: [0.03394884 0.02081479 0.25419724 0.00217417 0.58278782 0.05907281
#  0.02816471] | SSR: 0.6462564844269593
# Parameters: [0.05993927 0.01428291 0.26441024 0.00163412 0.54632957 0.07399516
#  0.04243387] | SSR: 0.6980599578632638
# Parameters: [0.06544229 0.01489368 0.27055234 0.0016472  0.55710241 0.06787014
#  0.03906661] | SSR: 0.6635839762660773
# Parameters: [0.04644984 0.0164439  0.2688699  0.00224223 0.57124207 0.06025937
#  0.03006182] | SSR: 0.49298915422136946
# Parameters: [0.02922303 0.01623722 0.29732377 0.00286174 0.54396357 0.04353369
#  0.01095841] | SSR: 0.409239335377943
# Parameters: [0.03829655 0.01617921 0.29613801 0.0023833  0.58256882 0.04986864
#  0.01871084] | SSR: 0.3906721541537938
# Parameters: [1.95646424e-02 1.58061359e-02 3.39345569e-01 2.92169911e-03
#  5.74451381e-01 2.94819773e-02 1.00000000e-06] | SSR: 0.43646341361556235
# Parameters: [0.01746053 0.016625   0.28237472 0.00252824 0.50676767 0.04467631
#  0.01008128] | SSR: 0.8699223813395878
# Parameters: [0.03400561 0.01657195 0.2716888  0.00225444 0.54361386 0.05491216
#  0.02279317] | SSR: 0.49225294021259325
# Parameters: [0.00931026 0.02211741 0.30369207 0.0028581  0.57983662 0.04144151
#  0.00136904] | SSR: 1.741050072641177
# Parameters: [0.06153999 0.01466158 0.24855413 0.0017338  0.57452682 0.07134419
#  0.04476509] | SSR: 0.6534160014796219
# Parameters: [0.04405805 0.01142074 0.32945188 0.00239181 0.44540104 0.03978667
#  0.00914161] | SSR: 1.2375728009181828
# Parameters: [0.04705574 0.01864135 0.24303074 0.00195169 0.61963366 0.07023455
#  0.03976334] | SSR: 0.6243902276672111
# Parameters: [0.02849274 0.01943131 0.27315691 0.00265341 0.5977267  0.04510089
#  0.01591533] | SSR: 0.3473932834081218
# Parameters: [0.01276948 0.0220055  0.27753024 0.00316305 0.62342526 0.03065375
#  0.00265605] | SSR: 0.7077860650614684
# Parameters: [0.01243271 0.020117   0.26775898 0.00292781 0.59856081 0.04472041
#  0.01266793] | SSR: 1.4607708449417296
# Parameters: [0.05218989 0.01619951 0.269854   0.00196735 0.56746701 0.06208271
#  0.03246694] | SSR: 0.5314188024167349
# Parameters: [0.01366355 0.02078852 0.29584286 0.00290795 0.57911931 0.03860022
#  0.00345569] | SSR: 0.9321400142455054
# Parameters: [0.04957088 0.01619331 0.26037631 0.00202734 0.57567494 0.0631582
#  0.03443774] | SSR: 0.5235521239511848
# Parameters: [0.04571815 0.01331488 0.2919652  0.00242562 0.56882605 0.05203885
#  0.02184837] | SSR: 0.5040682644838972
# Parameters: [0.03222907 0.01396648 0.31711297 0.00278351 0.51746375 0.03567835
#  0.00513117] | SSR: 0.8214093906744662
# Parameters: [0.04334908 0.01747263 0.2615513  0.00215965 0.59409118 0.0615955
#  0.0311053 ] | SSR: 0.4887527308121108
# Parameters: [0.02456898 0.01677206 0.28791752 0.00282279 0.57723732 0.04369099
#  0.01203854] | SSR: 0.3689090139987361
# Parameters: [0.02004459 0.01694362 0.30526412 0.00299008 0.56947578 0.03705343
#  0.00366796] | SSR: 0.41051178326938975
# Parameters: [0.01656201 0.02085883 0.27747492 0.00275306 0.5765103  0.04389123
#  0.01106293] | SSR: 0.9463120032228416
# Parameters: [0.03842912 0.01520087 0.28834263 0.00250748 0.57074711 0.05000195
#  0.01915201] | SSR: 0.3993775776881976
# Parameters: [0.02953841 0.01721002 0.30250956 0.00299654 0.60947485 0.03961501
#  0.00907779] | SSR: 0.3685350105669687
# Parameters: [1.62490405e-02 1.62343137e-02 3.24349416e-01 3.33045322e-03
#  5.63392859e-01 2.66515297e-02 1.00000000e-06] | SSR: 0.35321018258288317
# Parameters: [0.03846909 0.01656067 0.28608954 0.00259727 0.58627029 0.04822162
#  0.02086173] | SSR: 0.3601159871999442
# Parameters: [0.03193237 0.01735948 0.29082011 0.00265004 0.62387013 0.04308077
#  0.0164008 ] | SSR: 0.2886614656227012
# Parameters: [0.03328704 0.01792061 0.28756828 0.00254419 0.66382341 0.04285431
#  0.019122  ] | SSR: 0.3023475859207718
# Parameters: [0.02087008 0.01901257 0.3005091  0.00304503 0.61226459 0.03463504
#  0.00742114] | SSR: 0.28985923428819677
# Parameters: [0.01602365 0.01884377 0.29396261 0.00335828 0.60892739 0.03041589
#  0.00463668] | SSR: 0.3805961334472485
# Parameters: [0.02159188 0.01817763 0.29450646 0.00311454 0.60233775 0.03527908
#  0.00815522] | SSR: 0.2867306192234042
# Parameters: [0.02890063 0.01865251 0.30406565 0.00300215 0.62143045 0.03419014
#  0.01019947] | SSR: 0.33502199073587086
# Parameters: [0.02374897 0.01862669 0.28991821 0.00283    0.5926088  0.03671615
#  0.01348069] | SSR: 0.2910335966640599
# Parameters: [1.06125401e-02 1.98663343e-02 3.07432131e-01 3.29576436e-03
#  6.17624360e-01 2.48222613e-02 1.00000000e-06] | SSR: 0.667538523338417
# Parameters: [0.03150495 0.01738708 0.29142519 0.00277189 0.59410881 0.04237178
#  0.01554327] | SSR: 0.3010252210940438
# Parameters: [0.03719142 0.02052205 0.25976534 0.00240299 0.64927778 0.05088385
#  0.02488926] | SSR: 0.3509654207045102
# Parameters: [0.03195583 0.01945012 0.27591136 0.00263486 0.62780655 0.04482577
#  0.0186672 ] | SSR: 0.2953976655818441
# Parameters: [0.02593717 0.01733043 0.31174483 0.00307473 0.62353818 0.03235589
#  0.00976119] | SSR: 0.30673753296918943
# Parameters: [0.02468259 0.01773149 0.28303013 0.00274673 0.60043664 0.04274257
#  0.01535182] | SSR: 0.3366746728627593
# Parameters: [0.02784612 0.01842225 0.29880677 0.00293829 0.616182   0.03632825
#  0.01148756] | SSR: 0.27880063116022263
# Parameters: [0.02819145 0.01936552 0.27165437 0.00263516 0.59622714 0.04571178
#  0.01628335] | SSR: 0.36284147977222114
# Parameters: [0.02650074 0.0178392  0.30172221 0.00296484 0.61671042 0.03569486
#  0.01139173] | SSR: 0.2649983513336599
# Parameters: [0.0211939  0.01943804 0.29491602 0.00299314 0.63211412 0.0337882
#  0.00931511] | SSR: 0.2623811524391034
# Parameters: [0.01603837 0.02046352 0.29666143 0.00310376 0.65111677 0.0294964
#  0.00620104] | SSR: 0.35571143926964716
# Parameters: [0.01766819 0.01737156 0.31585975 0.00323254 0.59964711 0.02818061
#  0.00351916] | SSR: 0.28238732915132675
# Parameters: [0.02413768 0.01783638 0.30926477 0.00315241 0.63685581 0.03385151
#  0.00585952] | SSR: 0.313426154919692
# Parameters: [0.02384615 0.01842911 0.29475485 0.0029106  0.60367055 0.03599999
#  0.0115754 ] | SSR: 0.26450100006201327
# Parameters: [0.02786688 0.01728379 0.2970298  0.00289897 0.61474457 0.03632261
#  0.013106  ] | SSR: 0.27192553397774555
# Parameters: [0.01564301 0.01891526 0.308493   0.00336508 0.60053173 0.02594597
#  0.00318496] | SSR: 0.32421869275013426
# Parameters: [0.02786003 0.01774843 0.29523833 0.0028288  0.61803553 0.03879707
#  0.01309684] | SSR: 0.26534241832652183
# Parameters: [0.02777441 0.01797448 0.30501575 0.00281894 0.62654919 0.0347528
#  0.01284243] | SSR: 0.28464975758663436
# Parameters: [0.02622878 0.01802527 0.30238843 0.00289284 0.62049633 0.03488437
#  0.01167063] | SSR: 0.26200643143881003
# Parameters: [0.03414398 0.01896732 0.27981351 0.00260389 0.63519675 0.04376663
#  0.01980749] | SSR: 0.29792820854370283
# Parameters: [0.02178714 0.0177705  0.30684819 0.00307537 0.60853452 0.03207712
#  0.00759124] | SSR: 0.2566910316361979
# Parameters: [0.02223492 0.01773042 0.29916404 0.00293729 0.61647687 0.03440439
#  0.01072586] | SSR: 0.24950403883160743
# Parameters: [0.01942932 0.0173845  0.29934267 0.00293679 0.61662431 0.03344246
#  0.01034501] | SSR: 0.2821042266437646
# Parameters: [0.02060502 0.01899649 0.30155079 0.00298757 0.61840924 0.03386196
#  0.00842738] | SSR: 0.27752157823296486
# Parameters: [0.02605141 0.01771197 0.29816005 0.00292112 0.61566074 0.03570745
#  0.01193634] | SSR: 0.2564100021984134
# Parameters: [0.02009512 0.01852144 0.30417704 0.00308412 0.61443977 0.03050475
#  0.00810496] | SSR: 0.25606683194349406
# Parameters: [0.01962423 0.01862558 0.29839453 0.00298215 0.61511612 0.03212407
#  0.008871  ] | SSR: 0.27851417852742943
# Parameters: [0.02478161 0.0180358  0.30089029 0.00296917 0.61631184 0.03480216
#  0.01076155] | SSR: 0.2523896778170014
# Parameters: [0.0225461  0.0179233  0.30711488 0.00305313 0.63176779 0.0314767
#  0.0084548 ] | SSR: 0.2548294681435197
# Parameters: [0.0255847  0.01648158 0.3104391  0.00298773 0.60322527 0.03302807
#  0.01046928] | SSR: 0.28396437707817196
# Parameters: [0.0222916  0.01869893 0.29879679 0.00299178 0.62489191 0.03359816
#  0.00960366] | SSR: 0.24845831047767053
# Parameters: [0.01942491 0.01808683 0.30194051 0.0031163  0.61609894 0.03156441
#  0.0075232 ] | SSR: 0.26624546701148044
# Parameters: [0.02452781 0.01804066 0.30227645 0.0029487  0.61939698 0.03405438
#  0.01063377] | SSR: 0.25147103999684245
# Parameters: [0.0246496  0.01841878 0.29617453 0.00289757 0.63116431 0.0349366
#  0.01247188] | SSR: 0.24462034422028875
# Parameters: [0.02608083 0.01874292 0.2908377  0.00280867 0.6424792  0.03636634
#  0.0149122 ] | SSR: 0.25037449938584405
# Parameters: [0.0199848  0.01867927 0.30429538 0.0030451  0.62846768 0.03108602
#  0.00827979] | SSR: 0.253617657140704
# Parameters: [0.02590958 0.01791489 0.29831221 0.00287096 0.63369663 0.0364548
#  0.01216113] | SSR: 0.2508429891765809
# Parameters: [0.02441959 0.01851063 0.29285932 0.0028499  0.6169197  0.03690516
#  0.01287024] | SSR: 0.2577296096808753
# Parameters: [0.02301447 0.01807013 0.30355099 0.00300232 0.62805577 0.03283382
#  0.00955866] | SSR: 0.246550223613978
# Parameters: [0.02784651 0.01758062 0.29546613 0.0028457  0.62010212 0.03779521
#  0.01341063] | SSR: 0.2633866536586282
# Parameters: [0.02195023 0.01840461 0.30208807 0.00299525 0.62637629 0.03276332
#  0.0095625 ] | SSR: 0.2448979593730506
# Parameters: [0.02224073 0.01832946 0.29921344 0.00292908 0.63513351 0.03349654
#  0.0105863 ] | SSR: 0.24187559480247506
# Parameters: [0.02097029 0.0184763  0.29837502 0.00290904 0.64454435 0.03284373
#  0.01049868] | SSR: 0.24625584267697834
# Parameters: [0.02184108 0.01840712 0.29695214 0.00294394 0.63654453 0.03408494
#  0.01070051] | SSR: 0.2457799422871006
# Parameters: [0.01929689 0.01867352 0.30052779 0.00304254 0.62305857 0.03100742
#  0.00875583] | SSR: 0.2698792327383675
# Parameters: [0.02425641 0.01810455 0.2988661  0.00291385 0.63103711 0.03509296
#  0.0113098 ] | SSR: 0.24396247857386694
# Parameters: [0.02354912 0.01896489 0.29959084 0.00296951 0.64443839 0.03325457
#  0.01035795] | SSR: 0.24519207695742234
# Parameters: [0.02385173 0.01807237 0.30018496 0.00290865 0.64160807 0.03396262
#  0.01169566] | SSR: 0.24353223907410182
# Parameters: [0.02336807 0.01870181 0.29446904 0.00287136 0.64231629 0.03504948
#  0.01235123] | SSR: 0.24338862751887924
# Parameters: [0.02497774 0.01844902 0.30035843 0.00290899 0.63547661 0.03407394
#  0.01168101] | SSR: 0.25110653210167583
# Parameters: [0.02262525 0.01841759 0.29780371 0.0029352  0.63627755 0.03408219
#  0.01094563] | SSR: 0.24195317246743608
# Parameters: [0.02300574 0.01773487 0.29720912 0.00287363 0.62525108 0.03514078
#  0.01219149] | SSR: 0.24435740664354316
# Parameters: [0.0249062  0.01810381 0.2933179  0.00281313 0.64299169 0.0363113
#  0.01373807] | SSR: 0.24220330601411927
# Parameters: [0.02228015 0.01799964 0.29841526 0.00288669 0.64158292 0.03453079
#  0.01119046] | SSR: 0.23974718318583382
# Parameters: [0.02109543 0.01779006 0.29953563 0.00288125 0.64679223 0.03432789
#  0.01054974] | SSR: 0.24193679982969224
# Parameters: [0.0237167  0.01875919 0.29772529 0.00291436 0.6521624  0.03415233
#  0.01118484] | SSR: 0.24251644236819292
# Parameters: [0.02231183 0.01857656 0.29574235 0.00287428 0.65241215 0.0339314
#  0.01203082] | SSR: 0.24305330025330968
# Parameters: [0.02227654 0.01875279 0.29315418 0.00286967 0.64492808 0.03505282
#  0.01174072] | SSR: 0.24781712404455405
# Parameters: [0.02345793 0.01824247 0.29842727 0.00289891 0.64243807 0.03423517
#  0.01170693] | SSR: 0.24067125851287974
# Parameters: [0.02278587 0.01799211 0.30000103 0.00291483 0.64425465 0.0337333
#  0.01090107] | SSR: 0.23937030226745637
# Parameters: [0.02249478 0.01763727 0.30276703 0.00293657 0.64522382 0.03307521
#  0.01017599] | SSR: 0.2416390868538467
# Parameters: [0.02397755 0.01795038 0.29994448 0.00292349 0.63182807 0.03479477
#  0.01089869] | SSR: 0.2438260074990207
# Parameters: [0.02272826 0.01842001 0.29679288 0.00288659 0.64726613 0.03414724
#  0.01174779] | SSR: 0.2405140923183155
# Parameters: [0.02229027 0.01767084 0.29769514 0.00287547 0.6306789  0.03457239
#  0.01190551] | SSR: 0.2433290110627725
# Parameters: [0.02336009 0.0184871  0.29771775 0.00290464 0.64679152 0.03425735
#  0.01136501] | SSR: 0.24036161199399067
# Parameters: [0.02065902 0.01843574 0.30335962 0.00300285 0.64093527 0.03182658
#  0.00867427] | SSR: 0.24352611988400263
# Parameters: [0.02384441 0.01818679 0.29582833 0.00286056 0.64247758 0.03519012
#  0.01247212] | SSR: 0.24030253611324992
# Parameters: [0.02328831 0.018056   0.29830942 0.00285945 0.64942085 0.03437224
#  0.01190284] | SSR: 0.2396410670481405
# Parameters: [0.02397213 0.018066   0.2966414  0.00284568 0.65464698 0.03520809
#  0.01263833] | SSR: 0.24034069476246922
# Parameters: [0.02290185 0.01810257 0.29691733 0.00286065 0.65083068 0.03474744
#  0.01178382] | SSR: 0.23784946735069187
# Parameters: [0.02262381 0.01803262 0.29616236 0.00284152 0.65502698 0.03500357
#  0.01182227] | SSR: 0.23693520544351862
# Parameters: [0.02360167 0.01781435 0.29837156 0.0028601  0.64822001 0.03508003
#  0.01176424] | SSR: 0.23837365901709792
# Parameters: [0.02303887 0.01755504 0.2976335  0.00282931 0.64910276 0.03520498
#  0.01226108] | SSR: 0.2363233182687261
# Parameters: [0.02287825 0.01708901 0.29759137 0.00279165 0.65025837 0.03567879
#  0.01270912] | SSR: 0.23460094279926466
# Parameters: [0.02211429 0.017697   0.29898127 0.00287283 0.63999341 0.03438872
#  0.01100799] | SSR: 0.23860782863097554
# Parameters: [0.02174769 0.01743628 0.30069517 0.00286146 0.65145304 0.03417772
#  0.01075588] | SSR: 0.23533385078830998
# Parameters: [0.02315982 0.01746247 0.29875965 0.00282813 0.65516774 0.03473617
#  0.01191337] | SSR: 0.2380631007322489
# Parameters: [0.02211495 0.01723652 0.29899412 0.00284641 0.64897178 0.03499871
#  0.011204  ] | SSR: 0.23441955468338638
# Parameters: [0.02152827 0.01682678 0.29933647 0.00283989 0.64874724 0.03531194
#  0.01085457] | SSR: 0.23396051646819646
# Parameters: [0.02225807 0.01696746 0.29711264 0.00276961 0.65542158 0.03608869
#  0.01219248] | SSR: 0.23264707001740106
# Parameters: [0.02199417 0.01645514 0.29566845 0.002697   0.66100505 0.03726639
#  0.01283819] | SSR: 0.2312721061696275
# Parameters: [0.02289534 0.01690775 0.29718588 0.00276138 0.66568614 0.03625545
#  0.01260848] | SSR: 0.23190646499918757
# Parameters: [0.02120614 0.01653138 0.29745683 0.00274591 0.66244987 0.03589999
#  0.01209344] | SSR: 0.23273889218324628
# Parameters: [0.0210898  0.01661723 0.29669651 0.00275439 0.65758275 0.03657636
#  0.01199576] | SSR: 0.23739931312296464
# Parameters: [0.02160731 0.01682854 0.29721229 0.00277282 0.656979   0.03611631
#  0.01197516] | SSR: 0.2338218827763609
# Parameters: [0.02133539 0.01570306 0.29959377 0.00272136 0.65828122 0.03662688
#  0.01213055] | SSR: 0.22824206562834382
# Parameters: [0.02069118 0.01453829 0.30130948 0.00266128 0.65990834 0.03743854
#  0.01228468] | SSR: 0.2250352003473054
# Parameters: [0.02190964 0.01547141 0.29523648 0.00264424 0.66427096 0.0383844
#  0.01363374] | SSR: 0.2270210043935861
# Parameters: [0.02050233 0.0153565  0.29766745 0.00267193 0.66946923 0.03765635
#  0.01194467] | SSR: 0.2285048110945045
# Parameters: [0.02155919 0.01519865 0.29544549 0.0025757  0.67690093 0.03869304
#  0.01411067] | SSR: 0.22566974740877638
# Parameters: [0.02146641 0.01473121 0.29706487 0.00258645 0.67436115 0.03862488
#  0.01360023] | SSR: 0.22198167739526997
# Parameters: [0.02139596 0.01368254 0.29699116 0.00249326 0.68305223 0.03987916
#  0.01441277] | SSR: 0.2174221443359666
# Parameters: [0.0219218  0.01421441 0.29668728 0.00254117 0.67477667 0.03997811
#  0.01414462] | SSR: 0.21829496155316802
# Parameters: [0.01995445 0.01306851 0.29681577 0.00246279 0.67413769 0.04068626
#  0.01406847] | SSR: 0.22523681883292318
# Parameters: [0.02027284 0.01255352 0.29866101 0.00246025 0.68257096 0.04065243
#  0.01419028] | SSR: 0.21537980664312337
# Parameters: [0.01941218 0.01060271 0.30015729 0.00234187 0.69335392 0.04234545
#  0.01486632] | SSR: 0.21229336241050123
# Parameters: [0.02145321 0.01229393 0.29737339 0.00239101 0.68093098 0.0416022
#  0.01591855] | SSR: 0.21352141892010926
# Parameters: [0.01991549 0.01127118 0.30041491 0.00234636 0.69088925 0.04179353
#  0.01488229] | SSR: 0.21248939906645312
# Parameters: [0.01979632 0.0104218  0.30162574 0.00234937 0.68225595 0.04237074
#  0.01462581] | SSR: 0.21156618654009857
# Parameters: [0.01891488 0.00803337 0.30471586 0.0022362  0.68493347 0.0442096
#  0.01488338] | SSR: 0.22132817806368466
# Parameters: [0.02135587 0.01179573 0.30162973 0.00242987 0.6873387  0.04085881
#  0.01482725] | SSR: 0.21796343484900044
# Parameters: [0.02080906 0.00954237 0.29722752 0.00216526 0.70940529 0.04508375
#  0.01733749] | SSR: 0.21183251605745615
# Parameters: [0.01926051 0.00853138 0.30200407 0.00217797 0.70443086 0.04400293
#  0.01638981] | SSR: 0.22198317118723365
# Parameters: [0.02125648 0.01279365 0.29801648 0.00245037 0.68219021 0.04098431
#  0.01470591] | SSR: 0.21354186892508328
# Parameters: [0.01979804 0.01123518 0.29602927 0.00229513 0.69039783 0.04315809
#  0.0156725 ] | SSR: 0.2138608636434431
# Parameters: [0.01930141 0.00864912 0.30039301 0.00217514 0.69678304 0.04507457
#  0.01644691] | SSR: 0.2111515395888146
# Parameters: [0.01825413 0.00613242 0.30209394 0.00201608 0.70364844 0.04767228
#  0.01746397] | SSR: 0.23154266465797768
# Parameters: [0.02075743 0.01035761 0.30260169 0.00233898 0.69126178 0.04234322
#  0.01540843] | SSR: 0.21641167524624658
# Parameters: [0.02003789 0.01101579 0.29767237 0.00230609 0.69061382 0.04295437
#  0.01560649] | SSR: 0.21063396228640602
# Parameters: [0.01895082 0.00829118 0.30051616 0.00214251 0.70187614 0.04507986
#  0.01663233] | SSR: 0.21549492291786337
# Parameters: [0.02068006 0.01166803 0.2986414  0.00237341 0.6871117  0.0420082
#  0.01518752] | SSR: 0.21089425600915107
# Parameters: [0.01853319 0.00861207 0.30152154 0.00219684 0.7049013  0.04457797
#  0.01521083] | SSR: 0.21558207077680266
# Parameters: [0.0207232  0.01137347 0.29841043 0.00234247 0.68692356 0.04234614
#  0.01574162] | SSR: 0.21074355897014324
# Parameters: [0.02030168 0.00966405 0.29790731 0.00224038 0.69380997 0.04454453
#  0.01649261] | SSR: 0.2072206293076123
# Parameters: [0.02049478 0.00886048 0.2966535  0.00218739 0.69527033 0.04592003
#  0.01729778] | SSR: 0.20605357290456114
# Parameters: [0.02111431 0.00983474 0.29716384 0.00220074 0.69189284 0.04501393
#  0.01720328] | SSR: 0.20610262995721837
# Parameters: [0.01980465 0.01097861 0.30007542 0.00238748 0.67083792 0.04225568
#  0.01469377] | SSR: 0.21485601108502922
# Parameters: [0.02055795 0.00990143 0.29793949 0.00222082 0.69976345 0.04437673
#  0.01667656] | SSR: 0.2086487162027406
# Parameters: [0.021035   0.0099505  0.29462399 0.00216665 0.7029894  0.04554182
#  0.01799137] | SSR: 0.20607330510096747
# Parameters: [0.02202522 0.012095   0.29420842 0.00233846 0.69023556 0.04297149
#  0.01661155] | SSR: 0.21070734489684387
# Parameters: [0.0210309  0.00919808 0.29469347 0.0021302  0.70079943 0.04631309
#  0.01827781] | SSR: 0.20532947640908616
# Parameters: [0.02120631 0.00796311 0.29271951 0.00200859 0.7076433  0.04846553
#  0.01982296] | SSR: 0.2067853007983346
# Parameters: [0.02107567 0.00887111 0.29386246 0.00210048 0.70495211 0.04710856
#  0.01844834] | SSR: 0.20435184882728585
# Parameters: [0.0212519  0.00761993 0.29158848 0.00197949 0.71396638 0.04948977
#  0.0198017 ] | SSR: 0.20643560663293847
# Parameters: [0.01950235 0.00722847 0.29796561 0.00203651 0.70584483 0.04766523
#  0.0181032 ] | SSR: 0.21429085569618717
# Parameters: [0.0213945  0.01087837 0.29514772 0.00226297 0.69413788 0.04414493
#  0.01698446] | SSR: 0.20719013366932554
# Parameters: [0.02187729 0.00826842 0.29378034 0.00205655 0.70647345 0.04802251
#  0.01950197] | SSR: 0.2100209922709203
# Parameters: [0.02141744 0.00895526 0.29475335 0.00211894 0.70250854 0.04675548
#  0.0185281 ] | SSR: 0.2065790138584674
# Parameters: [0.02160279 0.00911244 0.29260289 0.00211272 0.69810813 0.04727979
#  0.01896091] | SSR: 0.2023390446455941
# Parameters: [0.0221252  0.00871795 0.28993458 0.00205867 0.69728047 0.04873133
#  0.02010309] | SSR: 0.1998440231723735
# Parameters: [0.02097501 0.00751824 0.29390519 0.00201219 0.70463159 0.048822
#  0.01954404] | SSR: 0.20696427970813486
# Parameters: [0.02107988 0.00835827 0.29421583 0.00207489 0.70200816 0.04765273
#  0.01890415] | SSR: 0.20474180504600117
# Parameters: [0.02085563 0.00927078 0.29414599 0.00214364 0.69611796 0.04646781
#  0.01810785] | SSR: 0.20321651667834334
# Parameters: [0.02108485 0.00823017 0.29087325 0.00204552 0.70794083 0.04862475
#  0.01969111] | SSR: 0.20235654633970193
# Parameters: [0.0211784  0.00762288 0.29234146 0.00204501 0.69825897 0.04897769
#  0.01938866] | SSR: 0.20318233171885197
# Parameters: [0.02191394 0.0083593  0.28907994 0.00198358 0.70683194 0.0494731
#  0.02067965] | SSR: 0.200614401020203
# Parameters: [0.02163013 0.00778205 0.2894361  0.00199889 0.7030264  0.0499829
#  0.02038586] | SSR: 0.19924550853880796
# Parameters: [0.02192974 0.00707403 0.28680742 0.00193323 0.70413989 0.0518178
#  0.02143988] | SSR: 0.19721597691098747
# Parameters: [0.02182396 0.00825493 0.28779706 0.00201372 0.70242674 0.04983328
#  0.02048402] | SSR: 0.19773961878617954
# Parameters: [0.02204197 0.00756604 0.28641746 0.00196333 0.69876127 0.05115594
#  0.02152145] | SSR: 0.1963475204947679
# Parameters: [0.02252512 0.00691351 0.28269495 0.00189476 0.69566585 0.05317963
#  0.023058  ] | SSR: 0.19366517502425842
# Parameters: [0.022739   0.00649287 0.2828622  0.00184907 0.70746624 0.05371435
#  0.02327627] | SSR: 0.19724635901737325
# Parameters: [0.02286211 0.00781791 0.28195837 0.00189172 0.70795588 0.0525578
#  0.0231062 ] | SSR: 0.19555625393167322
# Parameters: [0.02346346 0.00709283 0.28087947 0.00184726 0.69827832 0.05403448
#  0.02377949] | SSR: 0.19280900431387948
# Parameters: [0.02465277 0.00652416 0.27588258 0.00174813 0.69344706 0.05673934
#  0.02582368] | SSR: 0.19102951074317187
# Parameters: [0.02341689 0.00643937 0.27890211 0.00184193 0.69556296 0.0552622
#  0.02426068] | SSR: 0.19083469890036925
# Parameters: [0.02416836 0.00547941 0.2738132  0.00177111 0.68992847 0.05815675
#  0.02605119] | SSR: 0.18840161162511504
# Parameters: [0.02378938 0.00515543 0.27344135 0.00168469 0.70301385 0.05869695
#  0.0265367 ] | SSR: 0.1892452120693118
# Parameters: [0.02465218 0.00473287 0.27147724 0.00163563 0.69803532 0.06012748
#  0.02788511] | SSR: 0.1891620833375231
# Parameters: [0.02428376 0.00599208 0.27315926 0.00173929 0.69030128 0.05807872
#  0.02640966] | SSR: 0.18917572152751888
# Parameters: [0.0257656  0.00510179 0.26531457 0.00159972 0.68967374 0.06176411
#  0.02966599] | SSR: 0.18911909919715963
# Parameters: [0.02566279 0.00358188 0.26540825 0.0015578  0.68063429 0.06365447
#  0.02987389] | SSR: 0.18787652235816876
# Parameters: [0.02706313 0.00146386 0.25713318 0.00139084 0.66697349 0.06920281
#  0.03325774] | SSR: 0.1946977197044371
# Parameters: [0.02689627 0.00353438 0.2597326  0.00145849 0.68862958 0.06602546
#  0.03186949] | SSR: 0.18676775919117194
# Parameters: [0.02908184 0.00184482 0.24825142 0.00124036 0.68511145 0.07244838
#  0.03627523] | SSR: 0.18914923289985375
# Parameters: [0.02540962 0.00306951 0.2619307  0.00152236 0.68947195 0.06511892
#  0.03083118] | SSR: 0.18653031675804482
# Parameters: [0.02578804 0.00134219 0.25495476 0.00140948 0.68748439 0.06930871
#  0.03333493] | SSR: 0.19295185587172586
# Parameters: [0.02673592 0.00384226 0.26108317 0.00153943 0.67603605 0.06499617
#  0.03134516] | SSR: 0.18895779812190253
# Parameters: [0.02694216 0.00239138 0.25791495 0.00142772 0.68467284 0.06759082
#  0.03288234] | SSR: 0.1889375030719936
# Parameters: [0.02722802 0.00298159 0.25572202 0.00147199 0.67312094 0.06767444
#  0.03283467] | SSR: 0.18870771924569413
# Parameters: [0.02653244 0.0020069  0.25914396 0.00147139 0.67675315 0.06772648
#  0.03195913] | SSR: 0.19236428477060108
# Parameters: [0.02595731 0.00432807 0.26377192 0.00156764 0.68644359 0.0632547
# ...
#  0.01738894] | SSR: 0.05301854097444344
# Parameters: [0.01855174 0.00313275 0.12611273 0.00899748 2.33631017 0.17358687
#  0.01733049] | SSR: 0.05303775630157185
# Parameters: [0.0186162  0.00292961 0.12822716 0.00912809 2.39236475 0.17804544
#  0.01767548] | SSR: 0.05308290149877846
# Parameters: [0.01882677 0.0029005  0.12822209 0.00914161 2.34243982 0.17550595
#  0.01792552] | SSR: 0.05307678276797903
# Parameters: [0.01844181 0.00313676 0.12804912 0.0093145  2.37780985 0.17474519
#  0.01695649] | SSR: 0.05303836005310649
# Parameters: [0.01885752 0.00290266 0.12754673 0.00890032 2.3484149  0.17701013
#  0.01820591] | SSR: 0.05308573829041307
# Parameters: [0.01862997 0.00270191 0.13344408 0.00940968 2.34312068 0.1751397
#  0.01780352] | SSR: 0.052999666525236695
# Parameters: [0.01862212 0.00245816 0.13740952 0.00962128 2.32654669 0.17462918
#  0.01796971] | SSR: 0.05304260603758957
# Parameters: [0.01872615 0.00302291 0.1251499  0.00897459 2.40193949 0.17978879
#  0.0177089 ] | SSR: 0.05298370150555519
# Parameters: [0.01880554 0.00311866 0.12086152 0.00875241 2.44133201 0.18352425
#  0.01775405] | SSR: 0.053014315816680715
# Parameters: [0.01839846 0.00298603 0.13064502 0.00951442 2.3919718  0.17589043
#  0.01697957] | SSR: 0.05304348728884502
# Parameters: [0.01857756 0.00297519 0.13065541 0.00939704 2.34790968 0.17423941
#  0.01731118] | SSR: 0.053063659498044015
# Parameters: [0.01829579 0.00302564 0.13135571 0.00945649 2.39939742 0.17641704
#  0.01688561] | SSR: 0.05309991231913847
# Parameters: [0.01869403 0.00293178 0.1290055  0.00922033 2.35667922 0.17573372
#  0.01766554] | SSR: 0.05301230144992529
# Parameters: [0.01857828 0.00293855 0.12845099 0.00915058 2.39643315 0.17811052
#  0.0176012 ] | SSR: 0.05307244085014011
# Parameters: [0.01857774 0.00296603 0.1301043  0.00933542 2.36004054 0.17520719
#  0.01738368] | SSR: 0.05300861528209813
# Parameters: [0.01853474 0.00307858 0.12660254 0.00922126 2.3530018  0.17394313
#  0.0171344 ] | SSR: 0.05298284085100696
# Parameters: [0.01849638 0.00318576 0.1239185  0.0091677  2.33731003 0.17206682
#  0.01685642] | SSR: 0.0530407918968994
# Parameters: [0.01878669 0.00298324 0.12677314 0.00895145 2.33428108 0.1751921
#  0.01788942] | SSR: 0.053012654890122045
# Parameters: [0.01884187 0.00278865 0.12900448 0.00904765 2.33600624 0.17646503
#  0.01817905] | SSR: 0.052998667324034965
# Parameters: [0.01882534 0.002795   0.1285587  0.00917677 2.36072624 0.17761733
#  0.01797235] | SSR: 0.05298374514089852
# Parameters: [0.01859326 0.00281243 0.13090386 0.00944447 2.38329441 0.1773493
#  0.01749557] | SSR: 0.05298948490443636
# Parameters: [0.01865714 0.00282979 0.12921389 0.00923962 2.36850061 0.17726927
#  0.01767088] | SSR: 0.052937221726284414
# Parameters: [0.01863869 0.0027788  0.12931809 0.00924926 2.37441131 0.17803705
#  0.01767355] | SSR: 0.05293783647427827
# Parameters: [0.01879611 0.00275663 0.12786068 0.00909715 2.36755645 0.17838497
#  0.01803479] | SSR: 0.052997689701716665
# Parameters: [0.01879135 0.00303637 0.12292564 0.0089336  2.39145797 0.17937968
#  0.01768104] | SSR: 0.05296033298974375
# Parameters: [0.01856501 0.00302041 0.12562844 0.00926306 2.41441576 0.17888711
#  0.01716321] | SSR: 0.05299807827425354
# Parameters: [0.01863423 0.00296247 0.12647245 0.0092092  2.39481338 0.17828159
#  0.01741717] | SSR: 0.052962504955514224
# Parameters: [0.01856452 0.00311125 0.1263756  0.00924556 2.39065324 0.17693763
#  0.01713101] | SSR: 0.05302019716947604
# Parameters: [0.01873821 0.00284528 0.12748941 0.00913426 2.37333065 0.17802313
#  0.01780885] | SSR: 0.05295999999139702
# Parameters: [0.01880878 0.00306483 0.12235687 0.00880962 2.37206849 0.17816582
#  0.01775974] | SSR: 0.05297207305380949
# Parameters: [0.01857197 0.00315936 0.12293007 0.00897241 2.39787729 0.17805451
#  0.01722221] | SSR: 0.05296123257119104
# Parameters: [0.01862711 0.00297043 0.12570464 0.00917397 2.35550342 0.17538753
#  0.01734661] | SSR: 0.05294074827755814
# Parameters: [0.01884491 0.00288385 0.12399545 0.0089138  2.40515585 0.18164588
#  0.01798174] | SSR: 0.052978225415732695
# Parameters: [0.01876737 0.00293254 0.12464722 0.00899066 2.39211734 0.17972019
#  0.01776991] | SSR: 0.05294801049188915
# Parameters: [0.01855904 0.00285981 0.12889551 0.00937716 2.39181741 0.17786729
#  0.0173593 ] | SSR: 0.052959557925504906
# Parameters: [0.01871212 0.00293284 0.12547224 0.00902557 2.36821653 0.17763316
#  0.01768534] | SSR: 0.05293085923740933
# Parameters: [0.01875106 0.00291802 0.12497213 0.00893375 2.35491811 0.17730894
#  0.01781943] | SSR: 0.052949452428928456
# Parameters: [0.01881441 0.00267123 0.12974094 0.00927754 2.35667811 0.17773985
#  0.01801263] | SSR: 0.05295714697264677
# Parameters: [0.01860162 0.00268989 0.1316926  0.00941462 2.35316034 0.17594616
#  0.01764854] | SSR: 0.05295910301320181
# Parameters: [0.01861574 0.00283659 0.12832974 0.00929407 2.36552472 0.17670928
#  0.01747493] | SSR: 0.05292466229814433
# Parameters: [0.0185545  0.00283224 0.12874991 0.00937398 2.36162175 0.17605235
#  0.01730796] | SSR: 0.052942953359312823
# Parameters: [0.0188111  0.00281542 0.12676199 0.00902742 2.33952575 0.17653426
#  0.0179575 ] | SSR: 0.05294248818353897
# Parameters: [0.01882837 0.0030212  0.12255616 0.00887934 2.37428722 0.17862343
#  0.01775654] | SSR: 0.0529470149906664
# Parameters: [0.01861957 0.00313985 0.12245503 0.00890265 2.37580063 0.17708218
#  0.01731929] | SSR: 0.05295832268256898
# Parameters: [0.0187657  0.00278839 0.12791946 0.00918382 2.36145874 0.17757543
#  0.01783929] | SSR: 0.05293252957441457
# Parameters: [0.01866614 0.00283736 0.12848367 0.00924471 2.3316018  0.17448906
#  0.01758184] | SSR: 0.052930884763174736
# Parameters: [0.01855878 0.00269617 0.1322683  0.00946043 2.33723608 0.17440457
#  0.01754528] | SSR: 0.052963412265194146
# Parameters: [0.01876098 0.00293995 0.1249842  0.00902461 2.36502444 0.17756871
#  0.01770373] | SSR: 0.05292722727821403
# Parameters: [0.01856173 0.00293754 0.12755453 0.00931154 2.37928289 0.17678929
#  0.01727181] | SSR: 0.052944817484216034
# Parameters: [0.01874876 0.00284595 0.12696013 0.00909845 2.34946504 0.17659802
#  0.01778608] | SSR: 0.052927074401011166
# Parameters: [0.01878048 0.00274696 0.1289706  0.00914341 2.36157998 0.17828188
#  0.01800827] | SSR: 0.052941425854431186
# Parameters: [0.01866545 0.00291456 0.12652113 0.00916633 2.35702256 0.17611112
#  0.01751203] | SSR: 0.05292652752091838
# Parameters: [0.01875283 0.00291181 0.12469198 0.00905683 2.34530334 0.17606924
#  0.01763862] | SSR: 0.05292897937489546
# Parameters: [0.01864059 0.00298848 0.12506428 0.00907635 2.34772938 0.17533273
#  0.01741287] | SSR: 0.05293829632666845
# Parameters: [0.01873442 0.00283841 0.12720567 0.00915695 2.3580264  0.17701476
#  0.01773269] | SSR: 0.05292327949385183
# Parameters: [0.01875966 0.00293981 0.12413493 0.00899038 2.38513621 0.17914074
#  0.01771342] | SSR: 0.052936522848718005
# Parameters: [0.01868952 0.00286298 0.12739648 0.00918113 2.3449854  0.17565198
#  0.01761473] | SSR: 0.052922939880905545
# Parameters: [0.01870722 0.00282437 0.12769614 0.00925397 2.34188401 0.17543059
#  0.01758974] | SSR: 0.052925568326947225
# Parameters: [0.01865348 0.00282041 0.12933473 0.00927903 2.36382025 0.17681204
#  0.01762251] | SSR: 0.05293113446000851
# Parameters: [0.01872799 0.00288896 0.12585267 0.00911238 2.34993257 0.17625494
#  0.01763459] | SSR: 0.05292228023340576
# Parameters: [0.01863591 0.00277772 0.12929065 0.00933633 2.33978719 0.1749372
#  0.01753764] | SSR: 0.05293050497302963
# Parameters: [0.01872971 0.00289939 0.12606081 0.00910254 2.35871513 0.17691083
#  0.01766221] | SSR: 0.052921783610884614
# Parameters: [0.01864269 0.00288699 0.12705777 0.00926365 2.35798947 0.17599726
#  0.01741989] | SSR: 0.0529270036204259
# Parameters: [0.0186692  0.00287673 0.12703336 0.00922235 2.35585836 0.17614745
#  0.01751144] | SSR: 0.05292194509594308
# Parameters: [0.01872706 0.00280756 0.12764312 0.00921178 2.35009932 0.17649455
#  0.01769378] | SSR: 0.05291632533403897
# Parameters: [0.01875787 0.00275406 0.12820412 0.0092345  2.34663771 0.17668626
#  0.01778466] | SSR: 0.052916595514441465
# Parameters: [0.01869096 0.00289294 0.12645296 0.00911209 2.36758511 0.17747906
#  0.01764579] | SSR: 0.05292229409872822
# Parameters: [0.01880394 0.00289683 0.12528313 0.00901999 2.34453308 0.17642031
#  0.01780942] | SSR: 0.05293508462006208
# Parameters: [0.01866279 0.00285165 0.12756809 0.00922555 2.36027681 0.17663704
#  0.01755855] | SSR: 0.052919161101469915
# Parameters: [0.01866479 0.00289879 0.12651076 0.00917671 2.35267437 0.17600691
#  0.01750191] | SSR: 0.05292092519118442
# Parameters: [0.01870263 0.00288446 0.12606688 0.00915127 2.36791221 0.1774711
#  0.01758763] | SSR: 0.05291718054512603
# Parameters: [0.01870452 0.00285207 0.1269001  0.00923151 2.34540597 0.17564174
#  0.01753996] | SSR: 0.05292543640507149
# Parameters: [0.01869435 0.00288272 0.12656474 0.00914194 2.36204032 0.17701973
#  0.01761933] | SSR: 0.05291861299291841
# Parameters: [0.01865787 0.00285426 0.12770384 0.00923966 2.36651787 0.17708438
#  0.01754679] | SSR: 0.052919840246415425
# Parameters: [0.01871342 0.00286008 0.12671471 0.00913464 2.36363765 0.17745956
#  0.01768005] | SSR: 0.052916667005522014
# Parameters: [0.01864826 0.00282619 0.12787409 0.00926362 2.36218732 0.17685296
#  0.01753438] | SSR: 0.052919664786008416
# Parameters: [0.01870847 0.00280605 0.12781366 0.00921428 2.37094606 0.17799861
#  0.01770395] | SSR: 0.052920378130278146
# Parameters: [0.01869755 0.00282923 0.12748793 0.00920489 2.36637814 0.17750069
#  0.01765344] | SSR: 0.052917404846634375
# Parameters: [0.01872672 0.00284342 0.1265589  0.00914139 2.35706264 0.17704008
#  0.01768953] | SSR: 0.052916278407866335
# Parameters: [0.01876114 0.002838   0.12598643 0.00909225 2.35233502 0.17701793
#  0.0177609 ] | SSR: 0.05291989254725789
# Parameters: [0.01875874 0.00287642 0.12601288 0.00908251 2.35992899 0.17732497
#  0.01774628] | SSR: 0.05292323243438596
# Parameters: [0.01867588 0.00283875 0.12740879 0.00921834 2.36162274 0.17697096
#  0.01758735] | SSR: 0.052916621590374566
# Parameters: [0.01874796 0.00284727 0.12627336 0.00911852 2.36222405 0.1776363
#  0.01773034] | SSR: 0.05291529291009715
# Parameters: [0.01879054 0.00284509 0.12562599 0.009065   2.36319768 0.17813593
#  0.01781623] | SSR: 0.05291747340088318
# Parameters: [0.01873171 0.00280607 0.12719345 0.00919544 2.36051303 0.17742976
#  0.01770127] | SSR: 0.052914370844739954
# Parameters: [0.01875039 0.00276774 0.12750781 0.00922218 2.35974939 0.17763478
#  0.01774225] | SSR: 0.05291567727378467
# Parameters: [0.01873828 0.00285294 0.12618613 0.00912979 2.35449948 0.17692855
#  0.01768083] | SSR: 0.0529154275615868
# Parameters: [0.01874338 0.00278871 0.12764125 0.00917727 2.34913319 0.17680311
#  0.01777327] | SSR: 0.052916362438151086
# Parameters: [0.01874115 0.0027927  0.12725815 0.00920609 2.34926362 0.1766271
#  0.01770749] | SSR: 0.05291573701453991
# Parameters: [0.01879733 0.00280088 0.12652103 0.00911888 2.34774736 0.17701745
#  0.01783451] | SSR: 0.05291816645641702
# Parameters: [0.01870625 0.00282928 0.12718685 0.00919348 2.35815389 0.17698259
#  0.01764914] | SSR: 0.0529149699811934
# Parameters: [0.01871922 0.0028625  0.12615874 0.00916458 2.36281425 0.17723658
#  0.01761312] | SSR: 0.052916951138418815
# Parameters: [0.01873734 0.00280716 0.12727062 0.0091741  2.35255345 0.17691148
#  0.01773324] | SSR: 0.05291500349925633
# Parameters: [0.01873848 0.00284354 0.12605044 0.00911931 2.3625493  0.17766427
#  0.01770389] | SSR: 0.052914906137802385
# Parameters: [0.01874219 0.00280771 0.12698938 0.00918339 2.3571536  0.17729707
#  0.01771224] | SSR: 0.05291401408674354
# Parameters: [0.01874992 0.00278985 0.12720463 0.00920438 2.35719908 0.17742557
#  0.01772359] | SSR: 0.05291537993739344
# Parameters: [0.01872805 0.00286272 0.12621335 0.0091122  2.36720689 0.17790148
#  0.01769564] | SSR: 0.05291574838037318
# Parameters: [0.01873787 0.0028102  0.12699695 0.00918261 2.35374944 0.17694569
#  0.01770453] | SSR: 0.05291455031832266
# Parameters: [0.01873081 0.00279027 0.12751703 0.00920359 2.36175675 0.17760493
#  0.01772907] | SSR: 0.05291498909776795
# Parameters: [0.01871623 0.00277965 0.12778513 0.00923917 2.35389865 0.17688821
#  0.0176792 ] | SSR: 0.052915436988241436
# Parameters: [0.01874002 0.00283037 0.1266513  0.00914868 2.3601427  0.17744928
#  0.01771755] | SSR: 0.05291437835109016
# Parameters: [0.01872761 0.00282639 0.12661092 0.00917633 2.36573761 0.17776669
#  0.01767182] | SSR: 0.05291448218210271
# Parameters: [0.01873323 0.00285361 0.12610562 0.00913905 2.35767171 0.17711946
#  0.01765963] | SSR: 0.052914836894602364
# Parameters: [0.0187655  0.00282155 0.12612689 0.00913361 2.36113679 0.17778091
#  0.01774256] | SSR: 0.052914505522034395
# Parameters: [0.01874099 0.002801   0.12728514 0.00921187 2.35633781 0.17713255
#  0.01769885] | SSR: 0.052915207257695586
# Parameters: [0.01873911 0.0028329  0.12635911 0.00914245 2.36099643 0.17753134
#  0.01770263] | SSR: 0.052914156384110164
# Parameters: [0.01874792 0.00278502 0.12730238 0.0091931  2.36216532 0.17779504
#  0.0177554 ] | SSR: 0.052914879305032025
# Parameters: [0.0187369  0.00283646 0.12640481 0.00915256 2.35879511 0.17728835
#  0.01768357] | SSR: 0.05291415953254393
# Parameters: [0.01874299 0.00283593 0.12624187 0.00914094 2.36752921 0.17806671
#  0.01770451] | SSR: 0.052914395997451145
# Parameters: [0.01870894 0.00282869 0.12714479 0.00919204 2.36196826 0.17731315
#  0.01765562] | SSR: 0.05291472106166966
# Parameters: [0.01875136 0.00282333 0.12638136 0.00914822 2.36134466 0.17766397
#  0.01772082] | SSR: 0.05291404604566347
# Parameters: [0.01875362 0.00282297 0.12659517 0.00914129 2.35611232 0.17729802
#  0.01774035] | SSR: 0.052914336421678136
# Parameters: [0.01874126 0.00280974 0.12706515 0.00917678 2.35105875 0.17677838
#  0.0177179 ] | SSR: 0.05291494365531429
# Parameters: [0.01874256 0.00282938 0.12644769 0.0091499  2.36341159 0.17774463
#  0.01770786] | SSR: 0.0529139780672427
# Parameters: [0.01874496 0.00281501 0.12659755 0.00916938 2.35937922 0.17748019
#  0.01770209] | SSR: 0.05291408215548359
# Parameters: [0.01875706 0.00284186 0.12588514 0.00911519 2.35868495 0.17751412
#  0.0177186 ] | SSR: 0.05291462040934378
# Parameters: [0.01873805 0.00281502 0.12686638 0.00917537 2.36005601 0.17745085
#  0.01770561] | SSR: 0.05291397392622292
# Parameters: [0.0187307  0.00282269 0.12656092 0.00917907 2.36421243 0.17768952
#  0.0176696 ] | SSR: 0.052914436433078166
# Parameters: [0.01874789 0.0028229  0.1265866  0.00915074 2.35813735 0.1773959
#  0.01772266] | SSR: 0.05291397824116688
# Parameters: [0.01875056 0.00280533 0.12680321 0.00916728 2.36134171 0.17772992
#  0.01773755] | SSR: 0.05291406011397005
# Parameters: [0.01875163 0.002801   0.1269758  0.00918449 2.35923904 0.17754367
#  0.01772846] | SSR: 0.05291431506907663
# Parameters: [0.01874224 0.00282493 0.12651328 0.00915296 2.36055708 0.17753442
#  0.01770909] | SSR: 0.05291391882338174
# Parameters: [0.01874499 0.00282173 0.12671328 0.00915286 2.36119278 0.17761031
#  0.017731  ] | SSR: 0.05291416585957557
# Parameters: [0.01874497 0.00281669 0.12662648 0.00916525 2.35983261 0.17751272
#  0.01770932] | SSR: 0.052913908350410606
# Parameters: [0.0187378  0.00283466 0.12645713 0.00915438 2.35879912 0.17729853
#  0.01768748] | SSR: 0.05291410488533904
# Parameters: [0.01874737 0.00281266 0.12671669 0.00916406 2.36070606 0.17762207
#  0.01772503] | SSR: 0.05291390616658086
# Parameters: [0.01873586 0.00281361 0.12697478 0.00917797 2.35861371 0.17735251
#  0.01770541] | SSR: 0.052913884946287015
# Parameters: [0.0187281  0.00280874 0.1272715  0.00919285 2.35724824 0.17719677
#  0.01769771] | SSR: 0.05291415151963986
# Parameters: [0.01874322 0.00283091 0.12636259 0.00914126 2.36322195 0.17773524
#  0.01771204] | SSR: 0.052914228811808524
# Parameters: [0.01874244 0.00281351 0.12683269 0.00917285 2.35867069 0.17740662
#  0.01771219] | SSR: 0.052913864565483595
# Optimization successful: False
# Number of iterations: 939
#
# Optimized parameters:
# beta: 0.018742
# gamma: 0.002814
# rho: 0.126833
# delta: 0.009173
# p: 2.358671
# c: 0.177407
# alpha: 0.017712
# guess =  [np.float64(0.018742444708749022), np.float64(0.002813510775266756), np.float64(0.12683268600269887), np.float64(0.00917285294673148), np.float64(2.3586706877177557), np.float64(0.17740661528765506), np.float64(0.017712190612499942)]

# %%
# Calculate final SSR
final_ssr = result.fun
print(f"\nFinal SSR: {final_ssr:.6f}")

# Generate 95% confidence intervals for model predictions using bootstrap parameters
try:
    # Load bootstrap parameters if available
    bootstrap_params = np.loadtxt(f"{output_prefix}_params.txt", delimiter=",")
    
    # Generate model predictions for each bootstrap parameter set
    V_bootstrap = []
    F_bootstrap = []
    
    # Use a subset of bootstrap samples for speed (every 10th sample)
    n_samples = min(100, len(bootstrap_params))
    sample_indices = np.linspace(0, len(bootstrap_params)-1, n_samples, dtype=int)
    
    for idx in sample_indices:
        params = bootstrap_params[idx]
        try:
            solution = odeint(Model, y0, t, args=tuple(params))
            _, _, _, V_boot, F_boot = solution.T
            V_bootstrap.append(V_boot)
            F_bootstrap.append(F_boot)
        except:
            continue
    
    # Calculate 95% confidence intervals
    if len(V_bootstrap) > 10:
        V_bootstrap = np.array(V_bootstrap)
        F_bootstrap = np.array(F_bootstrap)
        
        V_ci_lower = np.percentile(V_bootstrap, 2.5, axis=0)
        V_ci_upper = np.percentile(V_bootstrap, 97.5, axis=0)
        F_ci_lower = np.percentile(F_bootstrap, 2.5, axis=0)
        F_ci_upper = np.percentile(F_bootstrap, 97.5, axis=0)
        
        print(f"Generated 95% CI from {len(V_bootstrap)} bootstrap samples")
        ci_available = True
    else:
        print("Insufficient bootstrap samples for CI calculation")
        ci_available = False
        
except:
    print("Bootstrap data not available for CI calculation")
    ci_available = False

# Plot results with 95% confidence intervals
plt.figure(figsize=(12, 5))

# Plot viral load
plt.subplot(121)
if ci_available:
    plt.fill_between(t, V_ci_lower, V_ci_upper, alpha=0.3, color='blue', label='95% CI')
plt.plot(t, V_fit, 'b-', label='Model', linewidth=2)
plt.plot(vl_data['time'], vl_data['value'], 'bo', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('Viral Load (log10)')
plt.legend()
plt.title('Viral Load Fit')

# Plot interferon
plt.subplot(122)
if ci_available:
    plt.fill_between(t, F_ci_lower, F_ci_upper, alpha=0.3, color='red', label='95% CI')
plt.plot(t, F_fit, 'r-', label='Model', linewidth=2)
plt.plot(t1_data['time'], t1_data['value'], 'ro', label='Data', markersize=6)
plt.xlabel('Time (hours)')
plt.ylabel('IFN-A2 Level')
plt.legend()
plt.title('Interferon Fit')

plt.tight_layout()
plt.savefig("h3n2(2003)_tracheal_fit_with_ci.png")
plt.show()
# Out:
# Final SSR: 0.052914
# Bootstrap data not available for CI calculation

# %%
# %% Bootstrap Analysis
import os

# Create output directory
strain = "h3n2(2003)"  # Change for each file
location = "tracheal"     # Change for each file
output_dir = f"/Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/{strain}/{location}/bootstrap_results"
os.makedirs(output_dir, exist_ok=True)
output_prefix = f"{output_dir}/{strain}_{location}"

# Calculate residuals between data and best-fit model
# Find indices for data_times in t
indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
V_best = V_fit[indices]
F_best = F_fit[indices]

# Calculate residuals (use for bootstrapping)
residuals_viral = vl_data['value'] - V_best
residuals_ifn = t1_data['value'] - F_best

# Use best-fit parameters from previous optimization
best_params = [beta_fit, gamma_fit, rho_fit, delta_fit, p_fit, c_fit, alpha_fit]

# Define bootstrap optimization function that uses relative error
def optimize_bootstrap(params, new_viral_data, new_ifn_data):
    """
    Objective function for bootstrap optimization.
    Uses relative error just like the original optimize function.
    """
    beta, gamma, rho, delta, p, c, alpha = params
    
    try:
        # Solve ODE system
        solution = odeint(Model, y0, t, args=(beta, gamma, rho, delta, p, c, alpha))
        _, _, _, V, F = solution.T
        
        # Get model predictions at data time points
        indices = [np.where(np.isclose(t, time))[0][0] for time in data_times]
        V_pred = V[indices]
        F_pred = F[indices]
        
        # Calculate relative SSR (same method as in original optimize function)
        vl_ssr = np.sum((((np.maximum(V_pred, 0)) - new_viral_data)/new_viral_data)**2)
        ifn_ssr = np.sum(((F_pred - new_ifn_data)/new_ifn_data)**2)
        
        total_ssr = vl_ssr + ifn_ssr
        return total_ssr
    except:
        return 1e12  # Large number if integration fails

# Number of bootstrap samples
n_bootstrap = 1000

# Initialize arrays for bootstrap results
bootstrap_params = []
bootstrap_ssr = []

print(f"Starting bootstrap analysis with {n_bootstrap} samples")
print(f"Using best-fit parameters: {best_params}")

# Run bootstrap
for i in range(n_bootstrap):
    # Generate new datasets by resampling residuals
    new_viral_data = V_best + np.random.choice(residuals_viral, size=len(residuals_viral), replace=True)
    new_ifn_data = F_best + np.random.choice(residuals_ifn, size=len(residuals_ifn), replace=True)
    
    # Ensure non-negative values
    new_viral_data = np.maximum(new_viral_data, 1e-6)  # Using small positive number instead of zero for relative error
    new_ifn_data = np.maximum(new_ifn_data, 1e-6)
    
    # Optimize with new dataset
    result_bootstrap = minimize(
        optimize_bootstrap, 
        best_params, 
        args=(new_viral_data, new_ifn_data), 
        method='Nelder-Mead', 
        bounds=bounds
    )
    
    bootstrap_params.append(result_bootstrap.x)
    bootstrap_ssr.append(result_bootstrap.fun)
    
    if (i+1) % 10 == 0 or i == 0:
        print(f"Processing bootstrap sample {i+1}/{n_bootstrap}")

# Save bootstrap parameters and SSR to text files
np.savetxt(f"{output_prefix}_params.txt", np.array(bootstrap_params), delimiter=",")
np.savetxt(f"{output_prefix}_ssr.txt", np.array(bootstrap_ssr), delimiter=",")

# Calculate and print statistics
print(f"\nBootstrap Statistics:")
print(f"Mean SSR: {np.mean(bootstrap_ssr)}")
print(f"Median SSR: {np.median(bootstrap_ssr)}")
print(f"Standard Deviation of SSR: {np.std(bootstrap_ssr)}")

# Calculate parameter statistics
param_names = ['beta', 'gamma', 'rho', 'delta', 'p', 'c', 'alpha']
param_stats = {}

# Create a results summary file
with open(f"{output_prefix}_summary.txt", "w") as f:
    f.write(f"Bootstrap Results Summary for {strain} {location}\n")
    f.write(f"Number of bootstrap samples: {n_bootstrap}\n\n")
    f.write(f"SSR Statistics:\n")
    f.write(f"Mean: {np.mean(bootstrap_ssr):.6f}\n")
    f.write(f"Median: {np.median(bootstrap_ssr):.6f}\n")
    f.write(f"Std Dev: {np.std(bootstrap_ssr):.6f}\n\n")
    
    f.write(f"Parameter Statistics:\n")
    for i, name in enumerate(param_names):
        param_values = np.array(bootstrap_params)[:, i]
        mean_val = np.mean(param_values)
        median_val = np.median(param_values)
        ci_low = np.percentile(param_values, 2.5)
        ci_high = np.percentile(param_values, 97.5)
        
        param_stats[name] = {
            'mean': mean_val,
            'median': median_val,
            'ci_low': ci_low,
            'ci_high': ci_high
        }
        
        f.write(f"{name}:\n")
        f.write(f"  Mean: {mean_val:.6f}\n")
        f.write(f"  Median: {median_val:.6f}\n")
        f.write(f"  95% CI: [{ci_low:.6f}, {ci_high:.6f}]\n\n")

print(f"Bootstrap analysis complete. Results saved to {output_dir}")
# Out:
# Starting bootstrap analysis with 1000 samples
# Using best-fit parameters: [np.float64(0.018742444708749022), np.float64(0.002813510775266756), np.float64(0.12683268600269887), np.float64(0.00917285294673148), np.float64(2.3586706877177557), np.float64(0.17740661528765506), np.float64(0.017712190612499942)]
# Processing bootstrap sample 1/1000
# Processing bootstrap sample 10/1000
# Processing bootstrap sample 20/1000
# Processing bootstrap sample 30/1000
# Processing bootstrap sample 40/1000
# Processing bootstrap sample 50/1000
# Processing bootstrap sample 60/1000
# Processing bootstrap sample 70/1000
# Processing bootstrap sample 80/1000
# Processing bootstrap sample 90/1000
# Processing bootstrap sample 100/1000
# Processing bootstrap sample 110/1000
# Processing bootstrap sample 120/1000
# Processing bootstrap sample 130/1000
# Processing bootstrap sample 140/1000
# Processing bootstrap sample 150/1000
# Processing bootstrap sample 160/1000
# Processing bootstrap sample 170/1000
# Processing bootstrap sample 180/1000
# Processing bootstrap sample 190/1000
# Processing bootstrap sample 200/1000
# Processing bootstrap sample 210/1000
# Processing bootstrap sample 220/1000
# Processing bootstrap sample 230/1000
# Processing bootstrap sample 240/1000
# Processing bootstrap sample 250/1000
# Processing bootstrap sample 260/1000
# Processing bootstrap sample 270/1000
# Processing bootstrap sample 280/1000
# Processing bootstrap sample 290/1000
# Processing bootstrap sample 300/1000
# Processing bootstrap sample 310/1000
# Processing bootstrap sample 320/1000
# Processing bootstrap sample 330/1000
# Processing bootstrap sample 340/1000
# Processing bootstrap sample 350/1000
# Processing bootstrap sample 360/1000
# Processing bootstrap sample 370/1000
# Processing bootstrap sample 380/1000
# Processing bootstrap sample 390/1000
# Processing bootstrap sample 400/1000
# Processing bootstrap sample 410/1000
# Processing bootstrap sample 420/1000
# Processing bootstrap sample 430/1000
# Processing bootstrap sample 440/1000
# Processing bootstrap sample 450/1000
# Processing bootstrap sample 460/1000
# Processing bootstrap sample 470/1000
# Processing bootstrap sample 480/1000
# Processing bootstrap sample 490/1000
# Processing bootstrap sample 500/1000
# Processing bootstrap sample 510/1000
# Processing bootstrap sample 520/1000
# Processing bootstrap sample 530/1000
# Processing bootstrap sample 540/1000
# Processing bootstrap sample 550/1000
# Processing bootstrap sample 560/1000
# Processing bootstrap sample 570/1000
# Processing bootstrap sample 580/1000
# Processing bootstrap sample 590/1000
# Processing bootstrap sample 600/1000
# Processing bootstrap sample 610/1000
# Processing bootstrap sample 620/1000
# Processing bootstrap sample 630/1000
# Processing bootstrap sample 640/1000
# Processing bootstrap sample 650/1000
# Processing bootstrap sample 660/1000
# Processing bootstrap sample 670/1000
# Processing bootstrap sample 680/1000
# Processing bootstrap sample 690/1000
# Processing bootstrap sample 700/1000
# Processing bootstrap sample 710/1000
# Processing bootstrap sample 720/1000
# Processing bootstrap sample 730/1000
# Processing bootstrap sample 740/1000
# Processing bootstrap sample 750/1000
# Processing bootstrap sample 760/1000
# Processing bootstrap sample 770/1000
# Processing bootstrap sample 780/1000
# Processing bootstrap sample 790/1000
# Processing bootstrap sample 800/1000
# Processing bootstrap sample 810/1000
# Processing bootstrap sample 820/1000
# Processing bootstrap sample 830/1000
# Processing bootstrap sample 840/1000
# Processing bootstrap sample 850/1000
# Processing bootstrap sample 860/1000
# Processing bootstrap sample 870/1000
# Processing bootstrap sample 880/1000
# Processing bootstrap sample 890/1000
# Processing bootstrap sample 900/1000
# Processing bootstrap sample 910/1000
# Processing bootstrap sample 920/1000
# Processing bootstrap sample 930/1000
# Processing bootstrap sample 940/1000
# Processing bootstrap sample 950/1000
# Processing bootstrap sample 960/1000
# Processing bootstrap sample 970/1000
# Processing bootstrap sample 980/1000
# Processing bootstrap sample 990/1000
# Processing bootstrap sample 1000/1000
#
# Bootstrap Statistics:
# Mean SSR: 0.41251243995389847
# Median SSR: 0.2678048159722791
# Standard Deviation of SSR: 0.4135289157574961
# Bootstrap analysis complete. Results saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h3n2(2003)/tracheal/bootstrap_results

# %%
# %% Parameter Distribution Plotting
# Log ALL parameters for consistent, nice-looking bootstrap charts
fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.flatten()

# Convert bootstrap_params to numpy array for easier indexing
bootstrap_params = np.array(bootstrap_params)

for i, name in enumerate(param_names):
    if i < len(axes):
        ax = axes[i]
        param_values = bootstrap_params[:, i]
        
        # Log ALL parameters - show only 5-95 percentile
        log_values = np.log10(np.maximum(param_values, 1e-12))
        p5, p95 = np.percentile(log_values, [5, 95])
        filtered_log_values = log_values[(log_values >= p5) & (log_values <= p95)]
        n_bins = min(30, max(10, len(filtered_log_values)//30))
        
        ax.hist(filtered_log_values, bins=n_bins, alpha=0.7, color='skyblue', edgecolor='black', linewidth=0.5)
        
        # Add reference lines
        ax.axvline(np.log10(best_params[i]), color='r', linestyle='--', linewidth=2, label='Best fit')
        ax.axvline(np.log10(param_stats[name]['mean']), color='g', linestyle='-', linewidth=2, label='Bootstrap mean')
        ax.axvline(np.log10(param_stats[name]['ci_low']), color='k', linestyle=':', linewidth=1.5, label='95% CI')
        ax.axvline(np.log10(param_stats[name]['ci_high']), color='k', linestyle=':', linewidth=1.5)
        
        ax.set_xlabel(f'log₁₀({name})', fontsize=12)
        ax.set_title(f'{name} (n={len(filtered_log_values)}, log scale, 5-95%)', fontsize=14)
        ax.set_ylabel('Frequency', fontsize=12)
        ax.tick_params(labelsize=10)
        
        if i == 0:  # Only add legend to first plot
            ax.legend(fontsize=10, loc='upper right')

# Remove empty subplots
for i in range(len(param_names), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
plt.close()

print(f"Parameter distribution plots saved to {output_prefix}_param_distributions.png")
print("All parameters plotted on log scale with 5-95 percentile range")
# Out:
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_5083/4098012820.py:40: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_5083/4098012820.py:40: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_5083/4098012820.py:41: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# /var/folders/g2/623_2z7951s0pxmq2_90ptrm0000gn/T/ipykernel_5083/4098012820.py:41: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(f"{output_prefix}_param_distributions.png", dpi=300, bbox_inches='tight')
# Parameter distribution plots saved to /Users/arjansuri/Desktop/Coding/TCU/BirdFlu/code/model3/h3n2(2003)/tracheal/bootstrap_results/h3n2(2003)_tracheal_param_distributions.png
# All parameters plotted on log scale with 5-95 percentile range
